# %% [markdown]
# # CSE527 Homework 3 - Part 3
# **Due date: 23:59 on Nov 26, 2023**
#
#
# ## Description
# ---
# Segmentation has been recently gaining more popularity in the field of computer vision. In this homework you will be implementing a standard UNet model to perform semantic segmentation. While transofrmer based architectures have demostrated impressive perfromance in semantic/instance segmentation, it's important to be familiar with other architectures commonly used for semantic segmentation.
#
# You will use the same dataset that you have used in part 2 of this homework, but the output of the model here is a class level segmentation mask.
#
# Input of the model will be an RGB image (3xHxW) and output will be a boolean mask (HxW).
#
# | Input Image      | Output Mask (class:horse) |
# | ----------- | ----------- |
# | ![Input Image](https://drive.google.com/uc?id=1BqmNxzV4t5MFQHjBFizlI1p9xlEatXiz)| ![Output Image](https://drive.google.com/uc?id=1NCW95D8JDBNsgzfFNa14ZiV_SiCpBPIv)|
#
#
# Read the paper: [U-Net: Convolutional Networks for Biomedical Image Segmentation
# ](https://arxiv.org/abs/1505.04597) to understand the structure of UNet models, what they are composed of, and how to build them.
#
# Also you should refer to this github repo to understand the implementations of a UNet: [milesial/Pytorch-UNet](https://github.com/milesial/Pytorch-UNet) . Specifically refer to unet/unet_model.py to gain understanding of the convolutional blocks, and skip connections.
#
# In this part you will be designing UNet architecture simmilar to it but with specific changes.

# %% [markdown]
# ## Code
# ---

# %%
HW3_ROOT_PATH = '/gdrive/My Drive/' + 'CSE527/Wen_Shihao_113085521_hw3/' #'YOUR HOMEWORK3 PATH HERE'
PATH_TO_PART3 = HW3_ROOT_PATH + 'part3/'
PATH_TO_COCO = HW3_ROOT_PATH + 'coco/'

# %% [markdown]
# You will be using this code [unet.zip](https://drive.google.com/file/d/1p2tMMUfF2vfcr3QHipJx0XyiBOMWoMNM/view?usp=sharing) to complete your work. This code contains all the tools for loading dataset, training the newtorks, loss methods and evaluation metrics.
#
#
# To pull this code into your drive, you have to first add the zip file as shortcut to current working directory (PATH_TO_PART3 above). To do this, open the above link and click on "Add shortcut to Drive" button (drive symbol with a plus) and navigate to working PATH_TO_PART3 directory and add shortcut.
#
#
# We will use the same dataset that you have used in the Part 2 : [coco.zip dataset](https://drive.google.com/file/d/1GVyxYHwVgiG9z_Sn46wslT_2n65DLZRw/view?usp=sharing). Put this in the root of your hw3 HW3_ROOT_PATH. If you have this extracted to some path you can re-use the it.

# %%
from google.colab import drive
drive.mount('/gdrive')
# CD into root of your homework2 part3 directory
# %cd -q $HW3_ROOT_PATH
# !mkdir -p '{PATH_TO_PART3}'
# %cd $PATH_TO_PART3
# Out:
# Mounted at /gdrive
# /gdrive/My Drive/CSE527/Wen_Shihao_113085521_hw3/part3

# %%
# !ls
# Out:
# CSE527_23F_HW3_P3.ipynb  unet.zip

# %%
# !pip install -U 'git+https://github.com/cocodataset/cocoapi.git#subdirectory=PythonAPI'

# %%
# !unzip -n ../coco.zip -d ..
# !unzip -n unet.zip
# Out:
# Archive:  ../coco.zip
# Archive:  unet.zip
#   inflating: unet/coco.py
#   inflating: unet/main.py
#   inflating: unet/transforms.py
#   inflating: unet/unet.py
#    creating: unet/util/
#  extracting: unet/util/__init__.py
#   inflating: unet/util/box_ops.py
#   inflating: unet/util/misc.py
#   inflating: unet/util/plot_utils.py

# %%
# %cd -q unet
# !ls
# Out:
# coco.py  images  main.py  __pycache__  transforms.py  unet.py  util

# %% [markdown]
# ### Load helper method

# %%
import matplotlib.pyplot as plt
import os
import numpy as np

def show_images(folder_path):
    image_paths = [os.path.join(folder_path, f) for f in os.listdir(folder_path) if os.path.isfile(os.path.join(folder_path, f))]
    image_paths = image_paths[:50]
    rows = 5
    cols = 10
    fig, axes = plt.subplots(rows, cols, figsize=(15, 8))
    for i, image_path in enumerate(image_paths):
        image = plt.imread(image_path)
        row = int(i / cols)
        col = i % cols
        axes[row, col].imshow(image)
        axes[row, col].set_title(os.path.basename(image_path))
        axes[row, col].axis('off')
    plt.tight_layout()
    plt.show()

# %% [markdown]
# ## Training
# ---
# You will use main.py for training, evaluating and visualizing.

# %%
# !python main.py --help
# Out:
# device cuda
# usage: main.py [-h] [--coco_path COCO_PATH] [--batch_size BATCH_SIZE] [--epochs EPOCHS] [--eval]
#                [--load_pretrained] [--skip {concat,sum}] [--checkpoint CHECKPOINT]
#
# Train a segmentation model on COCO data.
#
# options:
#   -h, --help            show this help message and exit
#   --coco_path COCO_PATH
#                         Path to COCO dataset directory.
#   --batch_size BATCH_SIZE
#                         Batch size for training.
#   --epochs EPOCHS       Epochs for training.
#   --eval                Whether to evaluate the model on the validation set.
#   --load_pretrained     Whether to evaluate the model on the validation set.
#   --skip {concat,sum}   Skip connection strategy: either concatenation (concat) or summation
#                         (sum).
#   --checkpoint CHECKPOINT
#                         Path to checkpoint file.

# %% [markdown]
# ##Implement UNet (15 points)
# ---
#
#
# `unet.py` contains two classes `UNet()` and `SumUNet()`, both are implementations of `torch.nn.Module()`.
#
# You need to complete the methods `UNet:__init__()` and `UNet:forward()` to implement a segmentation architecture that processes input of shape `N x 3 x H x W` (N is batch size) and will output a mask of shape `N x 1 x H x W`
#
# ###Requirements
# 1. Encoder part of the UNet will be made of pytorch Resnet's layers 1 to 4.
#
#     https://pytorch.org/vision/main/_modules/torchvision/models/resnet.html
#
#     Essentially, your UNet's encoder will be using `torchvision.models.resnet`'s `layer1, layer2, layer3, layer4` for downsampling.
#
# 2. When argument `load_pretrained_encoder_layers` of __init__() is set to true, the layers will be initialized with the pretrained weights. You can use the default pre-trained weights provided by pytorch.
#
# 3. As described in the paper or above repo, `concatenation` operations will be done for the skip connections. (in the upcoming section, you will instead use summation)
#
#
# Note:
# - You are recommended to size your model under 25M paramenters. As more parameters will hurt the trainig time and even effeciency.
# - For the decoder section (later half), you will not be able to use any pre-trained weights, so you will use randomly initialized blocks (that you will design on your own). Each block usually have layers of `[Conv, BatchNorm, ReLu]`
# - You need not use any ReLU on the last mask output layer.
#
# Hint:
# - chose a [resnet](https://pytorch.org/vision/main/_modules/torchvision/models/resnet.html) size
# - understand the `In` channels & `Out` channels of each layer of your chosen resnet()
# - build decoder layers so that they will work along the above 4 layers
# - conclude how to use the skip connections. ( you will using `concatenation`).
# - complete the forward() method
# - use print(x.shape) statements to understand the flow of tensors
#
# Log reference: [log](https://drive.google.com/file/d/1ZGd-ciOKkajri0GEOwc-uJDBjGJHJdNY/view?usp=drive_link)
#
# Aim for mIoU more than 0.35. You may not be penalized for low perfromance of your model.

# %%
# !python main.py --skip concat --coco_path "{PATH_TO_COCO}"
# Out:
# device cuda
# Namespace(coco_path='/gdrive/My Drive/CSE527/Wen_Shihao_113085521_hw3/coco/', batch_size=20, epochs=20, eval=False, load_pretrained=False, skip='concat', checkpoint='concat_checkpoint.pth')
# /usr/local/lib/python3.10/dist-packages/torchvision/models/_utils.py:208: UserWarning: The parameter 'pretrained' is deprecated since 0.13 and may be removed in the future, please use 'weights' instead.
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/torchvision/models/_utils.py:223: UserWarning: Arguments other than a weight enum or `None` for 'weights' are deprecated since 0.13 and may be removed in the future. The current behavior is equivalent to passing `weights=None`.
#   warnings.warn(msg)
# loading annotations into memory...
# Done (t=0.03s)
# creating index...
# index created!
# loading annotations into memory...
# Done (t=0.00s)
# creating index...
# index created!
# Epoch: [0]  [ 0/25]  eta: 0:00:51    time: 2.0519  data: 0.4766  max mem: 371
# Epoch: [0]  [10/25]  eta: 0:00:10    time: 0.6795  data: 0.4924  max mem: 385
# Epoch: [0]  [20/25]  eta: 0:00:03    time: 0.6268  data: 0.5780  max mem: 385
# Epoch: [0]  [24/25]  eta: 0:00:00    time: 0.6301  data: 0.5813  max mem: 385
# Epoch: [0] Total time: 0:00:16 (0.6743 s / it)
# train: dice: 0.802873, bce: 0.401249, loss: 0.533785
# LR 0.0005
# Epoch: [0]  [0/3]  eta: 0:00:00    time: 0.3052  data: 0.2595  max mem: 385
# Epoch: [0]  [2/3]  eta: 0:00:00    time: 0.2440  data: 0.2038  max mem: 386
# Epoch: [0] Total time: 0:00:00 (0.2443 s / it)
# val: dice: 0.772870, bce: 0.344940, loss: 0.486157, mIoU: 0.083788, mDice: 0.140760
# saving best model to concat_checkpoint.pth
# 0m 18s
# Epoch: [1]  [ 0/25]  eta: 0:00:14    time: 0.5722  data: 0.5240  max mem: 386
# Epoch: [1]  [10/25]  eta: 0:00:08    time: 0.5342  data: 0.4859  max mem: 386
# Epoch: [1]  [20/25]  eta: 0:00:03    time: 0.6365  data: 0.5876  max mem: 386
# Epoch: [1]  [24/25]  eta: 0:00:00    time: 0.6418  data: 0.5930  max mem: 386
# Epoch: [1] Total time: 0:00:15 (0.6226 s / it)
# train: dice: 0.706072, bce: 0.333432, loss: 0.456403
# LR 0.0005
# Epoch: [1]  [0/3]  eta: 0:00:00    time: 0.3114  data: 0.2659  max mem: 386
# Epoch: [1]  [2/3]  eta: 0:00:00    time: 0.2462  data: 0.2078  max mem: 386
# Epoch: [1] Total time: 0:00:00 (0.2466 s / it)
# val: dice: 0.743261, bce: 0.317530, loss: 0.458021, mIoU: 0.113164, mDice: 0.184667
# saving best model to concat_checkpoint.pth
# 0m 16s
# Epoch: [2]  [ 0/25]  eta: 0:00:14    time: 0.5824  data: 0.5345  max mem: 386
# Epoch: [2]  [10/25]  eta: 0:00:08    time: 0.5350  data: 0.4867  max mem: 386
# Epoch: [2]  [20/25]  eta: 0:00:03    time: 0.6343  data: 0.5848  max mem: 386
# Epoch: [2]  [24/25]  eta: 0:00:00    time: 0.6393  data: 0.5898  max mem: 386
# Epoch: [2] Total time: 0:00:15 (0.6197 s / it)
# train: dice: 0.665186, bce: 0.313709, loss: 0.429696
# LR 0.0005
# Epoch: [2]  [0/3]  eta: 0:00:00    time: 0.3172  data: 0.2713  max mem: 386
# Epoch: [2]  [2/3]  eta: 0:00:00    time: 0.2521  data: 0.2134  max mem: 386
# Epoch: [2] Total time: 0:00:00 (0.2525 s / it)
# val: dice: 0.652460, bce: 0.298852, loss: 0.415542, mIoU: 0.311382, mDice: 0.434272
# Epoch: [9]  [2/3]  eta: 0:00:00    time: 0.2447  data: 0.2059  max mem: 386
# Epoch: [9] Total time: 0:00:00 (0.2451 s / it)
# val: dice: 0.702041, bce: 0.315804, loss: 0.443262, mIoU: 0.161610, mDice: 0.249720
# 0m 16s
# Epoch: [10]  [ 0/25]  eta: 0:00:15    time: 0.6035  data: 0.5550  max mem: 386
# Epoch: [10]  [10/25]  eta: 0:00:08    time: 0.5898  data: 0.5411  max mem: 386
# Epoch: [10]  [20/25]  eta: 0:00:03    time: 0.6259  data: 0.5771  max mem: 386
# Epoch: [10]  [24/25]  eta: 0:00:00    time: 0.6221  data: 0.5734  max mem: 386
# Epoch: [10] Total time: 0:00:15 (0.6083 s / it)
# train: dice: 0.594135, bce: 0.275815, loss: 0.380861
# LR 0.0005
# Epoch: [10]  [0/3]  eta: 0:00:00    time: 0.3066  data: 0.2608  max mem: 386
# Epoch: [10]  [2/3]  eta: 0:00:00    time: 0.2518  data: 0.2133  max mem: 386
# Epoch: [10] Total time: 0:00:00 (0.2521 s / it)
# val: dice: 0.582315, bce: 0.272371, loss: 0.374653, mIoU: 0.369312, mDice: 0.493559
# saving best model to concat_checkpoint.pth
# 0m 16s
# Epoch: [11]  [ 0/25]  eta: 0:00:13    time: 0.5448  data: 0.4968  max mem: 386
# Epoch: [11]  [10/25]  eta: 0:00:08    time: 0.5519  data: 0.5030  max mem: 386
# Epoch: [11]  [20/25]  eta: 0:00:03    time: 0.6365  data: 0.5874  max mem: 386
# Epoch: [11]  [24/25]  eta: 0:00:00    time: 0.6305  data: 0.5817  max mem: 386
# Epoch: [11] Total time: 0:00:15 (0.6116 s / it)
# train: dice: 0.586976, bce: 0.276903, loss: 0.379227
# LR 0.0005
# Epoch: [11]  [0/3]  eta: 0:00:00    time: 0.3104  data: 0.2648  max mem: 386
# Epoch: [11]  [2/3]  eta: 0:00:00    time: 0.2463  data: 0.2079  max mem: 386
# Epoch: [11] Total time: 0:00:00 (0.2467 s / it)
# val: dice: 0.617815, bce: 0.276431, loss: 0.389088, mIoU: 0.301878, mDice: 0.419334
# 0m 16s
# Epoch: [12]  [ 0/25]  eta: 0:00:13    time: 0.5306  data: 0.4826  max mem: 386
# Epoch: [12]  [10/25]  eta: 0:00:08    time: 0.5363  data: 0.4880  max mem: 386
# Epoch: [12]  [20/25]  eta: 0:00:03    time: 0.6256  data: 0.5771  max mem: 386
# Epoch: [12]  [24/25]  eta: 0:00:00    time: 0.6276  data: 0.5790  max mem: 386
# Epoch: [12] Total time: 0:00:15 (0.6066 s / it)
# train: dice: 0.572635, bce: 0.267362, loss: 0.368102
# LR 0.0005
# Epoch: [12]  [0/3]  eta: 0:00:00    time: 0.3097  data: 0.2641  max mem: 386
# Epoch: [12]  [2/3]  eta: 0:00:00    time: 0.2416  data: 0.2033  max mem: 386
# Epoch: [12] Total time: 0:00:00 (0.2419 s / it)
# val: dice: 0.629046, bce: 0.270400, loss: 0.388753, mIoU: 0.281945, mDice: 0.399742
# 0m 16s
# Epoch: [19] Total time: 0:00:00 (0.2446 s / it)
# val: dice: 0.594238, bce: 0.295052, loss: 0.393784, mIoU: 0.329189, mDice: 0.452780
# 0m 16s
# Best val loss: 0.371726

# %% [markdown]
# ### Evaluation
# To just run the evaluation or to produce the predicted masks in the `images/` folder, you need to run the main.py with --eval.
# Note that this will load the latest stored checkpoint corresponding to the --skip flag that you have provided.

# %%
# !python main.py --skip concat --coco_path "{PATH_TO_COCO}" --eval
# Out:
# device cuda
# Namespace(coco_path='/gdrive/My Drive/CSE527/Wen_Shihao_113085521_hw3/coco/', batch_size=20, epochs=20, eval=True, load_pretrained=False, skip='concat', checkpoint='concat_checkpoint.pth')
# /usr/local/lib/python3.10/dist-packages/torchvision/models/_utils.py:208: UserWarning: The parameter 'pretrained' is deprecated since 0.13 and may be removed in the future, please use 'weights' instead.
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/torchvision/models/_utils.py:223: UserWarning: Arguments other than a weight enum or `None` for 'weights' are deprecated since 0.13 and may be removed in the future. The current behavior is equivalent to passing `weights=None`.
#   warnings.warn(msg)
# loading annotations into memory...
# Done (t=0.00s)
# creating index...
# index created!
# Performance on validation dataset: mIoU:0.35292181372642517 , mDice:0.47541388869285583

# %% [markdown]
# ### With --load_pretrained
#
# When properly configured using pre-trained weights should result in higher mIoUs. You can expect mIoU around .65

# %%
# !python main.py --skip concat --coco_path "{PATH_TO_COCO}"  --load_pretrained
# Out:
# device cuda
# Namespace(coco_path='/gdrive/My Drive/CSE527/Wen_Shihao_113085521_hw3/coco/', batch_size=20, epochs=20, eval=False, load_pretrained=True, skip='concat', checkpoint='concat_checkpoint.pth')
# /usr/local/lib/python3.10/dist-packages/torchvision/models/_utils.py:208: UserWarning: The parameter 'pretrained' is deprecated since 0.13 and may be removed in the future, please use 'weights' instead.
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/torchvision/models/_utils.py:223: UserWarning: Arguments other than a weight enum or `None` for 'weights' are deprecated since 0.13 and may be removed in the future. The current behavior is equivalent to passing `weights=ResNet18_Weights.IMAGENET1K_V1`. You can also use `weights=ResNet18_Weights.DEFAULT` to get the most up-to-date weights.
#   warnings.warn(msg)
# Downloading: "https://download.pytorch.org/models/resnet18-f37072fd.pth" to /root/.cache/torch/hub/checkpoints/resnet18-f37072fd.pth
# 100% 44.7M/44.7M [00:00<00:00, 125MB/s]
# loading annotations into memory...
# Done (t=0.05s)
# creating index...
# index created!
# loading annotations into memory...
# Done (t=0.01s)
# creating index...
# index created!
# Epoch: [0]  [ 0/25]  eta: 0:01:12    time: 2.9186  data: 0.7203  max mem: 371
# Epoch: [0]  [10/25]  eta: 0:00:12    time: 0.8352  data: 0.5912  max mem: 385
# Epoch: [0]  [20/25]  eta: 0:00:03    time: 0.6204  data: 0.5717  max mem: 385
# Epoch: [0]  [24/25]  eta: 0:00:00    time: 0.6505  data: 0.6018  max mem: 385
# Epoch: [0] Total time: 0:00:18 (0.7600 s / it)
# train: dice: 0.726475, bce: 0.328365, loss: 0.459741
# LR 0.0005
# Epoch: [0]  [0/3]  eta: 0:00:01    time: 0.4057  data: 0.3591  max mem: 385
# Epoch: [0]  [2/3]  eta: 0:00:00    time: 0.3341  data: 0.2883  max mem: 386
# Epoch: [0] Total time: 0:00:01 (0.3346 s / it)
# val: dice: 0.721694, bce: 0.272580, loss: 0.420788, mIoU: 0.138385, mDice: 0.218798
# saving best model to concat_checkpoint.pth
# 0m 20s
# Epoch: [1]  [ 0/25]  eta: 0:00:22    time: 0.8805  data: 0.8306  max mem: 386
# Epoch: [1]  [10/25]  eta: 0:00:08    time: 0.5841  data: 0.5354  max mem: 386
# Epoch: [1]  [20/25]  eta: 0:00:02    time: 0.5565  data: 0.5080  max mem: 386
# Epoch: [1]  [24/25]  eta: 0:00:00    time: 0.6088  data: 0.5602  max mem: 386
# Epoch: [1] Total time: 0:00:15 (0.6177 s / it)
# train: dice: 0.540145, bce: 0.194744, loss: 0.308726
# LR 0.0005
# Epoch: [1]  [0/3]  eta: 0:00:01    time: 0.4189  data: 0.3712  max mem: 386
# Epoch: [1]  [2/3]  eta: 0:00:00    time: 0.3353  data: 0.2952  max mem: 386
# Epoch: [1] Total time: 0:00:01 (0.3358 s / it)
# val: dice: 0.503195, bce: 0.166269, loss: 0.277454, mIoU: 0.483064, mDice: 0.601114
# val: dice: 0.339115, bce: 0.138678, loss: 0.204822, mIoU: 0.620435, mDice: 0.727954
# 0m 16s
# Epoch: [19]  [ 0/25]  eta: 0:00:20    time: 0.8108  data: 0.7614  max mem: 386
# Epoch: [19]  [10/25]  eta: 0:00:09    time: 0.6251  data: 0.5764  max mem: 386
# Epoch: [19]  [20/25]  eta: 0:00:02    time: 0.5639  data: 0.5155  max mem: 386
# Epoch: [19]  [24/25]  eta: 0:00:00    time: 0.5578  data: 0.5093  max mem: 386
# Epoch: [19] Total time: 0:00:14 (0.5925 s / it)
# train: dice: 0.255456, bce: 0.096685, loss: 0.149080
# LR 5e-05
# Epoch: [19]  [0/3]  eta: 0:00:01    time: 0.4352  data: 0.3890  max mem: 386
# Epoch: [19]  [2/3]  eta: 0:00:00    time: 0.3514  data: 0.3124  max mem: 386
# Epoch: [19] Total time: 0:00:01 (0.3518 s / it)
# val: dice: 0.375327, bce: 0.157238, loss: 0.229208, mIoU: 0.567306, mDice: 0.680395
# 0m 16s
# Best val loss: 0.201494

# %%
# !python main.py --skip concat --coco_path "{PATH_TO_COCO}" --eval
# Out:
# device cuda
# Namespace(coco_path='/gdrive/My Drive/CSE527/Wen_Shihao_113085521_hw3/coco/', batch_size=20, epochs=20, eval=True, load_pretrained=False, skip='concat', checkpoint='concat_checkpoint.pth')
# /usr/local/lib/python3.10/dist-packages/torchvision/models/_utils.py:208: UserWarning: The parameter 'pretrained' is deprecated since 0.13 and may be removed in the future, please use 'weights' instead.
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/torchvision/models/_utils.py:223: UserWarning: Arguments other than a weight enum or `None` for 'weights' are deprecated since 0.13 and may be removed in the future. The current behavior is equivalent to passing `weights=None`.
#   warnings.warn(msg)
# loading annotations into memory...
# Done (t=0.00s)
# creating index...
# index created!
# Performance on validation dataset: mIoU:0.6201887130737305 , mDice:0.7254003286361694

# %% [markdown]
# Let us see the masks generated by the best run:
# It is okay if the masks are not perfectly aligned. We are only training over 500 images for a short duration!

# %%
folder_path = 'images'
show_images(folder_path)
# Out:
# Output hidden; open in https://colab.research.google.com to view.

# %% [markdown]
# ##Implement SumUNet (10 points)
# ---
# This is very much similar to above UNet, but for the skip connections we will be using summation operation instead of concatenation. This is kind of an open ended question, in the sense that there are multuple ways you can design connections.
#
# Feel free to use any layers | blocks | up/down sampling.
#
#
# Hint:
# - Again you need to focus on the feature shapes
# - you can use sampling techniques to change the height/width
# - you can use conv layers to change number of channels
#
# Note: You can chose to remove --load_pretrained from the below cell if you think that will have a better perfromance

# %%
# !python main.py --skip sum --coco_path "{PATH_TO_COCO}"
# Out:
# device cuda
# Namespace(coco_path='/gdrive/My Drive/CSE527/Wen_Shihao_113085521_hw3/coco/', batch_size=20, epochs=20, eval=False, load_pretrained=False, skip='sum', checkpoint='sum_checkpoint.pth')
# /usr/local/lib/python3.10/dist-packages/torchvision/models/_utils.py:208: UserWarning: The parameter 'pretrained' is deprecated since 0.13 and may be removed in the future, please use 'weights' instead.
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/torchvision/models/_utils.py:223: UserWarning: Arguments other than a weight enum or `None` for 'weights' are deprecated since 0.13 and may be removed in the future. The current behavior is equivalent to passing `weights=None`.
#   warnings.warn(msg)
# loading annotations into memory...
# Done (t=0.05s)
# creating index...
# index created!
# loading annotations into memory...
# Done (t=0.01s)
# creating index...
# index created!
# Epoch: [0]  [ 0/25]  eta: 0:01:10    time: 2.8219  data: 0.6833  max mem: 372
# Epoch: [0]  [10/25]  eta: 0:00:11    time: 0.7765  data: 0.5362  max mem: 390
# Epoch: [0]  [20/25]  eta: 0:00:03    time: 0.5565  data: 0.5060  max mem: 391
# Epoch: [0]  [24/25]  eta: 0:00:00    time: 0.5935  data: 0.5429  max mem: 391
# Epoch: [0] Total time: 0:00:17 (0.6887 s / it)
# train: dice: 0.742679, bce: 0.371221, loss: 0.493802
# LR 0.0005
# Epoch: [0]  [0/3]  eta: 0:00:01    time: 0.4117  data: 0.3632  max mem: 391
# Epoch: [0]  [2/3]  eta: 0:00:00    time: 0.3397  data: 0.2883  max mem: 391
# Epoch: [0] Total time: 0:00:01 (0.3402 s / it)
# val: dice: 0.743751, bce: 0.326830, loss: 0.464414, mIoU: 0.129237, mDice: 0.205092
# saving best model to sum_checkpoint.pth
# 0m 18s
# Epoch: [1]  [ 0/25]  eta: 0:00:19    time: 0.7806  data: 0.7289  max mem: 391
# Epoch: [1]  [10/25]  eta: 0:00:08    time: 0.5730  data: 0.5225  max mem: 391
# Epoch: [1]  [20/25]  eta: 0:00:02    time: 0.5577  data: 0.5072  max mem: 391
# Epoch: [1]  [24/25]  eta: 0:00:00    time: 0.6065  data: 0.5558  max mem: 391
# Epoch: [1] Total time: 0:00:15 (0.6133 s / it)
# train: dice: 0.683342, bce: 0.323832, loss: 0.442470
# LR 0.0005
# Epoch: [1]  [0/3]  eta: 0:00:01    time: 0.4383  data: 0.3896  max mem: 391
# Epoch: [1]  [2/3]  eta: 0:00:00    time: 0.3459  data: 0.3049  max mem: 391
# Epoch: [1] Total time: 0:00:01 (0.3464 s / it)
# val: dice: 0.708238, bce: 0.307766, loss: 0.439921, mIoU: 0.179223, mDice: 0.273649
# saving best model to sum_checkpoint.pth
# 0m 17s
# Epoch: [2]  [ 0/25]  eta: 0:00:22    time: 0.9175  data: 0.8663  max mem: 391
# Epoch: [2]  [10/25]  eta: 0:00:08    time: 0.5791  data: 0.5286  max mem: 391
# Epoch: [2]  [20/25]  eta: 0:00:02    time: 0.5633  data: 0.5128  max mem: 391
# Epoch: [2]  [24/25]  eta: 0:00:00    time: 0.6188  data: 0.5681  max mem: 391
# Epoch: [2] Total time: 0:00:15 (0.6194 s / it)
# train: dice: 0.655212, bce: 0.308471, loss: 0.422896
# LR 0.0005
# Epoch: [2]  [0/3]  eta: 0:00:01    time: 0.4176  data: 0.3693  max mem: 391
# Epoch: [2]  [2/3]  eta: 0:00:00    time: 0.3314  data: 0.2906  max mem: 391
# Epoch: [2] Total time: 0:00:00 (0.3326 s / it)
# val: dice: 0.635335, bce: 0.298724, loss: 0.409806, mIoU: 0.344266, mDice: 0.472465
# saving best model to sum_checkpoint.pth
# 0m 17s
# Epoch: [3]  [ 0/25]  eta: 0:00:16    time: 0.6631  data: 0.6130  max mem: 391
# Epoch: [3]  [10/25]  eta: 0:00:08    time: 0.5472  data: 0.4968  max mem: 391
# Epoch: [3]  [20/25]  eta: 0:00:02    time: 0.5703  data: 0.5198  max mem: 391
# Epoch: [3]  [24/25]  eta: 0:00:00    time: 0.6197  data: 0.5690  max mem: 391
# Epoch: [3] Total time: 0:00:15 (0.6104 s / it)
# train: dice: 0.639601, bce: 0.307543, loss: 0.417122
# LR 0.0005
# Epoch: [3]  [0/3]  eta: 0:00:01    time: 0.4139  data: 0.3654  max mem: 391
# Epoch: [3]  [2/3]  eta: 0:00:00    time: 0.3315  data: 0.2903  max mem: 391
# Epoch: [3] Total time: 0:00:00 (0.3319 s / it)
# val: dice: 0.743041, bce: 0.319094, loss: 0.458996, mIoU: 0.097596, mDice: 0.159763
# 0m 16s
# Epoch: [4]  [ 0/25]  eta: 0:00:16    time: 0.6408  data: 0.5903  max mem: 391
# Epoch: [4]  [10/25]  eta: 0:00:08    time: 0.5434  data: 0.4931  max mem: 391
# Epoch: [4]  [20/25]  eta: 0:00:02    time: 0.5456  data: 0.4952  max mem: 391
# Epoch: [4]  [24/25]  eta: 0:00:00    time: 0.5964  data: 0.5458  max mem: 391
# Epoch: [4] Total time: 0:00:14 (0.5887 s / it)
# train: dice: 0.630199, bce: 0.301864, loss: 0.410215
# LR 0.0005
# Epoch: [4]  [0/3]  eta: 0:00:01    time: 0.4144  data: 0.3651  max mem: 391
# Epoch: [4]  [2/3]  eta: 0:00:00    time: 0.3417  data: 0.3005  max mem: 391
# Epoch: [4] Total time: 0:00:01 (0.3422 s / it)
# val: dice: 0.637343, bce: 0.301285, loss: 0.412184, mIoU: 0.284561, mDice: 0.399809
# 0m 16s
# Epoch: [5]  [ 0/25]  eta: 0:00:19    time: 0.7767  data: 0.7264  max mem: 391
# Epoch: [5]  [10/25]  eta: 0:00:08    time: 0.5590  data: 0.5086  max mem: 391
# Epoch: [5]  [20/25]  eta: 0:00:02    time: 0.5523  data: 0.5018  max mem: 391
# Epoch: [5]  [24/25]  eta: 0:00:00    time: 0.5960  data: 0.5453  max mem: 391
# Epoch: [5] Total time: 0:00:14 (0.5962 s / it)
# train: dice: 0.619845, bce: 0.283068, loss: 0.394204
# LR 0.0005
# Epoch: [5]  [0/3]  eta: 0:00:01    time: 0.4253  data: 0.3767  max mem: 391
# Epoch: [5]  [2/3]  eta: 0:00:00    time: 0.3356  data: 0.2947  max mem: 391
# Epoch: [5] Total time: 0:00:01 (0.3361 s / it)
# val: dice: 0.652681, bce: 0.278455, loss: 0.401950, mIoU: 0.241412, mDice: 0.347755
# saving best model to sum_checkpoint.pth
# 0m 16s
# Epoch: [6]  [ 0/25]  eta: 0:00:20    time: 0.8189  data: 0.7679  max mem: 391
# Epoch: [6]  [10/25]  eta: 0:00:08    time: 0.5819  data: 0.5313  max mem: 391
# Epoch: [6]  [20/25]  eta: 0:00:02    time: 0.5858  data: 0.5353  max mem: 391
# Epoch: [6]  [24/25]  eta: 0:00:00    time: 0.6187  data: 0.5680  max mem: 391
# Epoch: [6] Total time: 0:00:15 (0.6208 s / it)
# train: dice: 0.607311, bce: 0.289855, loss: 0.394615
# LR 0.0005
# Epoch: [6]  [0/3]  eta: 0:00:01    time: 0.4158  data: 0.3672  max mem: 391
# Epoch: [6]  [2/3]  eta: 0:00:00    time: 0.3295  data: 0.2873  max mem: 391
# Epoch: [6] Total time: 0:00:00 (0.3300 s / it)
# val: dice: 0.672849, bce: 0.288956, loss: 0.415640, mIoU: 0.203282, mDice: 0.303054
# 0m 17s
# Epoch: [7]  [ 0/25]  eta: 0:00:17    time: 0.6931  data: 0.6433  max mem: 391
# Epoch: [7]  [10/25]  eta: 0:00:08    time: 0.5552  data: 0.5049  max mem: 391
# Epoch: [7]  [20/25]  eta: 0:00:02    time: 0.5590  data: 0.5085  max mem: 391
# Epoch: [7]  [24/25]  eta: 0:00:00    time: 0.6014  data: 0.5507  max mem: 391
# Epoch: [7] Total time: 0:00:14 (0.5984 s / it)
# train: dice: 0.606586, bce: 0.287418, loss: 0.392743
# LR 0.0005
# Epoch: [7]  [0/3]  eta: 0:00:01    time: 0.4154  data: 0.3669  max mem: 391
# Epoch: [7]  [2/3]  eta: 0:00:00    time: 0.3328  data: 0.2918  max mem: 391
# Epoch: [7] Total time: 0:00:00 (0.3333 s / it)
# val: dice: 0.641468, bce: 0.271274, loss: 0.393438, mIoU: 0.269379, mDice: 0.382552
# saving best model to sum_checkpoint.pth
# 0m 16s
# Epoch: [8]  [ 0/25]  eta: 0:00:17    time: 0.7052  data: 0.6550  max mem: 391
# Epoch: [8]  [10/25]  eta: 0:00:08    time: 0.5511  data: 0.5006  max mem: 391
# Epoch: [8]  [20/25]  eta: 0:00:02    time: 0.5702  data: 0.5196  max mem: 391
# Epoch: [8]  [24/25]  eta: 0:00:00    time: 0.6169  data: 0.5660  max mem: 391
# Epoch: [8] Total time: 0:00:15 (0.6094 s / it)
# train: dice: 0.596562, bce: 0.282668, loss: 0.386253
# LR 0.0005
# Epoch: [8]  [0/3]  eta: 0:00:01    time: 0.4159  data: 0.3659  max mem: 391
# Epoch: [8]  [2/3]  eta: 0:00:00    time: 0.3298  data: 0.2883  max mem: 391
# Epoch: [8] Total time: 0:00:00 (0.3302 s / it)
# val: dice: 0.591074, bce: 0.269320, loss: 0.375498, mIoU: 0.342789, mDice: 0.467119
# saving best model to sum_checkpoint.pth
# 0m 16s
# Epoch: [9]  [ 0/25]  eta: 0:00:14    time: 0.5744  data: 0.5244  max mem: 391
# Epoch: [9]  [10/25]  eta: 0:00:08    time: 0.5385  data: 0.4883  max mem: 391
# Epoch: [9]  [20/25]  eta: 0:00:02    time: 0.5772  data: 0.5265  max mem: 391
# Epoch: [9]  [24/25]  eta: 0:00:00    time: 0.6264  data: 0.5755  max mem: 391
# Epoch: [9] Total time: 0:00:15 (0.6109 s / it)
# train: dice: 0.594501, bce: 0.281204, loss: 0.384592
# LR 0.0005
# Epoch: [9]  [0/3]  eta: 0:00:01    time: 0.3973  data: 0.3476  max mem: 391
# Epoch: [9]  [2/3]  eta: 0:00:00    time: 0.3187  data: 0.2769  max mem: 391
# Epoch: [9] Total time: 0:00:00 (0.3192 s / it)
# val: dice: 0.602734, bce: 0.273404, loss: 0.382083, mIoU: 0.323790, mDice: 0.446768
# 0m 16s
# Epoch: [10]  [ 0/25]  eta: 0:00:14    time: 0.5702  data: 0.5204  max mem: 391
# Epoch: [10]  [10/25]  eta: 0:00:07    time: 0.5154  data: 0.4649  max mem: 391
# Epoch: [10]  [20/25]  eta: 0:00:02    time: 0.5371  data: 0.4862  max mem: 391
# Epoch: [10]  [24/25]  eta: 0:00:00    time: 0.5896  data: 0.5385  max mem: 391
# Epoch: [10] Total time: 0:00:14 (0.5767 s / it)
# train: dice: 0.585419, bce: 0.276051, loss: 0.378143
# LR 0.0005
# Epoch: [10]  [0/3]  eta: 0:00:01    time: 0.4111  data: 0.3616  max mem: 391
# Epoch: [10]  [2/3]  eta: 0:00:00    time: 0.3241  data: 0.2828  max mem: 391
# Epoch: [10] Total time: 0:00:00 (0.3246 s / it)
# val: dice: 0.668705, bce: 0.290119, loss: 0.415052, mIoU: 0.218031, mDice: 0.325034
# 0m 15s
# Epoch: [11]  [ 0/25]  eta: 0:00:18    time: 0.7358  data: 0.6835  max mem: 391
# Epoch: [11]  [10/25]  eta: 0:00:08    time: 0.5414  data: 0.4909  max mem: 391
# Epoch: [11]  [20/25]  eta: 0:00:02    time: 0.5445  data: 0.4940  max mem: 391
# Epoch: [11]  [24/25]  eta: 0:00:00    time: 0.5892  data: 0.5385  max mem: 391
# Epoch: [11] Total time: 0:00:14 (0.5859 s / it)
# train: dice: 0.579701, bce: 0.276748, loss: 0.376723
# LR 0.0005
# Epoch: [11]  [0/3]  eta: 0:00:01    time: 0.4041  data: 0.3556  max mem: 391
# Epoch: [11]  [2/3]  eta: 0:00:00    time: 0.3343  data: 0.2933  max mem: 391
# Epoch: [11] Total time: 0:00:01 (0.3348 s / it)
# val: dice: 0.654470, bce: 0.286802, loss: 0.408132, mIoU: 0.239622, mDice: 0.353955
# 0m 16s
# Epoch: [12]  [ 0/25]  eta: 0:00:18    time: 0.7589  data: 0.7077  max mem: 391
# Epoch: [12]  [10/25]  eta: 0:00:08    time: 0.5623  data: 0.5117  max mem: 391
# Epoch: [12]  [20/25]  eta: 0:00:02    time: 0.5464  data: 0.4959  max mem: 391
# Epoch: [12]  [24/25]  eta: 0:00:00    time: 0.5925  data: 0.5419  max mem: 391
# Epoch: [12] Total time: 0:00:14 (0.5958 s / it)
# train: dice: 0.575515, bce: 0.263801, loss: 0.366667
# LR 0.0005
# Epoch: [12]  [0/3]  eta: 0:00:01    time: 0.4290  data: 0.3805  max mem: 391
# Epoch: [12]  [2/3]  eta: 0:00:00    time: 0.3365  data: 0.2952  max mem: 391
# Epoch: [12] Total time: 0:00:01 (0.3371 s / it)
# val: dice: 0.576325, bce: 0.285009, loss: 0.381144, mIoU: 0.362386, mDice: 0.490285
# 0m 16s
# Epoch: [13]  [ 0/25]  eta: 0:00:19    time: 0.7874  data: 0.7358  max mem: 391
# Epoch: [13]  [10/25]  eta: 0:00:08    time: 0.5804  data: 0.5297  max mem: 391
# Epoch: [13]  [20/25]  eta: 0:00:02    time: 0.5590  data: 0.5085  max mem: 391
# Epoch: [13]  [24/25]  eta: 0:00:00    time: 0.6010  data: 0.5504  max mem: 391
# Epoch: [13] Total time: 0:00:15 (0.6060 s / it)
# train: dice: 0.564163, bce: 0.263596, loss: 0.362783
# LR 0.0005
# Epoch: [13]  [0/3]  eta: 0:00:01    time: 0.4080  data: 0.3593  max mem: 391
# Epoch: [13]  [2/3]  eta: 0:00:00    time: 0.3350  data: 0.2940  max mem: 391
# Epoch: [13] Total time: 0:00:01 (0.3355 s / it)
# val: dice: 0.561660, bce: 0.285236, loss: 0.376456, mIoU: 0.397776, mDice: 0.523012
# 0m 16s
# Epoch: [14]  [ 0/25]  eta: 0:00:20    time: 0.8079  data: 0.7565  max mem: 391
# Epoch: [14]  [10/25]  eta: 0:00:08    time: 0.5633  data: 0.5126  max mem: 391
# Epoch: [14]  [20/25]  eta: 0:00:02    time: 0.5489  data: 0.4982  max mem: 391
# Epoch: [14]  [24/25]  eta: 0:00:00    time: 0.5986  data: 0.5477  max mem: 391
# Epoch: [14] Total time: 0:00:15 (0.6006 s / it)
# train: dice: 0.562164, bce: 0.268962, loss: 0.365719
# LR 0.0005
# Epoch: [14]  [0/3]  eta: 0:00:01    time: 0.4146  data: 0.3660  max mem: 391
# Epoch: [14]  [2/3]  eta: 0:00:00    time: 0.3318  data: 0.2907  max mem: 391
# Epoch: [14] Total time: 0:00:00 (0.3323 s / it)
# val: dice: 0.629611, bce: 0.293451, loss: 0.404383, mIoU: 0.279499, mDice: 0.390400
# 0m 16s
# Epoch: [15]  [ 0/25]  eta: 0:00:18    time: 0.7446  data: 0.6932  max mem: 391
# Epoch: [15]  [10/25]  eta: 0:00:08    time: 0.5571  data: 0.5065  max mem: 391
# Epoch: [15]  [20/25]  eta: 0:00:02    time: 0.5479  data: 0.4974  max mem: 391
# Epoch: [15]  [24/25]  eta: 0:00:00    time: 0.5912  data: 0.5406  max mem: 391
# Epoch: [15] Total time: 0:00:14 (0.5935 s / it)
# train: dice: 0.548134, bce: 0.254354, loss: 0.351301
# LR 0.0005
# Epoch: [15]  [0/3]  eta: 0:00:01    time: 0.3967  data: 0.3482  max mem: 391
# Epoch: [15]  [2/3]  eta: 0:00:00    time: 0.3300  data: 0.2877  max mem: 391
# Epoch: [15] Total time: 0:00:00 (0.3305 s / it)
# val: dice: 0.619667, bce: 0.282526, loss: 0.393782, mIoU: 0.282812, mDice: 0.398909
# 0m 16s
# Epoch: [16]  [ 0/25]  eta: 0:00:21    time: 0.8420  data: 0.7911  max mem: 391
# Epoch: [16]  [10/25]  eta: 0:00:08    time: 0.5652  data: 0.5146  max mem: 391
# Epoch: [16]  [20/25]  eta: 0:00:02    time: 0.5323  data: 0.4820  max mem: 391
# Epoch: [16]  [24/25]  eta: 0:00:00    time: 0.5841  data: 0.5337  max mem: 391
# Epoch: [16] Total time: 0:00:14 (0.5905 s / it)
# train: dice: 0.548544, bce: 0.259172, loss: 0.354665
# LR 0.0005
# Epoch: [16]  [0/3]  eta: 0:00:01    time: 0.4116  data: 0.3634  max mem: 391
# Epoch: [16]  [2/3]  eta: 0:00:00    time: 0.3387  data: 0.2971  max mem: 391
# Epoch: [16] Total time: 0:00:01 (0.3392 s / it)
# val: dice: 0.542683, bce: 0.302429, loss: 0.381713, mIoU: 0.417651, mDice: 0.544928
# 0m 16s
# Epoch: [17]  [ 0/25]  eta: 0:00:20    time: 0.8124  data: 0.7615  max mem: 391
# Epoch: [17]  [10/25]  eta: 0:00:08    time: 0.5926  data: 0.5420  max mem: 391
# Epoch: [17]  [20/25]  eta: 0:00:02    time: 0.5442  data: 0.4937  max mem: 391
# Epoch: [17]  [24/25]  eta: 0:00:00    time: 0.5716  data: 0.5209  max mem: 391
# Epoch: [17] Total time: 0:00:14 (0.5860 s / it)
# train: dice: 0.547965, bce: 0.253954, loss: 0.350978
# LR 0.0005
# Epoch: [17]  [0/3]  eta: 0:00:01    time: 0.4299  data: 0.3797  max mem: 391
# Epoch: [17]  [2/3]  eta: 0:00:00    time: 0.3329  data: 0.2914  max mem: 391
# Epoch: [17] Total time: 0:00:01 (0.3334 s / it)
# val: dice: 0.685241, bce: 0.339644, loss: 0.453691, mIoU: 0.192186, mDice: 0.291790
# 0m 16s
# Epoch: [18]  [ 0/25]  eta: 0:00:20    time: 0.8107  data: 0.7593  max mem: 391
# Epoch: [18]  [10/25]  eta: 0:00:09    time: 0.6023  data: 0.5517  max mem: 391
# Epoch: [18]  [20/25]  eta: 0:00:02    time: 0.5551  data: 0.5046  max mem: 391
# Epoch: [18]  [24/25]  eta: 0:00:00    time: 0.5602  data: 0.5098  max mem: 391
# Epoch: [18] Total time: 0:00:14 (0.5884 s / it)
# train: dice: 0.537105, bce: 0.250049, loss: 0.344778
# LR 0.0005
# Epoch: [18]  [0/3]  eta: 0:00:01    time: 0.4202  data: 0.3719  max mem: 391
# Epoch: [18]  [2/3]  eta: 0:00:00    time: 0.3395  data: 0.2987  max mem: 391
# Epoch: [18] Total time: 0:00:01 (0.3400 s / it)
# val: dice: 0.594427, bce: 0.289298, loss: 0.389990, mIoU: 0.313855, mDice: 0.438672
# 0m 16s
# Epoch: [19]  [ 0/25]  eta: 0:00:19    time: 0.7793  data: 0.7281  max mem: 391
# Epoch: [19]  [10/25]  eta: 0:00:09    time: 0.6053  data: 0.5546  max mem: 391
# Epoch: [19]  [20/25]  eta: 0:00:02    time: 0.5607  data: 0.5103  max mem: 391
# Epoch: [19]  [24/25]  eta: 0:00:00    time: 0.5674  data: 0.5169  max mem: 391
# Epoch: [19] Total time: 0:00:14 (0.5922 s / it)
# train: dice: 0.532839, bce: 0.255033, loss: 0.346709
# LR 5e-05
# Epoch: [19]  [0/3]  eta: 0:00:01    time: 0.4017  data: 0.3529  max mem: 391
# Epoch: [19]  [2/3]  eta: 0:00:00    time: 0.3203  data: 0.2793  max mem: 391
# Epoch: [19] Total time: 0:00:00 (0.3208 s / it)
# val: dice: 0.547581, bce: 0.373586, loss: 0.431005, mIoU: 0.392202, mDice: 0.515937
# 0m 16s
# Best val loss: 0.375498

# %%
# !python main.py --skip sum --coco_path "{PATH_TO_COCO}"  --eval
# Out:
# device cuda
# Namespace(coco_path='/gdrive/My Drive/CSE527/Wen_Shihao_113085521_hw3/coco/', batch_size=20, epochs=20, eval=True, load_pretrained=False, skip='sum', checkpoint='sum_checkpoint.pth')
# /usr/local/lib/python3.10/dist-packages/torchvision/models/_utils.py:208: UserWarning: The parameter 'pretrained' is deprecated since 0.13 and may be removed in the future, please use 'weights' instead.
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/torchvision/models/_utils.py:223: UserWarning: Arguments other than a weight enum or `None` for 'weights' are deprecated since 0.13 and may be removed in the future. The current behavior is equivalent to passing `weights=None`.
#   warnings.warn(msg)
# loading annotations into memory...
# Done (t=0.01s)
# creating index...
# index created!
# Performance on validation dataset: mIoU:0.34278902411460876 , mDice:0.4671187400817871

# %% [markdown]
# ## Submission guidelines
# ---
#
#
#
# The submission structure should look like:
#
# IMPORTANT: Remove the images/ folder, and any CHECKPOINT files.
#
#
# ```
# {last name}_{first name}_{sbu id}_hw2/
# ├── part1/
# │   └── ...
# ├── part2/
# │   └── ...
# ├── part3/
# │   ├── CSE527_23F_HW3_P3.ipynb
# │   └── unet/
# │       ├── utils/
# │       │   ├── ...
# │       │   └── ...
# │       ├── coco.py
# │       ├── main.py
# │       ├── transforms.py
# │       └── unet.py
# ```
#
#
# Follow instructions in part1's submission guidelines to generate your complete submission
