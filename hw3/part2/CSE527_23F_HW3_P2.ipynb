# %% [markdown]
# # CSE527 Homework 3 - Part 2
# **Due date: 23:59 on Nov 26, 2023**
#
#
# ## Description
# ---
# Detection is a fundamental task in CV. This homework is on based on DETR (https://arxiv.org/abs/2005.12872), one of the most famous yet simple detection model.
#
# In this part, you will get familiar with DETR code base and will be modfiying the code (https://github.com/facebookresearch/detr/tree/main) to perfrom a new task: **_Detection using Centroids_**.
#
# Traditionally bounding boxes are used to highlight detections, however in this homework you will perfrom detection of an object by selecting a _meaningful_ center point on it. We will call that point the centroid. For applications involving peculiar objects (like Giraffes,), where the center of the bounding box may not lie on the objects main body, a centroid detection may be more useful.

# %% [markdown]
# ## Code
# ---
# Although DETR is simple relative to other detection models, the code to train and test is still complex and is spread acorss multiple directories. For this reason, the code is provided in a zipped package (here [detr.zip](https://drive.google.com/file/d/1GuserI8EDxAlTG4eh98JhugVsSDWCS3f/view?usp=sharing)).
#
# To pull this code into your colab, you have to first add the zip file as shortcut to current working directory. To do this, open the above link and click on "Add shortcut to Drive" button (drive symbol with a plus) and navigate to working current directory and add shortcut.
#
# You have to repeat the same process to download this [coco.zip dataset](https://drive.google.com/file/d/1GVyxYHwVgiG9z_Sn46wslT_2n65DLZRw/view?usp=sharing).

# %%
HW3_ROOT_PATH = '/gdrive/MyDrive/' + 'CSE527/Wen_Shihao_113085521_hw3/' #'FILL IN YOUR HOMEWORK3 ROOT HERE'
PATH_TO_PART2 = HW3_ROOT_PATH + 'part2/'
PATH_TO_COCO = HW3_ROOT_PATH + 'coco/'
# TRY to use these variable wherever you load/save some file

# %%
from google.colab import drive
drive.mount('/gdrive')
# CD into root of your homework2 part3 directory
# %cd -q $PATH_TO_PART2
# Out:
# Mounted at /gdrive

# %%
# !ls
# Out:
# CSE527_23F_HW3_P2.ipynb  detr.zip

# %%
# !unzip -n detr.zip
# Out:
# Archive:  detr.zip
#    creating: detr/d2/
#    creating: detr/d2/configs/
#   inflating: detr/d2/configs/detr_256_6_6_torchvision.yaml
#   inflating: detr/d2/configs/detr_segm_256_6_6_torchvision.yaml
#   inflating: detr/d2/converter.py
#    creating: detr/d2/detr/
#   inflating: detr/d2/detr/__init__.py
#   inflating: detr/d2/detr/config.py
#   inflating: detr/d2/detr/dataset_mapper.py
#   inflating: detr/d2/detr/detr.py
#   inflating: detr/d2/README.md
#   inflating: detr/d2/train_net.py
#    creating: detr/datasets/
#   inflating: detr/datasets/__init__.py
#   inflating: detr/datasets/coco.py
#   inflating: detr/datasets/coco_eval.py
#   inflating: detr/datasets/coco_panoptic.py
#   inflating: detr/datasets/panoptic_eval.py
#   inflating: detr/datasets/transforms.py
#   inflating: detr/engine.py
#   inflating: detr/hubconf.py
#   inflating: detr/instances_train2017.json
#   inflating: detr/main.py
#    creating: detr/models/
#   inflating: detr/models/__init__.py
#   inflating: detr/models/backbone.py
#   inflating: detr/models/detr.py
#   inflating: detr/models/matcher.py
#   inflating: detr/models/position_encoding.py
#   inflating: detr/models/segmentation.py
#   inflating: detr/models/transformer.py
#   inflating: detr/README.md
#   inflating: detr/requirements.txt
#    creating: detr/util/
#  extracting: detr/util/__init__.py
#   inflating: detr/util/box_ops.py
#   inflating: detr/util/misc.py
#   inflating: detr/util/plot_utils.py

# %%
# %cd detr
# %mkdir checkpoints
# Out:
# /gdrive/MyDrive/CSE527/Wen_Shihao_113085521_hw3/part2/detr
# mkdir: cannot create directory ‘checkpoints’: File exists

# %% [markdown]
# ## Install dependencies
# ---
# If you are using colab, running below cell will suffice, else refer to requirements.txt to install all dependencies

# %%
# !pip install -U 'git+https://github.com/cocodataset/cocoapi.git#subdirectory=PythonAPI'

# %% [markdown]
# ##Model
# ---
# DETR consists of
# - a feature extractor,
# - transformer and
# - two output heads
#     - classification head
#     - regression head
#
# In the original implementation, regression head is designed to output the bouding box attributes ltrb (left, top, right, & bottom edges of object). In this homework we intend to train the model to output the centeroids of each object.
#
# ###How do we define centroids:###
# Original DETR uses the MS COCO's _bbox_ annotations to train the model, while in this HW we will use the _segmentation_ annotations.
# Each image may have multiple objects. The pixel outline of each object is provided as an annotation. We will use this contour information to generate the object mask.
#
#
# In the below image, you can see that centroid is near the biggest portion of the object body.
# ![](https://drive.google.com/uc?export=view&id=1CNym_GFV8EKwTQPZQSHZdPB7P-3qarEm)

# %% [markdown]
# ## Get yourself familiar with Data set
# ---
#
# To get your self familiar with the dataset, you are encouraged to play around with the COCO API. The sample code  given below displays the segmentation data format. In the later sections you will be yusing the segmentation data to estimate a centroid.

# %%
from pycocotools.coco import COCO
from PIL import Image
from hubconf import _make_detr
import torch
import requests
import numpy as np
import os
import matplotlib.pyplot as plt
import torchvision.transforms as T

coco = COCO('instances_train2017.json')
ids = coco.getImgIds()
sample = 0
im = coco.loadImgs(ids[sample])[0]
print(f'Image keys: {im.keys()}')
annos = coco.loadAnns(coco.getAnnIds(ids[sample]))
# Note: segmentation annotation is in the format of [x1, y1, x2, y2, x3, y3, . . . ], where (x1, y1) is a point
# on countour, x being dist from left and y is dist from top row of image
print(f'Anno segmentation: {(annos[0]["segmentation"])}')
############# (0 points) ########################


#################################################
# Out:
# loading annotations into memory...
# Done (t=0.64s)
# creating index...
# index created!
# Image keys: dict_keys(['license', 'file_name', 'coco_url', 'height', 'width', 'date_captured', 'flickr_url', 'id'])
# Anno segmentation: [[318.97, 254.35, 328.71, 199.41, 339.35, 164.86, 343.78, 154.23, 336.69, 135.62, 349.09, 145.37, 365.93, 145.37, 372.13, 137.39, 380.1, 145.37, 397.82, 146.25, 436.81, 148.02, 472.25, 159.54, 506.8, 175.49, 536.93, 188.78, 579.46, 202.07, 617.56, 205.62, 640.0, 199.41, 637.94, 349.15, 590.09, 351.81, 547.56, 334.98, 501.49, 317.25, 511.23, 349.15, 510.35, 376.62, 516.55, 407.63, 505.03, 407.63, 498.83, 381.93, 497.94, 407.63, 480.22, 405.86, 474.02, 367.76, 459.85, 316.37, 437.69, 284.47, 432.38, 257.89, 412.89, 230.42, 391.62, 210.05, 380.1, 222.45, 363.27, 233.97, 357.95, 251.69, 346.43, 259.66, 330.49, 264.98]]

# %% [markdown]
# ## Complete the code
# ---
#
# This provided detr/ folder has the following structure
# ```
# detr/
# ├── datasets/
# │   ├── coco.py
# │   ├── ...
# ├── models/
# │   ├── detr.py
# │   ├── matcher.py
# │   └── ...
# ├── utils/
# │   └── ...
# ├── engine.py
# ├── main.py
# ├── requirements.txt
# └── README.md
# ```
#
# In these python files, you will be implementing the missing code blocks. These blocks are highlited by the TODOs
# ```#### TODO CSE527 STUDENT CODE STARTS HERE ######```
#
#
# In total there are 5 sections the code has to be filled. They are located in the files: coco.py, detr.py, matcher.py.
#
# To complete this part you are very much encouraged to:
# - understand how dataset, data sampler, dataloader, model, loss, & optimizer work together during training
# - refer to the actual DETR implementation at [git:facebookresearch/detr](https://github.com/facebookresearch/detr/tree/main) to get an idea of the training pipeline.
# - try to understand flow of control from main.py.
#
# You cannot complete the missing code blocks just from the given description in this ipynb, so you must read the code around. That is, you will read the inputs, outputs and how the inputs to the code block are created and how the outputs from the code block will be utilized.
#
# ## Task
# You should modify the DETR to output centroids rather than bounding boxes.
# Dataset:
# At the dataset level, you are not actually given the centroids, so you will use the instance segmentation masks to estimage the centroid for each object in annotation.
#
# Model:
# For this you will need to replace the classification and regression heads (already removed in the code provided to you, you just need to add new).
#
#
#
# ### 1 - coco.py: ConvertCocoPolysToMask.\__call__()  [20 points]
# Here you will be writing the logic to convert annotations to centroids in the following method.
# Note: You will have to figure out the inputs and outputs by yourself.
# ```
# def convert_coco_poly_to_centroids(segmentations, h, w, boxes) -> Torch.Tensor(shape = num_segmentations x 2)
# ```
#
# This method is part of data loader, and is called when generating the <sample, prediction> pairs, which will eventually be passed onto model for training.
#
# The _centroid_ we are referring to is a hypothetical point on the center of the object's main body part. It should ideally never be a point outside the annotation mask, and is likley always in the middle of body. Here in our case centroid should lie on the middle of horse's torso.
#
# steps:
#  - convert segmentations into masks [5 points]
#  - figure out a way to remove thin sections of object (legs and tail of the horse) from the mask, so only the largest body part (torso) will influence the centroid [10 points]
#  - compute the center of mass of the mask [5 point]
#
#  Feel free to pass on more inputs/outputs to the above method to support your way of computing centroids.
#
#
# ### 2 & 3 - detr.py: DETR.\__init__(), DETR.forward() [10 points]
#
# This is the DETR model architectrure. Here you will change the classification and regression heads, so the model can output centroids (unlike bboxes in original implementation).
# Also you will write logic to freeze the remaining section of DETR.
#
# Original model takes 300 hours to completely train from scrtch, so it is important to freeze all weights except necessary ones (heads).
#
# ### 4 - matcher.py: HungarianMatcher.forward() [15 points]
#
# Matcher is a key part of detection models. Refer to the paper or original DETR implementation to see how/why matcher is used. In this implementation we use Hungarian algorithm to align predictions to the ground truths.
#
# Breif:
# All object instance predictions are matched against the ground truth objects. This is necessary to compute the loss.
# Basically matcher will guess which ground truth object each prediction might be referring based on the closeness of predicted centroids and ground truth centroids.
#
# 100 centroid predictions will be matched against the ground truth centroids. You will compute a cost matrix that encdes the relation of prediction to GT.
#
# Refer: https://en.wikipedia.org/wiki/Hungarian_algorithm
#
# How you compute the cost matrix is again upto you.
#
# ### 5 - detr.py: SetCriterion.loss_centroid() [10 points]
#
# Here you will implement the loss function. Given the predicted centroids and ground truth centroids (which you processed in coco.py), you will write logic to compute variable _centroid_loss_
#
# The loss method is up to you.
#
# Note: At code blocks 4 & 5, make sure the loss/cost is in the normalized range only. I.e., loss/cost is calculated on normalized inputs.

# %% [markdown]
# ## Computing centroid
# ---
#
# Below block provide you a sandbox environment to play around and create a centroid finding algorithm. You will eventually use this code at detr/dataset/coco.py to complete the traning pipeline.
#
# Try to produce centroids that are within 10 pixels a far from the provided gt centroids.

# %%
import cv2
import numpy as np
from pycocotools import mask as coco_mask

def convert_coco_poly_to_mask(segmentations, height, width):
    masks = []
    for polygons in segmentations:
        rles = coco_mask.frPyObjects(polygons, height, width)
        mask = coco_mask.decode(rles)
        if len(mask.shape) < 3:
            mask = mask[..., None]
        mask = torch.as_tensor(mask, dtype=torch.uint8)
        mask = mask.any(dim=2)
        masks.append(mask)
    if masks:
        masks = torch.stack(masks, dim=0)
    else:
        masks = torch.zeros((0, height, width), dtype=torch.uint8)
    return masks

def convert_coco_poly_to_centroids(segmentations, height, width, bboxes):
    """Converts COCO polygon annotations to centroids.
    Args:
        segmentations: A list of COCO polygon annotations.
        height: The height of the image.
        width: The width of the image.
        boxes: bounding boxes

    Returns:
        A PyTorch tensor containing the centroids of the objects in the image.
    """
    centroids = []

    # Step 1: Convert segmentations into masks
    masks = convert_coco_poly_to_mask(segmentations, height, width)

    for mask, bbox in zip(masks, bboxes):
        # Step 2: Remove thin sections of the object (legs and tail of the horse) from the mask
        _, labels, stats, _ = cv2.connectedComponentsWithStats(mask.numpy().astype(np.uint8), connectivity=8)
        largest_component_label = np.argmax(stats[1:, cv2.CC_STAT_AREA]) + 1
        mask = np.zeros_like(mask)
        mask[labels == largest_component_label] = 1

        # Step 3: Compute the center of mass of the mask
        m = cv2.moments(mask)
        cx = int(m["m10"] / m["m00"])
        cy = int(m["m01"] / m["m00"])
        centroids.append(torch.tensor([cx, cy], dtype=torch.float32))

    centroids = torch.stack(centroids, dim=0)
    return centroids

# %%
def estimate_centroids(img, anns):
    h, w = img['height'], img['width']
    # Get segmentations and convert them to centroids
    segmentations = [ann['segmentation'] for ann in anns]
    boxes = [obj["bbox"] for obj in anns]
    boxes = torch.as_tensor(boxes, dtype=torch.float32).reshape(-1, 4)
    boxes[:, 2:] += boxes[:, :2]
    boxes[:, 0::2].clamp_(min=0, max=w)
    boxes[:, 1::2].clamp_(min=0, max=h)
    return convert_coco_poly_to_centroids(segmentations, h, w, boxes)


def compute_drift_rate(centroids, gt_centroids, gt_areas):
  distance_matrix = torch.cdist(centroids, gt_centroids)
  distances = []
  equivalent_lengths = []
  for i in range(len(centroids)):
      min_distance = torch.min(distance_matrix[i])
      min_distance_index = torch.argmin(distance_matrix[i])
      distances.append(min_distance)
      equivalent_lengths.append(np.sqrt(gt_areas[min_distance_index]))
  return torch.div(torch.Tensor(distances), torch.Tensor(equivalent_lengths))


# driver code
img_id = 144505
img = coco.loadImgs(img_id)[0]
img_data = Image.open(requests.get(img['coco_url'], stream=True).raw)

# Get image annotations
anns = coco.loadAnns(coco.getAnnIds(img_id))
centroids = estimate_centroids(img, anns)
gt_centroids = torch.Tensor([[378, 298],[537, 258]])
print(f'Predicted centroids: {centroids}')
plt.imshow(img_data)
for centroid in centroids:
    plt.plot(centroid[0], centroid[1], 'ro')
for centroid in gt_centroids:
    plt.plot(centroid[0], centroid[1], 'bo')
# Show image
plt.title(f'Drift dist = {compute_drift_rate(centroids, gt_centroids, [ann["area"] for ann in anns])}')
plt.show()
# Out:
# Predicted centroids: tensor([[379., 326.],
#         [536., 267.]])

# %% [markdown]
# ## Training
# ---
#
# Implement all five mentioned code blocks and use the below command AS IS. You can change BS, num_epochs, num_workers. (use this output training  [log](https://drive.google.com/file/d/1ZGd-ciOKkajri0GEOwc-uJDBjGJHJdNY/view?usp=drive_link) for your reference).
#
# Make sure checkpoints are being saved correctly and sometime not mistakenly being overriden due to multiple executions.
#
# You can use the validation loss/loss_centroid  as a metric to track performance.
#
# For grading:
# - There are no strict limits on evaluation metrics.
# - In the last cell of this notebook _avg_drift_rate_ metric is computed on a subset of validation ds. Try to score below 0.35.

# %%
# !python -u main.py --coco_path $PATH_TO_COCO --batch_size 10 --num_workers 12 --epochs 20 --output_dir './checkpoints'  --resume https://dl.fbaipublicfiles.com/detr/detr-r50-e632da11.pth --freeze_body
# Out:
# Not using distributed mode
# fatal: not a git repository (or any parent up to mount point /)
# Stopping at filesystem boundary (GIT_DISCOVERY_ACROSS_FILESYSTEM not set).
# git:
#   sha: N/A, status: clean, branch: N/A
#
# Namespace(lr=0.0001, lr_backbone=1e-05, batch_size=10, weight_decay=0.0001, epochs=20, lr_drop=200, clip_max_norm=0.1, frozen_weights=None, freeze_body=True, backbone='resnet50', dilation=False, position_embedding='sine', enc_layers=6, dec_layers=6, dim_feedforward=2048, hidden_dim=256, dropout=0.1, nheads=8, num_queries=100, pre_norm=False, masks=False, aux_loss=True, set_cost_class=1, set_cost_bbox=5, set_cost_centroid=5, set_cost_giou=2, mask_loss_coef=1, dice_loss_coef=1, bbox_loss_coef=5, cent_loss_coef=5, giou_loss_coef=2, eos_coef=0.1, dataset_file='coco', coco_path='/gdrive/MyDrive/CSE527/Wen_Shihao_113085521_hw3/coco/', coco_panoptic_path=None, remove_difficult=False, output_dir='./checkpoints', device='cuda', seed=42, resume='https://dl.fbaipublicfiles.com/detr/detr-r50-e632da11.pth', start_epoch=0, eval=False, num_workers=12, world_size=1, dist_url='env://', distributed=False)
# /usr/local/lib/python3.10/dist-packages/torchvision/models/_utils.py:208: UserWarning: The parameter 'pretrained' is deprecated since 0.13 and may be removed in the future, please use 'weights' instead.
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/torchvision/models/_utils.py:223: UserWarning: Arguments other than a weight enum or `None` for 'weights' are deprecated since 0.13 and may be removed in the future. The current behavior is equivalent to passing `weights=ResNet50_Weights.IMAGENET1K_V1`. You can also use `weights=ResNet50_Weights.DEFAULT` to get the most up-to-date weights.
#   warnings.warn(msg)
# number of params: 17914885
# loading annotations into memory...
# Done (t=0.51s)
# creating index...
# index created!
# loading annotations into memory...
# Done (t=0.01s)
# creating index...
# index created!
# /usr/local/lib/python3.10/dist-packages/torch/utils/data/dataloader.py:557: UserWarning: This DataLoader will create 12 worker processes in total. Our suggested max number of worker in current system is 2, which is smaller than what this DataLoader is going to create. Please be aware that excessive worker creation might get DataLoader running slow or even freeze, lower the worker number to avoid potential slowness/freeze if necessary.
#   warnings.warn(_create_warning_msg(
# Downloading: "https://dl.fbaipublicfiles.com/detr/detr-r50-e632da11.pth" to /root/.cache/torch/hub/checkpoints/detr-r50-e632da11.pth
# 100% 159M/159M [00:01<00:00, 159MB/s]
# deleted some params ['bbox_embed.layers.0.weight', 'bbox_embed.layers.0.bias', 'bbox_embed.layers.1.weight', 'bbox_embed.layers.1.bias', 'bbox_embed.layers.2.weight', 'bbox_embed.layers.2.bias']
# Start training
# [MetricsLogger]: a running average is displayed for lr & class_error, but for the rest of metrics overall average over the epoch is displayed
# Epoch: [0]  [ 0/50]  eta: 0:09:59  lr: 0.000100  class_error: 18.52  loss: 33.3052 (33.3052)  loss_ce: 1.3250 (1.3250)  loss_centroid: 5.2203 (5.2203)  loss_ce_0: 1.3471 (1.3471)  loss_centroid_0: 2.0383 (2.0383)  loss_ce_1: 1.3050 (1.3050)  loss_centroid_1: 3.4508 (3.4508)  loss_ce_2: 1.3094 (1.3094)  loss_centroid_2: 4.5306 (4.5306)  loss_ce_3: 1.3025 (1.3025)  loss_centroid_3: 4.9106 (4.9106)  loss_ce_4: 1.3085 (1.3085)  loss_centroid_4: 5.2571 (5.2571)  loss_ce_unscaled: 1.3250 (1.3250)  class_error_unscaled: 18.5185 (18.5185)  cardinality_error_unscaled: 92.7000 (92.7000)  loss_centroid_unscaled: 1.0441 (1.0441)  loss_ce_0_unscaled: 1.3471 (1.3471)  cardinality_error_0_unscaled: 94.0000 (94.0000)  loss_centroid_0_unscaled: 0.4077 (0.4077)  loss_ce_1_unscaled: 1.3050 (1.3050)  cardinality_error_1_unscaled: 93.0000 (93.0000)  loss_centroid_1_unscaled: 0.6902 (0.6902)  loss_ce_2_unscaled: 1.3094 (1.3094)  cardinality_error_2_unscaled: 92.5000 (92.5000)  loss_centroid_2_unscaled: 0.9061 (0.9061)  loss_ce_3_unscaled: 1.3025 (1.3025)  cardinality_error_3_unscaled: 91.2000 (91.2000)  loss_centroid_3_unscaled: 0.9821 (0.9821)  loss_ce_4_unscaled: 1.3085 (1.3085)  cardinality_error_4_unscaled: 91.7000 (91.7000)  loss_centroid_4_unscaled: 1.0514 (1.0514)  time: 11.9821  data: 8.1700  max mem: 2053
# Epoch: [0]  [10/50]  eta: 0:01:00  lr: 0.000100  class_error: 26.32  loss: 9.6029 (12.7885)  loss_ce: 1.0623 (1.0905)  loss_centroid: 0.6714 (1.1763)  loss_ce_0: 1.3144 (1.2901)  loss_centroid_0: 0.3804 (0.6312)  loss_ce_1: 1.1552 (1.1624)  loss_centroid_1: 0.4357 (0.8464)  loss_ce_2: 1.1191 (1.1381)  loss_centroid_2: 0.4065 (0.9760)  loss_ce_3: 1.0594 (1.0971)  loss_centroid_3: 0.5130 (1.1356)  loss_ce_4: 1.0539 (1.0904)  loss_centroid_4: 0.4788 (1.1543)  loss_ce_unscaled: 1.0623 (1.0905)  class_error_unscaled: 17.6471 (18.4756)  cardinality_error_unscaled: 77.1000 (73.3909)  loss_centroid_unscaled: 0.1343 (0.2353)  loss_ce_0_unscaled: 1.3144 (1.2901)  cardinality_error_0_unscaled: 94.0000 (93.5636)  loss_centroid_0_unscaled: 0.0761 (0.1262)  loss_ce_1_unscaled: 1.1552 (1.1624)  cardinality_error_1_unscaled: 89.5000 (87.2091)  loss_centroid_1_unscaled: 0.0871 (0.1693)  loss_ce_2_unscaled: 1.1191 (1.1381)  cardinality_error_2_unscaled: 83.9000 (81.5091)  loss_centroid_2_unscaled: 0.0813 (0.1952)  loss_ce_3_unscaled: 1.0594 (1.0971)  cardinality_error_3_unscaled: 77.8000 (73.5000)  loss_centroid_3_unscaled: 0.1026 (0.2271)  loss_ce_4_unscaled: 1.0539 (1.0904)  cardinality_error_4_unscaled: 76.4000 (71.9182)  loss_centroid_4_unscaled: 0.0958 (0.2309)  time: 1.5100  data: 0.7702  max mem: 2273
# Epoch: [0]  [20/50]  eta: 0:00:30  lr: 0.000100  class_error: 100.00  loss: 8.5871 (10.1951)  loss_ce: 0.8495 (0.8866)  loss_centroid: 0.5249 (0.8170)  loss_ce_0: 1.1707 (1.1953)  loss_centroid_0: 0.3738 (0.5168)  loss_ce_1: 1.0402 (1.0310)  loss_centroid_1: 0.4297 (0.6407)  loss_ce_2: 0.9667 (0.9769)  loss_centroid_2: 0.4065 (0.6966)  loss_ce_3: 0.8971 (0.9172)  loss_centroid_3: 0.4631 (0.8009)  loss_ce_4: 0.8731 (0.8994)  loss_centroid_4: 0.4702 (0.8167)  loss_ce_unscaled: 0.8495 (0.8866)  class_error_unscaled: 36.3636 (46.9264)  cardinality_error_unscaled: 42.6000 (42.2476)  loss_centroid_unscaled: 0.1050 (0.1634)  loss_ce_0_unscaled: 1.1707 (1.1953)  cardinality_error_0_unscaled: 90.7000 (88.5000)  loss_centroid_0_unscaled: 0.0748 (0.1034)  loss_ce_1_unscaled: 1.0402 (1.0310)  cardinality_error_1_unscaled: 76.8000 (67.1286)  loss_centroid_1_unscaled: 0.0859 (0.1281)  loss_ce_2_unscaled: 0.9667 (0.9769)  cardinality_error_2_unscaled: 64.0000 (55.1095)  loss_centroid_2_unscaled: 0.0813 (0.1393)  loss_ce_3_unscaled: 0.8971 (0.9172)  cardinality_error_3_unscaled: 47.7000 (44.6286)  loss_centroid_3_unscaled: 0.0926 (0.1602)  loss_ce_4_unscaled: 0.8731 (0.8994)  cardinality_error_4_unscaled: 42.7000 (41.9619)  loss_centroid_4_unscaled: 0.0940 (0.1633)  time: 1.0247  data: 0.4384  max mem: 2273
# Epoch: [0]  [30/50]  eta: 0:00:17  lr: 0.000100  class_error: 100.00  loss: 7.5309 (8.9841)  loss_ce: 0.6415 (0.7694)  loss_centroid: 0.5160 (0.7437)  loss_ce_0: 1.0851 (1.0969)  loss_centroid_0: 0.3722 (0.4699)  loss_ce_1: 0.8747 (0.9220)  loss_centroid_1: 0.4227 (0.5655)  loss_ce_2: 0.8030 (0.8600)  loss_centroid_2: 0.3610 (0.5839)  loss_ce_3: 0.7053 (0.8010)  loss_centroid_3: 0.4290 (0.6763)  loss_ce_4: 0.6816 (0.7824)  loss_centroid_4: 0.4702 (0.7132)  loss_ce_unscaled: 0.6415 (0.7694)  class_error_unscaled: 76.4706 (64.0469)  cardinality_error_unscaled: 5.5000 (29.3355)  loss_centroid_unscaled: 0.1032 (0.1487)  loss_ce_0_unscaled: 1.0851 (1.0969)  cardinality_error_0_unscaled: 83.9000 (76.5355)  loss_centroid_0_unscaled: 0.0744 (0.0940)  loss_ce_1_unscaled: 0.8747 (0.9220)  cardinality_error_1_unscaled: 47.5000 (47.8065)  loss_centroid_1_unscaled: 0.0845 (0.1131)  loss_ce_2_unscaled: 0.8030 (0.8600)  cardinality_error_2_unscaled: 26.8000 (38.0935)  loss_centroid_2_unscaled: 0.0722 (0.1168)  loss_ce_3_unscaled: 0.7053 (0.8010)  cardinality_error_3_unscaled: 12.0000 (30.9290)  loss_centroid_3_unscaled: 0.0858 (0.1353)  loss_ce_4_unscaled: 0.6816 (0.7824)  cardinality_error_4_unscaled: 7.6000 (29.1323)  loss_centroid_4_unscaled: 0.0940 (0.1426)  time: 0.8567  data: 0.3147  max mem: 2275
# Epoch: [0]  [40/50]  eta: 0:00:07  lr: 0.000100  class_error: 100.00  loss: 6.8149 (8.1590)  loss_ce: 0.6299 (0.7166)  loss_centroid: 0.4099 (0.6489)  loss_ce_0: 0.9790 (1.0133)  loss_centroid_0: 0.3619 (0.4404)  loss_ce_1: 0.7950 (0.8454)  loss_centroid_1: 0.3870 (0.5087)  loss_ce_2: 0.7377 (0.7877)  loss_centroid_2: 0.3524 (0.5217)  loss_ce_3: 0.6586 (0.7406)  loss_centroid_3: 0.4173 (0.5913)  loss_ce_4: 0.6322 (0.7232)  loss_centroid_4: 0.4042 (0.6212)  loss_ce_unscaled: 0.6299 (0.7166)  class_error_unscaled: 100.0000 (72.8160)  cardinality_error_unscaled: 3.0000 (22.7829)  loss_centroid_unscaled: 0.0820 (0.1298)  loss_ce_0_unscaled: 0.9790 (1.0133)  cardinality_error_0_unscaled: 71.3000 (62.3220)  loss_centroid_0_unscaled: 0.0724 (0.0881)  loss_ce_1_unscaled: 0.7950 (0.8454)  cardinality_error_1_unscaled: 21.7000 (36.6756)  loss_centroid_1_unscaled: 0.0774 (0.1017)  loss_ce_2_unscaled: 0.7377 (0.7877)  cardinality_error_2_unscaled: 6.2000 (29.4049)  loss_centroid_2_unscaled: 0.0705 (0.1043)  loss_ce_3_unscaled: 0.6586 (0.7406)  cardinality_error_3_unscaled: 3.2000 (23.9878)  loss_centroid_3_unscaled: 0.0835 (0.1183)  loss_ce_4_unscaled: 0.6322 (0.7232)  cardinality_error_4_unscaled: 3.0000 (22.6293)  loss_centroid_4_unscaled: 0.0808 (0.1242)  time: 0.7623  data: 0.2500  max mem: 2275
# Epoch: [0]  [49/50]  eta: 0:00:00  lr: 0.000100  class_error: 100.00  loss: 6.3202 (7.6615)  loss_ce: 0.6006 (0.6761)  loss_centroid: 0.3947 (0.5970)  loss_ce_0: 0.8921 (0.9460)  loss_centroid_0: 0.3651 (0.4297)  loss_ce_1: 0.7028 (0.7864)  loss_centroid_1: 0.3870 (0.4849)  loss_ce_2: 0.6275 (0.7372)  loss_centroid_2: 0.3524 (0.4971)  loss_ce_3: 0.6134 (0.7002)  loss_centroid_3: 0.4018 (0.5520)  loss_ce_4: 0.6020 (0.6803)  loss_centroid_4: 0.3905 (0.5746)  loss_ce_unscaled: 0.6006 (0.6761)  class_error_unscaled: 100.0000 (77.7091)  cardinality_error_unscaled: 2.8000 (19.0560)  loss_centroid_unscaled: 0.0789 (0.1194)  loss_ce_0_unscaled: 0.8921 (0.9460)  cardinality_error_0_unscaled: 57.9000 (51.8540)  loss_centroid_0_unscaled: 0.0730 (0.0859)  loss_ce_1_unscaled: 0.7028 (0.7864)  cardinality_error_1_unscaled: 8.0000 (30.4460)  loss_centroid_1_unscaled: 0.0774 (0.0970)  loss_ce_2_unscaled: 0.6275 (0.7372)  cardinality_error_2_unscaled: 3.1000 (24.4860)  loss_centroid_2_unscaled: 0.0705 (0.0994)  loss_ce_3_unscaled: 0.6134 (0.7002)  cardinality_error_3_unscaled: 2.8000 (20.0440)  loss_centroid_3_unscaled: 0.0804 (0.1104)  loss_ce_4_unscaled: 0.6020 (0.6803)  cardinality_error_4_unscaled: 2.8000 (18.9300)  loss_centroid_4_unscaled: 0.0781 (0.1149)  time: 0.7051  data: 0.2125  max mem: 2276
# Epoch: [0] Total time: 0:00:35 (0.7080 s / it)
# SAVED
# SAVED
# Test:  [0/5]  eta: 0:00:29  class_error: 100.00  loss: 7.9758 (7.9758)  loss_ce: 0.5838 (0.5838)  loss_centroid: 0.6261 (0.6261)  loss_ce_0: 0.7333 (0.7333)  loss_centroid_0: 1.4701 (1.4701)  loss_ce_1: 0.6173 (0.6173)  loss_centroid_1: 0.4754 (0.4754)  loss_ce_2: 0.5649 (0.5649)  loss_centroid_2: 0.4819 (0.4819)  loss_ce_3: 0.5822 (0.5822)  loss_centroid_3: 0.4370 (0.4370)  loss_ce_4: 0.5892 (0.5892)  loss_centroid_4: 0.8147 (0.8147)  loss_ce_unscaled: 0.5838 (0.5838)  class_error_unscaled: 100.0000 (100.0000)  cardinality_error_unscaled: 3.1000 (3.1000)  loss_centroid_unscaled: 0.1252 (0.1252)  loss_ce_0_unscaled: 0.7333 (0.7333)  cardinality_error_0_unscaled: 2.8000 (2.8000)  loss_centroid_0_unscaled: 0.2940 (0.2940)  loss_ce_1_unscaled: 0.6173 (0.6173)  cardinality_error_1_unscaled: 3.1000 (3.1000)  loss_centroid_1_unscaled: 0.0951 (0.0951)  loss_ce_2_unscaled: 0.5649 (0.5649)  cardinality_error_2_unscaled: 3.1000 (3.1000)  loss_centroid_2_unscaled: 0.0964 (0.0964)  loss_ce_3_unscaled: 0.5822 (0.5822)  cardinality_error_3_unscaled: 3.1000 (3.1000)  loss_centroid_3_unscaled: 0.0874 (0.0874)  loss_ce_4_unscaled: 0.5892 (0.5892)  cardinality_error_4_unscaled: 3.1000 (3.1000)  loss_centroid_4_unscaled: 0.1629 (0.1629)  time: 5.9326  data: 4.9789  max mem: 3287
# Test:  [4/5]  eta: 0:00:02  class_error: 100.00  loss: 6.0876 (6.4361)  loss_ce: 0.4650 (0.4771)  loss_centroid: 0.6150 (0.5848)  loss_ce_0: 0.6592 (0.6713)  loss_centroid_0: 0.7069 (0.8533)  loss_ce_1: 0.5299 (0.5347)  loss_centroid_1: 0.4471 (0.4204)  loss_ce_2: 0.4746 (0.4782)  loss_centroid_2: 0.3833 (0.4123)  loss_ce_3: 0.4472 (0.4643)  loss_centroid_3: 0.3443 (0.3384)  loss_ce_4: 0.4735 (0.4851)  loss_centroid_4: 0.7807 (0.7160)  loss_ce_unscaled: 0.4650 (0.4771)  class_error_unscaled: 100.0000 (100.0000)  cardinality_error_unscaled: 2.0000 (2.1400)  loss_centroid_unscaled: 0.1230 (0.1170)  loss_ce_0_unscaled: 0.6592 (0.6713)  cardinality_error_0_unscaled: 3.2000 (3.7000)  loss_centroid_0_unscaled: 0.1414 (0.1707)  loss_ce_1_unscaled: 0.5299 (0.5347)  cardinality_error_1_unscaled: 2.0000 (2.1400)  loss_centroid_1_unscaled: 0.0894 (0.0841)  loss_ce_2_unscaled: 0.4746 (0.4782)  cardinality_error_2_unscaled: 2.0000 (2.1400)  loss_centroid_2_unscaled: 0.0767 (0.0825)  loss_ce_3_unscaled: 0.4472 (0.4643)  cardinality_error_3_unscaled: 2.0000 (2.1400)  loss_centroid_3_unscaled: 0.0689 (0.0677)  loss_ce_4_unscaled: 0.4735 (0.4851)  cardinality_error_4_unscaled: 2.0000 (2.1400)  loss_centroid_4_unscaled: 0.1561 (0.1432)  time: 2.2510  data: 1.0354  max mem: 5059
# Test: Total time: 0:00:11 (2.3150 s / it)
# [MetricsLogger]: a running average is displayed for lr & class_error, but for the rest of metrics overall average over the epoch is displayed
# Epoch: [1]  [ 0/50]  eta: 0:04:03  lr: 0.000100  class_error: 100.00  loss: 5.4613 (5.4613)  loss_ce: 0.5057 (0.5057)  loss_centroid: 0.5175 (0.5175)  loss_ce_0: 0.5977 (0.5977)  loss_centroid_0: 0.3626 (0.3626)  loss_ce_1: 0.4953 (0.4953)  loss_centroid_1: 0.3314 (0.3314)  loss_ce_2: 0.5058 (0.5058)  loss_centroid_2: 0.3285 (0.3285)  loss_ce_3: 0.4947 (0.4947)  loss_centroid_3: 0.2427 (0.2427)  loss_ce_4: 0.4892 (0.4892)  loss_centroid_4: 0.5900 (0.5900)  loss_ce_unscaled: 0.5057 (0.5057)  class_error_unscaled: 100.0000 (100.0000)  cardinality_error_unscaled: 2.1000 (2.1000)  loss_centroid_unscaled: 0.1035 (0.1035)  loss_ce_0_unscaled: 0.5977 (0.5977)  cardinality_error_0_unscaled: 2.1000 (2.1000)  loss_centroid_0_unscaled: 0.0725 (0.0725)  loss_ce_1_unscaled: 0.4953 (0.4953)  cardinality_error_1_unscaled: 2.1000 (2.1000)  loss_centroid_1_unscaled: 0.0663 (0.0663)  loss_ce_2_unscaled: 0.5058 (0.5058)  cardinality_error_2_unscaled: 2.1000 (2.1000)  loss_centroid_2_unscaled: 0.0657 (0.0657)  loss_ce_3_unscaled: 0.4947 (0.4947)  cardinality_error_3_unscaled: 2.1000 (2.1000)  loss_centroid_3_unscaled: 0.0485 (0.0485)  loss_ce_4_unscaled: 0.4892 (0.4892)  cardinality_error_4_unscaled: 2.1000 (2.1000)  loss_centroid_4_unscaled: 0.1180 (0.1180)  time: 4.8665  data: 3.1111  max mem: 5059
# Epoch: [1]  [10/50]  eta: 0:00:36  lr: 0.000100  class_error: 100.00  loss: 5.0820 (5.3174)  loss_ce: 0.4743 (0.4787)  loss_centroid: 0.4362 (0.4120)  loss_ce_0: 0.5862 (0.5847)  loss_centroid_0: 0.3626 (0.3668)  loss_ce_1: 0.4953 (0.4996)  loss_centroid_1: 0.3422 (0.3524)  loss_ce_2: 0.4814 (0.4905)  loss_centroid_2: 0.3476 (0.3594)  loss_ce_3: 0.4959 (0.4916)  loss_centroid_3: 0.3128 (0.3135)  loss_ce_4: 0.4830 (0.4762)  loss_centroid_4: 0.3737 (0.4920)  loss_ce_unscaled: 0.4743 (0.4787)  class_error_unscaled: 100.0000 (100.0000)  cardinality_error_unscaled: 2.0000 (2.0727)  loss_centroid_unscaled: 0.0872 (0.0824)  loss_ce_0_unscaled: 0.5862 (0.5847)  cardinality_error_0_unscaled: 1.9000 (1.7182)  loss_centroid_0_unscaled: 0.0725 (0.0734)  loss_ce_1_unscaled: 0.4953 (0.4996)  cardinality_error_1_unscaled: 2.0000 (2.0727)  loss_centroid_1_unscaled: 0.0684 (0.0705)  loss_ce_2_unscaled: 0.4814 (0.4905)  cardinality_error_2_unscaled: 2.0000 (2.0727)  loss_centroid_2_unscaled: 0.0695 (0.0719)  loss_ce_3_unscaled: 0.4959 (0.4916)  cardinality_error_3_unscaled: 2.0000 (2.0727)  loss_centroid_3_unscaled: 0.0626 (0.0627)  loss_ce_4_unscaled: 0.4830 (0.4762)  cardinality_error_4_unscaled: 2.0000 (2.0727)  loss_centroid_4_unscaled: 0.0747 (0.0984)  time: 0.9184  data: 0.3777  max mem: 5059
# Epoch: [1]  [20/50]  eta: 0:00:22  lr: 0.000100  class_error: 100.00  loss: 4.9104 (5.0914)  loss_ce: 0.4743 (0.4840)  loss_centroid: 0.2809 (0.3468)  loss_ce_0: 0.5738 (0.5825)  loss_centroid_0: 0.3401 (0.3429)  loss_ce_1: 0.4953 (0.5035)  loss_centroid_1: 0.3255 (0.3303)  loss_ce_2: 0.4748 (0.4943)  loss_centroid_2: 0.3135 (0.3231)  loss_ce_3: 0.4959 (0.5042)  loss_centroid_3: 0.3059 (0.3017)  loss_ce_4: 0.4572 (0.4858)  loss_centroid_4: 0.3265 (0.3923)  loss_ce_unscaled: 0.4743 (0.4840)  class_error_unscaled: 100.0000 (100.0000)  cardinality_error_unscaled: 2.0000 (2.2286)  loss_centroid_unscaled: 0.0562 (0.0694)  loss_ce_0_unscaled: 0.5738 (0.5825)  cardinality_error_0_unscaled: 1.8000 (1.8810)  loss_centroid_0_unscaled: 0.0680 (0.0686)  loss_ce_1_unscaled: 0.4953 (0.5035)  cardinality_error_1_unscaled: 2.0000 (2.2286)  loss_centroid_1_unscaled: 0.0651 (0.0661)  loss_ce_2_unscaled: 0.4748 (0.4943)  cardinality_error_2_unscaled: 2.0000 (2.2286)  loss_centroid_2_unscaled: 0.0627 (0.0646)  loss_ce_3_unscaled: 0.4959 (0.5042)  cardinality_error_3_unscaled: 2.0000 (2.2286)  loss_centroid_3_unscaled: 0.0612 (0.0603)  loss_ce_4_unscaled: 0.4572 (0.4858)  cardinality_error_4_unscaled: 2.0000 (2.2286)  loss_centroid_4_unscaled: 0.0653 (0.0785)  time: 0.7386  data: 0.2357  max mem: 5059
# Epoch: [1]  [30/50]  eta: 0:00:13  lr: 0.000100  class_error: 100.00  loss: 4.8400 (4.9630)  loss_ce: 0.4743 (0.4707)  loss_centroid: 0.2794 (0.3288)  loss_ce_0: 0.5682 (0.5715)  loss_centroid_0: 0.3084 (0.3284)  loss_ce_1: 0.4953 (0.4929)  loss_centroid_1: 0.3065 (0.3159)  loss_ce_2: 0.4718 (0.4765)  loss_centroid_2: 0.3427 (0.3433)  loss_ce_3: 0.4905 (0.4869)  loss_centroid_3: 0.3063 (0.3094)  loss_ce_4: 0.4538 (0.4734)  loss_centroid_4: 0.3158 (0.3652)  loss_ce_unscaled: 0.4743 (0.4707)  class_error_unscaled: 100.0000 (100.0000)  cardinality_error_unscaled: 2.0000 (2.1645)  loss_centroid_unscaled: 0.0559 (0.0658)  loss_ce_0_unscaled: 0.5682 (0.5715)  cardinality_error_0_unscaled: 1.7000 (1.8194)  loss_centroid_0_unscaled: 0.0617 (0.0657)  loss_ce_1_unscaled: 0.4953 (0.4929)  cardinality_error_1_unscaled: 2.0000 (2.1645)  loss_centroid_1_unscaled: 0.0613 (0.0632)  loss_ce_2_unscaled: 0.4718 (0.4765)  cardinality_error_2_unscaled: 2.0000 (2.1645)  loss_centroid_2_unscaled: 0.0685 (0.0687)  loss_ce_3_unscaled: 0.4905 (0.4869)  cardinality_error_3_unscaled: 2.0000 (2.1645)  loss_centroid_3_unscaled: 0.0613 (0.0619)  loss_ce_4_unscaled: 0.4538 (0.4734)  cardinality_error_4_unscaled: 2.0000 (2.1645)  loss_centroid_4_unscaled: 0.0632 (0.0730)  time: 0.6687  data: 0.1859  max mem: 5059
# Epoch: [1]  [40/50]  eta: 0:00:06  lr: 0.000100  class_error: 100.00  loss: 4.8410 (4.9174)  loss_ce: 0.4660 (0.4648)  loss_centroid: 0.3070 (0.3329)  loss_ce_0: 0.5614 (0.5622)  loss_centroid_0: 0.3225 (0.3274)  loss_ce_1: 0.4953 (0.4915)  loss_centroid_1: 0.3113 (0.3196)  loss_ce_2: 0.4718 (0.4739)  loss_centroid_2: 0.3362 (0.3374)  loss_ce_3: 0.4777 (0.4843)  loss_centroid_3: 0.3042 (0.3050)  loss_ce_4: 0.4538 (0.4702)  loss_centroid_4: 0.3114 (0.3482)  loss_ce_unscaled: 0.4660 (0.4648)  class_error_unscaled: 100.0000 (100.0000)  cardinality_error_unscaled: 2.0000 (2.1537)  loss_centroid_unscaled: 0.0614 (0.0666)  loss_ce_0_unscaled: 0.5614 (0.5622)  cardinality_error_0_unscaled: 1.8000 (1.8537)  loss_centroid_0_unscaled: 0.0645 (0.0655)  loss_ce_1_unscaled: 0.4953 (0.4915)  cardinality_error_1_unscaled: 2.0000 (2.1561)  loss_centroid_1_unscaled: 0.0623 (0.0639)  loss_ce_2_unscaled: 0.4718 (0.4739)  cardinality_error_2_unscaled: 2.0000 (2.1537)  loss_centroid_2_unscaled: 0.0672 (0.0675)  loss_ce_3_unscaled: 0.4777 (0.4843)  cardinality_error_3_unscaled: 2.0000 (2.1561)  loss_centroid_3_unscaled: 0.0608 (0.0610)  loss_ce_4_unscaled: 0.4538 (0.4702)  cardinality_error_4_unscaled: 2.0000 (2.1561)  loss_centroid_4_unscaled: 0.0623 (0.0696)  time: 0.6204  data: 0.1525  max mem: 5059
# Epoch: [1]  [49/50]  eta: 0:00:00  lr: 0.000100  class_error: 100.00  loss: 4.8393 (4.9017)  loss_ce: 0.4572 (0.4640)  loss_centroid: 0.3070 (0.3323)  loss_ce_0: 0.5555 (0.5559)  loss_centroid_0: 0.3170 (0.3241)  loss_ce_1: 0.4880 (0.4909)  loss_centroid_1: 0.3113 (0.3208)  loss_ce_2: 0.4673 (0.4745)  loss_centroid_2: 0.3355 (0.3309)  loss_ce_3: 0.4718 (0.4852)  loss_centroid_3: 0.3042 (0.3089)  loss_ce_4: 0.4532 (0.4693)  loss_centroid_4: 0.3114 (0.3450)  loss_ce_unscaled: 0.4572 (0.4640)  class_error_unscaled: 100.0000 (100.0000)  cardinality_error_unscaled: 2.0000 (2.1640)  loss_centroid_unscaled: 0.0614 (0.0665)  loss_ce_0_unscaled: 0.5555 (0.5559)  cardinality_error_0_unscaled: 1.8000 (1.9080)  loss_centroid_0_unscaled: 0.0634 (0.0648)  loss_ce_1_unscaled: 0.4880 (0.4909)  cardinality_error_1_unscaled: 2.0000 (2.1660)  loss_centroid_1_unscaled: 0.0623 (0.0642)  loss_ce_2_unscaled: 0.4673 (0.4745)  cardinality_error_2_unscaled: 2.0000 (2.1640)  loss_centroid_2_unscaled: 0.0671 (0.0662)  loss_ce_3_unscaled: 0.4718 (0.4852)  cardinality_error_3_unscaled: 2.0000 (2.1660)  loss_centroid_3_unscaled: 0.0608 (0.0618)  loss_ce_4_unscaled: 0.4532 (0.4693)  cardinality_error_4_unscaled: 2.0000 (2.1660)  loss_centroid_4_unscaled: 0.0623 (0.0690)  time: 0.5887  data: 0.1279  max mem: 5059
# Epoch: [1] Total time: 0:00:29 (0.5929 s / it)
# SAVED
# SAVED
# Test:  [0/5]  eta: 0:00:25  class_error: 100.00  loss: 8.2939 (8.2939)  loss_ce: 0.5688 (0.5688)  loss_centroid: 0.6447 (0.6447)  loss_ce_0: 0.6452 (0.6452)  loss_centroid_0: 1.0380 (1.0380)  loss_ce_1: 0.6054 (0.6054)  loss_centroid_1: 0.9041 (0.9041)  loss_ce_2: 0.6606 (0.6606)  loss_centroid_2: 0.5361 (0.5361)  loss_ce_3: 0.6631 (0.6631)  loss_centroid_3: 0.5504 (0.5504)  loss_ce_4: 0.6458 (0.6458)  loss_centroid_4: 0.8317 (0.8317)  loss_ce_unscaled: 0.5688 (0.5688)  class_error_unscaled: 100.0000 (100.0000)  cardinality_error_unscaled: 3.1000 (3.1000)  loss_centroid_unscaled: 0.1289 (0.1289)  loss_ce_0_unscaled: 0.6452 (0.6452)  cardinality_error_0_unscaled: 3.0000 (3.0000)  loss_centroid_0_unscaled: 0.2076 (0.2076)  loss_ce_1_unscaled: 0.6054 (0.6054)  cardinality_error_1_unscaled: 3.1000 (3.1000)  loss_centroid_1_unscaled: 0.1808 (0.1808)  loss_ce_2_unscaled: 0.6606 (0.6606)  cardinality_error_2_unscaled: 3.1000 (3.1000)  loss_centroid_2_unscaled: 0.1072 (0.1072)  loss_ce_3_unscaled: 0.6631 (0.6631)  cardinality_error_3_unscaled: 3.1000 (3.1000)  loss_centroid_3_unscaled: 0.1101 (0.1101)  loss_ce_4_unscaled: 0.6458 (0.6458)  cardinality_error_4_unscaled: 3.1000 (3.1000)  loss_centroid_4_unscaled: 0.1663 (0.1663)  time: 5.1296  data: 4.1232  max mem: 5059
# Test:  [4/5]  eta: 0:00:02  class_error: 100.00  loss: 6.3009 (6.5145)  loss_ce: 0.4532 (0.4665)  loss_centroid: 0.5444 (0.5344)  loss_ce_0: 0.5482 (0.5649)  loss_centroid_0: 0.5399 (0.6348)  loss_ce_1: 0.5067 (0.5075)  loss_centroid_1: 0.4928 (0.5942)  loss_ce_2: 0.4948 (0.5108)  loss_centroid_2: 0.5020 (0.4857)  loss_ce_3: 0.5201 (0.5332)  loss_centroid_3: 0.4682 (0.4913)  loss_ce_4: 0.4801 (0.5190)  loss_centroid_4: 0.6102 (0.6722)  loss_ce_unscaled: 0.4532 (0.4665)  class_error_unscaled: 100.0000 (100.0000)  cardinality_error_unscaled: 2.0000 (2.1400)  loss_centroid_unscaled: 0.1089 (0.1069)  loss_ce_0_unscaled: 0.5482 (0.5649)  cardinality_error_0_unscaled: 2.0000 (2.0400)  loss_centroid_0_unscaled: 0.1080 (0.1270)  loss_ce_1_unscaled: 0.5067 (0.5075)  cardinality_error_1_unscaled: 2.0000 (2.1400)  loss_centroid_1_unscaled: 0.0986 (0.1188)  loss_ce_2_unscaled: 0.4948 (0.5108)  cardinality_error_2_unscaled: 2.0000 (2.1400)  loss_centroid_2_unscaled: 0.1004 (0.0971)  loss_ce_3_unscaled: 0.5201 (0.5332)  cardinality_error_3_unscaled: 2.0000 (2.1400)  loss_centroid_3_unscaled: 0.0936 (0.0983)  loss_ce_4_unscaled: 0.4801 (0.5190)  cardinality_error_4_unscaled: 2.0000 (2.1400)  loss_centroid_4_unscaled: 0.1220 (0.1344)  time: 2.0811  data: 0.8685  max mem: 5059
# Test: Total time: 0:00:10 (2.1194 s / it)
# [MetricsLogger]: a running average is displayed for lr & class_error, but for the rest of metrics overall average over the epoch is displayed
# Epoch: [2]  [ 0/50]  eta: 0:04:48  lr: 0.000100  class_error: 100.00  loss: 5.4550 (5.4550)  loss_ce: 0.5458 (0.5458)  loss_centroid: 0.3399 (0.3399)  loss_ce_0: 0.5785 (0.5785)  loss_centroid_0: 0.3227 (0.3227)  loss_ce_1: 0.5437 (0.5437)  loss_centroid_1: 0.2501 (0.2501)  loss_ce_2: 0.5607 (0.5607)  loss_centroid_2: 0.3434 (0.3434)  loss_ce_3: 0.6133 (0.6133)  loss_centroid_3: 0.3421 (0.3421)  loss_ce_4: 0.5833 (0.5833)  loss_centroid_4: 0.4314 (0.4314)  loss_ce_unscaled: 0.5458 (0.5458)  class_error_unscaled: 100.0000 (100.0000)  cardinality_error_unscaled: 3.0000 (3.0000)  loss_centroid_unscaled: 0.0680 (0.0680)  loss_ce_0_unscaled: 0.5785 (0.5785)  cardinality_error_0_unscaled: 2.8000 (2.8000)  loss_centroid_0_unscaled: 0.0645 (0.0645)  loss_ce_1_unscaled: 0.5437 (0.5437)  cardinality_error_1_unscaled: 3.0000 (3.0000)  loss_centroid_1_unscaled: 0.0500 (0.0500)  loss_ce_2_unscaled: 0.5607 (0.5607)  cardinality_error_2_unscaled: 3.0000 (3.0000)  loss_centroid_2_unscaled: 0.0687 (0.0687)  loss_ce_3_unscaled: 0.6133 (0.6133)  cardinality_error_3_unscaled: 3.0000 (3.0000)  loss_centroid_3_unscaled: 0.0684 (0.0684)  loss_ce_4_unscaled: 0.5833 (0.5833)  cardinality_error_4_unscaled: 3.0000 (3.0000)  loss_centroid_4_unscaled: 0.0863 (0.0863)  time: 5.7620  data: 5.2799  max mem: 5059
# Epoch: [2]  [10/50]  eta: 0:00:39  lr: 0.000100  class_error: 100.00  loss: 4.8159 (4.9505)  loss_ce: 0.4576 (0.4781)  loss_centroid: 0.3399 (0.3474)  loss_ce_0: 0.5052 (0.5261)  loss_centroid_0: 0.3188 (0.3238)  loss_ce_1: 0.4905 (0.4950)  loss_centroid_1: 0.3043 (0.3018)  loss_ce_2: 0.4630 (0.4954)  loss_centroid_2: 0.2899 (0.3157)  loss_ce_3: 0.4702 (0.5130)  loss_centroid_3: 0.2980 (0.3200)  loss_ce_4: 0.4821 (0.4912)  loss_centroid_4: 0.3081 (0.3429)  loss_ce_unscaled: 0.4576 (0.4781)  class_error_unscaled: 100.0000 (100.0000)  cardinality_error_unscaled: 2.3000 (2.3818)  loss_centroid_unscaled: 0.0680 (0.0695)  loss_ce_0_unscaled: 0.5052 (0.5261)  cardinality_error_0_unscaled: 2.3000 (2.3455)  loss_centroid_0_unscaled: 0.0638 (0.0648)  loss_ce_1_unscaled: 0.4905 (0.4950)  cardinality_error_1_unscaled: 2.3000 (2.3818)  loss_centroid_1_unscaled: 0.0609 (0.0604)  loss_ce_2_unscaled: 0.4630 (0.4954)  cardinality_error_2_unscaled: 2.3000 (2.3818)  loss_centroid_2_unscaled: 0.0580 (0.0631)  loss_ce_3_unscaled: 0.4702 (0.5130)  cardinality_error_3_unscaled: 2.3000 (2.3818)  loss_centroid_3_unscaled: 0.0596 (0.0640)  loss_ce_4_unscaled: 0.4821 (0.4912)  cardinality_error_4_unscaled: 2.3000 (2.3818)  loss_centroid_4_unscaled: 0.0616 (0.0686)  time: 0.9988  data: 0.5169  max mem: 5059
# Epoch: [2]  [20/50]  eta: 0:00:23  lr: 0.000100  class_error: 100.00  loss: 4.5034 (4.7444)  loss_ce: 0.4500 (0.4605)  loss_centroid: 0.3035 (0.3208)  loss_ce_0: 0.5018 (0.5142)  loss_centroid_0: 0.3188 (0.3265)  loss_ce_1: 0.4673 (0.4787)  loss_centroid_1: 0.3164 (0.3136)  loss_ce_2: 0.4533 (0.4724)  loss_centroid_2: 0.2899 (0.2989)  loss_ce_3: 0.4633 (0.4809)  loss_centroid_3: 0.2869 (0.3034)  loss_ce_4: 0.4439 (0.4674)  loss_centroid_4: 0.2950 (0.3072)  loss_ce_unscaled: 0.4500 (0.4605)  class_error_unscaled: 100.0000 (100.0000)  cardinality_error_unscaled: 2.1000 (2.2286)  loss_centroid_unscaled: 0.0607 (0.0642)  loss_ce_0_unscaled: 0.5018 (0.5142)  cardinality_error_0_unscaled: 2.0000 (2.1857)  loss_centroid_0_unscaled: 0.0638 (0.0653)  loss_ce_1_unscaled: 0.4673 (0.4787)  cardinality_error_1_unscaled: 2.1000 (2.2286)  loss_centroid_1_unscaled: 0.0633 (0.0627)  loss_ce_2_unscaled: 0.4533 (0.4724)  cardinality_error_2_unscaled: 2.1000 (2.2286)  loss_centroid_2_unscaled: 0.0580 (0.0598)  loss_ce_3_unscaled: 0.4633 (0.4809)  cardinality_error_3_unscaled: 2.1000 (2.2286)  loss_centroid_3_unscaled: 0.0574 (0.0607)  loss_ce_4_unscaled: 0.4439 (0.4674)  cardinality_error_4_unscaled: 2.1000 (2.2286)  loss_centroid_4_unscaled: 0.0590 (0.0614)  time: 0.7729  data: 0.3094  max mem: 5059
# Epoch: [2]  [30/50]  eta: 0:00:13  lr: 0.000100  class_error: 100.00  loss: 4.4898 (4.6306)  loss_ce: 0.4433 (0.4496)  loss_centroid: 0.2880 (0.2985)  loss_ce_0: 0.4993 (0.5037)  loss_centroid_0: 0.3188 (0.3216)  loss_ce_1: 0.4598 (0.4662)  loss_centroid_1: 0.3124 (0.3171)  loss_ce_2: 0.4459 (0.4584)  loss_centroid_2: 0.2942 (0.3045)  loss_ce_3: 0.4557 (0.4628)  loss_centroid_3: 0.2830 (0.2957)  loss_ce_4: 0.4427 (0.4554)  loss_centroid_4: 0.2863 (0.2973)  loss_ce_unscaled: 0.4433 (0.4496)  class_error_unscaled: 100.0000 (100.0000)  cardinality_error_unscaled: 2.0000 (2.1097)  loss_centroid_unscaled: 0.0576 (0.0597)  loss_ce_0_unscaled: 0.4993 (0.5037)  cardinality_error_0_unscaled: 2.0000 (2.0806)  loss_centroid_0_unscaled: 0.0638 (0.0643)  loss_ce_1_unscaled: 0.4598 (0.4662)  cardinality_error_1_unscaled: 2.0000 (2.1097)  loss_centroid_1_unscaled: 0.0625 (0.0634)  loss_ce_2_unscaled: 0.4459 (0.4584)  cardinality_error_2_unscaled: 2.0000 (2.1097)  loss_centroid_2_unscaled: 0.0588 (0.0609)  loss_ce_3_unscaled: 0.4557 (0.4628)  cardinality_error_3_unscaled: 2.0000 (2.1097)  loss_centroid_3_unscaled: 0.0566 (0.0591)  loss_ce_4_unscaled: 0.4427 (0.4554)  cardinality_error_4_unscaled: 2.0000 (2.1097)  loss_centroid_4_unscaled: 0.0573 (0.0595)  time: 0.6816  data: 0.2254  max mem: 5059
# Epoch: [2]  [40/50]  eta: 0:00:06  lr: 0.000100  class_error: 100.00  loss: 4.6355 (4.6828)  loss_ce: 0.4561 (0.4597)  loss_centroid: 0.2825 (0.3036)  loss_ce_0: 0.5018 (0.5109)  loss_centroid_0: 0.3188 (0.3227)  loss_ce_1: 0.4638 (0.4751)  loss_centroid_1: 0.3043 (0.3039)  loss_ce_2: 0.4533 (0.4698)  loss_centroid_2: 0.2937 (0.3008)  loss_ce_3: 0.4631 (0.4648)  loss_centroid_3: 0.2983 (0.3145)  loss_ce_4: 0.4441 (0.4610)  loss_centroid_4: 0.2862 (0.2961)  loss_ce_unscaled: 0.4561 (0.4597)  class_error_unscaled: 100.0000 (100.0000)  cardinality_error_unscaled: 2.1000 (2.1976)  loss_centroid_unscaled: 0.0565 (0.0607)  loss_ce_0_unscaled: 0.5018 (0.5109)  cardinality_error_0_unscaled: 2.0000 (2.1732)  loss_centroid_0_unscaled: 0.0638 (0.0645)  loss_ce_1_unscaled: 0.4638 (0.4751)  cardinality_error_1_unscaled: 2.1000 (2.1976)  loss_centroid_1_unscaled: 0.0609 (0.0608)  loss_ce_2_unscaled: 0.4533 (0.4698)  cardinality_error_2_unscaled: 2.1000 (2.1976)  loss_centroid_2_unscaled: 0.0587 (0.0602)  loss_ce_3_unscaled: 0.4631 (0.4648)  cardinality_error_3_unscaled: 2.1000 (2.1976)  loss_centroid_3_unscaled: 0.0597 (0.0629)  loss_ce_4_unscaled: 0.4441 (0.4610)  cardinality_error_4_unscaled: 2.1000 (2.1976)  loss_centroid_4_unscaled: 0.0572 (0.0592)  time: 0.6320  data: 0.1831  max mem: 5059
# Epoch: [2]  [49/50]  eta: 0:00:00  lr: 0.000100  class_error: 100.00  loss: 4.4902 (4.6518)  loss_ce: 0.4502 (0.4566)  loss_centroid: 0.2825 (0.3023)  loss_ce_0: 0.4993 (0.5048)  loss_centroid_0: 0.3188 (0.3242)  loss_ce_1: 0.4598 (0.4725)  loss_centroid_1: 0.3013 (0.2996)  loss_ce_2: 0.4532 (0.4680)  loss_centroid_2: 0.2937 (0.2992)  loss_ce_3: 0.4557 (0.4623)  loss_centroid_3: 0.2869 (0.3049)  loss_ce_4: 0.4440 (0.4593)  loss_centroid_4: 0.2894 (0.2981)  loss_ce_unscaled: 0.4502 (0.4566)  class_error_unscaled: 100.0000 (100.0000)  cardinality_error_unscaled: 2.0000 (2.1660)  loss_centroid_unscaled: 0.0565 (0.0605)  loss_ce_0_unscaled: 0.4993 (0.5048)  cardinality_error_0_unscaled: 2.0000 (2.1440)  loss_centroid_0_unscaled: 0.0638 (0.0648)  loss_ce_1_unscaled: 0.4598 (0.4725)  cardinality_error_1_unscaled: 2.0000 (2.1660)  loss_centroid_1_unscaled: 0.0603 (0.0599)  loss_ce_2_unscaled: 0.4532 (0.4680)  cardinality_error_2_unscaled: 2.0000 (2.1660)  loss_centroid_2_unscaled: 0.0587 (0.0598)  loss_ce_3_unscaled: 0.4557 (0.4623)  cardinality_error_3_unscaled: 2.0000 (2.1660)  loss_centroid_3_unscaled: 0.0574 (0.0610)  loss_ce_4_unscaled: 0.4440 (0.4593)  cardinality_error_4_unscaled: 2.0000 (2.1660)  loss_centroid_4_unscaled: 0.0579 (0.0596)  time: 0.6018  data: 0.1547  max mem: 5059
# Epoch: [2] Total time: 0:00:30 (0.6072 s / it)
# SAVED
# SAVED
# Test:  [0/5]  eta: 0:00:17  class_error: 100.00  loss: 8.8411 (8.8411)  loss_ce: 0.5195 (0.5195)  loss_centroid: 0.7451 (0.7451)  loss_ce_0: 0.6183 (0.6183)  loss_centroid_0: 1.0064 (1.0064)  loss_ce_1: 0.5668 (0.5668)  loss_centroid_1: 1.4594 (1.4594)  loss_ce_2: 0.5260 (0.5260)  loss_centroid_2: 0.8995 (0.8995)  loss_ce_3: 0.5284 (0.5284)  loss_centroid_3: 0.6760 (0.6760)  loss_ce_4: 0.5398 (0.5398)  loss_centroid_4: 0.7558 (0.7558)  loss_ce_unscaled: 0.5195 (0.5195)  class_error_unscaled: 100.0000 (100.0000)  cardinality_error_unscaled: 3.1000 (3.1000)  loss_centroid_unscaled: 0.1490 (0.1490)  loss_ce_0_unscaled: 0.6183 (0.6183)  cardinality_error_0_unscaled: 3.1000 (3.1000)  loss_centroid_0_unscaled: 0.2013 (0.2013)  loss_ce_1_unscaled: 0.5668 (0.5668)  cardinality_error_1_unscaled: 3.1000 (3.1000)  loss_centroid_1_unscaled: 0.2919 (0.2919)  loss_ce_2_unscaled: 0.5260 (0.5260)  cardinality_error_2_unscaled: 3.1000 (3.1000)  loss_centroid_2_unscaled: 0.1799 (0.1799)  loss_ce_3_unscaled: 0.5284 (0.5284)  cardinality_error_3_unscaled: 3.1000 (3.1000)  loss_centroid_3_unscaled: 0.1352 (0.1352)  loss_ce_4_unscaled: 0.5398 (0.5398)  cardinality_error_4_unscaled: 3.1000 (3.1000)  loss_centroid_4_unscaled: 0.1512 (0.1512)  time: 3.5394  data: 2.5926  max mem: 5059
# Test:  [4/5]  eta: 0:00:01  class_error: 100.00  loss: 5.5221 (6.0604)  loss_ce: 0.4390 (0.4402)  loss_centroid: 0.4521 (0.4742)  loss_ce_0: 0.5014 (0.5276)  loss_centroid_0: 0.6483 (0.6935)  loss_ce_1: 0.4774 (0.4818)  loss_centroid_1: 0.5657 (0.7403)  loss_ce_2: 0.4273 (0.4385)  loss_centroid_2: 0.3621 (0.5078)  loss_ce_3: 0.4563 (0.4457)  loss_centroid_3: 0.3650 (0.4207)  loss_ce_4: 0.4366 (0.4513)  loss_centroid_4: 0.3770 (0.4387)  loss_ce_unscaled: 0.4390 (0.4402)  class_error_unscaled: 100.0000 (100.0000)  cardinality_error_unscaled: 2.0000 (2.1400)  loss_centroid_unscaled: 0.0904 (0.0948)  loss_ce_0_unscaled: 0.5014 (0.5276)  cardinality_error_0_unscaled: 1.9000 (2.0600)  loss_centroid_0_unscaled: 0.1297 (0.1387)  loss_ce_1_unscaled: 0.4774 (0.4818)  cardinality_error_1_unscaled: 2.0000 (2.1400)  loss_centroid_1_unscaled: 0.1131 (0.1481)  loss_ce_2_unscaled: 0.4273 (0.4385)  cardinality_error_2_unscaled: 2.0000 (2.1400)  loss_centroid_2_unscaled: 0.0724 (0.1016)  loss_ce_3_unscaled: 0.4563 (0.4457)  cardinality_error_3_unscaled: 2.0000 (2.1400)  loss_centroid_3_unscaled: 0.0730 (0.0841)  loss_ce_4_unscaled: 0.4366 (0.4513)  cardinality_error_4_unscaled: 2.0000 (2.1400)  loss_centroid_4_unscaled: 0.0754 (0.0877)  time: 1.7279  data: 0.5434  max mem: 5059
# Test: Total time: 0:00:08 (1.7621 s / it)
# [MetricsLogger]: a running average is displayed for lr & class_error, but for the rest of metrics overall average over the epoch is displayed
# Epoch: [3]  [ 0/50]  eta: 0:07:04  lr: 0.000100  class_error: 100.00  loss: 4.9660 (4.9660)  loss_ce: 0.5312 (0.5312)  loss_centroid: 0.3212 (0.3212)  loss_ce_0: 0.5264 (0.5264)  loss_centroid_0: 0.1891 (0.1891)  loss_ce_1: 0.5299 (0.5299)  loss_centroid_1: 0.2421 (0.2421)  loss_ce_2: 0.5418 (0.5418)  loss_centroid_2: 0.4104 (0.4104)  loss_ce_3: 0.5308 (0.5308)  loss_centroid_3: 0.3029 (0.3029)  loss_ce_4: 0.5644 (0.5644)  loss_centroid_4: 0.2759 (0.2759)  loss_ce_unscaled: 0.5312 (0.5312)  class_error_unscaled: 100.0000 (100.0000)  cardinality_error_unscaled: 2.8000 (2.8000)  loss_centroid_unscaled: 0.0642 (0.0642)  loss_ce_0_unscaled: 0.5264 (0.5264)  cardinality_error_0_unscaled: 2.8000 (2.8000)  loss_centroid_0_unscaled: 0.0378 (0.0378)  loss_ce_1_unscaled: 0.5299 (0.5299)  cardinality_error_1_unscaled: 2.8000 (2.8000)  loss_centroid_1_unscaled: 0.0484 (0.0484)  loss_ce_2_unscaled: 0.5418 (0.5418)  cardinality_error_2_unscaled: 2.8000 (2.8000)  loss_centroid_2_unscaled: 0.0821 (0.0821)  loss_ce_3_unscaled: 0.5308 (0.5308)  cardinality_error_3_unscaled: 2.8000 (2.8000)  loss_centroid_3_unscaled: 0.0606 (0.0606)  loss_ce_4_unscaled: 0.5644 (0.5644)  cardinality_error_4_unscaled: 2.8000 (2.8000)  loss_centroid_4_unscaled: 0.0552 (0.0552)  time: 8.4805  data: 7.1029  max mem: 5059
# Epoch: [3]  [10/50]  eta: 0:00:48  lr: 0.000100  class_error: 100.00  loss: 4.3985 (4.5023)  loss_ce: 0.4145 (0.4342)  loss_centroid: 0.3292 (0.3305)  loss_ce_0: 0.4443 (0.4626)  loss_centroid_0: 0.2913 (0.2929)  loss_ce_1: 0.4315 (0.4474)  loss_centroid_1: 0.2674 (0.2840)  loss_ce_2: 0.4297 (0.4448)  loss_centroid_2: 0.3398 (0.3520)  loss_ce_3: 0.4025 (0.4299)  loss_centroid_3: 0.3029 (0.2927)  loss_ce_4: 0.4133 (0.4388)  loss_centroid_4: 0.2793 (0.2926)  loss_ce_unscaled: 0.4145 (0.4342)  class_error_unscaled: 100.0000 (100.0000)  cardinality_error_unscaled: 1.9000 (2.0182)  loss_centroid_unscaled: 0.0658 (0.0661)  loss_ce_0_unscaled: 0.4443 (0.4626)  cardinality_error_0_unscaled: 1.9000 (2.0000)  loss_centroid_0_unscaled: 0.0583 (0.0586)  loss_ce_1_unscaled: 0.4315 (0.4474)  cardinality_error_1_unscaled: 1.9000 (2.0091)  loss_centroid_1_unscaled: 0.0535 (0.0568)  loss_ce_2_unscaled: 0.4297 (0.4448)  cardinality_error_2_unscaled: 1.9000 (2.0091)  loss_centroid_2_unscaled: 0.0680 (0.0704)  loss_ce_3_unscaled: 0.4025 (0.4299)  cardinality_error_3_unscaled: 1.9000 (2.0182)  loss_centroid_3_unscaled: 0.0606 (0.0585)  loss_ce_4_unscaled: 0.4133 (0.4388)  cardinality_error_4_unscaled: 1.9000 (2.0182)  loss_centroid_4_unscaled: 0.0559 (0.0585)  time: 1.2222  data: 0.6849  max mem: 5059
# Epoch: [3]  [20/50]  eta: 0:00:26  lr: 0.000100  class_error: 100.00  loss: 4.5538 (4.5098)  loss_ce: 0.4525 (0.4439)  loss_centroid: 0.3212 (0.3097)  loss_ce_0: 0.4705 (0.4662)  loss_centroid_0: 0.3013 (0.3125)  loss_ce_1: 0.4581 (0.4633)  loss_centroid_1: 0.2587 (0.2849)  loss_ce_2: 0.4569 (0.4550)  loss_centroid_2: 0.2939 (0.3083)  loss_ce_3: 0.4368 (0.4445)  loss_centroid_3: 0.2752 (0.2874)  loss_ce_4: 0.4551 (0.4486)  loss_centroid_4: 0.2759 (0.2856)  loss_ce_unscaled: 0.4525 (0.4439)  class_error_unscaled: 100.0000 (100.0000)  cardinality_error_unscaled: 2.1000 (2.1429)  loss_centroid_unscaled: 0.0642 (0.0619)  loss_ce_0_unscaled: 0.4705 (0.4662)  cardinality_error_0_unscaled: 2.1000 (2.1286)  loss_centroid_0_unscaled: 0.0603 (0.0625)  loss_ce_1_unscaled: 0.4581 (0.4633)  cardinality_error_1_unscaled: 2.1000 (2.1381)  loss_centroid_1_unscaled: 0.0517 (0.0570)  loss_ce_2_unscaled: 0.4569 (0.4550)  cardinality_error_2_unscaled: 2.1000 (2.1381)  loss_centroid_2_unscaled: 0.0588 (0.0617)  loss_ce_3_unscaled: 0.4368 (0.4445)  cardinality_error_3_unscaled: 2.1000 (2.1429)  loss_centroid_3_unscaled: 0.0550 (0.0575)  loss_ce_4_unscaled: 0.4551 (0.4486)  cardinality_error_4_unscaled: 2.1000 (2.1429)  loss_centroid_4_unscaled: 0.0552 (0.0571)  time: 0.8677  data: 0.3838  max mem: 5059
# Epoch: [3]  [30/50]  eta: 0:00:14  lr: 0.000100  class_error: 100.00  loss: 4.5156 (4.4819)  loss_ce: 0.4578 (0.4480)  loss_centroid: 0.3155 (0.3059)  loss_ce_0: 0.4644 (0.4643)  loss_centroid_0: 0.3081 (0.3213)  loss_ce_1: 0.4457 (0.4581)  loss_centroid_1: 0.2680 (0.2851)  loss_ce_2: 0.4450 (0.4528)  loss_centroid_2: 0.2779 (0.2936)  loss_ce_3: 0.4369 (0.4428)  loss_centroid_3: 0.2855 (0.2857)  loss_ce_4: 0.4440 (0.4454)  loss_centroid_4: 0.2759 (0.2790)  loss_ce_unscaled: 0.4578 (0.4480)  class_error_unscaled: 100.0000 (100.0000)  cardinality_error_unscaled: 2.0000 (2.1516)  loss_centroid_unscaled: 0.0631 (0.0612)  loss_ce_0_unscaled: 0.4644 (0.4643)  cardinality_error_0_unscaled: 2.0000 (2.1355)  loss_centroid_0_unscaled: 0.0616 (0.0643)  loss_ce_1_unscaled: 0.4457 (0.4581)  cardinality_error_1_unscaled: 2.0000 (2.1484)  loss_centroid_1_unscaled: 0.0536 (0.0570)  loss_ce_2_unscaled: 0.4450 (0.4528)  cardinality_error_2_unscaled: 2.0000 (2.1484)  loss_centroid_2_unscaled: 0.0556 (0.0587)  loss_ce_3_unscaled: 0.4369 (0.4428)  cardinality_error_3_unscaled: 2.0000 (2.1516)  loss_centroid_3_unscaled: 0.0571 (0.0571)  loss_ce_4_unscaled: 0.4440 (0.4454)  cardinality_error_4_unscaled: 2.0000 (2.1516)  loss_centroid_4_unscaled: 0.0552 (0.0558)  time: 0.7453  data: 0.2803  max mem: 5059
# Epoch: [3]  [40/50]  eta: 0:00:06  lr: 0.000100  class_error: 100.00  loss: 4.5538 (4.5125)  loss_ce: 0.4570 (0.4524)  loss_centroid: 0.3108 (0.3062)  loss_ce_0: 0.4632 (0.4650)  loss_centroid_0: 0.3057 (0.3196)  loss_ce_1: 0.4586 (0.4614)  loss_centroid_1: 0.2798 (0.2866)  loss_ce_2: 0.4498 (0.4595)  loss_centroid_2: 0.2680 (0.2886)  loss_ce_3: 0.4502 (0.4501)  loss_centroid_3: 0.2813 (0.2817)  loss_ce_4: 0.4454 (0.4481)  loss_centroid_4: 0.2858 (0.2933)  loss_ce_unscaled: 0.4570 (0.4524)  class_error_unscaled: 100.0000 (100.0000)  cardinality_error_unscaled: 2.0000 (2.1634)  loss_centroid_unscaled: 0.0622 (0.0612)  loss_ce_0_unscaled: 0.4632 (0.4650)  cardinality_error_0_unscaled: 2.0000 (2.1463)  loss_centroid_0_unscaled: 0.0611 (0.0639)  loss_ce_1_unscaled: 0.4586 (0.4614)  cardinality_error_1_unscaled: 2.0000 (2.1610)  loss_centroid_1_unscaled: 0.0560 (0.0573)  loss_ce_2_unscaled: 0.4498 (0.4595)  cardinality_error_2_unscaled: 2.0000 (2.1585)  loss_centroid_2_unscaled: 0.0536 (0.0577)  loss_ce_3_unscaled: 0.4502 (0.4501)  cardinality_error_3_unscaled: 2.0000 (2.1634)  loss_centroid_3_unscaled: 0.0563 (0.0563)  loss_ce_4_unscaled: 0.4454 (0.4481)  cardinality_error_4_unscaled: 2.0000 (2.1634)  loss_centroid_4_unscaled: 0.0572 (0.0587)  time: 0.6780  data: 0.2203  max mem: 5059
# Epoch: [3]  [49/50]  eta: 0:00:00  lr: 0.000100  class_error: 100.00  loss: 4.5620 (4.5539)  loss_ce: 0.4525 (0.4529)  loss_centroid: 0.3127 (0.3085)  loss_ce_0: 0.4632 (0.4648)  loss_centroid_0: 0.3066 (0.3201)  loss_ce_1: 0.4586 (0.4617)  loss_centroid_1: 0.2826 (0.2943)  loss_ce_2: 0.4491 (0.4615)  loss_centroid_2: 0.2680 (0.2872)  loss_ce_3: 0.4502 (0.4534)  loss_centroid_3: 0.2844 (0.2899)  loss_ce_4: 0.4454 (0.4482)  loss_centroid_4: 0.2894 (0.3114)  loss_ce_unscaled: 0.4525 (0.4529)  class_error_unscaled: 100.0000 (100.0000)  cardinality_error_unscaled: 2.0000 (2.1660)  loss_centroid_unscaled: 0.0625 (0.0617)  loss_ce_0_unscaled: 0.4632 (0.4648)  cardinality_error_0_unscaled: 2.0000 (2.1520)  loss_centroid_0_unscaled: 0.0613 (0.0640)  loss_ce_1_unscaled: 0.4586 (0.4617)  cardinality_error_1_unscaled: 2.0000 (2.1640)  loss_centroid_1_unscaled: 0.0565 (0.0589)  loss_ce_2_unscaled: 0.4491 (0.4615)  cardinality_error_2_unscaled: 2.0000 (2.1580)  loss_centroid_2_unscaled: 0.0536 (0.0574)  loss_ce_3_unscaled: 0.4502 (0.4534)  cardinality_error_3_unscaled: 2.0000 (2.1660)  loss_centroid_3_unscaled: 0.0569 (0.0580)  loss_ce_4_unscaled: 0.4454 (0.4482)  cardinality_error_4_unscaled: 2.0000 (2.1660)  loss_centroid_4_unscaled: 0.0579 (0.0623)  time: 0.6363  data: 0.1887  max mem: 5059
# Epoch: [3] Total time: 0:00:31 (0.6399 s / it)
# SAVED
# SAVED
# Test:  [0/5]  eta: 0:00:17  class_error: 100.00  loss: 7.4500 (7.4500)  loss_ce: 0.5002 (0.5002)  loss_centroid: 0.4247 (0.4247)  loss_ce_0: 0.5746 (0.5746)  loss_centroid_0: 0.7687 (0.7687)  loss_ce_1: 0.5781 (0.5781)  loss_centroid_1: 0.7992 (0.7992)  loss_ce_2: 0.5560 (0.5560)  loss_centroid_2: 0.9157 (0.9157)  loss_ce_3: 0.5267 (0.5267)  loss_centroid_3: 0.5654 (0.5654)  loss_ce_4: 0.5277 (0.5277)  loss_centroid_4: 0.7129 (0.7129)  loss_ce_unscaled: 0.5002 (0.5002)  class_error_unscaled: 100.0000 (100.0000)  cardinality_error_unscaled: 3.1000 (3.1000)  loss_centroid_unscaled: 0.0849 (0.0849)  loss_ce_0_unscaled: 0.5746 (0.5746)  cardinality_error_0_unscaled: 3.1000 (3.1000)  loss_centroid_0_unscaled: 0.1537 (0.1537)  loss_ce_1_unscaled: 0.5781 (0.5781)  cardinality_error_1_unscaled: 3.1000 (3.1000)  loss_centroid_1_unscaled: 0.1598 (0.1598)  loss_ce_2_unscaled: 0.5560 (0.5560)  cardinality_error_2_unscaled: 3.1000 (3.1000)  loss_centroid_2_unscaled: 0.1831 (0.1831)  loss_ce_3_unscaled: 0.5267 (0.5267)  cardinality_error_3_unscaled: 3.1000 (3.1000)  loss_centroid_3_unscaled: 0.1131 (0.1131)  loss_ce_4_unscaled: 0.5277 (0.5277)  cardinality_error_4_unscaled: 3.1000 (3.1000)  loss_centroid_4_unscaled: 0.1426 (0.1426)  time: 3.5484  data: 2.5976  max mem: 5059
# Test:  [4/5]  eta: 0:00:01  class_error: 100.00  loss: 5.1836 (5.7202)  loss_ce: 0.4484 (0.4500)  loss_centroid: 0.3528 (0.3644)  loss_ce_0: 0.4891 (0.4926)  loss_centroid_0: 0.4445 (0.5236)  loss_ce_1: 0.5065 (0.5071)  loss_centroid_1: 0.5174 (0.6112)  loss_ce_2: 0.4808 (0.4853)  loss_centroid_2: 0.4904 (0.5592)  loss_ce_3: 0.4238 (0.4454)  loss_centroid_3: 0.2767 (0.3405)  loss_ce_4: 0.4766 (0.4749)  loss_centroid_4: 0.3772 (0.4661)  loss_ce_unscaled: 0.4484 (0.4500)  class_error_unscaled: 100.0000 (100.0000)  cardinality_error_unscaled: 2.0000 (2.1400)  loss_centroid_unscaled: 0.0706 (0.0729)  loss_ce_0_unscaled: 0.4891 (0.4926)  cardinality_error_0_unscaled: 2.0000 (2.1200)  loss_centroid_0_unscaled: 0.0889 (0.1047)  loss_ce_1_unscaled: 0.5065 (0.5071)  cardinality_error_1_unscaled: 2.0000 (2.1400)  loss_centroid_1_unscaled: 0.1035 (0.1222)  loss_ce_2_unscaled: 0.4808 (0.4853)  cardinality_error_2_unscaled: 2.0000 (2.1400)  loss_centroid_2_unscaled: 0.0981 (0.1118)  loss_ce_3_unscaled: 0.4238 (0.4454)  cardinality_error_3_unscaled: 2.0000 (2.1400)  loss_centroid_3_unscaled: 0.0553 (0.0681)  loss_ce_4_unscaled: 0.4766 (0.4749)  cardinality_error_4_unscaled: 2.0000 (2.1400)  loss_centroid_4_unscaled: 0.0754 (0.0932)  time: 1.7809  data: 0.5595  max mem: 5060
# Test: Total time: 0:00:09 (1.8319 s / it)
# [MetricsLogger]: a running average is displayed for lr & class_error, but for the rest of metrics overall average over the epoch is displayed
# Epoch: [4]  [ 0/50]  eta: 0:04:48  lr: 0.000100  class_error: 100.00  loss: 4.6536 (4.6536)  loss_ce: 0.4147 (0.4147)  loss_centroid: 0.3855 (0.3855)  loss_ce_0: 0.3983 (0.3983)  loss_centroid_0: 0.3282 (0.3282)  loss_ce_1: 0.3931 (0.3931)  loss_centroid_1: 0.2628 (0.2628)  loss_ce_2: 0.4168 (0.4168)  loss_centroid_2: 0.3772 (0.3772)  loss_ce_3: 0.4033 (0.4033)  loss_centroid_3: 0.5468 (0.5468)  loss_ce_4: 0.4006 (0.4006)  loss_centroid_4: 0.3262 (0.3262)  loss_ce_unscaled: 0.4147 (0.4147)  class_error_unscaled: 100.0000 (100.0000)  cardinality_error_unscaled: 1.5000 (1.5000)  loss_centroid_unscaled: 0.0771 (0.0771)  loss_ce_0_unscaled: 0.3983 (0.3983)  cardinality_error_0_unscaled: 1.5000 (1.5000)  loss_centroid_0_unscaled: 0.0656 (0.0656)  loss_ce_1_unscaled: 0.3931 (0.3931)  cardinality_error_1_unscaled: 1.5000 (1.5000)  loss_centroid_1_unscaled: 0.0526 (0.0526)  loss_ce_2_unscaled: 0.4168 (0.4168)  cardinality_error_2_unscaled: 1.5000 (1.5000)  loss_centroid_2_unscaled: 0.0754 (0.0754)  loss_ce_3_unscaled: 0.4033 (0.4033)  cardinality_error_3_unscaled: 1.5000 (1.5000)  loss_centroid_3_unscaled: 0.1094 (0.1094)  loss_ce_4_unscaled: 0.4006 (0.4006)  cardinality_error_4_unscaled: 1.5000 (1.5000)  loss_centroid_4_unscaled: 0.0652 (0.0652)  time: 5.7766  data: 4.4839  max mem: 5060
# ...
# Epoch: [18]  [40/50]  eta: 0:00:06  lr: 0.000100  class_error: 40.74  loss: 3.8855 (3.8464)  loss_ce: 0.2708 (0.2695)  loss_centroid: 0.3379 (0.3324)  loss_ce_0: 0.3155 (0.3271)  loss_centroid_0: 0.3471 (0.3588)  loss_ce_1: 0.3017 (0.3097)  loss_centroid_1: 0.3295 (0.3413)  loss_ce_2: 0.2814 (0.2844)  loss_centroid_2: 0.3618 (0.3634)  loss_ce_3: 0.2782 (0.2898)  loss_centroid_3: 0.3525 (0.3594)  loss_ce_4: 0.2778 (0.2740)  loss_centroid_4: 0.3411 (0.3366)  loss_ce_unscaled: 0.2708 (0.2695)  class_error_unscaled: 40.0000 (38.9969)  cardinality_error_unscaled: 4.5000 (4.5976)  loss_centroid_unscaled: 0.0676 (0.0665)  loss_ce_0_unscaled: 0.3155 (0.3271)  cardinality_error_0_unscaled: 3.2000 (3.4780)  loss_centroid_0_unscaled: 0.0694 (0.0718)  loss_ce_1_unscaled: 0.3017 (0.3097)  cardinality_error_1_unscaled: 3.6000 (3.8634)  loss_centroid_1_unscaled: 0.0659 (0.0683)  loss_ce_2_unscaled: 0.2814 (0.2844)  cardinality_error_2_unscaled: 4.8000 (4.8585)  loss_centroid_2_unscaled: 0.0724 (0.0727)  loss_ce_3_unscaled: 0.2782 (0.2898)  cardinality_error_3_unscaled: 4.1000 (4.3756)  loss_centroid_3_unscaled: 0.0705 (0.0719)  loss_ce_4_unscaled: 0.2778 (0.2740)  cardinality_error_4_unscaled: 4.2000 (4.4171)  loss_centroid_4_unscaled: 0.0682 (0.0673)  time: 0.6257  data: 0.1613  max mem: 5061
# Epoch: [18]  [49/50]  eta: 0:00:00  lr: 0.000100  class_error: 45.00  loss: 3.8456 (3.8350)  loss_ce: 0.2664 (0.2652)  loss_centroid: 0.3418 (0.3374)  loss_ce_0: 0.3272 (0.3278)  loss_centroid_0: 0.3408 (0.3533)  loss_ce_1: 0.2982 (0.3074)  loss_centroid_1: 0.3295 (0.3409)  loss_ce_2: 0.2798 (0.2810)  loss_centroid_2: 0.3618 (0.3631)  loss_ce_3: 0.2770 (0.2823)  loss_centroid_3: 0.3665 (0.3675)  loss_ce_4: 0.2725 (0.2690)  loss_centroid_4: 0.3411 (0.3402)  loss_ce_unscaled: 0.2664 (0.2652)  class_error_unscaled: 39.1304 (38.6832)  cardinality_error_unscaled: 4.5000 (4.6360)  loss_centroid_unscaled: 0.0684 (0.0675)  loss_ce_0_unscaled: 0.3272 (0.3278)  cardinality_error_0_unscaled: 3.3000 (3.6580)  loss_centroid_0_unscaled: 0.0682 (0.0707)  loss_ce_1_unscaled: 0.2982 (0.3074)  cardinality_error_1_unscaled: 3.8000 (4.0060)  loss_centroid_1_unscaled: 0.0659 (0.0682)  loss_ce_2_unscaled: 0.2798 (0.2810)  cardinality_error_2_unscaled: 4.8000 (5.0980)  loss_centroid_2_unscaled: 0.0724 (0.0726)  loss_ce_3_unscaled: 0.2770 (0.2823)  cardinality_error_3_unscaled: 4.4000 (4.4900)  loss_centroid_3_unscaled: 0.0733 (0.0735)  loss_ce_4_unscaled: 0.2725 (0.2690)  cardinality_error_4_unscaled: 4.4000 (4.4920)  loss_centroid_4_unscaled: 0.0682 (0.0680)  time: 0.5979  data: 0.1412  max mem: 5061
# Epoch: [18] Total time: 0:00:30 (0.6038 s / it)
# SAVED
# SAVED
# Test:  [0/5]  eta: 0:00:16  class_error: 100.00  loss: 9.2717 (9.2717)  loss_ce: 1.2875 (1.2875)  loss_centroid: 0.4252 (0.4252)  loss_ce_0: 0.8617 (0.8617)  loss_centroid_0: 0.3777 (0.3777)  loss_ce_1: 0.7814 (0.7814)  loss_centroid_1: 0.6623 (0.6623)  loss_ce_2: 0.9110 (0.9110)  loss_centroid_2: 0.6073 (0.6073)  loss_ce_3: 1.1728 (1.1728)  loss_centroid_3: 0.5043 (0.5043)  loss_ce_4: 1.1593 (1.1593)  loss_centroid_4: 0.5213 (0.5213)  loss_ce_unscaled: 1.2875 (1.2875)  class_error_unscaled: 100.0000 (100.0000)  cardinality_error_unscaled: 8.7000 (8.7000)  loss_centroid_unscaled: 0.0850 (0.0850)  loss_ce_0_unscaled: 0.8617 (0.8617)  cardinality_error_0_unscaled: 8.6000 (8.6000)  loss_centroid_0_unscaled: 0.0755 (0.0755)  loss_ce_1_unscaled: 0.7814 (0.7814)  cardinality_error_1_unscaled: 8.4000 (8.4000)  loss_centroid_1_unscaled: 0.1325 (0.1325)  loss_ce_2_unscaled: 0.9110 (0.9110)  cardinality_error_2_unscaled: 9.6000 (9.6000)  loss_centroid_2_unscaled: 0.1215 (0.1215)  loss_ce_3_unscaled: 1.1728 (1.1728)  cardinality_error_3_unscaled: 8.2000 (8.2000)  loss_centroid_3_unscaled: 0.1009 (0.1009)  loss_ce_4_unscaled: 1.1593 (1.1593)  cardinality_error_4_unscaled: 8.1000 (8.1000)  loss_centroid_4_unscaled: 0.1043 (0.1043)  time: 3.3555  data: 2.2999  max mem: 5061
# Test:  [4/5]  eta: 0:00:01  class_error: 100.00  loss: 6.6827 (7.0369)  loss_ce: 0.7769 (0.8830)  loss_centroid: 0.3490 (0.3637)  loss_ce_0: 0.5789 (0.6393)  loss_centroid_0: 0.3777 (0.3613)  loss_ce_1: 0.5475 (0.5834)  loss_centroid_1: 0.4751 (0.5118)  loss_ce_2: 0.6148 (0.6413)  loss_centroid_2: 0.5661 (0.5564)  loss_ce_3: 0.7560 (0.8401)  loss_centroid_3: 0.3428 (0.3893)  loss_ce_4: 0.7519 (0.8348)  loss_centroid_4: 0.4384 (0.4324)  loss_ce_unscaled: 0.7769 (0.8830)  class_error_unscaled: 100.0000 (93.7895)  cardinality_error_unscaled: 4.6000 (4.9200)  loss_centroid_unscaled: 0.0698 (0.0727)  loss_ce_0_unscaled: 0.5789 (0.6393)  cardinality_error_0_unscaled: 4.0000 (4.7200)  loss_centroid_0_unscaled: 0.0755 (0.0723)  loss_ce_1_unscaled: 0.5475 (0.5834)  cardinality_error_1_unscaled: 4.1000 (4.5000)  loss_centroid_1_unscaled: 0.0950 (0.1024)  loss_ce_2_unscaled: 0.6148 (0.6413)  cardinality_error_2_unscaled: 5.3000 (5.8400)  loss_centroid_2_unscaled: 0.1132 (0.1113)  loss_ce_3_unscaled: 0.7560 (0.8401)  cardinality_error_3_unscaled: 4.6000 (4.8000)  loss_centroid_3_unscaled: 0.0686 (0.0779)  loss_ce_4_unscaled: 0.7519 (0.8348)  cardinality_error_4_unscaled: 4.4000 (4.6800)  loss_centroid_4_unscaled: 0.0877 (0.0865)  time: 1.7241  data: 0.5061  max mem: 5061
# Test: Total time: 0:00:08 (1.7574 s / it)
# [MetricsLogger]: a running average is displayed for lr & class_error, but for the rest of metrics overall average over the epoch is displayed
# Epoch: [19]  [ 0/50]  eta: 0:05:11  lr: 0.000100  class_error: 50.00  loss: 3.4390 (3.4390)  loss_ce: 0.2424 (0.2424)  loss_centroid: 0.2964 (0.2964)  loss_ce_0: 0.2970 (0.2970)  loss_centroid_0: 0.2878 (0.2878)  loss_ce_1: 0.2511 (0.2511)  loss_centroid_1: 0.3225 (0.3225)  loss_ce_2: 0.2596 (0.2596)  loss_centroid_2: 0.3429 (0.3429)  loss_ce_3: 0.2272 (0.2272)  loss_centroid_3: 0.4152 (0.4152)  loss_ce_4: 0.2624 (0.2624)  loss_centroid_4: 0.2345 (0.2345)  loss_ce_unscaled: 0.2424 (0.2424)  class_error_unscaled: 50.0000 (50.0000)  cardinality_error_unscaled: 3.3000 (3.3000)  loss_centroid_unscaled: 0.0593 (0.0593)  loss_ce_0_unscaled: 0.2970 (0.2970)  cardinality_error_0_unscaled: 3.2000 (3.2000)  loss_centroid_0_unscaled: 0.0576 (0.0576)  loss_ce_1_unscaled: 0.2511 (0.2511)  cardinality_error_1_unscaled: 3.2000 (3.2000)  loss_centroid_1_unscaled: 0.0645 (0.0645)  loss_ce_2_unscaled: 0.2596 (0.2596)  cardinality_error_2_unscaled: 4.4000 (4.4000)  loss_centroid_2_unscaled: 0.0686 (0.0686)  loss_ce_3_unscaled: 0.2272 (0.2272)  cardinality_error_3_unscaled: 3.7000 (3.7000)  loss_centroid_3_unscaled: 0.0830 (0.0830)  loss_ce_4_unscaled: 0.2624 (0.2624)  cardinality_error_4_unscaled: 3.4000 (3.4000)  loss_centroid_4_unscaled: 0.0469 (0.0469)  time: 6.2376  data: 4.2604  max mem: 5061
# Epoch: [19]  [10/50]  eta: 0:00:46  lr: 0.000100  class_error: 53.85  loss: 3.5468 (3.7699)  loss_ce: 0.2499 (0.2624)  loss_centroid: 0.2999 (0.3399)  loss_ce_0: 0.2812 (0.2984)  loss_centroid_0: 0.3873 (0.3781)  loss_ce_1: 0.3110 (0.3008)  loss_centroid_1: 0.3094 (0.3301)  loss_ce_2: 0.2609 (0.2664)  loss_centroid_2: 0.3429 (0.3468)  loss_ce_3: 0.2552 (0.2711)  loss_centroid_3: 0.3762 (0.3757)  loss_ce_4: 0.2624 (0.2631)  loss_centroid_4: 0.3382 (0.3370)  loss_ce_unscaled: 0.2499 (0.2624)  class_error_unscaled: 50.0000 (48.6770)  cardinality_error_unscaled: 3.1000 (3.2182)  loss_centroid_unscaled: 0.0600 (0.0680)  loss_ce_0_unscaled: 0.2812 (0.2984)  cardinality_error_0_unscaled: 3.2000 (3.0000)  loss_centroid_0_unscaled: 0.0775 (0.0756)  loss_ce_1_unscaled: 0.3110 (0.3008)  cardinality_error_1_unscaled: 3.2000 (3.0000)  loss_centroid_1_unscaled: 0.0619 (0.0660)  loss_ce_2_unscaled: 0.2609 (0.2664)  cardinality_error_2_unscaled: 4.0000 (3.9091)  loss_centroid_2_unscaled: 0.0686 (0.0694)  loss_ce_3_unscaled: 0.2552 (0.2711)  cardinality_error_3_unscaled: 2.8000 (3.1273)  loss_centroid_3_unscaled: 0.0752 (0.0751)  loss_ce_4_unscaled: 0.2624 (0.2631)  cardinality_error_4_unscaled: 2.8000 (3.0545)  loss_centroid_4_unscaled: 0.0676 (0.0674)  time: 1.1643  data: 0.4953  max mem: 5061
# Epoch: [19]  [20/50]  eta: 0:00:25  lr: 0.000100  class_error: 33.33  loss: 3.5468 (3.7056)  loss_ce: 0.2490 (0.2490)  loss_centroid: 0.3453 (0.3460)  loss_ce_0: 0.2775 (0.2876)  loss_centroid_0: 0.3703 (0.3613)  loss_ce_1: 0.2965 (0.2848)  loss_centroid_1: 0.3290 (0.3399)  loss_ce_2: 0.2585 (0.2557)  loss_centroid_2: 0.3458 (0.3520)  loss_ce_3: 0.2470 (0.2515)  loss_centroid_3: 0.3726 (0.3799)  loss_ce_4: 0.2353 (0.2466)  loss_centroid_4: 0.3571 (0.3514)  loss_ce_unscaled: 0.2490 (0.2490)  class_error_unscaled: 46.6667 (44.6311)  cardinality_error_unscaled: 3.3000 (3.6571)  loss_centroid_unscaled: 0.0691 (0.0692)  loss_ce_0_unscaled: 0.2775 (0.2876)  cardinality_error_0_unscaled: 3.1000 (3.1095)  loss_centroid_0_unscaled: 0.0741 (0.0723)  loss_ce_1_unscaled: 0.2965 (0.2848)  cardinality_error_1_unscaled: 3.1000 (3.0905)  loss_centroid_1_unscaled: 0.0658 (0.0680)  loss_ce_2_unscaled: 0.2585 (0.2557)  cardinality_error_2_unscaled: 4.2000 (4.1810)  loss_centroid_2_unscaled: 0.0692 (0.0704)  loss_ce_3_unscaled: 0.2470 (0.2515)  cardinality_error_3_unscaled: 3.1000 (3.4429)  loss_centroid_3_unscaled: 0.0745 (0.0760)  loss_ce_4_unscaled: 0.2353 (0.2466)  cardinality_error_4_unscaled: 3.4000 (3.4714)  loss_centroid_4_unscaled: 0.0714 (0.0703)  time: 0.8372  data: 0.2855  max mem: 5061
# Epoch: [19]  [30/50]  eta: 0:00:14  lr: 0.000100  class_error: 33.33  loss: 3.6674 (3.7122)  loss_ce: 0.2490 (0.2528)  loss_centroid: 0.3406 (0.3462)  loss_ce_0: 0.2837 (0.2934)  loss_centroid_0: 0.3682 (0.3630)  loss_ce_1: 0.2889 (0.2862)  loss_centroid_1: 0.3108 (0.3304)  loss_ce_2: 0.2596 (0.2647)  loss_centroid_2: 0.3429 (0.3464)  loss_ce_3: 0.2508 (0.2563)  loss_centroid_3: 0.3614 (0.3672)  loss_ce_4: 0.2390 (0.2509)  loss_centroid_4: 0.3571 (0.3547)  loss_ce_unscaled: 0.2490 (0.2528)  class_error_unscaled: 46.6667 (46.0316)  cardinality_error_unscaled: 3.0000 (3.4387)  loss_centroid_unscaled: 0.0681 (0.0692)  loss_ce_0_unscaled: 0.2837 (0.2934)  cardinality_error_0_unscaled: 3.0000 (3.0065)  loss_centroid_0_unscaled: 0.0736 (0.0726)  loss_ce_1_unscaled: 0.2889 (0.2862)  cardinality_error_1_unscaled: 3.0000 (2.9355)  loss_centroid_1_unscaled: 0.0622 (0.0661)  loss_ce_2_unscaled: 0.2596 (0.2647)  cardinality_error_2_unscaled: 3.6000 (3.8355)  loss_centroid_2_unscaled: 0.0686 (0.0693)  loss_ce_3_unscaled: 0.2508 (0.2563)  cardinality_error_3_unscaled: 2.8000 (3.1677)  loss_centroid_3_unscaled: 0.0723 (0.0734)  loss_ce_4_unscaled: 0.2390 (0.2509)  cardinality_error_4_unscaled: 2.9000 (3.2548)  loss_centroid_4_unscaled: 0.0714 (0.0709)  time: 0.7270  data: 0.2147  max mem: 5061
# Epoch: [19]  [40/50]  eta: 0:00:06  lr: 0.000100  class_error: 20.00  loss: 3.6568 (3.6880)  loss_ce: 0.2490 (0.2520)  loss_centroid: 0.3388 (0.3390)  loss_ce_0: 0.2930 (0.2965)  loss_centroid_0: 0.3624 (0.3614)  loss_ce_1: 0.2889 (0.2895)  loss_centroid_1: 0.3128 (0.3264)  loss_ce_2: 0.2588 (0.2621)  loss_centroid_2: 0.3429 (0.3449)  loss_ce_3: 0.2499 (0.2540)  loss_centroid_3: 0.3614 (0.3630)  loss_ce_4: 0.2470 (0.2506)  loss_centroid_4: 0.3459 (0.3486)  loss_ce_unscaled: 0.2490 (0.2520)  class_error_unscaled: 43.7500 (43.3565)  cardinality_error_unscaled: 3.1000 (3.5171)  loss_centroid_unscaled: 0.0678 (0.0678)  loss_ce_0_unscaled: 0.2930 (0.2965)  cardinality_error_0_unscaled: 3.1000 (3.0951)  loss_centroid_0_unscaled: 0.0725 (0.0723)  loss_ce_1_unscaled: 0.2889 (0.2895)  cardinality_error_1_unscaled: 3.0000 (2.9951)  loss_centroid_1_unscaled: 0.0626 (0.0653)  loss_ce_2_unscaled: 0.2588 (0.2621)  cardinality_error_2_unscaled: 3.6000 (3.9000)  loss_centroid_2_unscaled: 0.0686 (0.0690)  loss_ce_3_unscaled: 0.2499 (0.2540)  cardinality_error_3_unscaled: 2.8000 (3.1805)  loss_centroid_3_unscaled: 0.0723 (0.0726)  loss_ce_4_unscaled: 0.2470 (0.2506)  cardinality_error_4_unscaled: 3.0000 (3.2780)  loss_centroid_4_unscaled: 0.0692 (0.0697)  time: 0.6626  data: 0.1705  max mem: 5061
# Epoch: [19]  [49/50]  eta: 0:00:00  lr: 0.000100  class_error: 18.75  loss: 3.6674 (3.6972)  loss_ce: 0.2473 (0.2484)  loss_centroid: 0.3406 (0.3465)  loss_ce_0: 0.2970 (0.3011)  loss_centroid_0: 0.3524 (0.3561)  loss_ce_1: 0.2859 (0.2884)  loss_centroid_1: 0.3225 (0.3287)  loss_ce_2: 0.2596 (0.2631)  loss_centroid_2: 0.3446 (0.3498)  loss_ce_3: 0.2499 (0.2525)  loss_centroid_3: 0.3601 (0.3620)  loss_ce_4: 0.2390 (0.2497)  loss_centroid_4: 0.3498 (0.3510)  loss_ce_unscaled: 0.2473 (0.2484)  class_error_unscaled: 38.8889 (40.1902)  cardinality_error_unscaled: 3.5000 (3.9300)  loss_centroid_unscaled: 0.0681 (0.0693)  loss_ce_0_unscaled: 0.2970 (0.3011)  cardinality_error_0_unscaled: 3.3000 (3.5860)  loss_centroid_0_unscaled: 0.0705 (0.0712)  loss_ce_1_unscaled: 0.2859 (0.2884)  cardinality_error_1_unscaled: 3.1000 (3.4340)  loss_centroid_1_unscaled: 0.0645 (0.0657)  loss_ce_2_unscaled: 0.2596 (0.2631)  cardinality_error_2_unscaled: 4.1000 (4.3320)  loss_centroid_2_unscaled: 0.0689 (0.0700)  loss_ce_3_unscaled: 0.2499 (0.2525)  cardinality_error_3_unscaled: 3.1000 (3.5360)  loss_centroid_3_unscaled: 0.0720 (0.0724)  loss_ce_4_unscaled: 0.2390 (0.2497)  cardinality_error_4_unscaled: 3.1000 (3.6680)  loss_centroid_4_unscaled: 0.0700 (0.0702)  time: 0.6266  data: 0.1478  max mem: 5061
# Epoch: [19] Total time: 0:00:31 (0.6310 s / it)
# SAVED
# SAVED
# Test:  [0/5]  eta: 0:00:17  class_error: 100.00  loss: 11.6518 (11.6518)  loss_ce: 1.3122 (1.3122)  loss_centroid: 0.6213 (0.6213)  loss_ce_0: 0.8259 (0.8259)  loss_centroid_0: 0.9011 (0.9011)  loss_ce_1: 0.8919 (0.8919)  loss_centroid_1: 1.2847 (1.2847)  loss_ce_2: 1.0107 (1.0107)  loss_centroid_2: 1.3101 (1.3101)  loss_ce_3: 1.1891 (1.1891)  loss_centroid_3: 0.5445 (0.5445)  loss_ce_4: 1.2332 (1.2332)  loss_centroid_4: 0.5271 (0.5271)  loss_ce_unscaled: 1.3122 (1.3122)  class_error_unscaled: 100.0000 (100.0000)  cardinality_error_unscaled: 10.9000 (10.9000)  loss_centroid_unscaled: 0.1243 (0.1243)  loss_ce_0_unscaled: 0.8259 (0.8259)  cardinality_error_0_unscaled: 11.3000 (11.3000)  loss_centroid_0_unscaled: 0.1802 (0.1802)  loss_ce_1_unscaled: 0.8919 (0.8919)  cardinality_error_1_unscaled: 10.1000 (10.1000)  loss_centroid_1_unscaled: 0.2569 (0.2569)  loss_ce_2_unscaled: 1.0107 (1.0107)  cardinality_error_2_unscaled: 10.2000 (10.2000)  loss_centroid_2_unscaled: 0.2620 (0.2620)  loss_ce_3_unscaled: 1.1891 (1.1891)  cardinality_error_3_unscaled: 9.8000 (9.8000)  loss_centroid_3_unscaled: 0.1089 (0.1089)  loss_ce_4_unscaled: 1.2332 (1.2332)  cardinality_error_4_unscaled: 10.4000 (10.4000)  loss_centroid_4_unscaled: 0.1054 (0.1054)  time: 3.5013  data: 2.5599  max mem: 5061
# Test:  [4/5]  eta: 0:00:01  class_error: 100.00  loss: 8.6591 (8.8117)  loss_ce: 0.8169 (0.9078)  loss_centroid: 0.5874 (0.5467)  loss_ce_0: 0.6222 (0.6541)  loss_centroid_0: 0.6879 (0.7253)  loss_ce_1: 0.5812 (0.6175)  loss_centroid_1: 0.9748 (1.0359)  loss_ce_2: 0.6405 (0.6921)  loss_centroid_2: 1.0952 (1.0419)  loss_ce_3: 0.7949 (0.8516)  loss_centroid_3: 0.4189 (0.4199)  loss_ce_4: 0.7481 (0.8447)  loss_centroid_4: 0.4708 (0.4741)  loss_ce_unscaled: 0.8169 (0.9078)  class_error_unscaled: 100.0000 (90.7368)  cardinality_error_unscaled: 6.2000 (6.5800)  loss_centroid_unscaled: 0.1175 (0.1093)  loss_ce_0_unscaled: 0.6222 (0.6541)  cardinality_error_0_unscaled: 7.0000 (7.3200)  loss_centroid_0_unscaled: 0.1376 (0.1451)  loss_ce_1_unscaled: 0.5812 (0.6175)  cardinality_error_1_unscaled: 5.0000 (5.9600)  loss_centroid_1_unscaled: 0.1950 (0.2072)  loss_ce_2_unscaled: 0.6405 (0.6921)  cardinality_error_2_unscaled: 6.8000 (7.0400)  loss_centroid_2_unscaled: 0.2190 (0.2084)  loss_ce_3_unscaled: 0.7949 (0.8516)  cardinality_error_3_unscaled: 5.7000 (6.0400)  loss_centroid_3_unscaled: 0.0838 (0.0840)  loss_ce_4_unscaled: 0.7481 (0.8447)  cardinality_error_4_unscaled: 5.8000 (6.1800)  loss_centroid_4_unscaled: 0.0942 (0.0948)  time: 1.7589  data: 0.5590  max mem: 5061
# Test: Total time: 0:00:09 (1.8120 s / it)
# Training time 0:13:54

# %% [markdown]
# ## Visualizing
# ---------------

# %%
device = torch.device('cuda')
# colors for visualization
COLORS = [[0.000, 0.447, 0.741], [0.850, 0.325, 0.098], [0.929, 0.694, 0.125],
          [0.494, 0.184, 0.556], [0.466, 0.674, 0.188], [0.301, 0.745, 0.933]]

# standard PyTorch mean-std input image normalization
transform = T.Compose([
    T.Resize(800),
    T.ToTensor(),
    T.Normalize([0.485, 0.456, 0.406], [0.229, 0.224, 0.225])
])



def rescale_center(out_bbox, size):
    img_w, img_h = size
    b = out_bbox * torch.tensor([img_w, img_h], dtype=torch.float32, device=device)
    return b

def detect(im, model, transform, det_threshold = 0.75):
    # mean-std normalize the input image (batch-size: 1)
    img = transform(im).unsqueeze(0)

    # demo model only support by default images with aspect ratio between 0.5 and 2
    # if you want to use images with an aspect ratio outside this range
    # rescale your image so that the maximum size is at most 1333 for best results
    assert img.shape[-2] <= 1600 and img.shape[-1] <= 1600, 'demo model only supports images up to 1600 pixels on each side'

    # propagate through the model
    outputs = model(img.to(device))

    # keep only predictions with 0.7+ confidence
    probas = outputs['pred_logits'].softmax(-1)[0, :, :-1]
    keep = probas.max(-1).values > det_threshold

    # convert boxes from [0; 1] to image scales
    centroids = rescale_center(outputs['pred_centroids'][0, keep], im.size)
    return probas[keep].detach().cpu(), centroids.detach().cpu()

def getImg(url):
    return Image.open(requests.get(url, stream=True).raw)

def is_grayscale(image):
    if image.mode == "L":
        return True
    else:
        return False

def convert_grayscale_to_rgb(image):
    if not is_grayscale(image):
        return image
    else:
        return image.convert("RGB")


def plot_results(pil_img, prob, centroids, gt_centroids, boxes, file_name):
    # plt.figure(figsize=(16, 10))
    plt.imshow(pil_img)
    ax = plt.gca()
    ax.scatter([c[0] for c in gt_centroids], [c[1] for c in gt_centroids], color='blue', s=10)
    ax.scatter([c[0] for c in centroids], [c[1] for c in centroids.cpu()], color='red', s=10)
    if show_center:
        ax.scatter([c[0]+c[2]//2 for c in boxes], [c[1]+c[3]//2 for c in boxes], color='green', s=10)
    for (xc, yc, w, h), c in zip(boxes, COLORS * 100):
        ax.add_patch(plt.Rectangle((xc, yc), w, h,
                                   fill=False, color='white', linewidth=2))
    if show_probs:
        for p, c in zip(prob, centroids):
            cl = p.argmax()
            text = f'- {p[cl]:0.2f}'
            ax.text(c[0] + 15, c[1], text, fontsize=9,
                    bbox=dict(facecolor='white', alpha=0.5))
    plt.axis('off')
    # plt.savefig(f'images/{file_name}')
    plt.show()

# %% [markdown]
# ### before submission run below cell with display_results=True

# %%
display_results = False
show_probs = True
show_center = True
det_threshold = 0.7

model = _make_detr('resnet50', num_classes=2)
model.to(device)

checkpoint = torch.load('checkpoints/checkpoint.pth', map_location='cpu')
print("DETR returning", {n:p for n,p in model.named_parameters()}.keys())

model.load_state_dict(checkpoint['model'])
model.eval()
if not os.path.exists('images'):
    os.mkdir('images')

coco = COCO(PATH_TO_COCO + 'annotations/instances_val2017.json')
ids = coco.getImgIds()

val_drift_rates = []
for id in range(20):
    im = coco.loadImgs(ids[id])[0]
    annos = coco.loadAnns(coco.getAnnIds(ids[id]))
    img = getImg(im['coco_url']).convert("RGB")
    scores, centroids = detect(img, model, transform, det_threshold=det_threshold)
    gt_centroids = estimate_centroids(im, annos)
    plot_results(img, scores, centroids, gt_centroids, [anno['bbox'] for anno in annos], im['file_name'])
    drift_rates = compute_drift_rate(centroids, gt_centroids, [anno['area'] for anno in annos])
    print(f'im: {ids[id]}, drift rates : {drift_rates.cpu().numpy()}')
    val_drift_rates.append(drift_rates)

overall_drit_rates = torch.concat(val_drift_rates, dim=0)
print(f'Average drift rate: {overall_drit_rates.mean()}')
# Out:
# Output hidden; open in https://colab.research.google.com to view.

# %% [markdown]
# ## Discussion
# ---
# **write 1 up to 3 sentences for each question**
# 1. ***What is your intution behind your implementation of  coco.py:convert_coco_poly_to_centroids()*** [2 points]
#
#   I used convert_coco_poly_to_mask to get the mask, and then identified the main part by removing the thin (legs and tail) from the mask. I then calculated the center of mass of the mask by having the center of mass mostly affected by the larger body parts.
#
# 2. ***Which distance metric have you used for computing the cost matrix between centroids? why?*** [1 points]
#
#   I use L1 to calculate the cost matrix between centroids. Because it measures the absolute difference between the x and y coordinates, it is used to capture the absolute difference between the predicted and true centroids.
#
# 3. ***Why freezing the entire model and traning just the heads might never actually predict the true centroids?*** [2 points]
#
#   Freezing the entire model and training only the classification and regression heads may fail to predict the true centroids because the frozen backbone cannot provide meaningful features for the heads to learn from. This may hinder the model's ability to learn accurate centroid predictions.

# %% [markdown]
# ## Submission guidelines
# ---
#
#
#
# The submission structure should look like:
#
# IMPORTANT: Remove the _checkpoint.pth_ and make sure _heads.pth_ is in the submission.
#
#
# ```
# {last name}_{first name}_{sbu id}_hw2/
# ├── part1/
# │   └── ...
# ├── part2/
# │   ├── CSE527_23F_HW3_P2.ipynb
# │   └── detr/
# │       ├── checkpoints/
# │       │   └── heads.pth
# │       ├── datasets/
# │       │   ├── coco.py
# │       │   ├── ...
# │       │   └── ...
# │       ├── models/
# │       │   ├── detr.py
# │       │   ├── matcher.py
# │       │   ├── ...
# │       │   └── ...
# │       ├── utils/
# │       │   ├── ...
# │       │   └── ...
# │       ├── engine.py
# │       ├── main.py
# │       ├── hubconf.py
# │       └── requirements.txt
# ```
#
#
# Follow instructions in part1's submission guidelines to generate your complete submission
