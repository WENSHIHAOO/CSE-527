# %% [markdown]
# # CSE527 Homework 2
# **Due date: 23:59 on October 29, 2023 (Sunday)**
#
# In this semester, we will use Google Colab for the assignments, which allows us to utilize resources that some of us might not have in their local machines such as GPUs. You will need to use your Stony Brook (*.stonybrook.edu) account for coding and Google Drive to save your results.
#
# ## Google Colab Tutorial
# ---
# Go to https://colab.research.google.com/notebooks/, you will see a tutorial named "Welcome to Colaboratory" file, where you can learn the basics of using google colab.
#
# Settings used for assignments: ***Edit -> Notebook Settings -> Runtime Type (Python 3)***.
#
#
# ## Description
# ---
# This project is an introduction to deep learning tools for computer vision. You will design and train deep convolutional networks for scene recognition using [PyTorch](http://pytorch.org).
#
# In Problem 1 of the project you will train a deep convolutional network from scratch to recognize scenes. The starter codes gives you methods to load data and display them. You will need to define a simple network architecture and add jittering, normalization, and regularization to increase recognition accuracy to 50, 60, or perhaps 70%. Unfortunately, we only have 114 training examples so it doesn't seem possible to train a network from scratch which outperforms hand-crafted features
#
# For Problem 2 you will instead fine-tune a pre-trained deep network to achieve about 90% accuracy on the task. We will use the pretrained AlexNet network which was not trained to recognize scenes at all.
#
# These two approaches represent the most common approaches to recognition problems in computer vision today -- train a deep network from scratch if you have enough data (it's not always obvious whether or not you do), and if you cannot then instead fine-tune a pre-trained network.
#
# For Problem 3 you will train a small Vision Transformer (ViT) from scratch. ViT is pre-trained on large amounts of
# data and transferred to multiple mid-sized or small image recognition benchmarks(ImageNet, CIFAR-100, VTAB, etc.), ViT attains excellent results compared to state-of-the-art convolutional networks.
#
# There are 3 problems in this homework with a total of 100 points. Be sure to read **Submission Guidelines** below. They are important. For the problems requiring text descriptions, you might want to add a markdown block for that.
#
# ## Dataset
# ---
# Save the [dataset(click me)](https://drive.google.com/drive/folders/1-0wI50GfpXl3Dcxo2vjvItbnHMDdVurU?usp=drive_link) into your working folder in your Google Drive for this homework. <br>
# Under your root folder, there should be a folder named "data" (i.e. XXX/Surname_Givenname_SBUID/data) containing the images.
# **Do not upload** the data subfolder before submitting on blackboard due to size limit. There should be only one .ipynb file under your root folder Surname_Givenname_SBUID.
#
# ## Some Tutorials (PyTorch)
# ---
# - You will be using PyTorch for deep learning toolbox (follow the [link](http://pytorch.org) for installation).
# - For PyTorch beginners, please read this [tutorial](http://pytorch.org/tutorials/beginner/deep_learning_60min_blitz.html) before doing your homework.
# - Feel free to study more tutorials at http://pytorch.org/tutorials/.
# - Find cool visualization here at http://playground.tensorflow.org.

# %%
# import packages here
import os
import cv2
import numpy as np
import matplotlib.pyplot as plt
import glob
import random
import time

import torch
import torchvision
import torchvision.transforms as transforms

from torch.autograd import Variable
from torch import Tensor
import torch.nn as nn
import torch.nn.functional as F

# %%
# Mount your google drive where you've saved your assignment folder
from google.colab import drive
drive.mount('/content/gdrive')
# Out:
# Mounted at /content/gdrive

# %%
# Set your working directory (in your google drive)
#   change it to your specific homework directory.
# %cd '/content/gdrive/My Drive/CSE527/Wen_Shihao_113085521_hw2'
# Out:
# /content/gdrive/My Drive/CSE527/Wen_Shihao_113085521_hw2

# %% [markdown]
# ## Problem 0: Loading and Preprocessing data
# ---
# In this part, you are provided with a function that loads data into minibatches for training and testing in PyTorch. However, some preprocessing parts are missing. Your will need to implement them when doing Problem 1.

# %%
#--------------------------------------------------
#    Load Training Data and Testing Data
#--------------------------------------------------

def set_random_seed(seed):
     torch.manual_seed(seed)
     torch.cuda.manual_seed_all(seed)
     np.random.seed(seed)
     random.seed(seed)
     torch.backends.cudnn.deterministic = True
set_random_seed(0)

class_names = [name[13:] for name in glob.glob('./data/train/*')]
class_names = dict(zip(range(len(class_names)), class_names))
print("class_names: %s " % class_names)
# split data into train and test
def load_dataset(path, img_size, num_per_class=-1, batch_size=16, shuffle=False,
           augment=False, is_color=False, zero_centered=False, rotated=False):
    data = []
    labels = []
    channel_num = 3 if is_color else 1

    # read images and resizing
    for id, class_name in class_names.items():
        print("Loading images from class: %s" % id)
        img_path_class = glob.glob(path + class_name + '/*.jpg')
        if num_per_class > 0:
            img_path_class = img_path_class[:num_per_class]
        labels.extend([id]*len(img_path_class))
        for filename in img_path_class:
            if is_color:
                img = cv2.imread(filename)
            else:
                img = cv2.imread(filename, 0)

            # resize the image
            img = cv2.resize(img, img_size, cv2.INTER_LINEAR)

            if is_color:
                img = np.transpose(img, [2, 0, 1])

            # norm pixel values to [-1, 1]
            data.append(img.astype(np.float)/255*2-1)

    ##########--WRITE YOUR CODE HERE--##########
    # Data Augmentation
    if augment:
        augment_data = []
        augment_labels = []
        for img, label in zip(data, labels):
            # Add the original image
            augment_data.append(img)
            augment_labels.append(label)
            # Horizontal flip
            augment_data.append(np.flip(img, axis=1))
            augment_labels.append(label)

        # Replace the original with augment
        data = augment_data
        labels = augment_labels
    ##########-------END OF CODE-------##########

    ##########--WRITE YOUR CODE HERE--##########
    # Data Normalization
    if zero_centered:
        zero_centered_data = []
        for image in data:
          # zero_centered
          d=image - np.mean(image)
          # normalized
          zero_centered_data.append(d / np.std(d))
        data = zero_centered_data
    ##########-------END OF CODE-------##########

    # Data randomly rotating
    if rotated:
        rotated_data = []
        for image in data:
            angle = np.random.randint(0, 360)
            height, width = image.shape[:2]
            matrix = cv2.getRotationMatrix2D((width/2, height/2), angle, 1.0)

            # Calculate the new dimensions and adjust the translation
            cos = np.abs(matrix[0, 0])
            sin = np.abs(matrix[0, 1])
            new_width = int((height * sin) + (width * cos))
            new_height = int((height * cos) + (width * sin))
            matrix[0, 2] += (new_width - width) / 2
            matrix[1, 2] += (new_height - height) / 2

            # rotation
            rotated_image = cv2.warpAffine(image, matrix, (new_width, new_height))
            rotated_data.append(cv2.resize(rotated_image, img_size, cv2.INTER_LINEAR))

        data.extend(rotated_data)

    # randomly permute (this step is important for training)
    if shuffle:
        pass

    # divide data into minibatches of TorchTensors
    if batch_size > 1:
        batch_data = []
        batch_labels = []

        for i in range(int(len(data) / batch_size)):
            minibatch_d = data[i*batch_size: (i+1)*batch_size]
            minibatch_d = np.reshape(minibatch_d, (batch_size, channel_num, img_size[0], img_size[1]))
            batch_data.append(torch.from_numpy(minibatch_d))

            minibatch_l = labels[i*batch_size: (i+1)*batch_size]
            batch_labels.append(torch.LongTensor(minibatch_l))
        data, labels = batch_data, batch_labels

    return zip(batch_data, batch_labels)
# Out:
# class_names: {0: 'ostrya_virginiana', 1: 'campsis_radicans', 2: 'ranunculus_recurvatus', 3: 'juniperis_virginiana', 4: 'liriodendron_tulipifera', 5: 'quercus_montana', 6: 'asclepias_incarnata', 7: 'celastrus_orbiculatus', 8: 'vaccinium_stamineum', 9: 'heliopsis_helianthoides', 10: 'smilax_glauca', 11: 'glechoma_hederacea', 12: 'humulus_japonicus', 13: 'eupatorium_coalestinum', 14: 'rubus_phoenicolasius', 15: 'phlox_divaricata', 16: 'viola_striata', 17: 'lonicera_maackii', 18: 'lindera_benzoin', 19: 'ilex_opaca', 20: 'ailanthus_altissima', 21: 'lysimachia_nummularia'}

# %%
# load data into size (64, 64)
img_size = (64, 64)
batch_size = 16 # training sample number per batch

# load training dataset
trainloader_small = list(load_dataset('./data/train/', img_size, batch_size=batch_size, shuffle=True))
train_num = len(trainloader_small)
print("Finish loading %d minibatches (batch_size=%d) of training samples." % (train_num, batch_size))

# load testing dataset
testloader_small = list(load_dataset('./data/test/', img_size, num_per_class=50, batch_size=batch_size))
test_num = len(testloader_small)
print("Finish loading %d minibatches (batch_size=%d) of testing samples." % (test_num, batch_size))
# Out:
# Loading images from class: 0
# <ipython-input-106-f9969027fe30>:43: DeprecationWarning: `np.float` is a deprecated alias for the builtin `float`. To silence this warning, use `float` by itself. Doing this will not modify any behavior and is safe. If you specifically wanted the numpy scalar type, use `np.float64` here.
# Deprecated in NumPy 1.20; for more details and guidance: https://numpy.org/devdocs/release/1.20.0-notes.html#deprecations
#   data.append(img.astype(np.float)/255*2-1)
# Loading images from class: 1
# Loading images from class: 2
# Loading images from class: 3
# Loading images from class: 4
# Loading images from class: 5
# Loading images from class: 6
# Loading images from class: 7
# Loading images from class: 8
# Loading images from class: 9
# Loading images from class: 10
# Loading images from class: 11
# Loading images from class: 12
# Loading images from class: 13
# Loading images from class: 14

# %%
# show some images
def imshow(img):
    img = img / 2 + 0.5     # unnormalize
    npimg = img.numpy()
    if len(npimg.shape) > 2:
        npimg = np.transpose(img, [1, 2, 0])
    plt.figure
    plt.imshow(npimg, 'gray')
    plt.show()
img, label = trainloader_small[0][0][11][0], trainloader_small[0][1][11]
label = int(np.array(label))
print(class_names[label])
imshow(img)
# Out:
# campsis_radicans

# %% [markdown]
# ## Problem 1: Training a Network From Scratch [40 points]
# Gone are the days of hand designed features. Now we have end-to-end learning in which a highly non-linear representation is learned for our data to maximize our objective function (in this case, 16-way classification accuracy). Let's start!

# %% [markdown]
# First, let's define a simpe network architecture.

# %%
#--------------------------------------------------
#       Define Network Architecture
#--------------------------------------------------
class TNet(nn.Module):
    def __init__(self):
      super(TNet,self).__init__()

      self.features = torch.nn.Sequential(
        nn.Conv2d(1, 16, 3),
        nn.ReLU(),
        nn.MaxPool2d(4, stride=4),
      )

      self.classifier = nn.Sequential(
         nn.Linear(3600, 22),
      )

    def forward(self, x):
      x = self.features(x)
      x = torch.flatten(x, 1)
      x = self.classifier(x)
      return x

# %% [markdown]
# Then, let's define model training and evaluation functions.

# %%
#--------------------------------------------------
#       Model Training Function
#--------------------------------------------------
import torch.optim as optim
import time

def trainModel(net, trainloader, train_option, testloader=None):
  loss_func = nn.CrossEntropyLoss()
  lr = train_option['lr']
  epoch = train_option['epoch']
  device = train_option['device'] if 'device' in train_option.keys() else 'cpu'
  log_iter = train_option['log_iter'] if 'log_iter' in train_option.keys() else 20
  eval_epoch = 1

  if 'optimizer' in train_option.keys():
    optimizer = train_option['optimizer']
  else:
    optimizer = optim.Adam(net.parameters(), lr=lr)

  start_time = time.time()
  if device == 'gpu':
    net = net.cuda()

  iters = 0
  running_loss = 0.0
  for ep in range(epoch):
    net.train()
    for iter, (x, y) in enumerate(trainloader):
      iters += 1
      batch_x = Variable(x).float()
      batch_y = Variable(y).long()
      if device == 'gpu':
        batch_x = batch_x.cuda()
        batch_y = batch_y.cuda()

      outputs = net(batch_x)
      loss = loss_func(outputs, batch_y)
      optimizer.zero_grad()
      loss.backward()
      optimizer.step()
      running_loss += loss.item()

      time_lapse = time.strftime('%H:%M:%S', time.gmtime(time.time() - start_time))
      if iter % log_iter == 0:
        print('Epoch:{:2d} | Iter:{:5d} | Time: {} | Train Loss: {:.4f} | Average Loss: {:.4f} '.format(ep+1, iter, time_lapse, loss.item(), running_loss/iters))

    if testloader is not None and ep % eval_epoch == 0:
      evalModel(net, testloader)

# %%
#--------------------------------------------------
#       Model Evaluating Function
#--------------------------------------------------
import time

def evalModel(net, testloader):
  acc = 0.0
  count = 0
  start_time = time.time()
  device = 'gpu' if next(net.parameters()).is_cuda else 'cpu'
  net.eval()

  for iter, (x, y) in enumerate(testloader):
        count += x.shape[0]
        batch_x = Variable(x).float()
        batch_y = Variable(y).long()
        if device == 'gpu':
          batch_x = batch_x.cuda()
          batch_y = batch_y.cuda()
        outputs = net(batch_x)
        acc += torch.sum(outputs.max(1)[1]==batch_y)

  time_lapse = time.strftime('%H:%M:%S', time.gmtime(time.time() - start_time))
  print('Accuracy: {:5f} | Time: {}'.format(acc/count,time_lapse))

# %% [markdown]
# Finally, let's start training and evaluation.

# %%
#--------------------------------------------------
#       Start Training & Evaluation
#--------------------------------------------------
net = TNet()
train_option = {}
train_option['lr'] = 0.001
train_option['epoch'] = 20
train_option['device'] = 'gpu'
trainModel(net, trainloader_small, train_option, testloader_small)
# Out:
# Epoch: 1 | Iter:    0 | Time: 00:00:01 | Train Loss: 3.1690 | Average Loss: 3.1690
# Accuracy: 0.187500 | Time: 00:00:00
# Epoch: 2 | Iter:    0 | Time: 00:00:01 | Train Loss: 2.1485 | Average Loss: 4.0710
# Accuracy: 0.250000 | Time: 00:00:00
# Epoch: 3 | Iter:    0 | Time: 00:00:01 | Train Loss: 2.7593 | Average Loss: 3.5452
# Accuracy: 0.343750 | Time: 00:00:00
# Epoch: 4 | Iter:    0 | Time: 00:00:01 | Train Loss: 2.7718 | Average Loss: 3.2356
# Accuracy: 0.406250 | Time: 00:00:00
# Epoch: 5 | Iter:    0 | Time: 00:00:01 | Train Loss: 2.2925 | Average Loss: 3.0257
# Accuracy: 0.562500 | Time: 00:00:00
# Epoch: 6 | Iter:    0 | Time: 00:00:01 | Train Loss: 1.7444 | Average Loss: 2.8488
# Accuracy: 0.593750 | Time: 00:00:00
# Epoch: 7 | Iter:    0 | Time: 00:00:01 | Train Loss: 1.3787 | Average Loss: 2.6898
# Accuracy: 0.593750 | Time: 00:00:00
# Epoch: 8 | Iter:    0 | Time: 00:00:01 | Train Loss: 1.1745 | Average Loss: 2.5426
# Accuracy: 0.625000 | Time: 00:00:00
# Epoch: 9 | Iter:    0 | Time: 00:00:01 | Train Loss: 1.0301 | Average Loss: 2.4039
# Accuracy: 0.656250 | Time: 00:00:00
# Epoch:10 | Iter:    0 | Time: 00:00:01 | Train Loss: 0.8753 | Average Loss: 2.2733
# Accuracy: 0.687500 | Time: 00:00:00
# Epoch:11 | Iter:    0 | Time: 00:00:01 | Train Loss: 0.7082 | Average Loss: 2.1506
# Accuracy: 0.687500 | Time: 00:00:00
# Epoch:12 | Iter:    0 | Time: 00:00:01 | Train Loss: 0.5637 | Average Loss: 2.0355
# Accuracy: 0.687500 | Time: 00:00:00
# Epoch:13 | Iter:    0 | Time: 00:00:01 | Train Loss: 0.4553 | Average Loss: 1.9276
# Accuracy: 0.687500 | Time: 00:00:00
# Epoch:14 | Iter:    0 | Time: 00:00:01 | Train Loss: 0.3741 | Average Loss: 1.8268
# Accuracy: 0.656250 | Time: 00:00:00
# Epoch:15 | Iter:    0 | Time: 00:00:01 | Train Loss: 0.3086 | Average Loss: 1.7329
# Accuracy: 0.625000 | Time: 00:00:00
# Epoch:16 | Iter:    0 | Time: 00:00:01 | Train Loss: 0.2555 | Average Loss: 1.6459
# Accuracy: 0.593750 | Time: 00:00:00
# Epoch:17 | Iter:    0 | Time: 00:00:01 | Train Loss: 0.2140 | Average Loss: 1.5657
# Accuracy: 0.593750 | Time: 00:00:00
# Epoch:18 | Iter:    0 | Time: 00:00:01 | Train Loss: 0.1786 | Average Loss: 1.4917
# Accuracy: 0.593750 | Time: 00:00:00
# Epoch:19 | Iter:    0 | Time: 00:00:01 | Train Loss: 0.1496 | Average Loss: 1.4235
# Accuracy: 0.593750 | Time: 00:00:00
# Epoch:20 | Iter:    0 | Time: 00:00:01 | Train Loss: 0.1273 | Average Loss: 1.3607
# Accuracy: 0.625000 | Time: 00:00:00

# %% [markdown]
# You would get around 0.45-0.55 accuracy by this very simple network. Now it's your job to beat this result.
#
# ### Problem 1.1 [25 points]
# Try to boost the accuracy by doing the following steps:
#
# **Data Augmentation**: We don't have enough training data, let's augment the training data.
# If you left-right flip (mirror) an image of a scene, it never changes categories. A kitchen doesn't become a forest when mirrored. This isn't true in all domains — a "d" becomes a "b" when mirrored, so you can't "jitter" digit recognition training data in the same way. But we can synthetically increase our amount of training data by left-right mirroring training images during the learning process.
#
# After you implement mirroring, you should notice that your training error doesn't drop as quickly. That's actually a good thing, because it means the network isn't overfitting to the 114 original training images as much (because it sees 228 training images now, although they're not as good as 228 truly independent samples). Because the training and test errors fall more slowly, you may need more training epochs or you may try modifying the learning rate. You are **required** to implement mirroring as data augmentation for this part.
#
# You can try more elaborate forms of jittering -- zooming in a random amount, rotating a random amount, taking a random crop, etc. These are not required, you might want to try these in the bonus part.
#
# **Data Normalization**: The images aren't zero-centered. One simple trick which can help a lot is to subtract the mean from every image. It would arguably be more proper to only compute the mean from the training images (since the test/validation images should be strictly held out) but it won't make much of a difference. This part is **required**.
#
# **Network Regularization**: Add dropout layer. If you train your network (especially for more than the default 30 epochs) you'll see that the training error can decrease to zero while the val top1 error hovers at 40% to 50%. The network has learned weights which can perfectly recognize the training data, but those weights don't generalize to held out test data. The best regularization would be more training data but we don't have that. Instead we will use dropout regularization.
#
# What does dropout regularization do? It randomly turns off network connections at training time to fight overfitting. This prevents a unit in one layer from relying too strongly on a single unit in the previous layer. Dropout regularization can be interpreted as simultaneously training many "thinned" versions of your network. At test, all connections are restored which is analogous to taking an average prediction over all of the "thinned" networks. You can see a more complete discussion of dropout regularization in this [paper](https://www.cs.toronto.edu/~hinton/absps/JMLRdropout.pdf).
#
# The dropout layer has only one free parameter — the dropout rate — the proportion of connections that are randomly deleted. The default of 0.5 should be fine. Insert a dropout layer between your convolutional layers. In particular, insert it directly before your last convolutional layer. Your train accuracy should decrease much more slowly. That's to be expected — you're making life much harder for the training algorithm by cutting out connections randomly. In this part, you are **required** to add dropout layer to your network.
#
# **Please give detailed descriptions of your network layout in the following format:**<br>
# Data augmentation: [descriptions]<br>
# Data normalization: [descriptions]<br>
# Layer 1: [layer_type]: [Parameters]<br>
# Layer 2: [layer_type]: [Parameters]<br>
# ...<br>
# **Then report the final accuracy on test set.**
#
# The reported accuracy required for this section should exceed **0.60**. As the dataset is small and there may be overfitting, your can report the **largest** accuracy achieved during training epoches.

# %%
# load data into size (64, 64)
img_size = (64, 64)
batch_size = 16 # training sample number per batch

# load training dataset
trainloader_small = list(load_dataset('./data/train/', img_size, batch_size=batch_size, shuffle=True, augment=True, zero_centered=True))
train_num = len(trainloader_small)
print("Finish loading %d minibatches (batch_size=%d) of training samples." % (train_num, batch_size))

# load testing dataset
testloader_small = list(load_dataset('./data/test/', img_size, num_per_class=50, batch_size=batch_size, zero_centered=True))
test_num = len(testloader_small)
print("Finish loading %d minibatches (batch_size=%d) of testing samples." % (test_num, batch_size))
# Out:
# Loading images from class: 0
# Loading images from class: 1
# Loading images from class: 2
# Loading images from class: 3
# Loading images from class: 4
# Loading images from class: 5
# Loading images from class: 6
# Loading images from class: 7
# Loading images from class: 8
# Loading images from class: 9
# Loading images from class: 10
# Loading images from class: 11
# Loading images from class: 12
# Loading images from class: 13
# <ipython-input-4-f9969027fe30>:43: DeprecationWarning: `np.float` is a deprecated alias for the builtin `float`. To silence this warning, use `float` by itself. Doing this will not modify any behavior and is safe. If you specifically wanted the numpy scalar type, use `np.float64` here.
# Deprecated in NumPy 1.20; for more details and guidance: https://numpy.org/devdocs/release/1.20.0-notes.html#deprecations
#   data.append(img.astype(np.float)/255*2-1)
# Loading images from class: 14
# Loading images from class: 15
# Loading images from class: 16
# Loading images from class: 17
# Loading images from class: 18
# Loading images from class: 19
# Loading images from class: 20
# Loading images from class: 21
# Finish loading 14 minibatches (batch_size=16) of training samples.
# Loading images from class: 0
# Loading images from class: 1
# Loading images from class: 2
# Loading images from class: 3
# Loading images from class: 4
# Loading images from class: 5
# Loading images from class: 6
# Loading images from class: 7
# Loading images from class: 8
# Loading images from class: 9
# Loading images from class: 10
# Loading images from class: 11
# Loading images from class: 12
# Loading images from class: 13
# Loading images from class: 14
# Loading images from class: 15
# Loading images from class: 16
# Loading images from class: 17
# Loading images from class: 18
# Loading images from class: 19
# Loading images from class: 20
# Loading images from class: 21
# Finish loading 2 minibatches (batch_size=16) of testing samples.

# %%
#--------------------------------------------------
#       Define Network Architecture
#--------------------------------------------------
class My_TNet(nn.Module):
    def __init__(self):
      super(My_TNet,self).__init__()

      self.features = torch.nn.Sequential(
        nn.Conv2d(1, 16, 3),
        nn.ReLU(),
        nn.MaxPool2d(4, stride=4),
        nn.Dropout(0.5),
        nn.Conv2d(16, 256, 3),
        nn.ReLU(),
        nn.MaxPool2d(4, stride=4),
        nn.Dropout(0.5),
      )

      self.classifier = nn.Sequential(
         nn.Linear(2304, 22),
      )

    def forward(self, x):
      x = self.features(x)
      x = torch.flatten(x, 1)
      x = self.classifier(x)
      return x

# %%
#--------------------------------------------------
#       Start Training & Evaluation
#--------------------------------------------------
net = My_TNet()
train_option = {}
train_option['lr'] = 0.001
train_option['epoch'] = 40
train_option['device'] = 'gpu'
trainModel(net, trainloader_small, train_option, testloader_small)
# Out:
# Epoch: 1 | Iter:    0 | Time: 00:00:00 | Train Loss: 3.8407 | Average Loss: 3.8407
# Accuracy: 0.062500 | Time: 00:00:00
# Epoch: 2 | Iter:    0 | Time: 00:00:00 | Train Loss: 3.8288 | Average Loss: 6.5973
# Accuracy: 0.062500 | Time: 00:00:00
# Epoch: 3 | Iter:    0 | Time: 00:00:00 | Train Loss: 3.5858 | Average Loss: 4.9042
# Accuracy: 0.156250 | Time: 00:00:00
# Epoch: 4 | Iter:    0 | Time: 00:00:00 | Train Loss: 3.3105 | Average Loss: 4.3243
# Accuracy: 0.250000 | Time: 00:00:00
# Epoch: 5 | Iter:    0 | Time: 00:00:00 | Train Loss: 3.1234 | Average Loss: 4.0030
# Accuracy: 0.250000 | Time: 00:00:00
# Epoch: 6 | Iter:    0 | Time: 00:00:00 | Train Loss: 2.9873 | Average Loss: 3.7937
# Accuracy: 0.250000 | Time: 00:00:00
# Epoch: 7 | Iter:    0 | Time: 00:00:00 | Train Loss: 2.9188 | Average Loss: 3.6379
# Accuracy: 0.312500 | Time: 00:00:00
# Epoch: 8 | Iter:    0 | Time: 00:00:00 | Train Loss: 2.8577 | Average Loss: 3.5159
# Accuracy: 0.343750 | Time: 00:00:00
# Epoch: 9 | Iter:    0 | Time: 00:00:00 | Train Loss: 2.7487 | Average Loss: 3.4093
# Accuracy: 0.375000 | Time: 00:00:00
# Epoch:10 | Iter:    0 | Time: 00:00:00 | Train Loss: 2.6148 | Average Loss: 3.3184
# Accuracy: 0.375000 | Time: 00:00:00
# Epoch:11 | Iter:    0 | Time: 00:00:00 | Train Loss: 2.6229 | Average Loss: 3.2330
# Accuracy: 0.468750 | Time: 00:00:00
# Epoch:12 | Iter:    0 | Time: 00:00:00 | Train Loss: 2.4657 | Average Loss: 3.1487
# Accuracy: 0.468750 | Time: 00:00:00
# Epoch:13 | Iter:    0 | Time: 00:00:00 | Train Loss: 2.5071 | Average Loss: 3.0690
# Accuracy: 0.531250 | Time: 00:00:00
# Epoch:14 | Iter:    0 | Time: 00:00:00 | Train Loss: 2.3198 | Average Loss: 2.9949
# Accuracy: 0.562500 | Time: 00:00:00
# Epoch:15 | Iter:    0 | Time: 00:00:00 | Train Loss: 2.1969 | Average Loss: 2.9222
# Accuracy: 0.562500 | Time: 00:00:00
# Epoch:16 | Iter:    0 | Time: 00:00:00 | Train Loss: 1.9514 | Average Loss: 2.8513
# Accuracy: 0.531250 | Time: 00:00:00
# Epoch:17 | Iter:    0 | Time: 00:00:00 | Train Loss: 2.0453 | Average Loss: 2.7826
# Accuracy: 0.593750 | Time: 00:00:00
# Epoch:18 | Iter:    0 | Time: 00:00:00 | Train Loss: 1.8646 | Average Loss: 2.7138
# Accuracy: 0.468750 | Time: 00:00:00
# Epoch:19 | Iter:    0 | Time: 00:00:00 | Train Loss: 1.7362 | Average Loss: 2.6449
# Accuracy: 0.593750 | Time: 00:00:00
# Epoch:20 | Iter:    0 | Time: 00:00:00 | Train Loss: 1.5159 | Average Loss: 2.5785
# Accuracy: 0.593750 | Time: 00:00:00
# Epoch:21 | Iter:    0 | Time: 00:00:00 | Train Loss: 1.5845 | Average Loss: 2.5161
# Accuracy: 0.562500 | Time: 00:00:00
# Epoch:22 | Iter:    0 | Time: 00:00:00 | Train Loss: 1.4101 | Average Loss: 2.4542
# Accuracy: 0.562500 | Time: 00:00:00
# Epoch:23 | Iter:    0 | Time: 00:00:00 | Train Loss: 1.3676 | Average Loss: 2.3953
# Accuracy: 0.531250 | Time: 00:00:00
# Epoch:24 | Iter:    0 | Time: 00:00:00 | Train Loss: 1.2890 | Average Loss: 2.3381
# Accuracy: 0.562500 | Time: 00:00:00
# Epoch:25 | Iter:    0 | Time: 00:00:00 | Train Loss: 1.2968 | Average Loss: 2.2810
# Accuracy: 0.500000 | Time: 00:00:00
# Epoch:26 | Iter:    0 | Time: 00:00:00 | Train Loss: 1.2485 | Average Loss: 2.2280
# Accuracy: 0.593750 | Time: 00:00:00
# Epoch:27 | Iter:    0 | Time: 00:00:00 | Train Loss: 1.4042 | Average Loss: 2.1801
# Accuracy: 0.625000 | Time: 00:00:00
# Epoch:28 | Iter:    0 | Time: 00:00:00 | Train Loss: 1.0325 | Average Loss: 2.1315
# Accuracy: 0.562500 | Time: 00:00:00
# Epoch:29 | Iter:    0 | Time: 00:00:00 | Train Loss: 1.1676 | Average Loss: 2.0826
# Accuracy: 0.687500 | Time: 00:00:00
# Epoch:30 | Iter:    0 | Time: 00:00:01 | Train Loss: 1.0064 | Average Loss: 2.0376
# Accuracy: 0.625000 | Time: 00:00:00
# Epoch:31 | Iter:    0 | Time: 00:00:01 | Train Loss: 0.8809 | Average Loss: 1.9922
# Accuracy: 0.656250 | Time: 00:00:00
# Epoch:32 | Iter:    0 | Time: 00:00:01 | Train Loss: 1.0879 | Average Loss: 1.9487
# Accuracy: 0.593750 | Time: 00:00:00
# Epoch:33 | Iter:    0 | Time: 00:00:01 | Train Loss: 0.7704 | Average Loss: 1.9059
# Accuracy: 0.656250 | Time: 00:00:00
# Epoch:34 | Iter:    0 | Time: 00:00:01 | Train Loss: 0.6126 | Average Loss: 1.8629
# Accuracy: 0.625000 | Time: 00:00:00
# Epoch:35 | Iter:    0 | Time: 00:00:01 | Train Loss: 0.8057 | Average Loss: 1.8236
# Accuracy: 0.625000 | Time: 00:00:00
# Epoch:36 | Iter:    0 | Time: 00:00:01 | Train Loss: 0.6552 | Average Loss: 1.7873
# Accuracy: 0.656250 | Time: 00:00:00
# Epoch:37 | Iter:    0 | Time: 00:00:01 | Train Loss: 0.8177 | Average Loss: 1.7515
# Accuracy: 0.625000 | Time: 00:00:00
# Epoch:38 | Iter:    0 | Time: 00:00:01 | Train Loss: 0.3831 | Average Loss: 1.7152
# Accuracy: 0.625000 | Time: 00:00:00
# Epoch:39 | Iter:    0 | Time: 00:00:01 | Train Loss: 1.1578 | Average Loss: 1.6821
# Accuracy: 0.687500 | Time: 00:00:00
# Epoch:40 | Iter:    0 | Time: 00:00:01 | Train Loss: 0.4402 | Average Loss: 1.6509
# Accuracy: 0.687500 | Time: 00:00:00

# %% [markdown]
# Answer:
#
# Data augmentation: Add image data for horizontal flipping
#
# Data normalization: Zero_center the image data and normalize it.
#
# Layer 1: Convolutional layer: input channel = 1, output channel = 16, kernel = 3x3
#
# Layer 2: ReLu layer
#
# Layer 3: Max pool layer: kernel = 4x4
#
# Layer 4: Dropout layer: rate = 0.5
#
# Layer 5: Convolutional layer: input channels = 16, output channels = 256, kernels = 3x3
#
# Layer 6: ReLu layer
#
# Layer 7: Max pool layer: kernel = 4x4
#
# Layer 8: Dropout layer: rate = 0.5
#
# Layer 9: Linear classifier layer: input channel = 2304, output channel = 22
#
# Accuray on Test set: 0.656250 | Time for Training: 1s | Time for Testing: 0s

# %% [markdown]
# ## Problem 1.2 [15 points]
#
# Try **three techniques** taught in the class to increase the accuracy of your model. Such as increasing training data by randomly rotating training images, adding batch normalization, different activation functions (e.g., sigmoid) and model architecture modification. Note that too many layers can do you no good due to insufficient training data. Clearly describe your method and accuracy increase/decrease for each of the three techniques.
#
# The reported accuracy required for this section should exceed **0.70**. Your can report the **largest** accuracy achieved during training epoches.(At least **TWO** Technique should achieve this).
#
# ### Technique 1

# %%
#--------------------------------------------------
#    Load Training Data and Testing Data
#--------------------------------------------------
# load data into size (64, 64)
img_size = (64, 64)
batch_size = 16 # training sample number per batch

# load training dataset
trainloader_small = list(load_dataset('./data/train/', img_size, batch_size=batch_size, shuffle=True, augment=True, zero_centered=True))
train_num = len(trainloader_small)
print("Finish loading %d minibatches (batch_size=%d) of training samples." % (train_num, batch_size))

# load testing dataset
testloader_small = list(load_dataset('./data/test/', img_size, num_per_class=50, batch_size=batch_size, zero_centered=True))
test_num = len(testloader_small)
print("Finish loading %d minibatches (batch_size=%d) of testing samples." % (test_num, batch_size))
# Out:
# Loading images from class: 0
# Loading images from class: 1
# Loading images from class: 2
# Loading images from class: 3
# Loading images from class: 4
# Loading images from class: 5
# Loading images from class: 6
# Loading images from class: 7
# Loading images from class: 8
# Loading images from class: 9
# Loading images from class: 10
# Loading images from class: 11
# Loading images from class: 12
# Loading images from class: 13
# <ipython-input-197-f9969027fe30>:43: DeprecationWarning: `np.float` is a deprecated alias for the builtin `float`. To silence this warning, use `float` by itself. Doing this will not modify any behavior and is safe. If you specifically wanted the numpy scalar type, use `np.float64` here.
# Deprecated in NumPy 1.20; for more details and guidance: https://numpy.org/devdocs/release/1.20.0-notes.html#deprecations
#   data.append(img.astype(np.float)/255*2-1)
# Loading images from class: 14
# Loading images from class: 15
# Loading images from class: 16
# Loading images from class: 17
# Loading images from class: 18
# Loading images from class: 19
# Loading images from class: 20
# Loading images from class: 21
# Finish loading 14 minibatches (batch_size=16) of training samples.
# Loading images from class: 0
# Loading images from class: 1
# Loading images from class: 2
# Loading images from class: 3
# Loading images from class: 4
# Loading images from class: 5
# Loading images from class: 6
# Loading images from class: 7
# Loading images from class: 8
# Loading images from class: 9
# Loading images from class: 10
# Loading images from class: 11
# Loading images from class: 12
# Loading images from class: 13
# Loading images from class: 14
# Loading images from class: 15
# Loading images from class: 16
# Loading images from class: 17
# Loading images from class: 18
# Loading images from class: 19
# Loading images from class: 20
# Loading images from class: 21
# Finish loading 2 minibatches (batch_size=16) of testing samples.

# %%
#--------------------------------------------------
#       Define Network Architecture
#--------------------------------------------------
class Model_architecture_modification_TNet(nn.Module):
    def __init__(self):
      super(Model_architecture_modification_TNet,self).__init__()

      self.features = torch.nn.Sequential(
        nn.Conv2d(1, 8, 3),
        nn.ReLU(),
        nn.MaxPool2d(2, stride=2),
        nn.Dropout(0.5),
        nn.Conv2d(8, 16, 3),
        nn.ReLU(),
        nn.MaxPool2d(2, stride=2),
        nn.Dropout(0.5),
        nn.Conv2d(16, 256, 3),
        nn.ReLU(),
        nn.MaxPool2d(2, stride=2),
        nn.Dropout(0.5),
      )

      self.classifier = nn.Sequential(
         nn.Linear(9216, 22),
      )

    def forward(self, x):
      x = self.features(x)
      x = torch.flatten(x, 1)
      x = self.classifier(x)
      return x

# %%
#--------------------------------------------------
#       Start Training & Evaluation
#--------------------------------------------------
net = Model_architecture_modification_TNet()
train_option = {}
train_option['lr'] = 0.001
train_option['epoch'] = 100
train_option['device'] = 'gpu'
trainModel(net, trainloader_small, train_option, testloader_small)
# Out:
# Epoch: 1 | Iter:    0 | Time: 00:00:00 | Train Loss: 3.1228 | Average Loss: 3.1228
# Accuracy: 0.062500 | Time: 00:00:00
# Epoch: 2 | Iter:    0 | Time: 00:00:00 | Train Loss: 3.4431 | Average Loss: 6.5868
# Accuracy: 0.031250 | Time: 00:00:00
# Epoch: 3 | Iter:    0 | Time: 00:00:00 | Train Loss: 3.3142 | Average Loss: 4.8764
# Accuracy: 0.031250 | Time: 00:00:00
# Epoch: 4 | Iter:    0 | Time: 00:00:00 | Train Loss: 3.2519 | Average Loss: 4.2914
# Accuracy: 0.062500 | Time: 00:00:00
# Epoch: 5 | Iter:    0 | Time: 00:00:00 | Train Loss: 3.2199 | Average Loss: 3.9913
# Accuracy: 0.093750 | Time: 00:00:00
# Epoch: 6 | Iter:    0 | Time: 00:00:00 | Train Loss: 3.2086 | Average Loss: 3.8076
# Accuracy: 0.125000 | Time: 00:00:00
# Epoch: 7 | Iter:    0 | Time: 00:00:00 | Train Loss: 3.1550 | Average Loss: 3.6815
# Accuracy: 0.062500 | Time: 00:00:00
# Epoch: 8 | Iter:    0 | Time: 00:00:00 | Train Loss: 3.1115 | Average Loss: 3.5870
# Accuracy: 0.062500 | Time: 00:00:00
# Epoch: 9 | Iter:    0 | Time: 00:00:00 | Train Loss: 3.0478 | Average Loss: 3.5122
# Accuracy: 0.062500 | Time: 00:00:00
# Epoch:10 | Iter:    0 | Time: 00:00:00 | Train Loss: 2.9789 | Average Loss: 3.4474
# Accuracy: 0.187500 | Time: 00:00:00
# Epoch:11 | Iter:    0 | Time: 00:00:00 | Train Loss: 2.8932 | Average Loss: 3.3863
# Accuracy: 0.406250 | Time: 00:00:00
# Epoch:12 | Iter:    0 | Time: 00:00:00 | Train Loss: 2.8449 | Average Loss: 3.3234
# Accuracy: 0.437500 | Time: 00:00:00
# Epoch:13 | Iter:    0 | Time: 00:00:00 | Train Loss: 2.7838 | Average Loss: 3.2552
# Accuracy: 0.437500 | Time: 00:00:00
# Epoch:14 | Iter:    0 | Time: 00:00:00 | Train Loss: 2.7644 | Average Loss: 3.1839
# Accuracy: 0.468750 | Time: 00:00:00
# Epoch:15 | Iter:    0 | Time: 00:00:00 | Train Loss: 2.4706 | Average Loss: 3.1056
# Accuracy: 0.500000 | Time: 00:00:00
# Epoch:16 | Iter:    0 | Time: 00:00:00 | Train Loss: 2.3080 | Average Loss: 3.0247
# Accuracy: 0.468750 | Time: 00:00:00
# Epoch:17 | Iter:    0 | Time: 00:00:00 | Train Loss: 2.0731 | Average Loss: 2.9459
# Accuracy: 0.500000 | Time: 00:00:00
# Epoch:18 | Iter:    0 | Time: 00:00:00 | Train Loss: 1.8527 | Average Loss: 2.8650
# Accuracy: 0.500000 | Time: 00:00:00
# Epoch:19 | Iter:    0 | Time: 00:00:00 | Train Loss: 1.8311 | Average Loss: 2.7876
# Accuracy: 0.500000 | Time: 00:00:00
# Epoch:20 | Iter:    0 | Time: 00:00:01 | Train Loss: 1.8361 | Average Loss: 2.7144
# Accuracy: 0.468750 | Time: 00:00:00
# Epoch:21 | Iter:    0 | Time: 00:00:01 | Train Loss: 1.5638 | Average Loss: 2.6366
# Accuracy: 0.406250 | Time: 00:00:00
# Epoch:22 | Iter:    0 | Time: 00:00:01 | Train Loss: 1.5539 | Average Loss: 2.5678
# Accuracy: 0.500000 | Time: 00:00:00
# Epoch:23 | Iter:    0 | Time: 00:00:01 | Train Loss: 1.1582 | Average Loss: 2.4965
# Accuracy: 0.406250 | Time: 00:00:00
# Epoch:24 | Iter:    0 | Time: 00:00:01 | Train Loss: 1.7080 | Average Loss: 2.4288
# Accuracy: 0.468750 | Time: 00:00:00
# Epoch:25 | Iter:    0 | Time: 00:00:01 | Train Loss: 1.2158 | Average Loss: 2.3613
# Accuracy: 0.500000 | Time: 00:00:00
# Epoch:26 | Iter:    0 | Time: 00:00:01 | Train Loss: 1.1375 | Average Loss: 2.3044
# Accuracy: 0.437500 | Time: 00:00:00
# Epoch:27 | Iter:    0 | Time: 00:00:01 | Train Loss: 1.2157 | Average Loss: 2.2438
# Accuracy: 0.437500 | Time: 00:00:00
# Epoch:28 | Iter:    0 | Time: 00:00:01 | Train Loss: 1.0106 | Average Loss: 2.1859
# Accuracy: 0.437500 | Time: 00:00:00
# Epoch:29 | Iter:    0 | Time: 00:00:01 | Train Loss: 0.6690 | Average Loss: 2.1296
# Accuracy: 0.437500 | Time: 00:00:00
# Epoch:30 | Iter:    0 | Time: 00:00:01 | Train Loss: 1.0633 | Average Loss: 2.0780
# Accuracy: 0.500000 | Time: 00:00:00
# Epoch:31 | Iter:    0 | Time: 00:00:01 | Train Loss: 0.7018 | Average Loss: 2.0259
# Accuracy: 0.406250 | Time: 00:00:00
# Epoch:32 | Iter:    0 | Time: 00:00:01 | Train Loss: 1.2085 | Average Loss: 1.9777
# Accuracy: 0.531250 | Time: 00:00:00
# Epoch:33 | Iter:    0 | Time: 00:00:01 | Train Loss: 0.5508 | Average Loss: 1.9323
# Accuracy: 0.468750 | Time: 00:00:00
# Epoch:34 | Iter:    0 | Time: 00:00:01 | Train Loss: 1.1973 | Average Loss: 1.8884
# Accuracy: 0.437500 | Time: 00:00:00
# Epoch:35 | Iter:    0 | Time: 00:00:01 | Train Loss: 0.6775 | Average Loss: 1.8472
# Accuracy: 0.468750 | Time: 00:00:00
# Epoch:36 | Iter:    0 | Time: 00:00:01 | Train Loss: 0.7685 | Average Loss: 1.8139
# Accuracy: 0.500000 | Time: 00:00:00
# Epoch:37 | Iter:    0 | Time: 00:00:01 | Train Loss: 0.7045 | Average Loss: 1.7800
# Accuracy: 0.437500 | Time: 00:00:00
# Epoch:38 | Iter:    0 | Time: 00:00:01 | Train Loss: 0.7554 | Average Loss: 1.7434
# Accuracy: 0.500000 | Time: 00:00:00
# Epoch:39 | Iter:    0 | Time: 00:00:01 | Train Loss: 0.4746 | Average Loss: 1.7106
# Accuracy: 0.500000 | Time: 00:00:00
# Epoch:40 | Iter:    0 | Time: 00:00:02 | Train Loss: 0.6340 | Average Loss: 1.6765
# Accuracy: 0.500000 | Time: 00:00:00
# Epoch:41 | Iter:    0 | Time: 00:00:02 | Train Loss: 0.4147 | Average Loss: 1.6429
# Accuracy: 0.468750 | Time: 00:00:00
# Epoch:42 | Iter:    0 | Time: 00:00:02 | Train Loss: 0.7516 | Average Loss: 1.6092
# Accuracy: 0.531250 | Time: 00:00:00
# Epoch:43 | Iter:    0 | Time: 00:00:02 | Train Loss: 0.2950 | Average Loss: 1.5781
# Accuracy: 0.531250 | Time: 00:00:00
# Epoch:44 | Iter:    0 | Time: 00:00:02 | Train Loss: 0.9426 | Average Loss: 1.5505
# Accuracy: 0.500000 | Time: 00:00:00
# Epoch:45 | Iter:    0 | Time: 00:00:02 | Train Loss: 0.4332 | Average Loss: 1.5234
# Accuracy: 0.468750 | Time: 00:00:00
# Epoch:46 | Iter:    0 | Time: 00:00:02 | Train Loss: 0.8923 | Average Loss: 1.4975
# Accuracy: 0.468750 | Time: 00:00:00
# Epoch:47 | Iter:    0 | Time: 00:00:02 | Train Loss: 0.3016 | Average Loss: 1.4705
# Accuracy: 0.500000 | Time: 00:00:00
# Epoch:48 | Iter:    0 | Time: 00:00:02 | Train Loss: 0.5492 | Average Loss: 1.4454
# Accuracy: 0.468750 | Time: 00:00:00
# Epoch:49 | Iter:    0 | Time: 00:00:02 | Train Loss: 0.2174 | Average Loss: 1.4212
# Accuracy: 0.562500 | Time: 00:00:00
# Epoch:50 | Iter:    0 | Time: 00:00:02 | Train Loss: 0.9387 | Average Loss: 1.3980
# Accuracy: 0.531250 | Time: 00:00:00
# Epoch:51 | Iter:    0 | Time: 00:00:02 | Train Loss: 0.1908 | Average Loss: 1.3747
# Accuracy: 0.468750 | Time: 00:00:00
# Epoch:52 | Iter:    0 | Time: 00:00:02 | Train Loss: 0.7814 | Average Loss: 1.3555
# Accuracy: 0.437500 | Time: 00:00:00
# Epoch:53 | Iter:    0 | Time: 00:00:02 | Train Loss: 0.2838 | Average Loss: 1.3334
# Accuracy: 0.531250 | Time: 00:00:00
# Epoch:54 | Iter:    0 | Time: 00:00:02 | Train Loss: 0.6127 | Average Loss: 1.3135
# Accuracy: 0.531250 | Time: 00:00:00
# Epoch:55 | Iter:    0 | Time: 00:00:02 | Train Loss: 0.2970 | Average Loss: 1.2930
# Accuracy: 0.531250 | Time: 00:00:00
# Epoch:56 | Iter:    0 | Time: 00:00:02 | Train Loss: 0.4033 | Average Loss: 1.2719
# Accuracy: 0.500000 | Time: 00:00:00
# Epoch:57 | Iter:    0 | Time: 00:00:02 | Train Loss: 0.4071 | Average Loss: 1.2524
# Accuracy: 0.531250 | Time: 00:00:00
# Epoch:58 | Iter:    0 | Time: 00:00:02 | Train Loss: 0.1425 | Average Loss: 1.2341
# Accuracy: 0.500000 | Time: 00:00:00
# Epoch:59 | Iter:    0 | Time: 00:00:02 | Train Loss: 0.5099 | Average Loss: 1.2161
# Accuracy: 0.531250 | Time: 00:00:00
# Epoch:60 | Iter:    0 | Time: 00:00:02 | Train Loss: 0.6615 | Average Loss: 1.1992
# Accuracy: 0.500000 | Time: 00:00:00
# Epoch:61 | Iter:    0 | Time: 00:00:02 | Train Loss: 0.3146 | Average Loss: 1.1832
# Accuracy: 0.500000 | Time: 00:00:00
# Epoch:62 | Iter:    0 | Time: 00:00:02 | Train Loss: 0.3562 | Average Loss: 1.1675
# Accuracy: 0.500000 | Time: 00:00:00
# Epoch:63 | Iter:    0 | Time: 00:00:02 | Train Loss: 0.3959 | Average Loss: 1.1539
# Accuracy: 0.531250 | Time: 00:00:00
# Epoch:64 | Iter:    0 | Time: 00:00:02 | Train Loss: 0.1069 | Average Loss: 1.1391
# Accuracy: 0.500000 | Time: 00:00:00
# Epoch:65 | Iter:    0 | Time: 00:00:03 | Train Loss: 0.3300 | Average Loss: 1.1246
# Accuracy: 0.468750 | Time: 00:00:00
# Epoch:66 | Iter:    0 | Time: 00:00:03 | Train Loss: 0.5928 | Average Loss: 1.1103
# Accuracy: 0.468750 | Time: 00:00:00
# Epoch:67 | Iter:    0 | Time: 00:00:03 | Train Loss: 0.4531 | Average Loss: 1.0975
# Accuracy: 0.437500 | Time: 00:00:00
# Epoch:68 | Iter:    0 | Time: 00:00:03 | Train Loss: 0.1495 | Average Loss: 1.0840
# Accuracy: 0.500000 | Time: 00:00:00
# Epoch:69 | Iter:    0 | Time: 00:00:03 | Train Loss: 0.2694 | Average Loss: 1.0703
# Accuracy: 0.531250 | Time: 00:00:00
# Epoch:70 | Iter:    0 | Time: 00:00:03 | Train Loss: 0.0818 | Average Loss: 1.0559
# Accuracy: 0.468750 | Time: 00:00:00
# Epoch:71 | Iter:    0 | Time: 00:00:03 | Train Loss: 0.5762 | Average Loss: 1.0438
# Accuracy: 0.593750 | Time: 00:00:00
# Epoch:72 | Iter:    0 | Time: 00:00:03 | Train Loss: 0.1624 | Average Loss: 1.0309
# Accuracy: 0.500000 | Time: 00:00:00
# Epoch:73 | Iter:    0 | Time: 00:00:03 | Train Loss: 0.0973 | Average Loss: 1.0180
# Accuracy: 0.500000 | Time: 00:00:00
# Epoch:74 | Iter:    0 | Time: 00:00:03 | Train Loss: 0.3287 | Average Loss: 1.0053
# Accuracy: 0.531250 | Time: 00:00:00
# Epoch:75 | Iter:    0 | Time: 00:00:03 | Train Loss: 0.2557 | Average Loss: 0.9955
# Accuracy: 0.468750 | Time: 00:00:00
# Epoch:76 | Iter:    0 | Time: 00:00:03 | Train Loss: 0.3235 | Average Loss: 0.9832
# Accuracy: 0.531250 | Time: 00:00:00
# Epoch:77 | Iter:    0 | Time: 00:00:03 | Train Loss: 0.0194 | Average Loss: 0.9721
# Accuracy: 0.468750 | Time: 00:00:00
# Epoch:78 | Iter:    0 | Time: 00:00:03 | Train Loss: 0.1105 | Average Loss: 0.9614
# Accuracy: 0.468750 | Time: 00:00:00
# Epoch:79 | Iter:    0 | Time: 00:00:03 | Train Loss: 0.2343 | Average Loss: 0.9498
# Accuracy: 0.562500 | Time: 00:00:00
# Epoch:80 | Iter:    0 | Time: 00:00:03 | Train Loss: 0.1940 | Average Loss: 0.9390
# Accuracy: 0.531250 | Time: 00:00:00
# Epoch:81 | Iter:    0 | Time: 00:00:03 | Train Loss: 0.0982 | Average Loss: 0.9278
# Accuracy: 0.500000 | Time: 00:00:00
# Epoch:82 | Iter:    0 | Time: 00:00:03 | Train Loss: 0.0887 | Average Loss: 0.9178
# Accuracy: 0.500000 | Time: 00:00:00
# Epoch:83 | Iter:    0 | Time: 00:00:03 | Train Loss: 0.3464 | Average Loss: 0.9077
# Accuracy: 0.562500 | Time: 00:00:00
# Epoch:84 | Iter:    0 | Time: 00:00:03 | Train Loss: 0.1184 | Average Loss: 0.8975
# Accuracy: 0.562500 | Time: 00:00:00
# Epoch:85 | Iter:    0 | Time: 00:00:03 | Train Loss: 0.0680 | Average Loss: 0.8881
# Accuracy: 0.531250 | Time: 00:00:00
# Epoch:86 | Iter:    0 | Time: 00:00:03 | Train Loss: 0.2198 | Average Loss: 0.8787
# Accuracy: 0.531250 | Time: 00:00:00
# Epoch:87 | Iter:    0 | Time: 00:00:03 | Train Loss: 0.5875 | Average Loss: 0.8700
# Accuracy: 0.500000 | Time: 00:00:00
# Epoch:88 | Iter:    0 | Time: 00:00:03 | Train Loss: 0.0719 | Average Loss: 0.8611
# Accuracy: 0.531250 | Time: 00:00:00
# Epoch:89 | Iter:    0 | Time: 00:00:03 | Train Loss: 0.0220 | Average Loss: 0.8523
# Accuracy: 0.468750 | Time: 00:00:00
# Epoch:90 | Iter:    0 | Time: 00:00:03 | Train Loss: 0.3441 | Average Loss: 0.8434
# Accuracy: 0.531250 | Time: 00:00:00
# Epoch:91 | Iter:    0 | Time: 00:00:04 | Train Loss: 0.0316 | Average Loss: 0.8349
# Accuracy: 0.500000 | Time: 00:00:00
# Epoch:92 | Iter:    0 | Time: 00:00:04 | Train Loss: 0.1975 | Average Loss: 0.8263
# Accuracy: 0.531250 | Time: 00:00:00
# Epoch:93 | Iter:    0 | Time: 00:00:04 | Train Loss: 0.0759 | Average Loss: 0.8186
# Accuracy: 0.531250 | Time: 00:00:00
# Epoch:94 | Iter:    0 | Time: 00:00:04 | Train Loss: 0.1326 | Average Loss: 0.8121
# Accuracy: 0.562500 | Time: 00:00:00
# Epoch:95 | Iter:    0 | Time: 00:00:04 | Train Loss: 0.1419 | Average Loss: 0.8040
# Accuracy: 0.562500 | Time: 00:00:00
# Epoch:96 | Iter:    0 | Time: 00:00:04 | Train Loss: 0.0271 | Average Loss: 0.7963
# Accuracy: 0.625000 | Time: 00:00:00
# Epoch:97 | Iter:    0 | Time: 00:00:04 | Train Loss: 0.0346 | Average Loss: 0.7892
# Accuracy: 0.500000 | Time: 00:00:00
# Epoch:98 | Iter:    0 | Time: 00:00:04 | Train Loss: 0.2109 | Average Loss: 0.7824
# Accuracy: 0.562500 | Time: 00:00:00
# Epoch:99 | Iter:    0 | Time: 00:00:04 | Train Loss: 0.0318 | Average Loss: 0.7752
# Accuracy: 0.531250 | Time: 00:00:00
# Epoch:100 | Iter:    0 | Time: 00:00:04 | Train Loss: 0.0405 | Average Loss: 0.7676
# Accuracy: 0.531250 | Time: 00:00:00

# %% [markdown]
# Answer:
#
# Method 1: Model architecture modification Method: Add another convolution layer, and a ReLU layer, and a Max pool layer.
#
# Accuracy on test data: 0.625000 (Epoch:96)
#
# (compare with 0.656250 in vanilla network, Accuracy decreases)

# %% [markdown]
# ### Technique 2

# %%
#--------------------------------------------------
#    Load Training Data and Testing Data
#--------------------------------------------------
# load data into size (64, 64)
img_size = (64, 64)
batch_size = 16 # training sample number per batch

# load training dataset
trainloader_small = list(load_dataset('./data/train/', img_size, batch_size=batch_size, shuffle=True, augment=True, zero_centered=True))
train_num = len(trainloader_small)
print("Finish loading %d minibatches (batch_size=%d) of training samples." % (train_num, batch_size))

# load testing dataset
testloader_small = list(load_dataset('./data/test/', img_size, num_per_class=50, batch_size=batch_size, zero_centered=True))
test_num = len(testloader_small)
print("Finish loading %d minibatches (batch_size=%d) of testing samples." % (test_num, batch_size))
# Out:
# Loading images from class: 0
# Loading images from class: 1
# Loading images from class: 2
# Loading images from class: 3
# Loading images from class: 4
# Loading images from class: 5
# Loading images from class: 6
# Loading images from class: 7
# Loading images from class: 8
# Loading images from class: 9
# Loading images from class: 10
# <ipython-input-4-f9969027fe30>:43: DeprecationWarning: `np.float` is a deprecated alias for the builtin `float`. To silence this warning, use `float` by itself. Doing this will not modify any behavior and is safe. If you specifically wanted the numpy scalar type, use `np.float64` here.
# Deprecated in NumPy 1.20; for more details and guidance: https://numpy.org/devdocs/release/1.20.0-notes.html#deprecations
#   data.append(img.astype(np.float)/255*2-1)
# Loading images from class: 11
# Loading images from class: 12
# Loading images from class: 13
# Loading images from class: 14
# Loading images from class: 15
# Loading images from class: 16
# Loading images from class: 17
# Loading images from class: 18
# Loading images from class: 19
# Loading images from class: 20
# Loading images from class: 21
# Finish loading 14 minibatches (batch_size=16) of training samples.
# Loading images from class: 0
# Loading images from class: 1
# Loading images from class: 2
# Loading images from class: 3
# Loading images from class: 4
# Loading images from class: 5
# Loading images from class: 6
# Loading images from class: 7
# Loading images from class: 8
# Loading images from class: 9
# Loading images from class: 10
# Loading images from class: 11
# Loading images from class: 12
# Loading images from class: 13
# Loading images from class: 14
# Loading images from class: 15
# Loading images from class: 16
# Loading images from class: 17
# Loading images from class: 18
# Loading images from class: 19
# Loading images from class: 20
# Loading images from class: 21
# Finish loading 2 minibatches (batch_size=16) of testing samples.

# %%
#--------------------------------------------------
#       Define Network Architecture
#--------------------------------------------------
class Batch_normalized_TNet(nn.Module):
    def __init__(self):
      super(Batch_normalized_TNet,self).__init__()

      self.features = torch.nn.Sequential(
        nn.Conv2d(1, 16, 3),
        nn.ReLU(),
        nn.BatchNorm2d(16),
        nn.MaxPool2d(4, stride=4),
        nn.Conv2d(16, 256, 3),
        nn.ReLU(),
        nn.BatchNorm2d(256),
        nn.MaxPool2d(4, stride=4),
        nn.Dropout(0.5),
      )

      self.classifier = nn.Sequential(
         nn.Linear(2304, 22),
      )

    def forward(self, x):
      x = self.features(x)
      x = torch.flatten(x, 1)
      x = self.classifier(x)
      return x

# %%
#--------------------------------------------------
#       Start Training & Evaluation
#--------------------------------------------------
net = Batch_normalized_TNet()
train_option = {}
train_option['lr'] = 0.001
train_option['epoch'] = 300
train_option['device'] = 'gpu'
trainModel(net, trainloader_small, train_option, testloader_small)
# Out:
# Epoch: 1 | Iter:    0 | Time: 00:00:00 | Train Loss: 4.4798 | Average Loss: 4.4798
# Accuracy: 0.156250 | Time: 00:00:00
# Epoch: 2 | Iter:    0 | Time: 00:00:00 | Train Loss: 8.1077 | Average Loss: 14.1937
# Accuracy: 0.218750 | Time: 00:00:00
# Epoch: 3 | Iter:    0 | Time: 00:00:00 | Train Loss: 3.2829 | Average Loss: 9.7065
# Accuracy: 0.437500 | Time: 00:00:00
# Epoch: 4 | Iter:    0 | Time: 00:00:00 | Train Loss: 2.5109 | Average Loss: 7.5625
# Accuracy: 0.468750 | Time: 00:00:00
# Epoch: 5 | Iter:    0 | Time: 00:00:00 | Train Loss: 0.8720 | Average Loss: 6.1145
# Accuracy: 0.593750 | Time: 00:00:00
# Epoch: 6 | Iter:    0 | Time: 00:00:00 | Train Loss: 1.0926 | Average Loss: 5.1465
# Accuracy: 0.656250 | Time: 00:00:00
# Epoch: 7 | Iter:    0 | Time: 00:00:00 | Train Loss: 0.5786 | Average Loss: 4.4067
# Accuracy: 0.625000 | Time: 00:00:00
# Epoch: 8 | Iter:    0 | Time: 00:00:00 | Train Loss: 0.4370 | Average Loss: 3.8484
# Accuracy: 0.625000 | Time: 00:00:00
# Epoch: 9 | Iter:    0 | Time: 00:00:00 | Train Loss: 0.9387 | Average Loss: 3.4298
# Accuracy: 0.656250 | Time: 00:00:00
# Epoch:10 | Iter:    0 | Time: 00:00:00 | Train Loss: 0.1317 | Average Loss: 3.0869
# Accuracy: 0.593750 | Time: 00:00:00
# Epoch:11 | Iter:    0 | Time: 00:00:00 | Train Loss: 0.6144 | Average Loss: 2.8060
# Accuracy: 0.687500 | Time: 00:00:00
# Epoch:12 | Iter:    0 | Time: 00:00:00 | Train Loss: 0.1237 | Average Loss: 2.5716
# Accuracy: 0.718750 | Time: 00:00:00
# Epoch:13 | Iter:    0 | Time: 00:00:00 | Train Loss: 0.1515 | Average Loss: 2.3760
# Accuracy: 0.687500 | Time: 00:00:00
# Epoch:14 | Iter:    0 | Time: 00:00:00 | Train Loss: 0.1442 | Average Loss: 2.2072
# Accuracy: 0.718750 | Time: 00:00:00
# Epoch:15 | Iter:    0 | Time: 00:00:00 | Train Loss: 0.1413 | Average Loss: 2.0639
# Accuracy: 0.562500 | Time: 00:00:00
# Epoch:16 | Iter:    0 | Time: 00:00:00 | Train Loss: 0.3594 | Average Loss: 1.9378
# Accuracy: 0.593750 | Time: 00:00:00
# Epoch:17 | Iter:    0 | Time: 00:00:00 | Train Loss: 0.1282 | Average Loss: 1.8234
# Accuracy: 0.625000 | Time: 00:00:00
# Epoch:18 | Iter:    0 | Time: 00:00:00 | Train Loss: 0.0391 | Average Loss: 1.7228
# Accuracy: 0.625000 | Time: 00:00:00
# Epoch:19 | Iter:    0 | Time: 00:00:00 | Train Loss: 0.1405 | Average Loss: 1.6337
# Accuracy: 0.500000 | Time: 00:00:00
# Epoch:20 | Iter:    0 | Time: 00:00:00 | Train Loss: 0.3969 | Average Loss: 1.5552
# Accuracy: 0.593750 | Time: 00:00:00
# Epoch:21 | Iter:    0 | Time: 00:00:00 | Train Loss: 0.0188 | Average Loss: 1.4854
# Accuracy: 0.468750 | Time: 00:00:00
# Epoch:22 | Iter:    0 | Time: 00:00:00 | Train Loss: 2.1032 | Average Loss: 1.4254
# Accuracy: 0.593750 | Time: 00:00:00
# Epoch:23 | Iter:    0 | Time: 00:00:00 | Train Loss: 0.0023 | Average Loss: 1.3685
# Accuracy: 0.531250 | Time: 00:00:00
# Epoch:24 | Iter:    0 | Time: 00:00:00 | Train Loss: 0.1207 | Average Loss: 1.3147
# Accuracy: 0.593750 | Time: 00:00:00
# Epoch:25 | Iter:    0 | Time: 00:00:00 | Train Loss: 0.1338 | Average Loss: 1.2654
# Accuracy: 0.562500 | Time: 00:00:00
# Epoch:26 | Iter:    0 | Time: 00:00:00 | Train Loss: 0.0559 | Average Loss: 1.2164
# Accuracy: 0.562500 | Time: 00:00:00
# Epoch:27 | Iter:    0 | Time: 00:00:00 | Train Loss: 0.0306 | Average Loss: 1.1720
# Accuracy: 0.562500 | Time: 00:00:00
# Epoch:28 | Iter:    0 | Time: 00:00:01 | Train Loss: 0.0241 | Average Loss: 1.1293
# Accuracy: 0.531250 | Time: 00:00:00
# Epoch:29 | Iter:    0 | Time: 00:00:01 | Train Loss: 0.0461 | Average Loss: 1.0896
# Accuracy: 0.593750 | Time: 00:00:00
# Epoch:30 | Iter:    0 | Time: 00:00:01 | Train Loss: 0.0043 | Average Loss: 1.0524
# Accuracy: 0.625000 | Time: 00:00:00
# Epoch:31 | Iter:    0 | Time: 00:00:01 | Train Loss: 0.0032 | Average Loss: 1.0177
# Accuracy: 0.656250 | Time: 00:00:00
# Epoch:32 | Iter:    0 | Time: 00:00:01 | Train Loss: 0.0126 | Average Loss: 0.9853
# Accuracy: 0.687500 | Time: 00:00:00
# Epoch:33 | Iter:    0 | Time: 00:00:01 | Train Loss: 0.0164 | Average Loss: 0.9549
# Accuracy: 0.656250 | Time: 00:00:00
# Epoch:34 | Iter:    0 | Time: 00:00:01 | Train Loss: 0.0135 | Average Loss: 0.9262
# Accuracy: 0.562500 | Time: 00:00:00
# Epoch:35 | Iter:    0 | Time: 00:00:01 | Train Loss: 0.0035 | Average Loss: 0.8994
# Accuracy: 0.593750 | Time: 00:00:00
# Epoch:36 | Iter:    0 | Time: 00:00:01 | Train Loss: 0.0092 | Average Loss: 0.8739
# Accuracy: 0.593750 | Time: 00:00:00
# Epoch:37 | Iter:    0 | Time: 00:00:01 | Train Loss: 0.0084 | Average Loss: 0.8499
# Accuracy: 0.562500 | Time: 00:00:00
# Epoch:38 | Iter:    0 | Time: 00:00:01 | Train Loss: 0.0036 | Average Loss: 0.8271
# Accuracy: 0.531250 | Time: 00:00:00
# Epoch:39 | Iter:    0 | Time: 00:00:01 | Train Loss: 0.0066 | Average Loss: 0.8055
# Accuracy: 0.593750 | Time: 00:00:00
# Epoch:40 | Iter:    0 | Time: 00:00:01 | Train Loss: 0.0090 | Average Loss: 0.7851
# Accuracy: 0.562500 | Time: 00:00:00
# Epoch:41 | Iter:    0 | Time: 00:00:01 | Train Loss: 0.0018 | Average Loss: 0.7656
# Accuracy: 0.625000 | Time: 00:00:00
# Epoch:42 | Iter:    0 | Time: 00:00:01 | Train Loss: 0.0034 | Average Loss: 0.7472
# Accuracy: 0.625000 | Time: 00:00:00
# Epoch:43 | Iter:    0 | Time: 00:00:01 | Train Loss: 0.0043 | Average Loss: 0.7295
# Accuracy: 0.625000 | Time: 00:00:00
# Epoch:44 | Iter:    0 | Time: 00:00:01 | Train Loss: 0.0046 | Average Loss: 0.7127
# Accuracy: 0.625000 | Time: 00:00:00
# Epoch:45 | Iter:    0 | Time: 00:00:01 | Train Loss: 0.0009 | Average Loss: 0.6966
# Accuracy: 0.625000 | Time: 00:00:00
# Epoch:46 | Iter:    0 | Time: 00:00:01 | Train Loss: 0.0013 | Average Loss: 0.6813
# Accuracy: 0.656250 | Time: 00:00:00
# Epoch:47 | Iter:    0 | Time: 00:00:01 | Train Loss: 0.0074 | Average Loss: 0.6666
# Accuracy: 0.625000 | Time: 00:00:00
# Epoch:48 | Iter:    0 | Time: 00:00:01 | Train Loss: 0.0032 | Average Loss: 0.6525
# Accuracy: 0.625000 | Time: 00:00:00
# Epoch:49 | Iter:    0 | Time: 00:00:01 | Train Loss: 0.0005 | Average Loss: 0.6390
# Accuracy: 0.656250 | Time: 00:00:00
# Epoch:50 | Iter:    0 | Time: 00:00:01 | Train Loss: 0.0015 | Average Loss: 0.6260
# Accuracy: 0.687500 | Time: 00:00:00
# Epoch:51 | Iter:    0 | Time: 00:00:01 | Train Loss: 0.0100 | Average Loss: 0.6137
# Accuracy: 0.656250 | Time: 00:00:00
# Epoch:52 | Iter:    0 | Time: 00:00:01 | Train Loss: 0.0032 | Average Loss: 0.6017
# Accuracy: 0.687500 | Time: 00:00:00
# Epoch:53 | Iter:    0 | Time: 00:00:01 | Train Loss: 0.0059 | Average Loss: 0.5902
# Accuracy: 0.656250 | Time: 00:00:00
# Epoch:54 | Iter:    0 | Time: 00:00:01 | Train Loss: 0.0065 | Average Loss: 0.5792
# Accuracy: 0.656250 | Time: 00:00:00
# Epoch:55 | Iter:    0 | Time: 00:00:02 | Train Loss: 0.0023 | Average Loss: 0.5686
# Accuracy: 0.656250 | Time: 00:00:00
# Epoch:56 | Iter:    0 | Time: 00:00:02 | Train Loss: 0.0129 | Average Loss: 0.5583
# Accuracy: 0.656250 | Time: 00:00:00
# Epoch:57 | Iter:    0 | Time: 00:00:02 | Train Loss: 0.0027 | Average Loss: 0.5484
# Accuracy: 0.625000 | Time: 00:00:00
# Epoch:58 | Iter:    0 | Time: 00:00:02 | Train Loss: 0.0015 | Average Loss: 0.5388
# Accuracy: 0.593750 | Time: 00:00:00
# Epoch:59 | Iter:    0 | Time: 00:00:02 | Train Loss: 0.0016 | Average Loss: 0.5296
# Accuracy: 0.625000 | Time: 00:00:00
# Epoch:60 | Iter:    0 | Time: 00:00:02 | Train Loss: 0.0019 | Average Loss: 0.5207
# Accuracy: 0.625000 | Time: 00:00:00
# Epoch:61 | Iter:    0 | Time: 00:00:02 | Train Loss: 0.0455 | Average Loss: 0.5121
# Accuracy: 0.593750 | Time: 00:00:00
# Epoch:62 | Iter:    0 | Time: 00:00:02 | Train Loss: 0.0031 | Average Loss: 0.5037
# Accuracy: 0.562500 | Time: 00:00:00
# Epoch:63 | Iter:    0 | Time: 00:00:02 | Train Loss: 0.0028 | Average Loss: 0.4957
# Accuracy: 0.562500 | Time: 00:00:00
# Epoch:64 | Iter:    0 | Time: 00:00:02 | Train Loss: 0.0037 | Average Loss: 0.4879
# Accuracy: 0.593750 | Time: 00:00:00
# Epoch:65 | Iter:    0 | Time: 00:00:02 | Train Loss: 0.0020 | Average Loss: 0.4803
# Accuracy: 0.593750 | Time: 00:00:00
# Epoch:66 | Iter:    0 | Time: 00:00:02 | Train Loss: 0.0030 | Average Loss: 0.4730
# Accuracy: 0.593750 | Time: 00:00:00
# Epoch:67 | Iter:    0 | Time: 00:00:02 | Train Loss: 0.0012 | Average Loss: 0.4659
# Accuracy: 0.593750 | Time: 00:00:00
# Epoch:68 | Iter:    0 | Time: 00:00:02 | Train Loss: 0.0099 | Average Loss: 0.4590
# Accuracy: 0.593750 | Time: 00:00:00
# Epoch:69 | Iter:    0 | Time: 00:00:02 | Train Loss: 0.0024 | Average Loss: 0.4523
# Accuracy: 0.593750 | Time: 00:00:00
# Epoch:70 | Iter:    0 | Time: 00:00:02 | Train Loss: 0.0024 | Average Loss: 0.4458
# Accuracy: 0.562500 | Time: 00:00:00
# Epoch:71 | Iter:    0 | Time: 00:00:02 | Train Loss: 0.0005 | Average Loss: 0.4394
# Accuracy: 0.531250 | Time: 00:00:00
# Epoch:72 | Iter:    0 | Time: 00:00:02 | Train Loss: 0.0028 | Average Loss: 0.4333
# Accuracy: 0.531250 | Time: 00:00:00
# Epoch:73 | Iter:    0 | Time: 00:00:02 | Train Loss: 0.0266 | Average Loss: 0.4273
# Accuracy: 0.531250 | Time: 00:00:00
# Epoch:74 | Iter:    0 | Time: 00:00:02 | Train Loss: 0.0040 | Average Loss: 0.4215
# Accuracy: 0.562500 | Time: 00:00:00
# Epoch:75 | Iter:    0 | Time: 00:00:02 | Train Loss: 0.0012 | Average Loss: 0.4159
# Accuracy: 0.625000 | Time: 00:00:00
# Epoch:76 | Iter:    0 | Time: 00:00:02 | Train Loss: 0.0003 | Average Loss: 0.4103
# Accuracy: 0.593750 | Time: 00:00:00
# Epoch:77 | Iter:    0 | Time: 00:00:02 | Train Loss: 0.0008 | Average Loss: 0.4050
# Accuracy: 0.562500 | Time: 00:00:00
# Epoch:78 | Iter:    0 | Time: 00:00:02 | Train Loss: 0.0028 | Average Loss: 0.3997
# Accuracy: 0.562500 | Time: 00:00:00
# Epoch:79 | Iter:    0 | Time: 00:00:02 | Train Loss: 0.0006 | Average Loss: 0.3946
# Accuracy: 0.562500 | Time: 00:00:00
# Epoch:80 | Iter:    0 | Time: 00:00:02 | Train Loss: 0.0007 | Average Loss: 0.3897
# Accuracy: 0.562500 | Time: 00:00:00
# Epoch:81 | Iter:    0 | Time: 00:00:02 | Train Loss: 0.0004 | Average Loss: 0.3848
# Accuracy: 0.593750 | Time: 00:00:00
# Epoch:82 | Iter:    0 | Time: 00:00:02 | Train Loss: 0.0015 | Average Loss: 0.3801
# Accuracy: 0.593750 | Time: 00:00:00
# Epoch:83 | Iter:    0 | Time: 00:00:03 | Train Loss: 0.0019 | Average Loss: 0.3755
# Accuracy: 0.562500 | Time: 00:00:00
# Epoch:84 | Iter:    0 | Time: 00:00:03 | Train Loss: 0.0005 | Average Loss: 0.3710
# Accuracy: 0.562500 | Time: 00:00:00
# Epoch:85 | Iter:    0 | Time: 00:00:03 | Train Loss: 0.0014 | Average Loss: 0.3666
# Accuracy: 0.562500 | Time: 00:00:00
# Epoch:86 | Iter:    0 | Time: 00:00:03 | Train Loss: 0.0026 | Average Loss: 0.3623
# Accuracy: 0.562500 | Time: 00:00:00
# Epoch:87 | Iter:    0 | Time: 00:00:03 | Train Loss: 0.0004 | Average Loss: 0.3581
# Accuracy: 0.625000 | Time: 00:00:00
# Epoch:88 | Iter:    0 | Time: 00:00:03 | Train Loss: 0.0015 | Average Loss: 0.3540
# Accuracy: 0.625000 | Time: 00:00:00
# Epoch:89 | Iter:    0 | Time: 00:00:03 | Train Loss: 0.0023 | Average Loss: 0.3500
# Accuracy: 0.625000 | Time: 00:00:00
# Epoch:90 | Iter:    0 | Time: 00:00:03 | Train Loss: 0.0007 | Average Loss: 0.3461
# Accuracy: 0.593750 | Time: 00:00:00
# Epoch:91 | Iter:    0 | Time: 00:00:03 | Train Loss: 0.0012 | Average Loss: 0.3423
# Accuracy: 0.625000 | Time: 00:00:00
# Epoch:92 | Iter:    0 | Time: 00:00:03 | Train Loss: 0.0011 | Average Loss: 0.3386
# Accuracy: 0.625000 | Time: 00:00:00
# Epoch:93 | Iter:    0 | Time: 00:00:03 | Train Loss: 0.0013 | Average Loss: 0.3349
# Accuracy: 0.625000 | Time: 00:00:00
# Epoch:94 | Iter:    0 | Time: 00:00:03 | Train Loss: 0.0036 | Average Loss: 0.3313
# Accuracy: 0.625000 | Time: 00:00:00
# Epoch:95 | Iter:    0 | Time: 00:00:03 | Train Loss: 0.0007 | Average Loss: 0.3278
# Accuracy: 0.625000 | Time: 00:00:00
# Epoch:96 | Iter:    0 | Time: 00:00:03 | Train Loss: 0.0006 | Average Loss: 0.3244
# Accuracy: 0.593750 | Time: 00:00:00
# Epoch:97 | Iter:    0 | Time: 00:00:03 | Train Loss: 0.0018 | Average Loss: 0.3210
# Accuracy: 0.593750 | Time: 00:00:00
# Epoch:98 | Iter:    0 | Time: 00:00:03 | Train Loss: 0.0004 | Average Loss: 0.3177
# Accuracy: 0.593750 | Time: 00:00:00
# Epoch:99 | Iter:    0 | Time: 00:00:03 | Train Loss: 0.0003 | Average Loss: 0.3145
# Accuracy: 0.593750 | Time: 00:00:00
# Epoch:100 | Iter:    0 | Time: 00:00:03 | Train Loss: 0.0054 | Average Loss: 0.3114
# Accuracy: 0.656250 | Time: 00:00:00
# Epoch:101 | Iter:    0 | Time: 00:00:03 | Train Loss: 0.0139 | Average Loss: 0.3083
# Accuracy: 0.625000 | Time: 00:00:00
# Epoch:102 | Iter:    0 | Time: 00:00:03 | Train Loss: 0.0002 | Average Loss: 0.3053
# Accuracy: 0.656250 | Time: 00:00:00
# Epoch:103 | Iter:    0 | Time: 00:00:03 | Train Loss: 0.0022 | Average Loss: 0.3023
# Accuracy: 0.656250 | Time: 00:00:00
# Epoch:104 | Iter:    0 | Time: 00:00:03 | Train Loss: 0.0039 | Average Loss: 0.2994
# Accuracy: 0.656250 | Time: 00:00:00
# Epoch:105 | Iter:    0 | Time: 00:00:03 | Train Loss: 0.0005 | Average Loss: 0.2965
# Accuracy: 0.656250 | Time: 00:00:00
# Epoch:106 | Iter:    0 | Time: 00:00:03 | Train Loss: 0.0031 | Average Loss: 0.2937
# Accuracy: 0.656250 | Time: 00:00:00
# Epoch:107 | Iter:    0 | Time: 00:00:03 | Train Loss: 0.0116 | Average Loss: 0.2910
# Accuracy: 0.656250 | Time: 00:00:00
# Epoch:108 | Iter:    0 | Time: 00:00:03 | Train Loss: 0.0002 | Average Loss: 0.2883
# Accuracy: 0.656250 | Time: 00:00:00
# Epoch:109 | Iter:    0 | Time: 00:00:03 | Train Loss: 0.0005 | Average Loss: 0.2856
# Accuracy: 0.593750 | Time: 00:00:00
# Epoch:110 | Iter:    0 | Time: 00:00:04 | Train Loss: 0.0008 | Average Loss: 0.2830
# Accuracy: 0.593750 | Time: 00:00:00
# Epoch:111 | Iter:    0 | Time: 00:00:04 | Train Loss: 0.0028 | Average Loss: 0.2804
# Accuracy: 0.593750 | Time: 00:00:00
# Epoch:112 | Iter:    0 | Time: 00:00:04 | Train Loss: 0.0003 | Average Loss: 0.2779
# Accuracy: 0.593750 | Time: 00:00:00
# Epoch:113 | Iter:    0 | Time: 00:00:04 | Train Loss: 0.0005 | Average Loss: 0.2754
# Accuracy: 0.593750 | Time: 00:00:00
# Epoch:114 | Iter:    0 | Time: 00:00:04 | Train Loss: 0.0010 | Average Loss: 0.2730
# Accuracy: 0.625000 | Time: 00:00:00
# Epoch:115 | Iter:    0 | Time: 00:00:04 | Train Loss: 0.0038 | Average Loss: 0.2706
# Accuracy: 0.562500 | Time: 00:00:00
# Epoch:116 | Iter:    0 | Time: 00:00:04 | Train Loss: 0.0661 | Average Loss: 0.2684
# Accuracy: 0.593750 | Time: 00:00:00
# Epoch:117 | Iter:    0 | Time: 00:00:04 | Train Loss: 5.5944 | Average Loss: 0.2706
# Accuracy: 0.406250 | Time: 00:00:00
# Epoch:118 | Iter:    0 | Time: 00:00:04 | Train Loss: 15.3735 | Average Loss: 0.3106
# Accuracy: 0.343750 | Time: 00:00:00
# Epoch:119 | Iter:    0 | Time: 00:00:04 | Train Loss: 1.3428 | Average Loss: 0.3836
# Accuracy: 0.437500 | Time: 00:00:00
# Epoch:120 | Iter:    0 | Time: 00:00:04 | Train Loss: 0.2750 | Average Loss: 0.4181
# Accuracy: 0.531250 | Time: 00:00:00
# Epoch:121 | Iter:    0 | Time: 00:00:04 | Train Loss: 0.3770 | Average Loss: 0.4255
# Accuracy: 0.500000 | Time: 00:00:00
# Epoch:122 | Iter:    0 | Time: 00:00:04 | Train Loss: 0.6745 | Average Loss: 0.4251
# Accuracy: 0.625000 | Time: 00:00:00
# Epoch:123 | Iter:    0 | Time: 00:00:04 | Train Loss: 0.0211 | Average Loss: 0.4221
# Accuracy: 0.531250 | Time: 00:00:00
# Epoch:124 | Iter:    0 | Time: 00:00:04 | Train Loss: 0.0014 | Average Loss: 0.4190
# Accuracy: 0.468750 | Time: 00:00:00
# Epoch:125 | Iter:    0 | Time: 00:00:04 | Train Loss: 0.0106 | Average Loss: 0.4158
# Accuracy: 0.437500 | Time: 00:00:00
# Epoch:126 | Iter:    0 | Time: 00:00:04 | Train Loss: 0.0347 | Average Loss: 0.4125
# Accuracy: 0.593750 | Time: 00:00:00
# Epoch:127 | Iter:    0 | Time: 00:00:04 | Train Loss: 0.0206 | Average Loss: 0.4093
# Accuracy: 0.562500 | Time: 00:00:00
# Epoch:128 | Iter:    0 | Time: 00:00:04 | Train Loss: 0.0014 | Average Loss: 0.4062
# Accuracy: 0.593750 | Time: 00:00:00
# Epoch:129 | Iter:    0 | Time: 00:00:04 | Train Loss: 0.0113 | Average Loss: 0.4031
# Accuracy: 0.593750 | Time: 00:00:00
# Epoch:130 | Iter:    0 | Time: 00:00:04 | Train Loss: 0.0080 | Average Loss: 0.4000
# Accuracy: 0.593750 | Time: 00:00:00
# Epoch:131 | Iter:    0 | Time: 00:00:04 | Train Loss: 0.0043 | Average Loss: 0.3971
# Accuracy: 0.593750 | Time: 00:00:00
# Epoch:132 | Iter:    0 | Time: 00:00:04 | Train Loss: 0.0021 | Average Loss: 0.3941
# Accuracy: 0.562500 | Time: 00:00:00
# Epoch:133 | Iter:    0 | Time: 00:00:04 | Train Loss: 0.1618 | Average Loss: 0.3915
# Accuracy: 0.625000 | Time: 00:00:00
# Epoch:134 | Iter:    0 | Time: 00:00:04 | Train Loss: 0.0019 | Average Loss: 0.3886
# Accuracy: 0.656250 | Time: 00:00:00
# Epoch:135 | Iter:    0 | Time: 00:00:04 | Train Loss: 0.0015 | Average Loss: 0.3858
# Accuracy: 0.625000 | Time: 00:00:00
# Epoch:136 | Iter:    0 | Time: 00:00:04 | Train Loss: 0.0072 | Average Loss: 0.3830
# Accuracy: 0.625000 | Time: 00:00:00
# Epoch:137 | Iter:    0 | Time: 00:00:04 | Train Loss: 0.0016 | Average Loss: 0.3803
# Accuracy: 0.625000 | Time: 00:00:00
# Epoch:138 | Iter:    0 | Time: 00:00:05 | Train Loss: 0.0007 | Average Loss: 0.3775
# Accuracy: 0.625000 | Time: 00:00:00
# Epoch:139 | Iter:    0 | Time: 00:00:05 | Train Loss: 0.0006 | Average Loss: 0.3748
# Accuracy: 0.625000 | Time: 00:00:00
# Epoch:140 | Iter:    0 | Time: 00:00:05 | Train Loss: 0.0021 | Average Loss: 0.3722
# Accuracy: 0.625000 | Time: 00:00:00
# Epoch:141 | Iter:    0 | Time: 00:00:05 | Train Loss: 0.0025 | Average Loss: 0.3696
# Accuracy: 0.625000 | Time: 00:00:00
# Epoch:142 | Iter:    0 | Time: 00:00:05 | Train Loss: 0.0417 | Average Loss: 0.3671
# Accuracy: 0.625000 | Time: 00:00:00
# Epoch:143 | Iter:    0 | Time: 00:00:05 | Train Loss: 0.0038 | Average Loss: 0.3645
# Accuracy: 0.625000 | Time: 00:00:00
# Epoch:144 | Iter:    0 | Time: 00:00:05 | Train Loss: 0.0012 | Average Loss: 0.3620
# Accuracy: 0.625000 | Time: 00:00:00
# Epoch:145 | Iter:    0 | Time: 00:00:05 | Train Loss: 0.0003 | Average Loss: 0.3596
# Accuracy: 0.625000 | Time: 00:00:00
# Epoch:146 | Iter:    0 | Time: 00:00:05 | Train Loss: 0.0164 | Average Loss: 0.3571
# Accuracy: 0.625000 | Time: 00:00:00
# Epoch:147 | Iter:    0 | Time: 00:00:05 | Train Loss: 0.0216 | Average Loss: 0.3548
# Accuracy: 0.625000 | Time: 00:00:00
# Epoch:148 | Iter:    0 | Time: 00:00:05 | Train Loss: 0.0008 | Average Loss: 0.3524
# Accuracy: 0.625000 | Time: 00:00:00
# Epoch:149 | Iter:    0 | Time: 00:00:05 | Train Loss: 0.0027 | Average Loss: 0.3500
# Accuracy: 0.625000 | Time: 00:00:00
# Epoch:150 | Iter:    0 | Time: 00:00:05 | Train Loss: 0.0168 | Average Loss: 0.3477
# Accuracy: 0.625000 | Time: 00:00:00
# Epoch:151 | Iter:    0 | Time: 00:00:05 | Train Loss: 0.0038 | Average Loss: 0.3454
# Accuracy: 0.625000 | Time: 00:00:00
# Epoch:152 | Iter:    0 | Time: 00:00:05 | Train Loss: 0.0164 | Average Loss: 0.3432
# Accuracy: 0.656250 | Time: 00:00:00
# Epoch:153 | Iter:    0 | Time: 00:00:05 | Train Loss: 0.0128 | Average Loss: 0.3409
# Accuracy: 0.687500 | Time: 00:00:00
# Epoch:154 | Iter:    0 | Time: 00:00:05 | Train Loss: 0.0003 | Average Loss: 0.3387
# Accuracy: 0.687500 | Time: 00:00:00
# Epoch:155 | Iter:    0 | Time: 00:00:05 | Train Loss: 0.0002 | Average Loss: 0.3366
# Accuracy: 0.656250 | Time: 00:00:00
# Epoch:156 | Iter:    0 | Time: 00:00:05 | Train Loss: 0.0002 | Average Loss: 0.3345
# Accuracy: 0.562500 | Time: 00:00:00
# Epoch:157 | Iter:    0 | Time: 00:00:05 | Train Loss: 0.0007 | Average Loss: 0.3324
# Accuracy: 0.656250 | Time: 00:00:00
# Epoch:158 | Iter:    0 | Time: 00:00:05 | Train Loss: 0.0098 | Average Loss: 0.3305
# Accuracy: 0.625000 | Time: 00:00:00
# Epoch:159 | Iter:    0 | Time: 00:00:05 | Train Loss: 0.0073 | Average Loss: 0.3284
# Accuracy: 0.625000 | Time: 00:00:00
# Epoch:160 | Iter:    0 | Time: 00:00:05 | Train Loss: 0.0013 | Average Loss: 0.3263
# Accuracy: 0.656250 | Time: 00:00:00
# Epoch:161 | Iter:    0 | Time: 00:00:05 | Train Loss: 0.0029 | Average Loss: 0.3243
# Accuracy: 0.656250 | Time: 00:00:00
# Epoch:162 | Iter:    0 | Time: 00:00:05 | Train Loss: 0.0013 | Average Loss: 0.3223
# Accuracy: 0.656250 | Time: 00:00:00
# Epoch:163 | Iter:    0 | Time: 00:00:05 | Train Loss: 0.0343 | Average Loss: 0.3204
# Accuracy: 0.656250 | Time: 00:00:00
# Epoch:164 | Iter:    0 | Time: 00:00:05 | Train Loss: 0.0226 | Average Loss: 0.3185
# Accuracy: 0.593750 | Time: 00:00:00
# Epoch:165 | Iter:    0 | Time: 00:00:06 | Train Loss: 0.0015 | Average Loss: 0.3165
# Accuracy: 0.593750 | Time: 00:00:00
# Epoch:166 | Iter:    0 | Time: 00:00:06 | Train Loss: 0.0009 | Average Loss: 0.3146
# Accuracy: 0.593750 | Time: 00:00:00
# Epoch:167 | Iter:    0 | Time: 00:00:06 | Train Loss: 0.0035 | Average Loss: 0.3127
# Accuracy: 0.625000 | Time: 00:00:00
# Epoch:168 | Iter:    0 | Time: 00:00:06 | Train Loss: 0.0011 | Average Loss: 0.3109
# Accuracy: 0.625000 | Time: 00:00:00
# Epoch:169 | Iter:    0 | Time: 00:00:06 | Train Loss: 0.0018 | Average Loss: 0.3090
# Accuracy: 0.656250 | Time: 00:00:00
# Epoch:170 | Iter:    0 | Time: 00:00:06 | Train Loss: 0.0002 | Average Loss: 0.3072
# Accuracy: 0.656250 | Time: 00:00:00
# Epoch:171 | Iter:    0 | Time: 00:00:06 | Train Loss: 0.0005 | Average Loss: 0.3054
# Accuracy: 0.625000 | Time: 00:00:00
# Epoch:172 | Iter:    0 | Time: 00:00:06 | Train Loss: 0.0005 | Average Loss: 0.3036
# Accuracy: 0.625000 | Time: 00:00:00
# Epoch:173 | Iter:    0 | Time: 00:00:06 | Train Loss: 0.0001 | Average Loss: 0.3019
# Accuracy: 0.625000 | Time: 00:00:00
# Epoch:174 | Iter:    0 | Time: 00:00:06 | Train Loss: 0.0004 | Average Loss: 0.3001
# Accuracy: 0.625000 | Time: 00:00:00
# Epoch:175 | Iter:    0 | Time: 00:00:06 | Train Loss: 0.0002 | Average Loss: 0.2984
# Accuracy: 0.625000 | Time: 00:00:00
# Epoch:176 | Iter:    0 | Time: 00:00:06 | Train Loss: 0.0003 | Average Loss: 0.2967
# Accuracy: 0.656250 | Time: 00:00:00
# Epoch:177 | Iter:    0 | Time: 00:00:06 | Train Loss: 0.0004 | Average Loss: 0.2950
# Accuracy: 0.656250 | Time: 00:00:00
# Epoch:178 | Iter:    0 | Time: 00:00:06 | Train Loss: 0.0012 | Average Loss: 0.2934
# Accuracy: 0.656250 | Time: 00:00:00
# Epoch:179 | Iter:    0 | Time: 00:00:06 | Train Loss: 0.0003 | Average Loss: 0.2917
# Accuracy: 0.593750 | Time: 00:00:00
# Epoch:180 | Iter:    0 | Time: 00:00:06 | Train Loss: 0.0008 | Average Loss: 0.2901
# Accuracy: 0.625000 | Time: 00:00:00
# Epoch:181 | Iter:    0 | Time: 00:00:06 | Train Loss: 0.0010 | Average Loss: 0.2885
# Accuracy: 0.625000 | Time: 00:00:00
# Epoch:182 | Iter:    0 | Time: 00:00:06 | Train Loss: 0.0007 | Average Loss: 0.2870
# Accuracy: 0.593750 | Time: 00:00:00
# Epoch:183 | Iter:    0 | Time: 00:00:06 | Train Loss: 0.0058 | Average Loss: 0.2854
# Accuracy: 0.562500 | Time: 00:00:00
# Epoch:184 | Iter:    0 | Time: 00:00:06 | Train Loss: 0.0140 | Average Loss: 0.2839
# Accuracy: 0.625000 | Time: 00:00:00
# Epoch:185 | Iter:    0 | Time: 00:00:06 | Train Loss: 0.0011 | Average Loss: 0.2824
# Accuracy: 0.625000 | Time: 00:00:00
# Epoch:186 | Iter:    0 | Time: 00:00:06 | Train Loss: 0.0002 | Average Loss: 0.2808
# Accuracy: 0.625000 | Time: 00:00:00
# Epoch:187 | Iter:    0 | Time: 00:00:06 | Train Loss: 0.0002 | Average Loss: 0.2793
# Accuracy: 0.656250 | Time: 00:00:00
# Epoch:188 | Iter:    0 | Time: 00:00:06 | Train Loss: 0.0006 | Average Loss: 0.2779
# Accuracy: 0.687500 | Time: 00:00:00
# Epoch:189 | Iter:    0 | Time: 00:00:06 | Train Loss: 0.0001 | Average Loss: 0.2764
# Accuracy: 0.687500 | Time: 00:00:00
# Epoch:190 | Iter:    0 | Time: 00:00:06 | Train Loss: 0.0054 | Average Loss: 0.2749
# Accuracy: 0.656250 | Time: 00:00:00
# Epoch:191 | Iter:    0 | Time: 00:00:06 | Train Loss: 0.0002 | Average Loss: 0.2735
# Accuracy: 0.656250 | Time: 00:00:00
# Epoch:192 | Iter:    0 | Time: 00:00:07 | Train Loss: 0.0014 | Average Loss: 0.2721
# Accuracy: 0.656250 | Time: 00:00:00
# Epoch:193 | Iter:    0 | Time: 00:00:07 | Train Loss: 0.0002 | Average Loss: 0.2707
# Accuracy: 0.687500 | Time: 00:00:00
# Epoch:194 | Iter:    0 | Time: 00:00:07 | Train Loss: 0.0004 | Average Loss: 0.2693
# Accuracy: 0.687500 | Time: 00:00:00
# Epoch:195 | Iter:    0 | Time: 00:00:07 | Train Loss: 0.0210 | Average Loss: 0.2680
# Accuracy: 0.625000 | Time: 00:00:00
# Epoch:196 | Iter:    0 | Time: 00:00:07 | Train Loss: 0.0003 | Average Loss: 0.2666
# Accuracy: 0.625000 | Time: 00:00:00
# Epoch:197 | Iter:    0 | Time: 00:00:07 | Train Loss: 0.0298 | Average Loss: 0.2653
# Accuracy: 0.656250 | Time: 00:00:00
# Epoch:198 | Iter:    0 | Time: 00:00:07 | Train Loss: 0.0021 | Average Loss: 0.2639
# Accuracy: 0.656250 | Time: 00:00:00
# Epoch:199 | Iter:    0 | Time: 00:00:07 | Train Loss: 0.0002 | Average Loss: 0.2626
# Accuracy: 0.656250 | Time: 00:00:00
# Epoch:200 | Iter:    0 | Time: 00:00:07 | Train Loss: 0.0006 | Average Loss: 0.2613
# Accuracy: 0.687500 | Time: 00:00:00
# Epoch:201 | Iter:    0 | Time: 00:00:07 | Train Loss: 0.0001 | Average Loss: 0.2601
# Accuracy: 0.718750 | Time: 00:00:00
# Epoch:202 | Iter:    0 | Time: 00:00:07 | Train Loss: 0.0017 | Average Loss: 0.2588
# Accuracy: 0.750000 | Time: 00:00:00
# Epoch:203 | Iter:    0 | Time: 00:00:07 | Train Loss: 0.0003 | Average Loss: 0.2575
# Accuracy: 0.750000 | Time: 00:00:00
# Epoch:204 | Iter:    0 | Time: 00:00:07 | Train Loss: 0.0055 | Average Loss: 0.2564
# Accuracy: 0.562500 | Time: 00:00:00
# Epoch:205 | Iter:    0 | Time: 00:00:07 | Train Loss: 0.0003 | Average Loss: 0.2551
# Accuracy: 0.562500 | Time: 00:00:00
# Epoch:206 | Iter:    0 | Time: 00:00:07 | Train Loss: 0.0002 | Average Loss: 0.2539
# Accuracy: 0.593750 | Time: 00:00:00
# Epoch:207 | Iter:    0 | Time: 00:00:07 | Train Loss: 0.0003 | Average Loss: 0.2527
# Accuracy: 0.687500 | Time: 00:00:00
# Epoch:208 | Iter:    0 | Time: 00:00:07 | Train Loss: 0.0003 | Average Loss: 0.2515
# Accuracy: 0.718750 | Time: 00:00:00
# Epoch:209 | Iter:    0 | Time: 00:00:07 | Train Loss: 0.0003 | Average Loss: 0.2503
# Accuracy: 0.718750 | Time: 00:00:00
# Epoch:210 | Iter:    0 | Time: 00:00:07 | Train Loss: 0.0003 | Average Loss: 0.2491
# Accuracy: 0.718750 | Time: 00:00:00
# Epoch:211 | Iter:    0 | Time: 00:00:07 | Train Loss: 0.0004 | Average Loss: 0.2479
# Accuracy: 0.718750 | Time: 00:00:00
# Epoch:212 | Iter:    0 | Time: 00:00:07 | Train Loss: 0.0000 | Average Loss: 0.2467
# Accuracy: 0.718750 | Time: 00:00:00
# Epoch:213 | Iter:    0 | Time: 00:00:07 | Train Loss: 0.0009 | Average Loss: 0.2455
# Accuracy: 0.718750 | Time: 00:00:00
# Epoch:214 | Iter:    0 | Time: 00:00:07 | Train Loss: 0.0001 | Average Loss: 0.2444
# Accuracy: 0.718750 | Time: 00:00:00
# Epoch:215 | Iter:    0 | Time: 00:00:07 | Train Loss: 0.0003 | Average Loss: 0.2433
# Accuracy: 0.718750 | Time: 00:00:00
# Epoch:216 | Iter:    0 | Time: 00:00:07 | Train Loss: 0.0013 | Average Loss: 0.2421
# Accuracy: 0.718750 | Time: 00:00:00
# Epoch:217 | Iter:    0 | Time: 00:00:07 | Train Loss: 0.0004 | Average Loss: 0.2410
# Accuracy: 0.718750 | Time: 00:00:00
# Epoch:218 | Iter:    0 | Time: 00:00:07 | Train Loss: 0.0002 | Average Loss: 0.2399
# Accuracy: 0.718750 | Time: 00:00:00
# Epoch:219 | Iter:    0 | Time: 00:00:08 | Train Loss: 0.0094 | Average Loss: 0.2388
# Accuracy: 0.718750 | Time: 00:00:00
# Epoch:220 | Iter:    0 | Time: 00:00:08 | Train Loss: 0.0003 | Average Loss: 0.2377
# Accuracy: 0.718750 | Time: 00:00:00
# Epoch:221 | Iter:    0 | Time: 00:00:08 | Train Loss: 0.0002 | Average Loss: 0.2366
# Accuracy: 0.687500 | Time: 00:00:00
# Epoch:222 | Iter:    0 | Time: 00:00:08 | Train Loss: 0.0001 | Average Loss: 0.2356
# Accuracy: 0.687500 | Time: 00:00:00
# Epoch:223 | Iter:    0 | Time: 00:00:08 | Train Loss: 0.0000 | Average Loss: 0.2345
# Accuracy: 0.687500 | Time: 00:00:00
# Epoch:224 | Iter:    0 | Time: 00:00:08 | Train Loss: 0.0008 | Average Loss: 0.2335
# Accuracy: 0.687500 | Time: 00:00:00
# Epoch:225 | Iter:    0 | Time: 00:00:08 | Train Loss: 0.0008 | Average Loss: 0.2324
# Accuracy: 0.687500 | Time: 00:00:00
# Epoch:226 | Iter:    0 | Time: 00:00:08 | Train Loss: 0.0021 | Average Loss: 0.2314
# Accuracy: 0.718750 | Time: 00:00:00
# Epoch:227 | Iter:    0 | Time: 00:00:08 | Train Loss: 0.0000 | Average Loss: 0.2304
# Accuracy: 0.718750 | Time: 00:00:00
# Epoch:228 | Iter:    0 | Time: 00:00:08 | Train Loss: 0.0001 | Average Loss: 0.2294
# Accuracy: 0.718750 | Time: 00:00:00
# Epoch:229 | Iter:    0 | Time: 00:00:08 | Train Loss: 0.0000 | Average Loss: 0.2284
# Accuracy: 0.687500 | Time: 00:00:00
# Epoch:230 | Iter:    0 | Time: 00:00:08 | Train Loss: 0.0032 | Average Loss: 0.2274
# Accuracy: 0.593750 | Time: 00:00:00
# Epoch:231 | Iter:    0 | Time: 00:00:08 | Train Loss: 0.0018 | Average Loss: 0.2265
# Accuracy: 0.593750 | Time: 00:00:00
# Epoch:232 | Iter:    0 | Time: 00:00:08 | Train Loss: 0.0012 | Average Loss: 0.2255
# Accuracy: 0.625000 | Time: 00:00:00
# Epoch:233 | Iter:    0 | Time: 00:00:08 | Train Loss: 0.0012 | Average Loss: 0.2245
# Accuracy: 0.656250 | Time: 00:00:00
# Epoch:234 | Iter:    0 | Time: 00:00:08 | Train Loss: 0.0001 | Average Loss: 0.2236
# Accuracy: 0.687500 | Time: 00:00:00
# Epoch:235 | Iter:    0 | Time: 00:00:08 | Train Loss: 0.0015 | Average Loss: 0.2226
# Accuracy: 0.687500 | Time: 00:00:00
# Epoch:236 | Iter:    0 | Time: 00:00:08 | Train Loss: 0.0001 | Average Loss: 0.2217
# Accuracy: 0.687500 | Time: 00:00:00
# Epoch:237 | Iter:    0 | Time: 00:00:08 | Train Loss: 0.0398 | Average Loss: 0.2208
# Accuracy: 0.718750 | Time: 00:00:00
# Epoch:238 | Iter:    0 | Time: 00:00:08 | Train Loss: 0.0001 | Average Loss: 0.2198
# Accuracy: 0.687500 | Time: 00:00:00
# Epoch:239 | Iter:    0 | Time: 00:00:08 | Train Loss: 0.0006 | Average Loss: 0.2189
# Accuracy: 0.656250 | Time: 00:00:00
# Epoch:240 | Iter:    0 | Time: 00:00:08 | Train Loss: 0.0005 | Average Loss: 0.2180
# Accuracy: 0.656250 | Time: 00:00:00
# Epoch:241 | Iter:    0 | Time: 00:00:08 | Train Loss: 0.0005 | Average Loss: 0.2171
# Accuracy: 0.687500 | Time: 00:00:00
# Epoch:242 | Iter:    0 | Time: 00:00:08 | Train Loss: 0.0079 | Average Loss: 0.2162
# Accuracy: 0.687500 | Time: 00:00:00
# Epoch:243 | Iter:    0 | Time: 00:00:08 | Train Loss: 0.0041 | Average Loss: 0.2153
# Accuracy: 0.625000 | Time: 00:00:00
# Epoch:244 | Iter:    0 | Time: 00:00:08 | Train Loss: 0.0001 | Average Loss: 0.2145
# Accuracy: 0.625000 | Time: 00:00:00
# Epoch:245 | Iter:    0 | Time: 00:00:08 | Train Loss: 0.0007 | Average Loss: 0.2136
# Accuracy: 0.625000 | Time: 00:00:00
# Epoch:246 | Iter:    0 | Time: 00:00:08 | Train Loss: 0.0006 | Average Loss: 0.2128
# Accuracy: 0.593750 | Time: 00:00:00
# Epoch:247 | Iter:    0 | Time: 00:00:09 | Train Loss: 0.0010 | Average Loss: 0.2119
# Accuracy: 0.531250 | Time: 00:00:00
# Epoch:248 | Iter:    0 | Time: 00:00:09 | Train Loss: 0.0108 | Average Loss: 0.2112
# Accuracy: 0.531250 | Time: 00:00:00
# Epoch:249 | Iter:    0 | Time: 00:00:09 | Train Loss: 0.0010 | Average Loss: 0.2104
# Accuracy: 0.531250 | Time: 00:00:00
# Epoch:250 | Iter:    0 | Time: 00:00:09 | Train Loss: 0.0003 | Average Loss: 0.2097
# Accuracy: 0.531250 | Time: 00:00:00
# Epoch:251 | Iter:    0 | Time: 00:00:09 | Train Loss: 0.0207 | Average Loss: 0.2089
# Accuracy: 0.468750 | Time: 00:00:00
# Epoch:252 | Iter:    0 | Time: 00:00:09 | Train Loss: 0.0010 | Average Loss: 0.2082
# Accuracy: 0.468750 | Time: 00:00:00
# Epoch:253 | Iter:    0 | Time: 00:00:09 | Train Loss: 0.0167 | Average Loss: 0.2078
# Accuracy: 0.562500 | Time: 00:00:00
# Epoch:254 | Iter:    0 | Time: 00:00:09 | Train Loss: 0.0004 | Average Loss: 0.2071
# Accuracy: 0.562500 | Time: 00:00:00
# Epoch:255 | Iter:    0 | Time: 00:00:09 | Train Loss: 0.0465 | Average Loss: 0.2063
# Accuracy: 0.562500 | Time: 00:00:00
# Epoch:256 | Iter:    0 | Time: 00:00:09 | Train Loss: 0.0057 | Average Loss: 0.2056
# Accuracy: 0.593750 | Time: 00:00:00
# Epoch:257 | Iter:    0 | Time: 00:00:09 | Train Loss: 0.0057 | Average Loss: 0.2050
# Accuracy: 0.656250 | Time: 00:00:00
# Epoch:258 | Iter:    0 | Time: 00:00:09 | Train Loss: 0.0181 | Average Loss: 0.2043
# Accuracy: 0.437500 | Time: 00:00:00
# Epoch:259 | Iter:    0 | Time: 00:00:09 | Train Loss: 0.0514 | Average Loss: 0.2039
# Accuracy: 0.437500 | Time: 00:00:00
# Epoch:260 | Iter:    0 | Time: 00:00:09 | Train Loss: 0.0020 | Average Loss: 0.2043
# Accuracy: 0.437500 | Time: 00:00:00
# Epoch:261 | Iter:    0 | Time: 00:00:09 | Train Loss: 0.3398 | Average Loss: 0.2149
# Accuracy: 0.531250 | Time: 00:00:00
# Epoch:262 | Iter:    0 | Time: 00:00:09 | Train Loss: 0.3981 | Average Loss: 0.2161
# Accuracy: 0.562500 | Time: 00:00:00
# Epoch:263 | Iter:    0 | Time: 00:00:09 | Train Loss: 0.4802 | Average Loss: 0.2179
# Accuracy: 0.531250 | Time: 00:00:00
# Epoch:264 | Iter:    0 | Time: 00:00:09 | Train Loss: 0.0104 | Average Loss: 0.2193
# Accuracy: 0.437500 | Time: 00:00:00
# Epoch:265 | Iter:    0 | Time: 00:00:09 | Train Loss: 0.0469 | Average Loss: 0.2188
# Accuracy: 0.437500 | Time: 00:00:00
# Epoch:266 | Iter:    0 | Time: 00:00:09 | Train Loss: 0.0093 | Average Loss: 0.2183
# Accuracy: 0.562500 | Time: 00:00:00
# Epoch:267 | Iter:    0 | Time: 00:00:09 | Train Loss: 0.0043 | Average Loss: 0.2176
# Accuracy: 0.562500 | Time: 00:00:00
# Epoch:268 | Iter:    0 | Time: 00:00:09 | Train Loss: 0.0126 | Average Loss: 0.2169
# Accuracy: 0.531250 | Time: 00:00:00
# Epoch:269 | Iter:    0 | Time: 00:00:09 | Train Loss: 0.0028 | Average Loss: 0.2162
# Accuracy: 0.500000 | Time: 00:00:00
# Epoch:270 | Iter:    0 | Time: 00:00:09 | Train Loss: 0.0660 | Average Loss: 0.2155
# Accuracy: 0.531250 | Time: 00:00:00
# Epoch:271 | Iter:    0 | Time: 00:00:09 | Train Loss: 0.1071 | Average Loss: 0.2148
# Accuracy: 0.562500 | Time: 00:00:00
# Epoch:272 | Iter:    0 | Time: 00:00:09 | Train Loss: 0.0000 | Average Loss: 0.2140
# Accuracy: 0.562500 | Time: 00:00:00
# Epoch:273 | Iter:    0 | Time: 00:00:09 | Train Loss: 0.0002 | Average Loss: 0.2132
# Accuracy: 0.562500 | Time: 00:00:00
# Epoch:274 | Iter:    0 | Time: 00:00:10 | Train Loss: 0.0001 | Average Loss: 0.2125
# Accuracy: 0.656250 | Time: 00:00:00
# Epoch:275 | Iter:    0 | Time: 00:00:10 | Train Loss: 0.0024 | Average Loss: 0.2117
# Accuracy: 0.656250 | Time: 00:00:00
# Epoch:276 | Iter:    0 | Time: 00:00:10 | Train Loss: 0.0012 | Average Loss: 0.2110
# Accuracy: 0.656250 | Time: 00:00:00
# Epoch:277 | Iter:    0 | Time: 00:00:10 | Train Loss: 0.0001 | Average Loss: 0.2102
# Accuracy: 0.656250 | Time: 00:00:00
# Epoch:278 | Iter:    0 | Time: 00:00:10 | Train Loss: 0.0009 | Average Loss: 0.2094
# Accuracy: 0.593750 | Time: 00:00:00
# Epoch:279 | Iter:    0 | Time: 00:00:10 | Train Loss: 0.0043 | Average Loss: 0.2087
# Accuracy: 0.625000 | Time: 00:00:00
# Epoch:280 | Iter:    0 | Time: 00:00:10 | Train Loss: 0.0106 | Average Loss: 0.2080
# Accuracy: 0.562500 | Time: 00:00:00
# Epoch:281 | Iter:    0 | Time: 00:00:10 | Train Loss: 0.0005 | Average Loss: 0.2073
# Accuracy: 0.562500 | Time: 00:00:00
# Epoch:282 | Iter:    0 | Time: 00:00:10 | Train Loss: 0.0005 | Average Loss: 0.2065
# Accuracy: 0.562500 | Time: 00:00:00
# Epoch:283 | Iter:    0 | Time: 00:00:10 | Train Loss: 0.0001 | Average Loss: 0.2058
# Accuracy: 0.562500 | Time: 00:00:00
# Epoch:284 | Iter:    0 | Time: 00:00:10 | Train Loss: 0.0003 | Average Loss: 0.2051
# Accuracy: 0.593750 | Time: 00:00:00
# Epoch:285 | Iter:    0 | Time: 00:00:10 | Train Loss: 0.0007 | Average Loss: 0.2044
# Accuracy: 0.625000 | Time: 00:00:00
# Epoch:286 | Iter:    0 | Time: 00:00:10 | Train Loss: 0.0003 | Average Loss: 0.2037
# Accuracy: 0.656250 | Time: 00:00:00
# Epoch:287 | Iter:    0 | Time: 00:00:10 | Train Loss: 0.0034 | Average Loss: 0.2031
# Accuracy: 0.593750 | Time: 00:00:00
# Epoch:288 | Iter:    0 | Time: 00:00:10 | Train Loss: 0.0686 | Average Loss: 0.2024
# Accuracy: 0.562500 | Time: 00:00:00
# Epoch:289 | Iter:    0 | Time: 00:00:10 | Train Loss: 0.0211 | Average Loss: 0.2017
# Accuracy: 0.593750 | Time: 00:00:00
# Epoch:290 | Iter:    0 | Time: 00:00:10 | Train Loss: 0.0000 | Average Loss: 0.2010
# Accuracy: 0.562500 | Time: 00:00:00
# Epoch:291 | Iter:    0 | Time: 00:00:10 | Train Loss: 0.0000 | Average Loss: 0.2004
# Accuracy: 0.593750 | Time: 00:00:00
# Epoch:292 | Iter:    0 | Time: 00:00:10 | Train Loss: 0.0054 | Average Loss: 0.1997
# Accuracy: 0.593750 | Time: 00:00:00
# Epoch:293 | Iter:    0 | Time: 00:00:10 | Train Loss: 0.0031 | Average Loss: 0.1990
# Accuracy: 0.593750 | Time: 00:00:00
# Epoch:294 | Iter:    0 | Time: 00:00:10 | Train Loss: 0.0037 | Average Loss: 0.1983
# Accuracy: 0.625000 | Time: 00:00:00
# Epoch:295 | Iter:    0 | Time: 00:00:10 | Train Loss: 0.1323 | Average Loss: 0.1977
# Accuracy: 0.625000 | Time: 00:00:00
# Epoch:296 | Iter:    0 | Time: 00:00:11 | Train Loss: 0.0000 | Average Loss: 0.1970
# Accuracy: 0.687500 | Time: 00:00:00
# Epoch:297 | Iter:    0 | Time: 00:00:11 | Train Loss: 0.0001 | Average Loss: 0.1964
# Accuracy: 0.656250 | Time: 00:00:00
# Epoch:298 | Iter:    0 | Time: 00:00:11 | Train Loss: 0.0000 | Average Loss: 0.1957
# Accuracy: 0.656250 | Time: 00:00:00
# Epoch:299 | Iter:    0 | Time: 00:00:11 | Train Loss: 0.0033 | Average Loss: 0.1951
# Accuracy: 0.656250 | Time: 00:00:00
# Epoch:300 | Iter:    0 | Time: 00:00:11 | Train Loss: 0.0032 | Average Loss: 0.1944
# Accuracy: 0.656250 | Time: 00:00:00

# %% [markdown]
# Answer:
#
# Method 2: Batch normalization Method: Two batch normalization layers are added.
#
# Accuracy on test data: 0.718750 (Epoch:228)
#
# (compare with 0.656250 in vanilla network, Accuracy increases)

# %% [markdown]
# ### Technique 3

# %%
#--------------------------------------------------
#    Load Training Data and Testing Data
#--------------------------------------------------
# load data into size (64, 64)
img_size = (64, 64)
batch_size = 16 # training sample number per batch

# load training dataset
trainloader_small = list(load_dataset('./data/train/', img_size, batch_size=batch_size, shuffle=True, augment=True, zero_centered=True))
train_num = len(trainloader_small)
print("Finish loading %d minibatches (batch_size=%d) of training samples." % (train_num, batch_size))

# load testing dataset
testloader_small = list(load_dataset('./data/test/', img_size, num_per_class=50, batch_size=batch_size, zero_centered=True))
test_num = len(testloader_small)
print("Finish loading %d minibatches (batch_size=%d) of testing samples." % (test_num, batch_size))
# Out:
# Loading images from class: 0
# Loading images from class: 1
# Loading images from class: 2
# Loading images from class: 3
# Loading images from class: 4
# Loading images from class: 5
# Loading images from class: 6
# Loading images from class: 7
# Loading images from class: 8
# Loading images from class: 9
# Loading images from class: 10
# Loading images from class: 11
# Loading images from class: 12
# Loading images from class: 13
# <ipython-input-197-f9969027fe30>:43: DeprecationWarning: `np.float` is a deprecated alias for the builtin `float`. To silence this warning, use `float` by itself. Doing this will not modify any behavior and is safe. If you specifically wanted the numpy scalar type, use `np.float64` here.
# Deprecated in NumPy 1.20; for more details and guidance: https://numpy.org/devdocs/release/1.20.0-notes.html#deprecations
#   data.append(img.astype(np.float)/255*2-1)
# Loading images from class: 14
# Loading images from class: 15
# Loading images from class: 16
# Loading images from class: 17
# Loading images from class: 18
# Loading images from class: 19
# Loading images from class: 20
# Loading images from class: 21
# Finish loading 14 minibatches (batch_size=16) of training samples.
# Loading images from class: 0
# Loading images from class: 1
# Loading images from class: 2
# Loading images from class: 3
# Loading images from class: 4
# Loading images from class: 5
# Loading images from class: 6
# Loading images from class: 7
# Loading images from class: 8
# Loading images from class: 9
# Loading images from class: 10
# Loading images from class: 11
# Loading images from class: 12
# Loading images from class: 13
# Loading images from class: 14
# Loading images from class: 15
# Loading images from class: 16
# Loading images from class: 17
# Loading images from class: 18
# Loading images from class: 19
# Loading images from class: 20
# Loading images from class: 21
# Finish loading 2 minibatches (batch_size=16) of testing samples.

# %%
#--------------------------------------------------
#       Define Network Architecture
#--------------------------------------------------
class Different_activation_function_TNet(nn.Module):
    def __init__(self):
      super(Different_activation_function_TNet,self).__init__()

      self.features = torch.nn.Sequential(
        nn.Conv2d(1, 16, 3),
        nn.Sigmoid(),
        nn.MaxPool2d(4, stride=4),
        nn.Dropout(0.5),
        nn.Conv2d(16, 256, 3),
        nn.Sigmoid(),
        nn.MaxPool2d(4, stride=4),
        nn.Dropout(0.5),
      )

      self.classifier = nn.Sequential(
         nn.Linear(2304, 22),
      )

    def forward(self, x):
      x = self.features(x)
      x = torch.flatten(x, 1)
      x = self.classifier(x)
      return x

# %%
#--------------------------------------------------
#       Start Training & Evaluation
#--------------------------------------------------
net = Different_activation_function_TNet()
train_option = {}
train_option['lr'] = 0.001
train_option['epoch'] = 500
train_option['device'] = 'gpu'
trainModel(net, trainloader_small, train_option, testloader_small)
# Out:
# Epoch: 1 | Iter:    0 | Time: 00:00:00 | Train Loss: 2.8208 | Average Loss: 2.8208
# Accuracy: 0.031250 | Time: 00:00:00
# Epoch: 2 | Iter:    0 | Time: 00:00:00 | Train Loss: 4.6034 | Average Loss: 6.6523
# Accuracy: 0.093750 | Time: 00:00:00
# Epoch: 3 | Iter:    0 | Time: 00:00:00 | Train Loss: 4.3263 | Average Loss: 5.0364
# Accuracy: 0.093750 | Time: 00:00:00
# Epoch: 4 | Iter:    0 | Time: 00:00:00 | Train Loss: 3.0435 | Average Loss: 4.5802
# Accuracy: 0.093750 | Time: 00:00:00
# Epoch: 5 | Iter:    0 | Time: 00:00:00 | Train Loss: 2.9139 | Average Loss: 4.2823
# Accuracy: 0.093750 | Time: 00:00:00
# Epoch: 6 | Iter:    0 | Time: 00:00:00 | Train Loss: 2.9540 | Average Loss: 4.0781
# Accuracy: 0.093750 | Time: 00:00:00
# Epoch: 7 | Iter:    0 | Time: 00:00:00 | Train Loss: 3.1301 | Average Loss: 3.9457
# Accuracy: 0.093750 | Time: 00:00:00
# Epoch: 8 | Iter:    0 | Time: 00:00:00 | Train Loss: 3.1108 | Average Loss: 3.8463
# Accuracy: 0.093750 | Time: 00:00:00
# Epoch: 9 | Iter:    0 | Time: 00:00:00 | Train Loss: 3.0738 | Average Loss: 3.7702
# Accuracy: 0.093750 | Time: 00:00:00
# Epoch:10 | Iter:    0 | Time: 00:00:00 | Train Loss: 3.0533 | Average Loss: 3.7111
# Accuracy: 0.093750 | Time: 00:00:00
# Epoch:11 | Iter:    0 | Time: 00:00:00 | Train Loss: 3.0195 | Average Loss: 3.6599
# Accuracy: 0.093750 | Time: 00:00:00
# Epoch:12 | Iter:    0 | Time: 00:00:00 | Train Loss: 3.0542 | Average Loss: 3.6190
# Accuracy: 0.093750 | Time: 00:00:00
# Epoch:13 | Iter:    0 | Time: 00:00:00 | Train Loss: 3.0417 | Average Loss: 3.5832
# Accuracy: 0.093750 | Time: 00:00:00
# Epoch:14 | Iter:    0 | Time: 00:00:00 | Train Loss: 3.0006 | Average Loss: 3.5511
# Accuracy: 0.093750 | Time: 00:00:00
# Epoch:15 | Iter:    0 | Time: 00:00:00 | Train Loss: 3.0013 | Average Loss: 3.5229
# Accuracy: 0.093750 | Time: 00:00:00
# Epoch:16 | Iter:    0 | Time: 00:00:00 | Train Loss: 2.9982 | Average Loss: 3.4979
# Accuracy: 0.093750 | Time: 00:00:00
# Epoch:17 | Iter:    0 | Time: 00:00:00 | Train Loss: 3.0327 | Average Loss: 3.4756
# Accuracy: 0.093750 | Time: 00:00:00
# Epoch:18 | Iter:    0 | Time: 00:00:00 | Train Loss: 2.9567 | Average Loss: 3.4552
# Accuracy: 0.093750 | Time: 00:00:00
# Epoch:19 | Iter:    0 | Time: 00:00:00 | Train Loss: 2.9940 | Average Loss: 3.4366
# Accuracy: 0.093750 | Time: 00:00:00
# Epoch:20 | Iter:    0 | Time: 00:00:00 | Train Loss: 2.9818 | Average Loss: 3.4199
# Accuracy: 0.093750 | Time: 00:00:00
# Epoch:21 | Iter:    0 | Time: 00:00:00 | Train Loss: 2.9584 | Average Loss: 3.4044
# Accuracy: 0.093750 | Time: 00:00:00
# Epoch:22 | Iter:    0 | Time: 00:00:00 | Train Loss: 2.9705 | Average Loss: 3.3901
# Accuracy: 0.093750 | Time: 00:00:00
# Epoch:23 | Iter:    0 | Time: 00:00:00 | Train Loss: 2.9875 | Average Loss: 3.3773
# Accuracy: 0.093750 | Time: 00:00:00
# Epoch:24 | Iter:    0 | Time: 00:00:00 | Train Loss: 2.9769 | Average Loss: 3.3651
# Accuracy: 0.093750 | Time: 00:00:00
# Epoch:25 | Iter:    0 | Time: 00:00:00 | Train Loss: 2.9452 | Average Loss: 3.3540
# Accuracy: 0.093750 | Time: 00:00:00
# Epoch:26 | Iter:    0 | Time: 00:00:00 | Train Loss: 2.9403 | Average Loss: 3.3434
# Accuracy: 0.093750 | Time: 00:00:00
# Epoch:27 | Iter:    0 | Time: 00:00:00 | Train Loss: 2.9209 | Average Loss: 3.3335
# Accuracy: 0.093750 | Time: 00:00:00
# Epoch:28 | Iter:    0 | Time: 00:00:00 | Train Loss: 2.9669 | Average Loss: 3.3244
# Accuracy: 0.093750 | Time: 00:00:00
# Epoch:29 | Iter:    0 | Time: 00:00:00 | Train Loss: 2.9026 | Average Loss: 3.3155
# Accuracy: 0.093750 | Time: 00:00:00
# Epoch:30 | Iter:    0 | Time: 00:00:00 | Train Loss: 2.9291 | Average Loss: 3.3072
# Accuracy: 0.093750 | Time: 00:00:00
# Epoch:31 | Iter:    0 | Time: 00:00:01 | Train Loss: 2.9199 | Average Loss: 3.2993
# Accuracy: 0.093750 | Time: 00:00:00
# Epoch:32 | Iter:    0 | Time: 00:00:01 | Train Loss: 2.8936 | Average Loss: 3.2917
# Accuracy: 0.093750 | Time: 00:00:00
# Epoch:33 | Iter:    0 | Time: 00:00:01 | Train Loss: 2.9012 | Average Loss: 3.2848
# Accuracy: 0.093750 | Time: 00:00:00
# Epoch:34 | Iter:    0 | Time: 00:00:01 | Train Loss: 2.9022 | Average Loss: 3.2779
# Accuracy: 0.093750 | Time: 00:00:00
# Epoch:35 | Iter:    0 | Time: 00:00:01 | Train Loss: 2.8999 | Average Loss: 3.2714
# Accuracy: 0.125000 | Time: 00:00:00
# Epoch:36 | Iter:    0 | Time: 00:00:01 | Train Loss: 2.8927 | Average Loss: 3.2651
# Accuracy: 0.125000 | Time: 00:00:00
# Epoch:37 | Iter:    0 | Time: 00:00:01 | Train Loss: 2.8885 | Average Loss: 3.2591
# Accuracy: 0.093750 | Time: 00:00:00
# Epoch:38 | Iter:    0 | Time: 00:00:01 | Train Loss: 2.8922 | Average Loss: 3.2536
# Accuracy: 0.093750 | Time: 00:00:00
# Epoch:39 | Iter:    0 | Time: 00:00:01 | Train Loss: 2.8889 | Average Loss: 3.2481
# Accuracy: 0.125000 | Time: 00:00:00
# Epoch:40 | Iter:    0 | Time: 00:00:01 | Train Loss: 2.8842 | Average Loss: 3.2427
# Accuracy: 0.125000 | Time: 00:00:00
# Epoch:41 | Iter:    0 | Time: 00:00:01 | Train Loss: 2.8689 | Average Loss: 3.2377
# Accuracy: 0.125000 | Time: 00:00:00
# Epoch:42 | Iter:    0 | Time: 00:00:01 | Train Loss: 2.8527 | Average Loss: 3.2326
# Accuracy: 0.093750 | Time: 00:00:00
# Epoch:43 | Iter:    0 | Time: 00:00:01 | Train Loss: 2.8373 | Average Loss: 3.2277
# Accuracy: 0.093750 | Time: 00:00:00
# Epoch:44 | Iter:    0 | Time: 00:00:01 | Train Loss: 2.8718 | Average Loss: 3.2231
# Accuracy: 0.093750 | Time: 00:00:00
# Epoch:45 | Iter:    0 | Time: 00:00:01 | Train Loss: 2.8424 | Average Loss: 3.2184
# Accuracy: 0.093750 | Time: 00:00:00
# Epoch:46 | Iter:    0 | Time: 00:00:01 | Train Loss: 2.8321 | Average Loss: 3.2139
# Accuracy: 0.093750 | Time: 00:00:00
# Epoch:47 | Iter:    0 | Time: 00:00:01 | Train Loss: 2.8455 | Average Loss: 3.2097
# Accuracy: 0.093750 | Time: 00:00:00
# Epoch:48 | Iter:    0 | Time: 00:00:01 | Train Loss: 2.8093 | Average Loss: 3.2055
# Accuracy: 0.125000 | Time: 00:00:00
# Epoch:49 | Iter:    0 | Time: 00:00:01 | Train Loss: 2.8492 | Average Loss: 3.2012
# Accuracy: 0.125000 | Time: 00:00:00
# Epoch:50 | Iter:    0 | Time: 00:00:01 | Train Loss: 2.8105 | Average Loss: 3.1971
# Accuracy: 0.125000 | Time: 00:00:00
# Epoch:51 | Iter:    0 | Time: 00:00:01 | Train Loss: 2.8029 | Average Loss: 3.1930
# Accuracy: 0.125000 | Time: 00:00:00
# Epoch:52 | Iter:    0 | Time: 00:00:01 | Train Loss: 2.7753 | Average Loss: 3.1891
# Accuracy: 0.125000 | Time: 00:00:00
# Epoch:53 | Iter:    0 | Time: 00:00:01 | Train Loss: 2.7741 | Average Loss: 3.1851
# Accuracy: 0.125000 | Time: 00:00:00
# Epoch:54 | Iter:    0 | Time: 00:00:01 | Train Loss: 2.7891 | Average Loss: 3.1811
# Accuracy: 0.125000 | Time: 00:00:00
# Epoch:55 | Iter:    0 | Time: 00:00:01 | Train Loss: 2.7494 | Average Loss: 3.1772
# Accuracy: 0.125000 | Time: 00:00:00
# Epoch:56 | Iter:    0 | Time: 00:00:01 | Train Loss: 2.7138 | Average Loss: 3.1730
# Accuracy: 0.156250 | Time: 00:00:00
# Epoch:57 | Iter:    0 | Time: 00:00:01 | Train Loss: 2.7363 | Average Loss: 3.1688
# Accuracy: 0.156250 | Time: 00:00:00
# Epoch:58 | Iter:    0 | Time: 00:00:01 | Train Loss: 2.7252 | Average Loss: 3.1650
# Accuracy: 0.156250 | Time: 00:00:00
# Epoch:59 | Iter:    0 | Time: 00:00:01 | Train Loss: 2.6988 | Average Loss: 3.1608
# Accuracy: 0.156250 | Time: 00:00:00
# Epoch:60 | Iter:    0 | Time: 00:00:01 | Train Loss: 2.7254 | Average Loss: 3.1567
# Accuracy: 0.156250 | Time: 00:00:00
# Epoch:61 | Iter:    0 | Time: 00:00:01 | Train Loss: 2.7005 | Average Loss: 3.1526
# Accuracy: 0.156250 | Time: 00:00:00
# Epoch:62 | Iter:    0 | Time: 00:00:02 | Train Loss: 2.6873 | Average Loss: 3.1482
# Accuracy: 0.156250 | Time: 00:00:00
# Epoch:63 | Iter:    0 | Time: 00:00:02 | Train Loss: 2.6243 | Average Loss: 3.1435
# Accuracy: 0.156250 | Time: 00:00:00
# Epoch:64 | Iter:    0 | Time: 00:00:02 | Train Loss: 2.6197 | Average Loss: 3.1386
# Accuracy: 0.156250 | Time: 00:00:00
# Epoch:65 | Iter:    0 | Time: 00:00:02 | Train Loss: 2.5838 | Average Loss: 3.1338
# Accuracy: 0.187500 | Time: 00:00:00
# Epoch:66 | Iter:    0 | Time: 00:00:02 | Train Loss: 2.5199 | Average Loss: 3.1286
# Accuracy: 0.187500 | Time: 00:00:00
# Epoch:67 | Iter:    0 | Time: 00:00:02 | Train Loss: 2.5265 | Average Loss: 3.1231
# Accuracy: 0.187500 | Time: 00:00:00
# Epoch:68 | Iter:    0 | Time: 00:00:02 | Train Loss: 2.4786 | Average Loss: 3.1173
# Accuracy: 0.218750 | Time: 00:00:00
# Epoch:69 | Iter:    0 | Time: 00:00:02 | Train Loss: 2.3698 | Average Loss: 3.1109
# Accuracy: 0.218750 | Time: 00:00:00
# Epoch:70 | Iter:    0 | Time: 00:00:02 | Train Loss: 2.4245 | Average Loss: 3.1042
# Accuracy: 0.281250 | Time: 00:00:00
# Epoch:71 | Iter:    0 | Time: 00:00:02 | Train Loss: 2.2103 | Average Loss: 3.0968
# Accuracy: 0.312500 | Time: 00:00:00
# Epoch:72 | Iter:    0 | Time: 00:00:02 | Train Loss: 2.3380 | Average Loss: 3.0891
# Accuracy: 0.343750 | Time: 00:00:00
# Epoch:73 | Iter:    0 | Time: 00:00:02 | Train Loss: 2.1251 | Average Loss: 3.0811
# Accuracy: 0.343750 | Time: 00:00:00
# Epoch:74 | Iter:    0 | Time: 00:00:02 | Train Loss: 2.3850 | Average Loss: 3.0731
# Accuracy: 0.343750 | Time: 00:00:00
# Epoch:75 | Iter:    0 | Time: 00:00:02 | Train Loss: 2.2056 | Average Loss: 3.0644
# Accuracy: 0.343750 | Time: 00:00:00
# Epoch:76 | Iter:    0 | Time: 00:00:02 | Train Loss: 2.0253 | Average Loss: 3.0554
# Accuracy: 0.406250 | Time: 00:00:00
# Epoch:77 | Iter:    0 | Time: 00:00:02 | Train Loss: 2.0696 | Average Loss: 3.0465
# Accuracy: 0.406250 | Time: 00:00:00
# Epoch:78 | Iter:    0 | Time: 00:00:02 | Train Loss: 2.1687 | Average Loss: 3.0368
# Accuracy: 0.375000 | Time: 00:00:00
# Epoch:79 | Iter:    0 | Time: 00:00:02 | Train Loss: 2.0218 | Average Loss: 3.0273
# Accuracy: 0.375000 | Time: 00:00:00
# Epoch:80 | Iter:    0 | Time: 00:00:02 | Train Loss: 2.1679 | Average Loss: 3.0174
# Accuracy: 0.406250 | Time: 00:00:00
# Epoch:81 | Iter:    0 | Time: 00:00:02 | Train Loss: 2.0135 | Average Loss: 3.0072
# Accuracy: 0.375000 | Time: 00:00:00
# Epoch:82 | Iter:    0 | Time: 00:00:02 | Train Loss: 1.7914 | Average Loss: 2.9969
# Accuracy: 0.406250 | Time: 00:00:00
# Epoch:83 | Iter:    0 | Time: 00:00:02 | Train Loss: 2.0281 | Average Loss: 2.9867
# Accuracy: 0.375000 | Time: 00:00:00
# Epoch:84 | Iter:    0 | Time: 00:00:02 | Train Loss: 1.9857 | Average Loss: 2.9764
# Accuracy: 0.312500 | Time: 00:00:00
# Epoch:85 | Iter:    0 | Time: 00:00:02 | Train Loss: 1.7337 | Average Loss: 2.9658
# Accuracy: 0.343750 | Time: 00:00:00
# Epoch:86 | Iter:    0 | Time: 00:00:02 | Train Loss: 1.8460 | Average Loss: 2.9553
# Accuracy: 0.375000 | Time: 00:00:00
# Epoch:87 | Iter:    0 | Time: 00:00:02 | Train Loss: 1.9427 | Average Loss: 2.9446
# Accuracy: 0.343750 | Time: 00:00:00
# Epoch:88 | Iter:    0 | Time: 00:00:02 | Train Loss: 1.8140 | Average Loss: 2.9337
# Accuracy: 0.343750 | Time: 00:00:00
# Epoch:89 | Iter:    0 | Time: 00:00:02 | Train Loss: 1.7269 | Average Loss: 2.9233
# Accuracy: 0.406250 | Time: 00:00:00
# Epoch:90 | Iter:    0 | Time: 00:00:02 | Train Loss: 1.8018 | Average Loss: 2.9127
# Accuracy: 0.406250 | Time: 00:00:00
# Epoch:91 | Iter:    0 | Time: 00:00:02 | Train Loss: 1.8587 | Average Loss: 2.9020
# Accuracy: 0.406250 | Time: 00:00:00
# Epoch:92 | Iter:    0 | Time: 00:00:02 | Train Loss: 1.9860 | Average Loss: 2.8913
# Accuracy: 0.375000 | Time: 00:00:00
# Epoch:93 | Iter:    0 | Time: 00:00:03 | Train Loss: 1.5876 | Average Loss: 2.8800
# Accuracy: 0.437500 | Time: 00:00:00
# Epoch:94 | Iter:    0 | Time: 00:00:03 | Train Loss: 1.5944 | Average Loss: 2.8697
# Accuracy: 0.437500 | Time: 00:00:00
# Epoch:95 | Iter:    0 | Time: 00:00:03 | Train Loss: 1.7217 | Average Loss: 2.8584
# Accuracy: 0.437500 | Time: 00:00:00
# Epoch:96 | Iter:    0 | Time: 00:00:03 | Train Loss: 1.6359 | Average Loss: 2.8480
# Accuracy: 0.406250 | Time: 00:00:00
# Epoch:97 | Iter:    0 | Time: 00:00:03 | Train Loss: 1.5789 | Average Loss: 2.8369
# Accuracy: 0.406250 | Time: 00:00:00
# Epoch:98 | Iter:    0 | Time: 00:00:03 | Train Loss: 1.5707 | Average Loss: 2.8261
# Accuracy: 0.406250 | Time: 00:00:00
# Epoch:99 | Iter:    0 | Time: 00:00:03 | Train Loss: 1.7328 | Average Loss: 2.8158
# Accuracy: 0.406250 | Time: 00:00:00
# Epoch:100 | Iter:    0 | Time: 00:00:03 | Train Loss: 1.5688 | Average Loss: 2.8056
# Accuracy: 0.406250 | Time: 00:00:00
# Epoch:101 | Iter:    0 | Time: 00:00:03 | Train Loss: 1.6504 | Average Loss: 2.7951
# Accuracy: 0.375000 | Time: 00:00:00
# Epoch:102 | Iter:    0 | Time: 00:00:03 | Train Loss: 1.4580 | Average Loss: 2.7846
# Accuracy: 0.437500 | Time: 00:00:00
# Epoch:103 | Iter:    0 | Time: 00:00:03 | Train Loss: 1.5584 | Average Loss: 2.7740
# Accuracy: 0.437500 | Time: 00:00:00
# Epoch:104 | Iter:    0 | Time: 00:00:03 | Train Loss: 1.5874 | Average Loss: 2.7637
# Accuracy: 0.437500 | Time: 00:00:00
# Epoch:105 | Iter:    0 | Time: 00:00:03 | Train Loss: 1.8734 | Average Loss: 2.7538
# Accuracy: 0.468750 | Time: 00:00:00
# Epoch:106 | Iter:    0 | Time: 00:00:03 | Train Loss: 1.6541 | Average Loss: 2.7436
# Accuracy: 0.437500 | Time: 00:00:00
# Epoch:107 | Iter:    0 | Time: 00:00:03 | Train Loss: 1.3248 | Average Loss: 2.7333
# Accuracy: 0.437500 | Time: 00:00:00
# Epoch:108 | Iter:    0 | Time: 00:00:03 | Train Loss: 1.6818 | Average Loss: 2.7236
# Accuracy: 0.406250 | Time: 00:00:00
# Epoch:109 | Iter:    0 | Time: 00:00:03 | Train Loss: 1.7384 | Average Loss: 2.7138
# Accuracy: 0.437500 | Time: 00:00:00
# Epoch:110 | Iter:    0 | Time: 00:00:03 | Train Loss: 1.3566 | Average Loss: 2.7034
# Accuracy: 0.406250 | Time: 00:00:00
# Epoch:111 | Iter:    0 | Time: 00:00:03 | Train Loss: 1.5653 | Average Loss: 2.6936
# Accuracy: 0.468750 | Time: 00:00:00
# Epoch:112 | Iter:    0 | Time: 00:00:03 | Train Loss: 1.5039 | Average Loss: 2.6835
# Accuracy: 0.437500 | Time: 00:00:00
# Epoch:113 | Iter:    0 | Time: 00:00:03 | Train Loss: 1.5801 | Average Loss: 2.6741
# Accuracy: 0.468750 | Time: 00:00:00
# Epoch:114 | Iter:    0 | Time: 00:00:03 | Train Loss: 1.3704 | Average Loss: 2.6642
# Accuracy: 0.406250 | Time: 00:00:00
# Epoch:115 | Iter:    0 | Time: 00:00:03 | Train Loss: 1.7005 | Average Loss: 2.6546
# Accuracy: 0.500000 | Time: 00:00:00
# Epoch:116 | Iter:    0 | Time: 00:00:03 | Train Loss: 1.4344 | Average Loss: 2.6446
# Accuracy: 0.468750 | Time: 00:00:00
# Epoch:117 | Iter:    0 | Time: 00:00:03 | Train Loss: 1.2973 | Average Loss: 2.6347
# Accuracy: 0.437500 | Time: 00:00:00
# Epoch:118 | Iter:    0 | Time: 00:00:03 | Train Loss: 1.3790 | Average Loss: 2.6247
# Accuracy: 0.468750 | Time: 00:00:00
# Epoch:119 | Iter:    0 | Time: 00:00:03 | Train Loss: 1.5805 | Average Loss: 2.6157
# Accuracy: 0.531250 | Time: 00:00:00
# Epoch:120 | Iter:    0 | Time: 00:00:03 | Train Loss: 1.3604 | Average Loss: 2.6063
# Accuracy: 0.437500 | Time: 00:00:00
# Epoch:121 | Iter:    0 | Time: 00:00:03 | Train Loss: 1.6607 | Average Loss: 2.5967
# Accuracy: 0.468750 | Time: 00:00:00
# Epoch:122 | Iter:    0 | Time: 00:00:03 | Train Loss: 1.2724 | Average Loss: 2.5871
# Accuracy: 0.500000 | Time: 00:00:00
# Epoch:123 | Iter:    0 | Time: 00:00:03 | Train Loss: 1.5329 | Average Loss: 2.5778
# Accuracy: 0.468750 | Time: 00:00:00
# Epoch:124 | Iter:    0 | Time: 00:00:04 | Train Loss: 1.2248 | Average Loss: 2.5687
# Accuracy: 0.468750 | Time: 00:00:00
# Epoch:125 | Iter:    0 | Time: 00:00:04 | Train Loss: 1.5435 | Average Loss: 2.5597
# Accuracy: 0.500000 | Time: 00:00:00
# Epoch:126 | Iter:    0 | Time: 00:00:04 | Train Loss: 1.1326 | Average Loss: 2.5505
# Accuracy: 0.500000 | Time: 00:00:00
# Epoch:127 | Iter:    0 | Time: 00:00:04 | Train Loss: 1.2754 | Average Loss: 2.5417
# Accuracy: 0.500000 | Time: 00:00:00
# Epoch:128 | Iter:    0 | Time: 00:00:04 | Train Loss: 1.2223 | Average Loss: 2.5326
# Accuracy: 0.500000 | Time: 00:00:00
# Epoch:129 | Iter:    0 | Time: 00:00:04 | Train Loss: 1.3382 | Average Loss: 2.5240
# Accuracy: 0.500000 | Time: 00:00:00
# Epoch:130 | Iter:    0 | Time: 00:00:04 | Train Loss: 1.0512 | Average Loss: 2.5145
# Accuracy: 0.500000 | Time: 00:00:00
# Epoch:131 | Iter:    0 | Time: 00:00:04 | Train Loss: 1.5503 | Average Loss: 2.5055
# Accuracy: 0.531250 | Time: 00:00:00
# Epoch:132 | Iter:    0 | Time: 00:00:04 | Train Loss: 1.4417 | Average Loss: 2.4970
# Accuracy: 0.500000 | Time: 00:00:00
# Epoch:133 | Iter:    0 | Time: 00:00:04 | Train Loss: 1.3220 | Average Loss: 2.4886
# Accuracy: 0.468750 | Time: 00:00:00
# Epoch:134 | Iter:    0 | Time: 00:00:04 | Train Loss: 1.0988 | Average Loss: 2.4795
# Accuracy: 0.500000 | Time: 00:00:00
# Epoch:135 | Iter:    0 | Time: 00:00:04 | Train Loss: 1.1802 | Average Loss: 2.4709
# Accuracy: 0.500000 | Time: 00:00:00
# Epoch:136 | Iter:    0 | Time: 00:00:04 | Train Loss: 1.0287 | Average Loss: 2.4622
# Accuracy: 0.500000 | Time: 00:00:00
# Epoch:137 | Iter:    0 | Time: 00:00:04 | Train Loss: 1.1888 | Average Loss: 2.4535
# Accuracy: 0.468750 | Time: 00:00:00
# Epoch:138 | Iter:    0 | Time: 00:00:04 | Train Loss: 1.1215 | Average Loss: 2.4448
# Accuracy: 0.500000 | Time: 00:00:00
# Epoch:139 | Iter:    0 | Time: 00:00:04 | Train Loss: 0.9578 | Average Loss: 2.4359
# Accuracy: 0.500000 | Time: 00:00:00
# Epoch:140 | Iter:    0 | Time: 00:00:04 | Train Loss: 1.4380 | Average Loss: 2.4276
# Accuracy: 0.500000 | Time: 00:00:00
# Epoch:141 | Iter:    0 | Time: 00:00:04 | Train Loss: 1.2495 | Average Loss: 2.4192
# Accuracy: 0.500000 | Time: 00:00:00
# Epoch:142 | Iter:    0 | Time: 00:00:04 | Train Loss: 1.0744 | Average Loss: 2.4106
# Accuracy: 0.531250 | Time: 00:00:00
# Epoch:143 | Iter:    0 | Time: 00:00:04 | Train Loss: 1.1924 | Average Loss: 2.4021
# Accuracy: 0.531250 | Time: 00:00:00
# Epoch:144 | Iter:    0 | Time: 00:00:04 | Train Loss: 1.0857 | Average Loss: 2.3940
# Accuracy: 0.500000 | Time: 00:00:00
# Epoch:145 | Iter:    0 | Time: 00:00:04 | Train Loss: 1.3218 | Average Loss: 2.3856
# Accuracy: 0.500000 | Time: 00:00:00
# Epoch:146 | Iter:    0 | Time: 00:00:04 | Train Loss: 0.9586 | Average Loss: 2.3774
# Accuracy: 0.531250 | Time: 00:00:00
# Epoch:147 | Iter:    0 | Time: 00:00:04 | Train Loss: 1.2133 | Average Loss: 2.3694
# Accuracy: 0.531250 | Time: 00:00:00
# Epoch:148 | Iter:    0 | Time: 00:00:04 | Train Loss: 1.1339 | Average Loss: 2.3613
# Accuracy: 0.531250 | Time: 00:00:00
# Epoch:149 | Iter:    0 | Time: 00:00:04 | Train Loss: 0.9336 | Average Loss: 2.3532
# Accuracy: 0.500000 | Time: 00:00:00
# Epoch:150 | Iter:    0 | Time: 00:00:04 | Train Loss: 1.1502 | Average Loss: 2.3457
# Accuracy: 0.531250 | Time: 00:00:00
# Epoch:151 | Iter:    0 | Time: 00:00:04 | Train Loss: 0.9942 | Average Loss: 2.3378
# Accuracy: 0.468750 | Time: 00:00:00
# Epoch:152 | Iter:    0 | Time: 00:00:04 | Train Loss: 1.1450 | Average Loss: 2.3296
# Accuracy: 0.500000 | Time: 00:00:00
# Epoch:153 | Iter:    0 | Time: 00:00:04 | Train Loss: 1.1111 | Average Loss: 2.3216
# Accuracy: 0.500000 | Time: 00:00:00
# Epoch:154 | Iter:    0 | Time: 00:00:04 | Train Loss: 0.9309 | Average Loss: 2.3134
# Accuracy: 0.531250 | Time: 00:00:00
# Epoch:155 | Iter:    0 | Time: 00:00:04 | Train Loss: 1.4482 | Average Loss: 2.3057
# Accuracy: 0.500000 | Time: 00:00:00
# Epoch:156 | Iter:    0 | Time: 00:00:04 | Train Loss: 0.7501 | Average Loss: 2.2981
# Accuracy: 0.531250 | Time: 00:00:00
# Epoch:157 | Iter:    0 | Time: 00:00:05 | Train Loss: 1.2437 | Average Loss: 2.2908
# Accuracy: 0.562500 | Time: 00:00:00
# Epoch:158 | Iter:    0 | Time: 00:00:05 | Train Loss: 0.8835 | Average Loss: 2.2826
# Accuracy: 0.531250 | Time: 00:00:00
# Epoch:159 | Iter:    0 | Time: 00:00:05 | Train Loss: 1.0828 | Average Loss: 2.2751
# Accuracy: 0.500000 | Time: 00:00:00
# Epoch:160 | Iter:    0 | Time: 00:00:05 | Train Loss: 0.7316 | Average Loss: 2.2674
# Accuracy: 0.531250 | Time: 00:00:00
# Epoch:161 | Iter:    0 | Time: 00:00:05 | Train Loss: 1.2797 | Average Loss: 2.2598
# Accuracy: 0.531250 | Time: 00:00:00
# Epoch:162 | Iter:    0 | Time: 00:00:05 | Train Loss: 0.9412 | Average Loss: 2.2522
# Accuracy: 0.531250 | Time: 00:00:00
# Epoch:163 | Iter:    0 | Time: 00:00:05 | Train Loss: 1.0440 | Average Loss: 2.2451
# Accuracy: 0.500000 | Time: 00:00:00
# Epoch:164 | Iter:    0 | Time: 00:00:05 | Train Loss: 0.8337 | Average Loss: 2.2375
# Accuracy: 0.500000 | Time: 00:00:00
# Epoch:165 | Iter:    0 | Time: 00:00:05 | Train Loss: 0.8616 | Average Loss: 2.2302
# Accuracy: 0.531250 | Time: 00:00:00
# Epoch:166 | Iter:    0 | Time: 00:00:05 | Train Loss: 1.0818 | Average Loss: 2.2229
# Accuracy: 0.531250 | Time: 00:00:00
# Epoch:167 | Iter:    0 | Time: 00:00:05 | Train Loss: 0.8074 | Average Loss: 2.2155
# Accuracy: 0.500000 | Time: 00:00:00
# Epoch:168 | Iter:    0 | Time: 00:00:05 | Train Loss: 1.2473 | Average Loss: 2.2084
# Accuracy: 0.500000 | Time: 00:00:00
# Epoch:169 | Iter:    0 | Time: 00:00:05 | Train Loss: 0.9599 | Average Loss: 2.2010
# Accuracy: 0.531250 | Time: 00:00:00
# Epoch:170 | Iter:    0 | Time: 00:00:05 | Train Loss: 1.1562 | Average Loss: 2.1939
# Accuracy: 0.562500 | Time: 00:00:00
# Epoch:171 | Iter:    0 | Time: 00:00:05 | Train Loss: 0.7238 | Average Loss: 2.1866
# Accuracy: 0.531250 | Time: 00:00:00
# Epoch:172 | Iter:    0 | Time: 00:00:05 | Train Loss: 1.0073 | Average Loss: 2.1797
# Accuracy: 0.562500 | Time: 00:00:00
# Epoch:173 | Iter:    0 | Time: 00:00:05 | Train Loss: 1.0001 | Average Loss: 2.1728
# Accuracy: 0.562500 | Time: 00:00:00
# Epoch:174 | Iter:    0 | Time: 00:00:05 | Train Loss: 1.1641 | Average Loss: 2.1660
# Accuracy: 0.500000 | Time: 00:00:00
# Epoch:175 | Iter:    0 | Time: 00:00:05 | Train Loss: 1.0341 | Average Loss: 2.1592
# Accuracy: 0.531250 | Time: 00:00:00
# Epoch:176 | Iter:    0 | Time: 00:00:05 | Train Loss: 0.8510 | Average Loss: 2.1522
# Accuracy: 0.562500 | Time: 00:00:00
# Epoch:177 | Iter:    0 | Time: 00:00:05 | Train Loss: 0.8053 | Average Loss: 2.1453
# Accuracy: 0.562500 | Time: 00:00:00
# Epoch:178 | Iter:    0 | Time: 00:00:05 | Train Loss: 0.9348 | Average Loss: 2.1385
# Accuracy: 0.531250 | Time: 00:00:00
# Epoch:179 | Iter:    0 | Time: 00:00:05 | Train Loss: 0.7941 | Average Loss: 2.1318
# Accuracy: 0.625000 | Time: 00:00:00
# Epoch:180 | Iter:    0 | Time: 00:00:05 | Train Loss: 0.9390 | Average Loss: 2.1247
# Accuracy: 0.593750 | Time: 00:00:00
# Epoch:181 | Iter:    0 | Time: 00:00:05 | Train Loss: 1.0928 | Average Loss: 2.1180
# Accuracy: 0.593750 | Time: 00:00:00
# Epoch:182 | Iter:    0 | Time: 00:00:05 | Train Loss: 0.9838 | Average Loss: 2.1113
# Accuracy: 0.562500 | Time: 00:00:00
# Epoch:183 | Iter:    0 | Time: 00:00:05 | Train Loss: 0.6436 | Average Loss: 2.1047
# Accuracy: 0.562500 | Time: 00:00:00
# Epoch:184 | Iter:    0 | Time: 00:00:05 | Train Loss: 1.1142 | Average Loss: 2.0983
# Accuracy: 0.562500 | Time: 00:00:00
# Epoch:185 | Iter:    0 | Time: 00:00:05 | Train Loss: 1.1211 | Average Loss: 2.0920
# Accuracy: 0.593750 | Time: 00:00:00
# Epoch:186 | Iter:    0 | Time: 00:00:05 | Train Loss: 0.7953 | Average Loss: 2.0855
# Accuracy: 0.562500 | Time: 00:00:00
# Epoch:187 | Iter:    0 | Time: 00:00:05 | Train Loss: 0.9395 | Average Loss: 2.0794
# Accuracy: 0.531250 | Time: 00:00:00
# Epoch:188 | Iter:    0 | Time: 00:00:05 | Train Loss: 0.5930 | Average Loss: 2.0729
# Accuracy: 0.593750 | Time: 00:00:00
# Epoch:189 | Iter:    0 | Time: 00:00:06 | Train Loss: 1.0560 | Average Loss: 2.0662
# Accuracy: 0.562500 | Time: 00:00:00
# Epoch:190 | Iter:    0 | Time: 00:00:06 | Train Loss: 0.6683 | Average Loss: 2.0602
# Accuracy: 0.562500 | Time: 00:00:00
# Epoch:191 | Iter:    0 | Time: 00:00:06 | Train Loss: 0.8402 | Average Loss: 2.0534
# Accuracy: 0.562500 | Time: 00:00:00
# Epoch:192 | Iter:    0 | Time: 00:00:06 | Train Loss: 0.6475 | Average Loss: 2.0467
# Accuracy: 0.593750 | Time: 00:00:00
# Epoch:193 | Iter:    0 | Time: 00:00:06 | Train Loss: 0.7794 | Average Loss: 2.0401
# Accuracy: 0.593750 | Time: 00:00:00
# Epoch:194 | Iter:    0 | Time: 00:00:06 | Train Loss: 0.7268 | Average Loss: 2.0336
# Accuracy: 0.593750 | Time: 00:00:00
# Epoch:195 | Iter:    0 | Time: 00:00:06 | Train Loss: 0.8346 | Average Loss: 2.0273
# Accuracy: 0.562500 | Time: 00:00:00
# Epoch:196 | Iter:    0 | Time: 00:00:06 | Train Loss: 0.7032 | Average Loss: 2.0211
# Accuracy: 0.562500 | Time: 00:00:00
# Epoch:197 | Iter:    0 | Time: 00:00:06 | Train Loss: 1.1047 | Average Loss: 2.0147
# Accuracy: 0.593750 | Time: 00:00:00
# Epoch:198 | Iter:    0 | Time: 00:00:06 | Train Loss: 0.5939 | Average Loss: 2.0082
# Accuracy: 0.562500 | Time: 00:00:00
# Epoch:199 | Iter:    0 | Time: 00:00:06 | Train Loss: 0.6363 | Average Loss: 2.0016
# Accuracy: 0.562500 | Time: 00:00:00
# Epoch:200 | Iter:    0 | Time: 00:00:06 | Train Loss: 1.1787 | Average Loss: 1.9958
# Accuracy: 0.593750 | Time: 00:00:00
# Epoch:201 | Iter:    0 | Time: 00:00:06 | Train Loss: 0.8817 | Average Loss: 1.9894
# Accuracy: 0.593750 | Time: 00:00:00
# Epoch:202 | Iter:    0 | Time: 00:00:06 | Train Loss: 0.8337 | Average Loss: 1.9832
# Accuracy: 0.562500 | Time: 00:00:00
# Epoch:203 | Iter:    0 | Time: 00:00:06 | Train Loss: 0.7401 | Average Loss: 1.9771
# Accuracy: 0.562500 | Time: 00:00:00
# Epoch:204 | Iter:    0 | Time: 00:00:06 | Train Loss: 0.6718 | Average Loss: 1.9709
# Accuracy: 0.562500 | Time: 00:00:00
# Epoch:205 | Iter:    0 | Time: 00:00:06 | Train Loss: 0.6415 | Average Loss: 1.9649
# Accuracy: 0.562500 | Time: 00:00:00
# Epoch:206 | Iter:    0 | Time: 00:00:06 | Train Loss: 0.6079 | Average Loss: 1.9588
# Accuracy: 0.593750 | Time: 00:00:00
# Epoch:207 | Iter:    0 | Time: 00:00:06 | Train Loss: 0.6099 | Average Loss: 1.9526
# Accuracy: 0.593750 | Time: 00:00:00
# Epoch:208 | Iter:    0 | Time: 00:00:06 | Train Loss: 0.4869 | Average Loss: 1.9464
# Accuracy: 0.593750 | Time: 00:00:00
# Epoch:209 | Iter:    0 | Time: 00:00:06 | Train Loss: 0.7564 | Average Loss: 1.9401
# Accuracy: 0.562500 | Time: 00:00:00
# Epoch:210 | Iter:    0 | Time: 00:00:06 | Train Loss: 0.5486 | Average Loss: 1.9339
# Accuracy: 0.593750 | Time: 00:00:00
# Epoch:211 | Iter:    0 | Time: 00:00:06 | Train Loss: 0.8743 | Average Loss: 1.9279
# Accuracy: 0.562500 | Time: 00:00:00
# Epoch:212 | Iter:    0 | Time: 00:00:06 | Train Loss: 0.7899 | Average Loss: 1.9219
# Accuracy: 0.562500 | Time: 00:00:00
# Epoch:213 | Iter:    0 | Time: 00:00:06 | Train Loss: 0.6215 | Average Loss: 1.9161
# Accuracy: 0.593750 | Time: 00:00:00
# Epoch:214 | Iter:    0 | Time: 00:00:06 | Train Loss: 0.5565 | Average Loss: 1.9101
# Accuracy: 0.562500 | Time: 00:00:00
# Epoch:215 | Iter:    0 | Time: 00:00:06 | Train Loss: 0.6907 | Average Loss: 1.9044
# Accuracy: 0.562500 | Time: 00:00:00
# Epoch:216 | Iter:    0 | Time: 00:00:07 | Train Loss: 0.8516 | Average Loss: 1.8985
# Accuracy: 0.562500 | Time: 00:00:00
# Epoch:217 | Iter:    0 | Time: 00:00:07 | Train Loss: 0.9114 | Average Loss: 1.8931
# Accuracy: 0.562500 | Time: 00:00:00
# Epoch:218 | Iter:    0 | Time: 00:00:07 | Train Loss: 0.4602 | Average Loss: 1.8873
# Accuracy: 0.593750 | Time: 00:00:00
# Epoch:219 | Iter:    0 | Time: 00:00:07 | Train Loss: 0.4872 | Average Loss: 1.8816
# Accuracy: 0.593750 | Time: 00:00:00
# Epoch:220 | Iter:    0 | Time: 00:00:07 | Train Loss: 0.5211 | Average Loss: 1.8757
# Accuracy: 0.562500 | Time: 00:00:00
# Epoch:221 | Iter:    0 | Time: 00:00:07 | Train Loss: 0.5729 | Average Loss: 1.8701
# Accuracy: 0.593750 | Time: 00:00:00
# Epoch:222 | Iter:    0 | Time: 00:00:07 | Train Loss: 0.9048 | Average Loss: 1.8645
# Accuracy: 0.562500 | Time: 00:00:00
# Epoch:223 | Iter:    0 | Time: 00:00:07 | Train Loss: 0.7573 | Average Loss: 1.8589
# Accuracy: 0.562500 | Time: 00:00:00
# Epoch:224 | Iter:    0 | Time: 00:00:07 | Train Loss: 0.6918 | Average Loss: 1.8533
# Accuracy: 0.562500 | Time: 00:00:00
# Epoch:225 | Iter:    0 | Time: 00:00:07 | Train Loss: 0.6831 | Average Loss: 1.8476
# Accuracy: 0.562500 | Time: 00:00:00
# Epoch:226 | Iter:    0 | Time: 00:00:07 | Train Loss: 0.7612 | Average Loss: 1.8422
# Accuracy: 0.562500 | Time: 00:00:00
# Epoch:227 | Iter:    0 | Time: 00:00:07 | Train Loss: 0.5835 | Average Loss: 1.8365
# Accuracy: 0.625000 | Time: 00:00:00
# Epoch:228 | Iter:    0 | Time: 00:00:07 | Train Loss: 0.6032 | Average Loss: 1.8309
# Accuracy: 0.562500 | Time: 00:00:00
# Epoch:229 | Iter:    0 | Time: 00:00:07 | Train Loss: 0.5567 | Average Loss: 1.8254
# Accuracy: 0.562500 | Time: 00:00:00
# Epoch:230 | Iter:    0 | Time: 00:00:07 | Train Loss: 0.6109 | Average Loss: 1.8200
# Accuracy: 0.562500 | Time: 00:00:00
# Epoch:231 | Iter:    0 | Time: 00:00:07 | Train Loss: 0.4679 | Average Loss: 1.8144
# Accuracy: 0.562500 | Time: 00:00:00
# Epoch:232 | Iter:    0 | Time: 00:00:07 | Train Loss: 0.9575 | Average Loss: 1.8094
# Accuracy: 0.531250 | Time: 00:00:00
# Epoch:233 | Iter:    0 | Time: 00:00:07 | Train Loss: 0.7809 | Average Loss: 1.8041
# Accuracy: 0.562500 | Time: 00:00:00
# Epoch:234 | Iter:    0 | Time: 00:00:07 | Train Loss: 0.4460 | Average Loss: 1.7987
# Accuracy: 0.562500 | Time: 00:00:00
# Epoch:235 | Iter:    0 | Time: 00:00:07 | Train Loss: 0.8318 | Average Loss: 1.7931
# Accuracy: 0.593750 | Time: 00:00:00
# Epoch:236 | Iter:    0 | Time: 00:00:07 | Train Loss: 0.5379 | Average Loss: 1.7880
# Accuracy: 0.593750 | Time: 00:00:00
# Epoch:237 | Iter:    0 | Time: 00:00:07 | Train Loss: 0.6298 | Average Loss: 1.7828
# Accuracy: 0.625000 | Time: 00:00:00
# Epoch:238 | Iter:    0 | Time: 00:00:07 | Train Loss: 0.4934 | Average Loss: 1.7774
# Accuracy: 0.625000 | Time: 00:00:00
# Epoch:239 | Iter:    0 | Time: 00:00:07 | Train Loss: 1.0510 | Average Loss: 1.7725
# Accuracy: 0.593750 | Time: 00:00:00
# Epoch:240 | Iter:    0 | Time: 00:00:07 | Train Loss: 0.6879 | Average Loss: 1.7672
# Accuracy: 0.562500 | Time: 00:00:00
# Epoch:241 | Iter:    0 | Time: 00:00:08 | Train Loss: 0.4908 | Average Loss: 1.7618
# Accuracy: 0.625000 | Time: 00:00:00
# Epoch:242 | Iter:    0 | Time: 00:00:08 | Train Loss: 0.5810 | Average Loss: 1.7567
# Accuracy: 0.562500 | Time: 00:00:00
# Epoch:243 | Iter:    0 | Time: 00:00:08 | Train Loss: 0.8960 | Average Loss: 1.7514
# Accuracy: 0.593750 | Time: 00:00:00
# Epoch:244 | Iter:    0 | Time: 00:00:08 | Train Loss: 0.4745 | Average Loss: 1.7462
# Accuracy: 0.562500 | Time: 00:00:00
# Epoch:245 | Iter:    0 | Time: 00:00:08 | Train Loss: 0.6485 | Average Loss: 1.7414
# Accuracy: 0.562500 | Time: 00:00:00
# Epoch:246 | Iter:    0 | Time: 00:00:08 | Train Loss: 0.6437 | Average Loss: 1.7364
# Accuracy: 0.531250 | Time: 00:00:00
# Epoch:247 | Iter:    0 | Time: 00:00:08 | Train Loss: 0.4556 | Average Loss: 1.7313
# Accuracy: 0.531250 | Time: 00:00:00
# Epoch:248 | Iter:    0 | Time: 00:00:08 | Train Loss: 0.4959 | Average Loss: 1.7263
# Accuracy: 0.593750 | Time: 00:00:00
# Epoch:249 | Iter:    0 | Time: 00:00:08 | Train Loss: 0.7053 | Average Loss: 1.7212
# Accuracy: 0.593750 | Time: 00:00:00
# Epoch:250 | Iter:    0 | Time: 00:00:08 | Train Loss: 0.3328 | Average Loss: 1.7159
# Accuracy: 0.656250 | Time: 00:00:00
# Epoch:251 | Iter:    0 | Time: 00:00:08 | Train Loss: 0.8801 | Average Loss: 1.7112
# Accuracy: 0.593750 | Time: 00:00:00
# Epoch:252 | Iter:    0 | Time: 00:00:08 | Train Loss: 0.6065 | Average Loss: 1.7063
# Accuracy: 0.625000 | Time: 00:00:00
# Epoch:253 | Iter:    0 | Time: 00:00:08 | Train Loss: 0.3312 | Average Loss: 1.7014
# Accuracy: 0.593750 | Time: 00:00:00
# Epoch:254 | Iter:    0 | Time: 00:00:08 | Train Loss: 0.8023 | Average Loss: 1.6966
# Accuracy: 0.625000 | Time: 00:00:00
# Epoch:255 | Iter:    0 | Time: 00:00:08 | Train Loss: 0.5158 | Average Loss: 1.6920
# Accuracy: 0.593750 | Time: 00:00:00
# Epoch:256 | Iter:    0 | Time: 00:00:08 | Train Loss: 0.3097 | Average Loss: 1.6871
# Accuracy: 0.593750 | Time: 00:00:00
# Epoch:257 | Iter:    0 | Time: 00:00:08 | Train Loss: 0.6989 | Average Loss: 1.6823
# Accuracy: 0.562500 | Time: 00:00:00
# Epoch:258 | Iter:    0 | Time: 00:00:08 | Train Loss: 0.3539 | Average Loss: 1.6774
# Accuracy: 0.593750 | Time: 00:00:00
# Epoch:259 | Iter:    0 | Time: 00:00:08 | Train Loss: 0.3857 | Average Loss: 1.6724
# Accuracy: 0.593750 | Time: 00:00:00
# Epoch:260 | Iter:    0 | Time: 00:00:08 | Train Loss: 0.9222 | Average Loss: 1.6681
# Accuracy: 0.593750 | Time: 00:00:00
# Epoch:261 | Iter:    0 | Time: 00:00:08 | Train Loss: 0.7435 | Average Loss: 1.6634
# Accuracy: 0.562500 | Time: 00:00:00
# Epoch:262 | Iter:    0 | Time: 00:00:08 | Train Loss: 0.5711 | Average Loss: 1.6590
# Accuracy: 0.625000 | Time: 00:00:00
# Epoch:263 | Iter:    0 | Time: 00:00:08 | Train Loss: 0.5381 | Average Loss: 1.6545
# Accuracy: 0.593750 | Time: 00:00:00
# Epoch:264 | Iter:    0 | Time: 00:00:08 | Train Loss: 0.4937 | Average Loss: 1.6498
# Accuracy: 0.625000 | Time: 00:00:00
# Epoch:265 | Iter:    0 | Time: 00:00:08 | Train Loss: 0.9775 | Average Loss: 1.6455
# Accuracy: 0.562500 | Time: 00:00:00
# Epoch:266 | Iter:    0 | Time: 00:00:08 | Train Loss: 0.4515 | Average Loss: 1.6409
# Accuracy: 0.625000 | Time: 00:00:00
# Epoch:267 | Iter:    0 | Time: 00:00:08 | Train Loss: 0.5247 | Average Loss: 1.6363
# Accuracy: 0.625000 | Time: 00:00:00
# Epoch:268 | Iter:    0 | Time: 00:00:09 | Train Loss: 0.6711 | Average Loss: 1.6316
# Accuracy: 0.562500 | Time: 00:00:00
# Epoch:269 | Iter:    0 | Time: 00:00:09 | Train Loss: 0.2659 | Average Loss: 1.6271
# Accuracy: 0.625000 | Time: 00:00:00
# Epoch:270 | Iter:    0 | Time: 00:00:09 | Train Loss: 0.6459 | Average Loss: 1.6226
# Accuracy: 0.593750 | Time: 00:00:00
# Epoch:271 | Iter:    0 | Time: 00:00:09 | Train Loss: 0.3116 | Average Loss: 1.6179
# Accuracy: 0.625000 | Time: 00:00:00
# Epoch:272 | Iter:    0 | Time: 00:00:09 | Train Loss: 0.5773 | Average Loss: 1.6135
# Accuracy: 0.593750 | Time: 00:00:00
# Epoch:273 | Iter:    0 | Time: 00:00:09 | Train Loss: 0.6760 | Average Loss: 1.6091
# Accuracy: 0.562500 | Time: 00:00:00
# Epoch:274 | Iter:    0 | Time: 00:00:09 | Train Loss: 0.4989 | Average Loss: 1.6046
# Accuracy: 0.593750 | Time: 00:00:00
# Epoch:275 | Iter:    0 | Time: 00:00:09 | Train Loss: 0.5091 | Average Loss: 1.6002
# Accuracy: 0.656250 | Time: 00:00:00
# Epoch:276 | Iter:    0 | Time: 00:00:09 | Train Loss: 0.3177 | Average Loss: 1.5958
# Accuracy: 0.625000 | Time: 00:00:00
# Epoch:277 | Iter:    0 | Time: 00:00:09 | Train Loss: 0.5067 | Average Loss: 1.5914
# Accuracy: 0.656250 | Time: 00:00:00
# Epoch:278 | Iter:    0 | Time: 00:00:09 | Train Loss: 0.2507 | Average Loss: 1.5870
# Accuracy: 0.656250 | Time: 00:00:00
# Epoch:279 | Iter:    0 | Time: 00:00:09 | Train Loss: 0.6840 | Average Loss: 1.5826
# Accuracy: 0.593750 | Time: 00:00:00
# Epoch:280 | Iter:    0 | Time: 00:00:09 | Train Loss: 0.3383 | Average Loss: 1.5783
# Accuracy: 0.593750 | Time: 00:00:00
# Epoch:281 | Iter:    0 | Time: 00:00:09 | Train Loss: 0.4299 | Average Loss: 1.5741
# Accuracy: 0.656250 | Time: 00:00:00
# Epoch:282 | Iter:    0 | Time: 00:00:09 | Train Loss: 0.2615 | Average Loss: 1.5699
# Accuracy: 0.687500 | Time: 00:00:00
# Epoch:283 | Iter:    0 | Time: 00:00:09 | Train Loss: 0.4793 | Average Loss: 1.5655
# Accuracy: 0.625000 | Time: 00:00:00
# Epoch:284 | Iter:    0 | Time: 00:00:09 | Train Loss: 0.6541 | Average Loss: 1.5613
# Accuracy: 0.593750 | Time: 00:00:00
# Epoch:285 | Iter:    0 | Time: 00:00:09 | Train Loss: 0.1413 | Average Loss: 1.5571
# Accuracy: 0.625000 | Time: 00:00:00
# Epoch:286 | Iter:    0 | Time: 00:00:09 | Train Loss: 0.8971 | Average Loss: 1.5530
# Accuracy: 0.625000 | Time: 00:00:00
# Epoch:287 | Iter:    0 | Time: 00:00:09 | Train Loss: 0.5193 | Average Loss: 1.5488
# Accuracy: 0.593750 | Time: 00:00:00
# Epoch:288 | Iter:    0 | Time: 00:00:09 | Train Loss: 0.6207 | Average Loss: 1.5446
# Accuracy: 0.687500 | Time: 00:00:00
# Epoch:289 | Iter:    0 | Time: 00:00:09 | Train Loss: 0.3318 | Average Loss: 1.5405
# Accuracy: 0.656250 | Time: 00:00:00
# Epoch:290 | Iter:    0 | Time: 00:00:09 | Train Loss: 0.5795 | Average Loss: 1.5364
# Accuracy: 0.687500 | Time: 00:00:00
# Epoch:291 | Iter:    0 | Time: 00:00:09 | Train Loss: 0.5149 | Average Loss: 1.5322
# Accuracy: 0.625000 | Time: 00:00:00
# Epoch:292 | Iter:    0 | Time: 00:00:09 | Train Loss: 0.4603 | Average Loss: 1.5282
# Accuracy: 0.656250 | Time: 00:00:00
# Epoch:293 | Iter:    0 | Time: 00:00:09 | Train Loss: 0.5296 | Average Loss: 1.5240
# Accuracy: 0.593750 | Time: 00:00:00
# Epoch:294 | Iter:    0 | Time: 00:00:10 | Train Loss: 0.3914 | Average Loss: 1.5200
# Accuracy: 0.593750 | Time: 00:00:00
# Epoch:295 | Iter:    0 | Time: 00:00:10 | Train Loss: 0.7711 | Average Loss: 1.5159
# Accuracy: 0.656250 | Time: 00:00:00
# Epoch:296 | Iter:    0 | Time: 00:00:10 | Train Loss: 0.3726 | Average Loss: 1.5120
# Accuracy: 0.656250 | Time: 00:00:00
# Epoch:297 | Iter:    0 | Time: 00:00:10 | Train Loss: 0.2551 | Average Loss: 1.5079
# Accuracy: 0.625000 | Time: 00:00:00
# Epoch:298 | Iter:    0 | Time: 00:00:10 | Train Loss: 0.3325 | Average Loss: 1.5039
# Accuracy: 0.625000 | Time: 00:00:00
# Epoch:299 | Iter:    0 | Time: 00:00:10 | Train Loss: 0.3558 | Average Loss: 1.5000
# Accuracy: 0.593750 | Time: 00:00:00
# Epoch:300 | Iter:    0 | Time: 00:00:10 | Train Loss: 0.4350 | Average Loss: 1.4961
# Accuracy: 0.625000 | Time: 00:00:00
# Epoch:301 | Iter:    0 | Time: 00:00:10 | Train Loss: 0.3860 | Average Loss: 1.4922
# Accuracy: 0.625000 | Time: 00:00:00
# Epoch:302 | Iter:    0 | Time: 00:00:10 | Train Loss: 0.2900 | Average Loss: 1.4883
# Accuracy: 0.593750 | Time: 00:00:00
# Epoch:303 | Iter:    0 | Time: 00:00:10 | Train Loss: 0.3805 | Average Loss: 1.4845
# Accuracy: 0.593750 | Time: 00:00:00
# Epoch:304 | Iter:    0 | Time: 00:00:10 | Train Loss: 0.3725 | Average Loss: 1.4807
# Accuracy: 0.656250 | Time: 00:00:00
# Epoch:305 | Iter:    0 | Time: 00:00:10 | Train Loss: 0.2528 | Average Loss: 1.4768
# Accuracy: 0.656250 | Time: 00:00:00
# Epoch:306 | Iter:    0 | Time: 00:00:10 | Train Loss: 0.5425 | Average Loss: 1.4730
# Accuracy: 0.656250 | Time: 00:00:00
# Epoch:307 | Iter:    0 | Time: 00:00:10 | Train Loss: 0.3323 | Average Loss: 1.4691
# Accuracy: 0.625000 | Time: 00:00:00
# Epoch:308 | Iter:    0 | Time: 00:00:10 | Train Loss: 0.5227 | Average Loss: 1.4656
# Accuracy: 0.562500 | Time: 00:00:00
# Epoch:309 | Iter:    0 | Time: 00:00:10 | Train Loss: 0.5479 | Average Loss: 1.4619
# Accuracy: 0.656250 | Time: 00:00:00
# Epoch:310 | Iter:    0 | Time: 00:00:10 | Train Loss: 0.3661 | Average Loss: 1.4582
# Accuracy: 0.718750 | Time: 00:00:00
# Epoch:311 | Iter:    0 | Time: 00:00:10 | Train Loss: 0.2867 | Average Loss: 1.4545
# Accuracy: 0.625000 | Time: 00:00:00
# Epoch:312 | Iter:    0 | Time: 00:00:10 | Train Loss: 0.3047 | Average Loss: 1.4508
# Accuracy: 0.656250 | Time: 00:00:00
# Epoch:313 | Iter:    0 | Time: 00:00:10 | Train Loss: 0.3071 | Average Loss: 1.4471
# Accuracy: 0.625000 | Time: 00:00:00
# Epoch:314 | Iter:    0 | Time: 00:00:10 | Train Loss: 0.4547 | Average Loss: 1.4435
# Accuracy: 0.656250 | Time: 00:00:00
# Epoch:315 | Iter:    0 | Time: 00:00:10 | Train Loss: 0.2649 | Average Loss: 1.4397
# Accuracy: 0.656250 | Time: 00:00:00
# Epoch:316 | Iter:    0 | Time: 00:00:10 | Train Loss: 0.4856 | Average Loss: 1.4360
# Accuracy: 0.656250 | Time: 00:00:00
# Epoch:317 | Iter:    0 | Time: 00:00:10 | Train Loss: 0.4343 | Average Loss: 1.4322
# Accuracy: 0.593750 | Time: 00:00:00
# Epoch:318 | Iter:    0 | Time: 00:00:10 | Train Loss: 0.2976 | Average Loss: 1.4285
# Accuracy: 0.625000 | Time: 00:00:00
# Epoch:319 | Iter:    0 | Time: 00:00:10 | Train Loss: 0.2300 | Average Loss: 1.4249
# Accuracy: 0.656250 | Time: 00:00:00
# Epoch:320 | Iter:    0 | Time: 00:00:10 | Train Loss: 0.3986 | Average Loss: 1.4214
# Accuracy: 0.656250 | Time: 00:00:00
# Epoch:321 | Iter:    0 | Time: 00:00:10 | Train Loss: 0.2059 | Average Loss: 1.4176
# Accuracy: 0.593750 | Time: 00:00:00
# Epoch:322 | Iter:    0 | Time: 00:00:10 | Train Loss: 0.4146 | Average Loss: 1.4139
# Accuracy: 0.593750 | Time: 00:00:00
# Epoch:323 | Iter:    0 | Time: 00:00:10 | Train Loss: 0.2976 | Average Loss: 1.4103
# Accuracy: 0.625000 | Time: 00:00:00
# Epoch:324 | Iter:    0 | Time: 00:00:10 | Train Loss: 0.4283 | Average Loss: 1.4068
# Accuracy: 0.656250 | Time: 00:00:00
# Epoch:325 | Iter:    0 | Time: 00:00:10 | Train Loss: 0.4246 | Average Loss: 1.4033
# Accuracy: 0.687500 | Time: 00:00:00
# Epoch:326 | Iter:    0 | Time: 00:00:10 | Train Loss: 0.2778 | Average Loss: 1.3998
# Accuracy: 0.656250 | Time: 00:00:00
# Epoch:327 | Iter:    0 | Time: 00:00:11 | Train Loss: 0.4829 | Average Loss: 1.3965
# Accuracy: 0.656250 | Time: 00:00:00
# Epoch:328 | Iter:    0 | Time: 00:00:11 | Train Loss: 0.1659 | Average Loss: 1.3930
# Accuracy: 0.625000 | Time: 00:00:00
# Epoch:329 | Iter:    0 | Time: 00:00:11 | Train Loss: 0.2702 | Average Loss: 1.3896
# Accuracy: 0.656250 | Time: 00:00:00
# Epoch:330 | Iter:    0 | Time: 00:00:11 | Train Loss: 0.4784 | Average Loss: 1.3862
# Accuracy: 0.625000 | Time: 00:00:00
# Epoch:331 | Iter:    0 | Time: 00:00:11 | Train Loss: 0.2931 | Average Loss: 1.3828
# Accuracy: 0.656250 | Time: 00:00:00
# Epoch:332 | Iter:    0 | Time: 00:00:11 | Train Loss: 0.4123 | Average Loss: 1.3792
# Accuracy: 0.593750 | Time: 00:00:00
# Epoch:333 | Iter:    0 | Time: 00:00:11 | Train Loss: 0.3107 | Average Loss: 1.3760
# Accuracy: 0.625000 | Time: 00:00:00
# Epoch:334 | Iter:    0 | Time: 00:00:11 | Train Loss: 0.4185 | Average Loss: 1.3727
# Accuracy: 0.625000 | Time: 00:00:00
# Epoch:335 | Iter:    0 | Time: 00:00:11 | Train Loss: 0.2288 | Average Loss: 1.3694
# Accuracy: 0.625000 | Time: 00:00:00
# Epoch:336 | Iter:    0 | Time: 00:00:11 | Train Loss: 0.6575 | Average Loss: 1.3661
# Accuracy: 0.625000 | Time: 00:00:00
# Epoch:337 | Iter:    0 | Time: 00:00:11 | Train Loss: 0.1705 | Average Loss: 1.3627
# Accuracy: 0.656250 | Time: 00:00:00
# Epoch:338 | Iter:    0 | Time: 00:00:11 | Train Loss: 0.5218 | Average Loss: 1.3593
# Accuracy: 0.687500 | Time: 00:00:00
# Epoch:339 | Iter:    0 | Time: 00:00:11 | Train Loss: 0.2898 | Average Loss: 1.3560
# Accuracy: 0.656250 | Time: 00:00:00
# Epoch:340 | Iter:    0 | Time: 00:00:11 | Train Loss: 0.3206 | Average Loss: 1.3529
# Accuracy: 0.625000 | Time: 00:00:00
# Epoch:341 | Iter:    0 | Time: 00:00:11 | Train Loss: 0.3136 | Average Loss: 1.3496
# Accuracy: 0.687500 | Time: 00:00:00
# Epoch:342 | Iter:    0 | Time: 00:00:11 | Train Loss: 0.2960 | Average Loss: 1.3463
# Accuracy: 0.625000 | Time: 00:00:00
# Epoch:343 | Iter:    0 | Time: 00:00:11 | Train Loss: 0.3132 | Average Loss: 1.3433
# Accuracy: 0.687500 | Time: 00:00:00
# Epoch:344 | Iter:    0 | Time: 00:00:11 | Train Loss: 0.3057 | Average Loss: 1.3401
# Accuracy: 0.625000 | Time: 00:00:00
# Epoch:345 | Iter:    0 | Time: 00:00:11 | Train Loss: 0.0628 | Average Loss: 1.3368
# Accuracy: 0.656250 | Time: 00:00:00
# Epoch:346 | Iter:    0 | Time: 00:00:11 | Train Loss: 0.3861 | Average Loss: 1.3337
# Accuracy: 0.687500 | Time: 00:00:00
# Epoch:347 | Iter:    0 | Time: 00:00:11 | Train Loss: 0.2328 | Average Loss: 1.3304
# Accuracy: 0.687500 | Time: 00:00:00
# Epoch:348 | Iter:    0 | Time: 00:00:11 | Train Loss: 0.1969 | Average Loss: 1.3271
# Accuracy: 0.656250 | Time: 00:00:00
# Epoch:349 | Iter:    0 | Time: 00:00:11 | Train Loss: 0.4715 | Average Loss: 1.3240
# Accuracy: 0.687500 | Time: 00:00:00
# Epoch:350 | Iter:    0 | Time: 00:00:11 | Train Loss: 0.1911 | Average Loss: 1.3208
# Accuracy: 0.656250 | Time: 00:00:00
# Epoch:351 | Iter:    0 | Time: 00:00:11 | Train Loss: 0.5457 | Average Loss: 1.3178
# Accuracy: 0.687500 | Time: 00:00:00
# Epoch:352 | Iter:    0 | Time: 00:00:11 | Train Loss: 0.4595 | Average Loss: 1.3149
# Accuracy: 0.687500 | Time: 00:00:00
# Epoch:353 | Iter:    0 | Time: 00:00:11 | Train Loss: 0.1989 | Average Loss: 1.3118
# Accuracy: 0.656250 | Time: 00:00:00
# Epoch:354 | Iter:    0 | Time: 00:00:11 | Train Loss: 0.3374 | Average Loss: 1.3088
# Accuracy: 0.656250 | Time: 00:00:00
# Epoch:355 | Iter:    0 | Time: 00:00:11 | Train Loss: 0.2030 | Average Loss: 1.3057
# Accuracy: 0.656250 | Time: 00:00:00
# Epoch:356 | Iter:    0 | Time: 00:00:11 | Train Loss: 0.3356 | Average Loss: 1.3027
# Accuracy: 0.625000 | Time: 00:00:00
# Epoch:357 | Iter:    0 | Time: 00:00:11 | Train Loss: 0.4572 | Average Loss: 1.2996
# Accuracy: 0.625000 | Time: 00:00:00
# Epoch:358 | Iter:    0 | Time: 00:00:11 | Train Loss: 0.3029 | Average Loss: 1.2966
# Accuracy: 0.718750 | Time: 00:00:00
# Epoch:359 | Iter:    0 | Time: 00:00:12 | Train Loss: 0.2572 | Average Loss: 1.2936
# Accuracy: 0.593750 | Time: 00:00:00
# Epoch:360 | Iter:    0 | Time: 00:00:12 | Train Loss: 0.3420 | Average Loss: 1.2906
# Accuracy: 0.625000 | Time: 00:00:00
# Epoch:361 | Iter:    0 | Time: 00:00:12 | Train Loss: 0.3200 | Average Loss: 1.2876
# Accuracy: 0.687500 | Time: 00:00:00
# Epoch:362 | Iter:    0 | Time: 00:00:12 | Train Loss: 0.1251 | Average Loss: 1.2846
# Accuracy: 0.656250 | Time: 00:00:00
# Epoch:363 | Iter:    0 | Time: 00:00:12 | Train Loss: 0.4322 | Average Loss: 1.2816
# Accuracy: 0.656250 | Time: 00:00:00
# Epoch:364 | Iter:    0 | Time: 00:00:12 | Train Loss: 0.2677 | Average Loss: 1.2785
# Accuracy: 0.656250 | Time: 00:00:00
# Epoch:365 | Iter:    0 | Time: 00:00:12 | Train Loss: 0.2455 | Average Loss: 1.2754
# Accuracy: 0.656250 | Time: 00:00:00
# Epoch:366 | Iter:    0 | Time: 00:00:12 | Train Loss: 0.2865 | Average Loss: 1.2725
# Accuracy: 0.687500 | Time: 00:00:00
# Epoch:367 | Iter:    0 | Time: 00:00:12 | Train Loss: 0.1474 | Average Loss: 1.2696
# Accuracy: 0.687500 | Time: 00:00:00
# Epoch:368 | Iter:    0 | Time: 00:00:12 | Train Loss: 0.5447 | Average Loss: 1.2667
# Accuracy: 0.687500 | Time: 00:00:00
# Epoch:369 | Iter:    0 | Time: 00:00:12 | Train Loss: 0.2788 | Average Loss: 1.2638
# Accuracy: 0.687500 | Time: 00:00:00
# Epoch:370 | Iter:    0 | Time: 00:00:12 | Train Loss: 0.3851 | Average Loss: 1.2609
# Accuracy: 0.656250 | Time: 00:00:00
# Epoch:371 | Iter:    0 | Time: 00:00:12 | Train Loss: 0.0576 | Average Loss: 1.2580
# Accuracy: 0.656250 | Time: 00:00:00
# Epoch:372 | Iter:    0 | Time: 00:00:12 | Train Loss: 0.8879 | Average Loss: 1.2553
# Accuracy: 0.687500 | Time: 00:00:00
# Epoch:373 | Iter:    0 | Time: 00:00:12 | Train Loss: 0.2134 | Average Loss: 1.2524
# Accuracy: 0.750000 | Time: 00:00:00
# Epoch:374 | Iter:    0 | Time: 00:00:12 | Train Loss: 0.2848 | Average Loss: 1.2498
# Accuracy: 0.656250 | Time: 00:00:00
# Epoch:375 | Iter:    0 | Time: 00:00:12 | Train Loss: 0.3557 | Average Loss: 1.2470
# Accuracy: 0.687500 | Time: 00:00:00
# Epoch:376 | Iter:    0 | Time: 00:00:12 | Train Loss: 0.1112 | Average Loss: 1.2442
# Accuracy: 0.656250 | Time: 00:00:00
# Epoch:377 | Iter:    0 | Time: 00:00:12 | Train Loss: 0.2220 | Average Loss: 1.2414
# Accuracy: 0.656250 | Time: 00:00:00
# Epoch:378 | Iter:    0 | Time: 00:00:12 | Train Loss: 0.4082 | Average Loss: 1.2386
# Accuracy: 0.687500 | Time: 00:00:00
# Epoch:379 | Iter:    0 | Time: 00:00:12 | Train Loss: 0.1820 | Average Loss: 1.2359
# Accuracy: 0.625000 | Time: 00:00:00
# Epoch:380 | Iter:    0 | Time: 00:00:12 | Train Loss: 0.3697 | Average Loss: 1.2330
# Accuracy: 0.718750 | Time: 00:00:00
# Epoch:381 | Iter:    0 | Time: 00:00:12 | Train Loss: 0.1104 | Average Loss: 1.2303
# Accuracy: 0.718750 | Time: 00:00:00
# Epoch:382 | Iter:    0 | Time: 00:00:12 | Train Loss: 0.4069 | Average Loss: 1.2276
# Accuracy: 0.687500 | Time: 00:00:00
# Epoch:383 | Iter:    0 | Time: 00:00:12 | Train Loss: 0.1727 | Average Loss: 1.2248
# Accuracy: 0.687500 | Time: 00:00:00
# Epoch:384 | Iter:    0 | Time: 00:00:12 | Train Loss: 0.3989 | Average Loss: 1.2221
# Accuracy: 0.656250 | Time: 00:00:00
# Epoch:385 | Iter:    0 | Time: 00:00:12 | Train Loss: 0.2200 | Average Loss: 1.2193
# Accuracy: 0.687500 | Time: 00:00:00
# Epoch:386 | Iter:    0 | Time: 00:00:12 | Train Loss: 0.3216 | Average Loss: 1.2168
# Accuracy: 0.718750 | Time: 00:00:00
# Epoch:387 | Iter:    0 | Time: 00:00:12 | Train Loss: 0.2371 | Average Loss: 1.2141
# Accuracy: 0.687500 | Time: 00:00:00
# Epoch:388 | Iter:    0 | Time: 00:00:12 | Train Loss: 0.2156 | Average Loss: 1.2113
# Accuracy: 0.687500 | Time: 00:00:00
# Epoch:389 | Iter:    0 | Time: 00:00:12 | Train Loss: 0.2259 | Average Loss: 1.2088
# Accuracy: 0.687500 | Time: 00:00:00
# Epoch:390 | Iter:    0 | Time: 00:00:13 | Train Loss: 0.2203 | Average Loss: 1.2061
# Accuracy: 0.687500 | Time: 00:00:00
# Epoch:391 | Iter:    0 | Time: 00:00:13 | Train Loss: 0.1984 | Average Loss: 1.2033
# Accuracy: 0.625000 | Time: 00:00:00
# Epoch:392 | Iter:    0 | Time: 00:00:13 | Train Loss: 0.3346 | Average Loss: 1.2007
# Accuracy: 0.625000 | Time: 00:00:00
# Epoch:393 | Iter:    0 | Time: 00:00:13 | Train Loss: 0.4081 | Average Loss: 1.1982
# Accuracy: 0.687500 | Time: 00:00:00
# Epoch:394 | Iter:    0 | Time: 00:00:13 | Train Loss: 0.1016 | Average Loss: 1.1956
# Accuracy: 0.625000 | Time: 00:00:00
# Epoch:395 | Iter:    0 | Time: 00:00:13 | Train Loss: 0.0853 | Average Loss: 1.1929
# Accuracy: 0.656250 | Time: 00:00:00
# Epoch:396 | Iter:    0 | Time: 00:00:13 | Train Loss: 0.3948 | Average Loss: 1.1904
# Accuracy: 0.656250 | Time: 00:00:00
# Epoch:397 | Iter:    0 | Time: 00:00:13 | Train Loss: 0.1411 | Average Loss: 1.1879
# Accuracy: 0.656250 | Time: 00:00:00
# Epoch:398 | Iter:    0 | Time: 00:00:13 | Train Loss: 0.2747 | Average Loss: 1.1853
# Accuracy: 0.625000 | Time: 00:00:00
# Epoch:399 | Iter:    0 | Time: 00:00:13 | Train Loss: 0.1097 | Average Loss: 1.1827
# Accuracy: 0.625000 | Time: 00:00:00
# Epoch:400 | Iter:    0 | Time: 00:00:13 | Train Loss: 0.2229 | Average Loss: 1.1801
# Accuracy: 0.656250 | Time: 00:00:00
# Epoch:401 | Iter:    0 | Time: 00:00:13 | Train Loss: 0.2867 | Average Loss: 1.1777
# Accuracy: 0.656250 | Time: 00:00:00
# Epoch:402 | Iter:    0 | Time: 00:00:13 | Train Loss: 0.3442 | Average Loss: 1.1752
# Accuracy: 0.625000 | Time: 00:00:00
# Epoch:403 | Iter:    0 | Time: 00:00:13 | Train Loss: 0.0789 | Average Loss: 1.1727
# Accuracy: 0.625000 | Time: 00:00:00
# Epoch:404 | Iter:    0 | Time: 00:00:13 | Train Loss: 0.4174 | Average Loss: 1.1701
# Accuracy: 0.656250 | Time: 00:00:00
# Epoch:405 | Iter:    0 | Time: 00:00:13 | Train Loss: 0.2044 | Average Loss: 1.1678
# Accuracy: 0.687500 | Time: 00:00:00
# Epoch:406 | Iter:    0 | Time: 00:00:13 | Train Loss: 0.1657 | Average Loss: 1.1653
# Accuracy: 0.718750 | Time: 00:00:00
# Epoch:407 | Iter:    0 | Time: 00:00:13 | Train Loss: 0.3481 | Average Loss: 1.1628
# Accuracy: 0.687500 | Time: 00:00:00
# Epoch:408 | Iter:    0 | Time: 00:00:13 | Train Loss: 0.1181 | Average Loss: 1.1602
# Accuracy: 0.687500 | Time: 00:00:00
# Epoch:409 | Iter:    0 | Time: 00:00:13 | Train Loss: 0.2165 | Average Loss: 1.1578
# Accuracy: 0.718750 | Time: 00:00:00
# Epoch:410 | Iter:    0 | Time: 00:00:13 | Train Loss: 0.2391 | Average Loss: 1.1554
# Accuracy: 0.656250 | Time: 00:00:00
# Epoch:411 | Iter:    0 | Time: 00:00:13 | Train Loss: 0.4184 | Average Loss: 1.1531
# Accuracy: 0.718750 | Time: 00:00:00
# Epoch:412 | Iter:    0 | Time: 00:00:13 | Train Loss: 0.1160 | Average Loss: 1.1506
# Accuracy: 0.687500 | Time: 00:00:00
# Epoch:413 | Iter:    0 | Time: 00:00:13 | Train Loss: 0.1498 | Average Loss: 1.1481
# Accuracy: 0.656250 | Time: 00:00:00
# Epoch:414 | Iter:    0 | Time: 00:00:13 | Train Loss: 0.2873 | Average Loss: 1.1457
# Accuracy: 0.625000 | Time: 00:00:00
# Epoch:415 | Iter:    0 | Time: 00:00:13 | Train Loss: 0.2328 | Average Loss: 1.1433
# Accuracy: 0.687500 | Time: 00:00:00
# Epoch:416 | Iter:    0 | Time: 00:00:13 | Train Loss: 0.1631 | Average Loss: 1.1411
# Accuracy: 0.656250 | Time: 00:00:00
# Epoch:417 | Iter:    0 | Time: 00:00:13 | Train Loss: 0.2832 | Average Loss: 1.1387
# Accuracy: 0.656250 | Time: 00:00:00
# Epoch:418 | Iter:    0 | Time: 00:00:13 | Train Loss: 0.1513 | Average Loss: 1.1363
# Accuracy: 0.687500 | Time: 00:00:00
# Epoch:419 | Iter:    0 | Time: 00:00:13 | Train Loss: 0.1036 | Average Loss: 1.1340
# Accuracy: 0.687500 | Time: 00:00:00
# Epoch:420 | Iter:    0 | Time: 00:00:13 | Train Loss: 0.1230 | Average Loss: 1.1316
# Accuracy: 0.625000 | Time: 00:00:00
# Epoch:421 | Iter:    0 | Time: 00:00:14 | Train Loss: 0.2814 | Average Loss: 1.1294
# Accuracy: 0.687500 | Time: 00:00:00
# Epoch:422 | Iter:    0 | Time: 00:00:14 | Train Loss: 0.2106 | Average Loss: 1.1271
# Accuracy: 0.593750 | Time: 00:00:00
# Epoch:423 | Iter:    0 | Time: 00:00:14 | Train Loss: 0.4024 | Average Loss: 1.1248
# Accuracy: 0.656250 | Time: 00:00:00
# Epoch:424 | Iter:    0 | Time: 00:00:14 | Train Loss: 0.2111 | Average Loss: 1.1225
# Accuracy: 0.625000 | Time: 00:00:00
# Epoch:425 | Iter:    0 | Time: 00:00:14 | Train Loss: 0.2125 | Average Loss: 1.1202
# Accuracy: 0.656250 | Time: 00:00:00
# Epoch:426 | Iter:    0 | Time: 00:00:14 | Train Loss: 0.3654 | Average Loss: 1.1179
# Accuracy: 0.687500 | Time: 00:00:00
# Epoch:427 | Iter:    0 | Time: 00:00:14 | Train Loss: 0.3272 | Average Loss: 1.1155
# Accuracy: 0.656250 | Time: 00:00:00
# Epoch:428 | Iter:    0 | Time: 00:00:14 | Train Loss: 0.1013 | Average Loss: 1.1132
# Accuracy: 0.656250 | Time: 00:00:00
# Epoch:429 | Iter:    0 | Time: 00:00:14 | Train Loss: 0.2828 | Average Loss: 1.1108
# Accuracy: 0.656250 | Time: 00:00:00
# Epoch:430 | Iter:    0 | Time: 00:00:14 | Train Loss: 0.3105 | Average Loss: 1.1087
# Accuracy: 0.625000 | Time: 00:00:00
# Epoch:431 | Iter:    0 | Time: 00:00:14 | Train Loss: 0.2039 | Average Loss: 1.1065
# Accuracy: 0.593750 | Time: 00:00:00
# Epoch:432 | Iter:    0 | Time: 00:00:14 | Train Loss: 0.2682 | Average Loss: 1.1043
# Accuracy: 0.625000 | Time: 00:00:00
# Epoch:433 | Iter:    0 | Time: 00:00:14 | Train Loss: 0.3960 | Average Loss: 1.1021
# Accuracy: 0.656250 | Time: 00:00:00
# Epoch:434 | Iter:    0 | Time: 00:00:14 | Train Loss: 0.0679 | Average Loss: 1.0998
# Accuracy: 0.656250 | Time: 00:00:00
# Epoch:435 | Iter:    0 | Time: 00:00:14 | Train Loss: 0.2027 | Average Loss: 1.0976
# Accuracy: 0.656250 | Time: 00:00:00
# Epoch:436 | Iter:    0 | Time: 00:00:14 | Train Loss: 0.3628 | Average Loss: 1.0955
# Accuracy: 0.656250 | Time: 00:00:00
# Epoch:437 | Iter:    0 | Time: 00:00:14 | Train Loss: 0.1134 | Average Loss: 1.0933
# Accuracy: 0.656250 | Time: 00:00:00
# Epoch:438 | Iter:    0 | Time: 00:00:14 | Train Loss: 0.2554 | Average Loss: 1.0911
# Accuracy: 0.656250 | Time: 00:00:00
# Epoch:439 | Iter:    0 | Time: 00:00:14 | Train Loss: 0.2419 | Average Loss: 1.0892
# Accuracy: 0.687500 | Time: 00:00:00
# Epoch:440 | Iter:    0 | Time: 00:00:14 | Train Loss: 0.1726 | Average Loss: 1.0869
# Accuracy: 0.656250 | Time: 00:00:00
# Epoch:441 | Iter:    0 | Time: 00:00:14 | Train Loss: 0.2052 | Average Loss: 1.0847
# Accuracy: 0.687500 | Time: 00:00:00
# Epoch:442 | Iter:    0 | Time: 00:00:14 | Train Loss: 0.1337 | Average Loss: 1.0825
# Accuracy: 0.687500 | Time: 00:00:00
# Epoch:443 | Iter:    0 | Time: 00:00:14 | Train Loss: 0.1304 | Average Loss: 1.0804
# Accuracy: 0.687500 | Time: 00:00:00
# Epoch:444 | Iter:    0 | Time: 00:00:14 | Train Loss: 0.2510 | Average Loss: 1.0783
# Accuracy: 0.656250 | Time: 00:00:00
# Epoch:445 | Iter:    0 | Time: 00:00:14 | Train Loss: 0.1821 | Average Loss: 1.0763
# Accuracy: 0.625000 | Time: 00:00:00
# Epoch:446 | Iter:    0 | Time: 00:00:14 | Train Loss: 0.4823 | Average Loss: 1.0742
# Accuracy: 0.656250 | Time: 00:00:00
# Epoch:447 | Iter:    0 | Time: 00:00:14 | Train Loss: 0.1384 | Average Loss: 1.0720
# Accuracy: 0.687500 | Time: 00:00:00
# Epoch:448 | Iter:    0 | Time: 00:00:14 | Train Loss: 0.1400 | Average Loss: 1.0699
# Accuracy: 0.687500 | Time: 00:00:00
# Epoch:449 | Iter:    0 | Time: 00:00:14 | Train Loss: 0.0585 | Average Loss: 1.0678
# Accuracy: 0.687500 | Time: 00:00:00
# Epoch:450 | Iter:    0 | Time: 00:00:14 | Train Loss: 0.2204 | Average Loss: 1.0656
# Accuracy: 0.687500 | Time: 00:00:00
# Epoch:451 | Iter:    0 | Time: 00:00:14 | Train Loss: 0.2016 | Average Loss: 1.0634
# Accuracy: 0.656250 | Time: 00:00:00
# Epoch:452 | Iter:    0 | Time: 00:00:14 | Train Loss: 0.1425 | Average Loss: 1.0613
# Accuracy: 0.687500 | Time: 00:00:00
# Epoch:453 | Iter:    0 | Time: 00:00:15 | Train Loss: 0.0419 | Average Loss: 1.0593
# Accuracy: 0.625000 | Time: 00:00:00
# Epoch:454 | Iter:    0 | Time: 00:00:15 | Train Loss: 0.3935 | Average Loss: 1.0572
# Accuracy: 0.687500 | Time: 00:00:00
# Epoch:455 | Iter:    0 | Time: 00:00:15 | Train Loss: 0.1043 | Average Loss: 1.0552
# Accuracy: 0.687500 | Time: 00:00:00
# Epoch:456 | Iter:    0 | Time: 00:00:15 | Train Loss: 0.0975 | Average Loss: 1.0532
# Accuracy: 0.687500 | Time: 00:00:00
# Epoch:457 | Iter:    0 | Time: 00:00:15 | Train Loss: 0.1680 | Average Loss: 1.0511
# Accuracy: 0.687500 | Time: 00:00:00
# Epoch:458 | Iter:    0 | Time: 00:00:15 | Train Loss: 0.2270 | Average Loss: 1.0492
# Accuracy: 0.656250 | Time: 00:00:00
# Epoch:459 | Iter:    0 | Time: 00:00:15 | Train Loss: 0.2887 | Average Loss: 1.0470
# Accuracy: 0.687500 | Time: 00:00:00
# Epoch:460 | Iter:    0 | Time: 00:00:15 | Train Loss: 0.0563 | Average Loss: 1.0450
# Accuracy: 0.687500 | Time: 00:00:00
# Epoch:461 | Iter:    0 | Time: 00:00:15 | Train Loss: 0.2675 | Average Loss: 1.0430
# Accuracy: 0.687500 | Time: 00:00:00
# Epoch:462 | Iter:    0 | Time: 00:00:15 | Train Loss: 0.2008 | Average Loss: 1.0411
# Accuracy: 0.687500 | Time: 00:00:00
# Epoch:463 | Iter:    0 | Time: 00:00:15 | Train Loss: 0.1641 | Average Loss: 1.0390
# Accuracy: 0.687500 | Time: 00:00:00
# Epoch:464 | Iter:    0 | Time: 00:00:15 | Train Loss: 0.0834 | Average Loss: 1.0370
# Accuracy: 0.718750 | Time: 00:00:00
# Epoch:465 | Iter:    0 | Time: 00:00:15 | Train Loss: 0.2288 | Average Loss: 1.0350
# Accuracy: 0.687500 | Time: 00:00:00
# Epoch:466 | Iter:    0 | Time: 00:00:15 | Train Loss: 0.0646 | Average Loss: 1.0331
# Accuracy: 0.656250 | Time: 00:00:00
# Epoch:467 | Iter:    0 | Time: 00:00:15 | Train Loss: 0.2361 | Average Loss: 1.0311
# Accuracy: 0.687500 | Time: 00:00:00
# Epoch:468 | Iter:    0 | Time: 00:00:15 | Train Loss: 0.3141 | Average Loss: 1.0292
# Accuracy: 0.687500 | Time: 00:00:00
# Epoch:469 | Iter:    0 | Time: 00:00:15 | Train Loss: 0.1139 | Average Loss: 1.0273
# Accuracy: 0.687500 | Time: 00:00:00
# Epoch:470 | Iter:    0 | Time: 00:00:15 | Train Loss: 0.1604 | Average Loss: 1.0253
# Accuracy: 0.687500 | Time: 00:00:00
# Epoch:471 | Iter:    0 | Time: 00:00:15 | Train Loss: 0.1018 | Average Loss: 1.0233
# Accuracy: 0.687500 | Time: 00:00:00
# Epoch:472 | Iter:    0 | Time: 00:00:15 | Train Loss: 0.1624 | Average Loss: 1.0214
# Accuracy: 0.687500 | Time: 00:00:00
# Epoch:473 | Iter:    0 | Time: 00:00:15 | Train Loss: 0.0690 | Average Loss: 1.0196
# Accuracy: 0.656250 | Time: 00:00:00
# Epoch:474 | Iter:    0 | Time: 00:00:15 | Train Loss: 0.1808 | Average Loss: 1.0176
# Accuracy: 0.687500 | Time: 00:00:00
# Epoch:475 | Iter:    0 | Time: 00:00:15 | Train Loss: 0.1105 | Average Loss: 1.0158
# Accuracy: 0.656250 | Time: 00:00:00
# Epoch:476 | Iter:    0 | Time: 00:00:15 | Train Loss: 0.0781 | Average Loss: 1.0139
# Accuracy: 0.656250 | Time: 00:00:00
# Epoch:477 | Iter:    0 | Time: 00:00:15 | Train Loss: 0.1765 | Average Loss: 1.0119
# Accuracy: 0.625000 | Time: 00:00:00
# Epoch:478 | Iter:    0 | Time: 00:00:15 | Train Loss: 0.2545 | Average Loss: 1.0100
# Accuracy: 0.687500 | Time: 00:00:00
# Epoch:479 | Iter:    0 | Time: 00:00:15 | Train Loss: 0.0968 | Average Loss: 1.0082
# Accuracy: 0.687500 | Time: 00:00:00
# Epoch:480 | Iter:    0 | Time: 00:00:15 | Train Loss: 0.3090 | Average Loss: 1.0063
# Accuracy: 0.656250 | Time: 00:00:00
# Epoch:481 | Iter:    0 | Time: 00:00:15 | Train Loss: 0.0540 | Average Loss: 1.0044
# Accuracy: 0.687500 | Time: 00:00:00
# Epoch:482 | Iter:    0 | Time: 00:00:15 | Train Loss: 0.2198 | Average Loss: 1.0026
# Accuracy: 0.687500 | Time: 00:00:00
# Epoch:483 | Iter:    0 | Time: 00:00:15 | Train Loss: 0.5101 | Average Loss: 1.0008
# Accuracy: 0.687500 | Time: 00:00:00
# Epoch:484 | Iter:    0 | Time: 00:00:16 | Train Loss: 0.0301 | Average Loss: 0.9989
# Accuracy: 0.687500 | Time: 00:00:00
# Epoch:485 | Iter:    0 | Time: 00:00:16 | Train Loss: 0.0407 | Average Loss: 0.9970
# Accuracy: 0.687500 | Time: 00:00:00
# Epoch:486 | Iter:    0 | Time: 00:00:16 | Train Loss: 0.2005 | Average Loss: 0.9952
# Accuracy: 0.718750 | Time: 00:00:00
# Epoch:487 | Iter:    0 | Time: 00:00:16 | Train Loss: 0.0948 | Average Loss: 0.9933
# Accuracy: 0.656250 | Time: 00:00:00
# Epoch:488 | Iter:    0 | Time: 00:00:16 | Train Loss: 0.1461 | Average Loss: 0.9915
# Accuracy: 0.656250 | Time: 00:00:00
# Epoch:489 | Iter:    0 | Time: 00:00:16 | Train Loss: 0.1177 | Average Loss: 0.9897
# Accuracy: 0.656250 | Time: 00:00:00
# Epoch:490 | Iter:    0 | Time: 00:00:16 | Train Loss: 0.1085 | Average Loss: 0.9879
# Accuracy: 0.656250 | Time: 00:00:00
# Epoch:491 | Iter:    0 | Time: 00:00:16 | Train Loss: 0.2490 | Average Loss: 0.9861
# Accuracy: 0.687500 | Time: 00:00:00
# Epoch:492 | Iter:    0 | Time: 00:00:16 | Train Loss: 0.0589 | Average Loss: 0.9843
# Accuracy: 0.687500 | Time: 00:00:00
# Epoch:493 | Iter:    0 | Time: 00:00:16 | Train Loss: 0.1954 | Average Loss: 0.9825
# Accuracy: 0.687500 | Time: 00:00:00
# Epoch:494 | Iter:    0 | Time: 00:00:16 | Train Loss: 0.1789 | Average Loss: 0.9808
# Accuracy: 0.656250 | Time: 00:00:00
# Epoch:495 | Iter:    0 | Time: 00:00:16 | Train Loss: 0.0446 | Average Loss: 0.9791
# Accuracy: 0.656250 | Time: 00:00:00
# Epoch:496 | Iter:    0 | Time: 00:00:16 | Train Loss: 0.1622 | Average Loss: 0.9773
# Accuracy: 0.687500 | Time: 00:00:00
# Epoch:497 | Iter:    0 | Time: 00:00:16 | Train Loss: 0.3329 | Average Loss: 0.9756
# Accuracy: 0.656250 | Time: 00:00:00
# Epoch:498 | Iter:    0 | Time: 00:00:16 | Train Loss: 0.1061 | Average Loss: 0.9739
# Accuracy: 0.656250 | Time: 00:00:00
# Epoch:499 | Iter:    0 | Time: 00:00:16 | Train Loss: 0.1133 | Average Loss: 0.9721
# Accuracy: 0.687500 | Time: 00:00:00
# Epoch:500 | Iter:    0 | Time: 00:00:16 | Train Loss: 0.0753 | Average Loss: 0.9704
# Accuracy: 0.687500 | Time: 00:00:00

# %% [markdown]
# Answer:
#
# Method 3: Different activation function methods: replace the ReLu layer with a Sigmoid layer.
#
# Accuracy on test data: 0.718750 (Epoch:486)
#
# (compare with 0.656250 in vanilla network, Accuracy increases)

# %% [markdown]
# ## Problem 2: Fine Tuning a Pre-Trained Deep Network [30 points]
# Our convolutional network to this point isn't "deep". Fortunately, the representations learned by deep convolutional networks is that they generalize surprisingly well to other recognition tasks.
#
# But how do we use an existing deep network for a new recognition task? Take for instance,  [AlexNet](http://papers.nips.cc/paper/4824-imagenet-classification-with-deep-convolutional-neural-networks) network has 1000 units in the final layer corresponding to 1000 ImageNet categories.
#
#
# **Hints**:
# - Many pre-trained models are available in PyTorch at [here](http://pytorch.org/docs/master/torchvision/models.html).
# - For fine-tuning pretrained network using PyTorch, please read this [tutorial](http://pytorch.org/tutorials/beginner/transfer_learning_tutorial.html).

# %% [markdown]
# ### Problem 2.1 [10 points]
#
# **Strategy A**: *Fine-tune* an existing network. In this scenario you take an existing network, replace the final layer (or more) with random weights, and train the entire network again with images and ground truth labels for your recognition task. You are effectively treating the pre-trained deep network as a better initialization than the random weights used when training from scratch. When you don't have enough training data to train a complex network from scratch (e.g. with the 22 classes) this is an attractive option. Fine-tuning can work far better than Strategy B of taking the activations directly from an pre-trained CNN. For example, in [this paper](http://www.cc.gatech.edu/~hays/papers/deep_geo.pdf) from CVPR 2015, there wasn't enough data to train a deep network from scratch, but fine tuning led to 4 times higher accuracy than using off-the-shelf networks directly.
#
# (30 points) You are required to implement Strategy A to fine-tune a pre-trained **AlexNet** for this scene classification task. You should be able to achieve accuracy of **0.90** approximately. The minimum accuracy required for this section is **0.80**.
#
# Please provide detailed descriptions of:<br>
# (1) which layers of AlexNet have been replaced<br>
# (2) the architecture of the new layers added including activation methods (same as problem 1)<br>
# (3) the final accuracy on test set along with time consumption for both training and testing <br>

# %%
# reload data with a larger size
img_size = (224, 224)
batch_size = 16 # training sample number per batch

# load training dataset
trainloader_large = list(load_dataset('./data/train/', img_size, batch_size=batch_size, shuffle=True,
                                      augment=True, is_color=True, zero_centered=True))
train_num = len(trainloader_large)
print("Finish loading %d minibatches (batch_size=%d) of training samples." % (train_num, batch_size))

# load testing dataset
testloader_large = list(load_dataset('./data/test/', img_size, num_per_class=50, batch_size=batch_size, is_color=True, zero_centered=True))
test_num = len(testloader_large)
print("Finish loading %d minibatches (batch_size=%d) of testing samples." % (test_num, batch_size))
# Out:
# Loading images from class: 0
# <ipython-input-4-f9969027fe30>:43: DeprecationWarning: `np.float` is a deprecated alias for the builtin `float`. To silence this warning, use `float` by itself. Doing this will not modify any behavior and is safe. If you specifically wanted the numpy scalar type, use `np.float64` here.
# Deprecated in NumPy 1.20; for more details and guidance: https://numpy.org/devdocs/release/1.20.0-notes.html#deprecations
#   data.append(img.astype(np.float)/255*2-1)
# Loading images from class: 1
# Loading images from class: 2
# Loading images from class: 3
# Loading images from class: 4
# Loading images from class: 5
# Loading images from class: 6
# Loading images from class: 7
# Loading images from class: 8
# Loading images from class: 9
# Loading images from class: 10
# Loading images from class: 11
# Loading images from class: 12
# Loading images from class: 13
# Loading images from class: 14
# Loading images from class: 15
# Loading images from class: 16
# Loading images from class: 17
# Loading images from class: 18
# Loading images from class: 19
# Loading images from class: 20
# Loading images from class: 21
# Finish loading 14 minibatches (batch_size=16) of training samples.
# Loading images from class: 0
# Loading images from class: 1
# Loading images from class: 2
# Loading images from class: 3
# Loading images from class: 4
# Loading images from class: 5
# Loading images from class: 6
# Loading images from class: 7
# Loading images from class: 8
# Loading images from class: 9
# Loading images from class: 10
# Loading images from class: 11
# Loading images from class: 12
# Loading images from class: 13
# Loading images from class: 14
# Loading images from class: 15
# Loading images from class: 16
# Loading images from class: 17
# Loading images from class: 18
# Loading images from class: 19
# Loading images from class: 20
# Loading images from class: 21
# Finish loading 2 minibatches (batch_size=16) of testing samples.

# %%
#--------------------------------------------------
#       Fine-Tune Pretrained Network
#--------------------------------------------------
net = torchvision.models.alexnet(pretrained = True)
net.classifier[6] = nn.Linear(net.classifier[6].in_features, 22)
train_option = {}
train_option['lr'] = 0.0001
train_option['epoch'] = 20
train_option['device'] = 'gpu'
trainModel(net, trainloader_large, train_option, testloader_large)
# Out:
# Epoch: 1 | Iter:    0 | Time: 00:00:00 | Train Loss: 3.6167 | Average Loss: 3.6167
# Accuracy: 0.312500 | Time: 00:00:00
# Epoch: 2 | Iter:    0 | Time: 00:00:00 | Train Loss: 2.5542 | Average Loss: 3.5045
# Accuracy: 0.625000 | Time: 00:00:00
# Epoch: 3 | Iter:    0 | Time: 00:00:01 | Train Loss: 1.4005 | Average Loss: 3.0989
# Accuracy: 0.718750 | Time: 00:00:00
# Epoch: 4 | Iter:    0 | Time: 00:00:01 | Train Loss: 0.1981 | Average Loss: 2.5985
# Accuracy: 0.875000 | Time: 00:00:00
# Epoch: 5 | Iter:    0 | Time: 00:00:02 | Train Loss: 0.1297 | Average Loss: 2.1145
# Accuracy: 0.875000 | Time: 00:00:00
# Epoch: 6 | Iter:    0 | Time: 00:00:02 | Train Loss: 0.0030 | Average Loss: 1.7312
# Accuracy: 0.843750 | Time: 00:00:00
# Epoch: 7 | Iter:    0 | Time: 00:00:03 | Train Loss: 5.8971 | Average Loss: 1.5259
# Accuracy: 0.562500 | Time: 00:00:00
# Epoch: 8 | Iter:    0 | Time: 00:00:03 | Train Loss: 0.1193 | Average Loss: 1.4505
# Accuracy: 0.812500 | Time: 00:00:00
# Epoch: 9 | Iter:    0 | Time: 00:00:04 | Train Loss: 0.7051 | Average Loss: 1.3406
# Accuracy: 0.937500 | Time: 00:00:00
# Epoch:10 | Iter:    0 | Time: 00:00:04 | Train Loss: 0.0001 | Average Loss: 1.2065
# Accuracy: 0.875000 | Time: 00:00:00
# Epoch:11 | Iter:    0 | Time: 00:00:05 | Train Loss: 0.0016 | Average Loss: 1.0895
# Accuracy: 0.906250 | Time: 00:00:00
# Epoch:12 | Iter:    0 | Time: 00:00:05 | Train Loss: 0.0017 | Average Loss: 0.9915
# Accuracy: 0.906250 | Time: 00:00:00
# Epoch:13 | Iter:    0 | Time: 00:00:06 | Train Loss: 0.0006 | Average Loss: 0.9095
# Accuracy: 0.906250 | Time: 00:00:00
# Epoch:14 | Iter:    0 | Time: 00:00:06 | Train Loss: 0.0001 | Average Loss: 0.8401
# Accuracy: 0.906250 | Time: 00:00:00
# Epoch:15 | Iter:    0 | Time: 00:00:07 | Train Loss: 0.0001 | Average Loss: 0.7805
# Accuracy: 0.906250 | Time: 00:00:00
# Epoch:16 | Iter:    0 | Time: 00:00:07 | Train Loss: 0.0000 | Average Loss: 0.7288
# Accuracy: 0.906250 | Time: 00:00:00
# Epoch:17 | Iter:    0 | Time: 00:00:08 | Train Loss: 0.0000 | Average Loss: 0.6835
# Accuracy: 0.906250 | Time: 00:00:00
# Epoch:18 | Iter:    0 | Time: 00:00:08 | Train Loss: 0.0001 | Average Loss: 0.6435
# Accuracy: 0.937500 | Time: 00:00:00
# Epoch:19 | Iter:    0 | Time: 00:00:09 | Train Loss: 0.0000 | Average Loss: 0.6080
# Accuracy: 0.968750 | Time: 00:00:00
# Epoch:20 | Iter:    0 | Time: 00:00:09 | Train Loss: 0.0000 | Average Loss: 0.5761
# Accuracy: 0.968750 | Time: 00:00:00

# %% [markdown]
# Answer:
#
# (1) which layers of AlexNet have been replaced
#
# Only the last layer, layer 6, is replaced.
#
#
# (2) the architecture of the new layers added including activation methods (same as problem 1)
#
# Data augmentation: Add image data for horizontal flipping
#
# Data normalization: Zero_center the image data and normalize it.
#
# Classifier Layer 1: No change
#
# Classifier Layer 2: No change
#
# Classifier Layer 3: No change
#
# Classifier Layer 4: No change
#
# Classifier Layer 5: No change
#
# Classifier Layer 6: Replaced by Linear classifier layer, this layer has input channel = 4096, output channel = 22
#
#
# (3) the final accuracy on test set along with time consumption for both training and testing
#
# Accuracy on Test set: 0.968750 | Time for Training: 9s | Time for Testing: 1s

# %% [markdown]
# ### Problem 2.2 [10 points]
# **Strategy B**: One could use those 1000 activations as a feature in place of a hand crafted feature such as a bag-of-features representation. You would train a classifier (typically a linear SVM) in that 1000 dimensional feature space. However, those activations are clearly very object specific and may not generalize well to new recognition tasks. It is generally better to use the activations in slightly earlier layers of the network, e.g. the 4096 activations in the last 2nd fully-connected layer. You can often get away with sub-sampling those 4096 activations considerably, e.g. taking only the first 1000 activations.
#
# (20 points) Implement Strategy B where you use the activations of the pre-trained network as features to train one-vs-all SVMs for your scene classification task. Report the final accuracy on test set along with time consumption for both training and testing. You should be able to achieve accuracy of **0.85** approximately. The minimum accuracy required for this section is **0.75**.

# %%
#--------------------------------------------------
#       Get Features from AlexNet
#--------------------------------------------------
import time
def trainAndTestModel(net, trainloader, train_option, testloader):
  device = train_option['device'] if 'device' in train_option.keys() else 'cpu'
  if device == 'gpu':
    net = net.cuda()

  #train
  start_time = time.time()
  train_features = []
  train_labels = []
  for x, y in trainloader:
    batch_x = Variable(x).float()
    batch_y = Variable(y).long()
    if device == 'gpu':
      batch_x = batch_x.cuda()
      batch_y = batch_y.cuda()

    outputs = net(batch_x)
    for i, img in enumerate(outputs):
      train_features.append(img[:1000].cpu().detach().numpy())
      train_labels.append(batch_y[i].cpu().detach().numpy())


  time_lapse = time.strftime('%H:%M:%S', time.gmtime(time.time() - start_time))
  print('Train time: {}'.format(time_lapse))


  #test
  start_time = time.time()
  test_features = []
  test_labels = []
  for x, y in testloader:
    batch_x = Variable(x).float()
    batch_y = Variable(y).long()
    if device == 'gpu':
      batch_x = batch_x.cuda()
      batch_y = batch_y.cuda()

    outputs = net(batch_x)
    for i, img in enumerate(outputs):
      test_features.append(img[:1000].cpu().detach().numpy())
      test_labels.append(batch_y[i].cpu().detach().numpy())

  time_lapse = time.strftime('%H:%M:%S', time.gmtime(time.time() - start_time))
  print('Test time: {}'.format(time_lapse))

  return train_features, train_labels, test_features, test_labels

# %%
#--------------------------------------------------
#       Train and Evaluate SVM
#--------------------------------------------------
from sklearn import svm
net = torchvision.models.alexnet(pretrained = True)
net.classifier = nn.Sequential(*list(net.classifier.children())[:-2])
train_option = {}
train_option['device'] = 'gpu'
train_features, train_labels, test_features, test_labels = trainAndTestModel(net, trainloader_large, train_option, testloader_large)

pred_svm = svm.SVC().fit(train_features, train_labels).predict(test_features)
print('Accuracy: {:5f}'.format(sum(np.array(pred_svm) == test_labels) / float(len(pred_svm))))
# Out:
# /usr/local/lib/python3.10/dist-packages/torchvision/models/_utils.py:208: UserWarning: The parameter 'pretrained' is deprecated since 0.13 and may be removed in the future, please use 'weights' instead.
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/torchvision/models/_utils.py:223: UserWarning: Arguments other than a weight enum or `None` for 'weights' are deprecated since 0.13 and may be removed in the future. The current behavior is equivalent to passing `weights=AlexNet_Weights.IMAGENET1K_V1`. You can also use `weights=AlexNet_Weights.DEFAULT` to get the most up-to-date weights.
#   warnings.warn(msg)
# Train time: 00:00:00
# Test time: 00:00:00
# Accuracy: 0.875000

# %% [markdown]
# Answer:
#
# Accuracy on Test set: 0.875000 | Time for Training: 0s | Time for Testing: 0s

# %% [markdown]
# ### Problem 2.3 [10 points]
#
# Now fine-tune the [ResNet network](https://pytorch.org/docs/stable/_modules/torchvision/models/resnet.html) [(paper)](https://arxiv.org/abs/1512.03385) and compare performance with AlexNet. **Explain** why ResNet performed better or worse. You are **required** to use **resnet50** model. You should be able to achieve accuracy of **0.99** approximately. The minimum accuracy required for this section is **0.85**.

# %%
#--------------------------------------------------
#       Fine-Tune Pretrained Network
#--------------------------------------------------
net = torchvision.models.resnet50(pretrained = True)
net.fc = nn.Linear(net.fc.in_features, 22)
train_option = {}
train_option['lr'] = 0.0001
train_option['epoch'] = 10
train_option['device'] = 'gpu'
trainModel(net, trainloader_large, train_option, testloader_large)
# Out:
# Epoch: 1 | Iter:    0 | Time: 00:00:00 | Train Loss: 3.1976 | Average Loss: 3.1976
# Accuracy: 0.343750 | Time: 00:00:00
# Epoch: 2 | Iter:    0 | Time: 00:00:02 | Train Loss: 1.6732 | Average Loss: 3.3181
# Accuracy: 0.531250 | Time: 00:00:00
# Epoch: 3 | Iter:    0 | Time: 00:00:05 | Train Loss: 1.2196 | Average Loss: 2.8256
# Accuracy: 0.593750 | Time: 00:00:00
# Epoch: 4 | Iter:    0 | Time: 00:00:07 | Train Loss: 0.8732 | Average Loss: 2.4356
# Accuracy: 0.718750 | Time: 00:00:00
# Epoch: 5 | Iter:    0 | Time: 00:00:10 | Train Loss: 0.6088 | Average Loss: 2.1070
# Accuracy: 0.781250 | Time: 00:00:00
# Epoch: 6 | Iter:    0 | Time: 00:00:13 | Train Loss: 0.4142 | Average Loss: 1.8354
# Accuracy: 0.750000 | Time: 00:00:00
# Epoch: 7 | Iter:    0 | Time: 00:00:15 | Train Loss: 0.2876 | Average Loss: 1.6124
# Accuracy: 0.812500 | Time: 00:00:00
# Epoch: 8 | Iter:    0 | Time: 00:00:18 | Train Loss: 0.2014 | Average Loss: 1.4289
# Accuracy: 0.812500 | Time: 00:00:00
# Epoch: 9 | Iter:    0 | Time: 00:00:20 | Train Loss: 0.1540 | Average Loss: 1.2789
# Accuracy: 0.875000 | Time: 00:00:00
# Epoch:10 | Iter:    0 | Time: 00:00:23 | Train Loss: 0.1276 | Average Loss: 1.1561
# Accuracy: 0.843750 | Time: 00:00:00

# %% [markdown]
# Answer:
#
# Accuracy on Test set: 0.875000(Epoch: 9) | Time for Training: 20s | Time for Testing: 6s
#
# (compare with 0.968750 in AlexNet)
#
# AlexNet performs better because ResNet is deeper and since we don not have enough data, the extra layers will lead to overfitting. So 8-layer AlexNet is better than 50-layer ResNet50.

# %% [markdown]
# ### Problem 3 Transformer [30 points]
# In this section you are supposed to build a Vision Transformer (ViT). Transformer has achieved significant success in the field of Natural Language Processing, such as machine translation. ViT explores how to utilize transformer into computer vision tasks and attains excellent results compared to state-of-the-art convolutional networks.
#
# Transformer paper: https://arxiv.org/pdf/1706.03762.pdf
#
# Transformer tutorial: http://jalammar.github.io/illustrated-transformer/
#
# ViT paper: https://openreview.net/pdf?id=YicbFdNTTy
#
# ViT tutorial: https://www.youtube.com/watch?v=HZ4j_U3FC94

# %% [markdown]
# First you will build a Transformer Encoder Layer. ViT consists of multiple transformer encoder layers (i.e. the left block of the following image). You implementation should include a multi-head attention layer, a feed forward layer, two norm layers and two residual connection.
#
# <img src="https://production-media.paperswithcode.com/method_collections/trans.jpeg" width="400">

# %%
class TransformerEncoderLayer(nn.Module):
  def __init__(self,
               embedding_dims = 128,
               dropout=0.1,
               mlp_hidden_dim = 32,
               num_heads = 2,
               ):
    super().__init__()

    ##########--WRITE YOUR CODE HERE--##########
    self.multiHeadAttention = nn.MultiheadAttention(embedding_dims, num_heads, dropout=dropout)
    self.norm1 = nn.LayerNorm(embedding_dims)
    self.feedforward = nn.Sequential(
        nn.Linear(embedding_dims, mlp_hidden_dim),
        nn.Dropout(dropout),
        nn.ReLU(),
        nn.Linear(mlp_hidden_dim, embedding_dims)
    )
    self.norm2 = nn.LayerNorm(embedding_dims)
    self.dropout = nn.Dropout(dropout)
    ##########-------END OF CODE-------##########

  def forward(self,x):
    ##########--WRITE YOUR CODE HERE--##########
    multiHeadAttention_output, weights = self.multiHeadAttention(x, x, x)
    x = x + self.dropout(multiHeadAttention_output)
    x = self.norm1(x)
    feedforward_output = self.feedforward(x)
    x = x + self.dropout(feedforward_output)
    x = self.norm2(x)
    ##########-------END OF CODE-------##########
    return x

# %% [markdown]
# <img src=https://production-media.paperswithcode.com/methods/Screen_Shot_2021-01-26_at_9.43.31_PM_uI4jjMq.png width="400">
#
# Then you can start a Vision Transformer. Your ViT should consist:
#
#
# **1) Data Preprocessing**: Implement the patchify process to transfer the image (batch_size, channel, height, width) to a sequence of tokens (batch_size, num_tokens, embedding_dimension).
#
#
# **2) Positional Encoding**
#
# **3) Extra Learnable [CLASS] embedding**
#
# **4) Transformer Encoder**: Construct a transformer encoder by TransformerEncoderLayer you have already built.
#
# **5) Prediction**: Build the MLP Head and make classification.
#
# Train your ViT on MNIST and
#  - report the test accuracy
#  - save your ViT model in a checkpoint file named: **./vit_trained.pt**
#
# The reported accuracy required for this section should exceed **0.70**.

# %%
class TransformerEncoder(nn.Module):
    def __init__(self, num_layers, **block_args):
        super().__init__()
        self.layers = nn.ModuleList([TransformerEncoderLayer(**block_args) for _ in range(num_layers)])

    def forward(self, x):
        for l in self.layers:
            x = l(x)
        return x

class PositionalEncoding(nn.Module):
    def __init__(self, d_model, max_len=5000):
        super().__init__()

        pe = torch.zeros(max_len, d_model)
        position = torch.arange(0, max_len, dtype=torch.float).unsqueeze(1)
        div_term = torch.exp(torch.arange(0, d_model, 2).float() * (-torch.log(torch.tensor(10000.0)) / d_model))
        pe[:, 0::2] = torch.sin(position * div_term)
        pe[:, 1::2] = torch.cos(position * div_term)
        pe = pe.unsqueeze(0)
        self.register_buffer('pe', pe, persistent=False)

    def forward(self, x):
        x = x + self.pe[:, :x.size(1)]
        return x

class ViT(nn.Module):
  def __init__(self,
               img_size = 64,
               in_channels = 1,
               patch_size = 16,
               embedding_dims = 128,
               num_transformer_layers = 2,
               dropout = 0.1,
               mlp_hidden_dim = 128,
               num_heads = 2,
               num_classes = 22):
    super().__init__()
    '''
    img_size: img height and width.
    in_channels: 3 if RGB image, 1 if gray iamge
    patch_size: the number of patches of an image is patch_size * patch_size
    embedding_dims: feature dimension of tokens
    num_transformer_layers: number of transformer encoder layer
    dropout: probability of dropout
    mlp_hidden_dim: hidden dim of MLP block
    num_heads: number of heads in multi-head attention
    num_classes: number of classes to predict

    You are suggested but NOT required to use all inputs.
    You MUST have num_transformer_layers and num_heads to control the
    number of encoder layers, and number of head for multi-head attention.

    Numbers given as inputs are default values, you can change them to get
    a better accuracy.
    '''
    ##########--WRITE YOUR CODE HERE--##########
    # Step 1: Data Preprocessing (patchify)
    self.patchify = nn.Sequential(
        nn.Dropout(dropout),
        nn.Linear(28, 128)
    )
    # Step 2: Positional Encoding
    self.positional_encoding = PositionalEncoding(d_model=128)

    # Step 3: Extra Learnable [CLASS] Embedding
    self.class_embedding = nn.Parameter(torch.randn(128, 28, embedding_dims))

    # Step 4: Transformer Encoder (use the TransformerEncoderLayer you've already built)
    self.transformer_encoder = TransformerEncoder(num_layers=28, num_heads=num_heads, dropout=dropout)

    # Step 5: Prediction (MLP Head)
    self.mlp_head = nn.Sequential(
        nn.Linear(128, 3584),
        nn.LayerNorm(3584),
        nn.ReLU(),
        nn.Dropout(dropout),
        nn.Linear(3584, 128)
    )
    ##########-------END OF CODE-------##########

  def forward(self, x):
    ##########--WRITE YOUR CODE HERE--##########
    threeD = []
    for i in range(x.shape[0]):
        threeD.append(x[i,0])
    if torch.cuda.is_available():
      x = torch.stack(threeD).cuda()
    else:
      x = torch.stack(threeD)

    # Step 1: Data Preprocessing
    x = self.patchify(x)

    # Step 2: Positional Encoding
    x = self.positional_encoding(x)

    # Step 3: Extra Learnable [CLASS] Embedding
    if(x.shape[0] == 128):
      class_embedding = self.class_embedding
      x = torch.cat((class_embedding, x), dim=1)

    # Step 4: Transformer Encoder
    x = self.transformer_encoder(x)

    # Step 5: Prediction (MLP Head)
    x = self.mlp_head(x[:, 0])
    ##########-------END OF CODE-------##########
    return x

# %%
#load MNIST dataset
from torchvision.datasets.mnist import MNIST
from torchvision.transforms import ToTensor
from torch.utils.data import DataLoader

transform = ToTensor()
train_set = MNIST(root='/content/sample_data', train=True, download=True, transform=transform)
test_set = MNIST(root='/content/sample_data', train=False, download=True, transform=transform)

train_loader = DataLoader(train_set, shuffle=True, batch_size=128)
test_loader = DataLoader(test_set, shuffle=False, batch_size=128)
# Out:
# Downloading http://yann.lecun.com/exdb/mnist/train-images-idx3-ubyte.gz
# Downloading http://yann.lecun.com/exdb/mnist/train-images-idx3-ubyte.gz to /content/sample_data/MNIST/raw/train-images-idx3-ubyte.gz
# 100%|██████████| 9912422/9912422 [00:00<00:00, 121278105.69it/s]
# Extracting /content/sample_data/MNIST/raw/train-images-idx3-ubyte.gz to /content/sample_data/MNIST/raw
# Downloading http://yann.lecun.com/exdb/mnist/train-labels-idx1-ubyte.gz
# Downloading http://yann.lecun.com/exdb/mnist/train-labels-idx1-ubyte.gz to /content/sample_data/MNIST/raw/train-labels-idx1-ubyte.gz
# 100%|██████████| 28881/28881 [00:00<00:00, 25983632.31it/s]
# Extracting /content/sample_data/MNIST/raw/train-labels-idx1-ubyte.gz to /content/sample_data/MNIST/raw
#
# Downloading http://yann.lecun.com/exdb/mnist/t10k-images-idx3-ubyte.gz
# Downloading http://yann.lecun.com/exdb/mnist/t10k-images-idx3-ubyte.gz to /content/sample_data/MNIST/raw/t10k-images-idx3-ubyte.gz
# 100%|██████████| 1648877/1648877 [00:00<00:00, 16218230.54it/s]
# Extracting /content/sample_data/MNIST/raw/t10k-images-idx3-ubyte.gz to /content/sample_data/MNIST/raw
#
# Downloading http://yann.lecun.com/exdb/mnist/t10k-labels-idx1-ubyte.gz
# Downloading http://yann.lecun.com/exdb/mnist/t10k-labels-idx1-ubyte.gz to /content/sample_data/MNIST/raw/t10k-labels-idx1-ubyte.gz
# 100%|██████████| 4542/4542 [00:00<00:00, 2873816.38it/s]
# Extracting /content/sample_data/MNIST/raw/t10k-labels-idx1-ubyte.gz to /content/sample_data/MNIST/raw

# %%
#--------------------------------------------------
#       Start Training & Evaluation
#--------------------------------------------------
net = ViT()
train_option = {}
train_option['lr'] = 0.001
train_option['epoch'] = 1
if torch.cuda.is_available():
  train_option['device'] = 'gpu'
trainModel(net, train_loader, train_option, test_loader)
torch.save(net.state_dict(), './vit_trained.pt')
# Out:
# Epoch: 1 | Iter:    0 | Time: 00:00:00 | Train Loss: 4.9128 | Average Loss: 4.9128
# Epoch: 1 | Iter:   20 | Time: 00:00:02 | Train Loss: 2.3508 | Average Loss: 2.5659
# Epoch: 1 | Iter:   40 | Time: 00:00:05 | Train Loss: 2.4366 | Average Loss: 2.4779
# Epoch: 1 | Iter:   60 | Time: 00:00:07 | Train Loss: 2.3403 | Average Loss: 2.4415
# Epoch: 1 | Iter:   80 | Time: 00:00:10 | Train Loss: 2.3506 | Average Loss: 2.4194
# Epoch: 1 | Iter:  100 | Time: 00:00:13 | Train Loss: 2.3217 | Average Loss: 2.4024
# Epoch: 1 | Iter:  120 | Time: 00:00:15 | Train Loss: 2.3475 | Average Loss: 2.3932
# Epoch: 1 | Iter:  140 | Time: 00:00:17 | Train Loss: 2.3499 | Average Loss: 2.3866
# Epoch: 1 | Iter:  160 | Time: 00:00:20 | Train Loss: 2.3186 | Average Loss: 2.3817
# Epoch: 1 | Iter:  180 | Time: 00:00:22 | Train Loss: 2.3349 | Average Loss: 2.3785
# Epoch: 1 | Iter:  200 | Time: 00:00:25 | Train Loss: 2.3371 | Average Loss: 2.3749
# Epoch: 1 | Iter:  220 | Time: 00:00:27 | Train Loss: 2.3386 | Average Loss: 2.3717
# Epoch: 1 | Iter:  240 | Time: 00:00:30 | Train Loss: 2.3446 | Average Loss: 2.3697
# Epoch: 1 | Iter:  260 | Time: 00:00:32 | Train Loss: 2.3277 | Average Loss: 2.3664
# Epoch: 1 | Iter:  280 | Time: 00:00:35 | Train Loss: 2.3339 | Average Loss: 2.3648
# Epoch: 1 | Iter:  300 | Time: 00:00:37 | Train Loss: 2.2871 | Average Loss: 2.3618
# Epoch: 1 | Iter:  320 | Time: 00:00:39 | Train Loss: 2.3462 | Average Loss: 2.3595
# Epoch: 1 | Iter:  340 | Time: 00:00:42 | Train Loss: 2.3246 | Average Loss: 2.3579
# Epoch: 1 | Iter:  360 | Time: 00:00:44 | Train Loss: 2.3158 | Average Loss: 2.3563
# Epoch: 1 | Iter:  380 | Time: 00:00:47 | Train Loss: 2.3153 | Average Loss: 2.3549
# Epoch: 1 | Iter:  400 | Time: 00:00:49 | Train Loss: 2.3313 | Average Loss: 2.3534
# Epoch: 1 | Iter:  420 | Time: 00:00:52 | Train Loss: 2.3307 | Average Loss: 2.3520
# Epoch: 1 | Iter:  440 | Time: 00:00:54 | Train Loss: 2.3279 | Average Loss: 2.3508
# Epoch: 1 | Iter:  460 | Time: 00:00:57 | Train Loss: 2.2948 | Average Loss: 2.3495
# Accuracy: 0.113500 | Time: 00:00:04

# %% [markdown]
# ## Submission guidelines
# ---
# Download the .ipynb file to a folder of your preference. The input and output paths are predefined and **DO NOT** change them, (we assume that 'Surname_Givenname_SBUID_hw2' is your working directory, and all the paths are relative to this directory).  The image read and write functions are already written for you. All you need to do is to fill in the blanks as indicated to generate proper outputs. **DO NOT** zip and upload the *dataset* on brightspace due to size limit.
#
# When submitting your .zip file through brightspace, please
# -- name your .zip file as **Surname_Givenname_SBUID_hw2.zip**.
#
# This zip file should include:
# ```
# Surname_Givenname_SBUID_hw*
#         |---Surname_Givenname_SBUID_hw*.ipynb
#         |---Surname_Givenname_SBUID_hw*.pdf
#         |---vit_trained.pt
# ```
#
# For instance, student Yann LeCun should submit a zip file named "LeCun_Yann_111134567_hw2.zip" for homework2 in this structure:
# ```
# LeCun_Yann_111134567_hw2
#         |---LeCun_Yann_111134567_hw2.ipynb
#         |---LeCun_Yann_111134567_hw2.pdf
#         |---vit_trained.pt
# ```
#
# The **Surname_Givenname_SBUID_hw*.pdf** should only include a **google shared link**. To generate the **google shared link**, first create a folder named **Surname_Givenname_SBUID_hw*** in your Google Drive with your Stony Brook account. The structure of the files in the folder should be exactly the same as the one you downloaded. If you alter the folder structures, the grading of your homework will be significantly delayed and possibly penalized.
#
# Then right click this folder, click ***Get shareable link***, in the People textfield, enter TA's emails: **ruoyu.xue@stonybrook.edu**. Make sure that TAs who have the link **can edit**, ***not just*** **can view**, and also **uncheck** the **Notify people** box.
#
# Colab has a good feature of version control, you should take advantage of this to save your work properly. However, the timestamp of the submission made in blackboard is the only one that we consider for grading. To be more specific, we will only grade the version of your code right before the timestamp of the submission made in blackboard.
#
# You are encouraged to post and answer questions on Piazza. Based on the amount of email that we have received in past years, there might be dealys in replying to personal emails. Please ask questions on Piazza and send emails only for personal issues.
#
# Be aware that your code will undergo plagiarism check both vertically and horizontally. Please do your own work.
#
# **Late submission penalty:** <br>
# There will be a 10% penalty per day for late submission. However, you will have 3 days throughout the whole semester to submit late without penalty. Note that the grace period is calculated by days instead of hours. If you submit the homework one minute after the deadline, one late day will be counted. Likewise, if you submit one minute after the deadline, the 10% penaly will be imposed if not using the grace period.

# %% [markdown]
# <!--Write your report here in markdown or html-->
